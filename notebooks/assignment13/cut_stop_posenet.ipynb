# %% [markdown]
# # Model to Classify Stop positions in PoseNet dataset
#
# Section for configurations and imports.

# %%
import os 
import tempfile

import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow import keras

# MLflow dashboard
import mlflow
mlflow.set_tracking_uri('http://35.228.45.76:5000')
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='../../keys/mlflow-312506-8cfad529f4fd.json'

# Import data augmentation
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from augmentation.methods import *

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
random_state = 47
np.random.seed(random_state)

# %%
physical_devices = tf.config.experimental.list_physical_devices( 'GPU' )
print( 'Num GPUs Available: ', len( physical_devices ) )
if len( physical_devices ) > 0:
    tf.config.experimental.set_memory_growth( physical_devices[0], True )
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # 1. Data Preparation
# ## 1.1 Load Kinect files
#
# These files are marked start and stop frames in one-hot encoding. <br />
# We're only interested in the 'start' column.

# %%
data_path = '../../datasets/new_posenet_marked_start_end/'

df = None

# %%
for file in os.listdir(data_path):
    if file.endswith('.csv') and 'kinect' not in file:
        try:
            dataset = pd.read_csv(data_path + file)
            dataset.drop(columns=['start'], inplace=True)
            dataset = dataset[dataset.columns.drop(list(dataset.filter(regex='_score')))]
            dataset = dataset[dataset.columns.drop(list(dataset.filter(regex='_eye_')))]
            dataset = dataset[dataset.columns.drop(list(dataset.filter(regex='_ear_')))]
            dataset.rename({'nose_x': 'head_x', 'nose_y': 'head_y'})

            if df is None:
                df = dataset
            else:
                df = pd.concat((df, dataset), ignore_index=True)

        except IOError as e:
            print('Error in reading file: ', e)

print(df.shape)
# Out:
# (141945, 27)

# %% [markdown]
# ## 1.2 Data Augmentation
#
# ### Mirror X coordinate

# %%
df = mirror(df,'x', append=True)
print(df.shape)
# Out:
# (283890, 27)

# %% [markdown]
# ## 1.3 Check Class Imbalance
#
# This shows the small fraction of start frames.

# %%
X = df.drop(columns=['end'])
y = df['end']

# %%
print(
    'Total: {}\n\nNone: {} ({:.2f}% of total)\nEnd: {} ({:.2f}% of total)\n'
    .format(
      len(y), 
      len(y.values[y.values == 0]),
      len(y.values[y.values == 0]) / len(y),
      len(y.values[y.values == 1]),
      len(y.values[y.values == 1]) / len(y)
    )
  )
# Out:
# Total: 283890
#
# None: 237442 (0.84% of total)
# End: 46448 (0.16% of total)

# %% [markdown]
# ## 1.4 Oversample the minority class

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=random_state) # Perform oversamling using SMOTE
resampled_X, resampled_y = sm.fit_resample(X, y)

print(resampled_X.shape)
print(resampled_y.shape)
# Out:
# (474884, 26)
# (474884,)

# %%
print(
    'Total: {}\n\nNone: {} ({:.2f}% of total)\nEnd: {} ({:.2f}% of total)\n'
    .format(
      len(resampled_y), 
      len(resampled_y.values[resampled_y.values == 0]),
      len(resampled_y.values[resampled_y.values == 0]) / len(resampled_y),
      len(resampled_y.values[resampled_y.values == 1]),
      len(resampled_y.values[resampled_y.values == 1]) / len(resampled_y)
    )
  )
# Out:
# Total: 474884
#
# None: 237442 (0.50% of total)
# End: 237442 (0.50% of total)

# %% [markdown]
# ## 1.5 Split and normalize the data
#
# We already dropped the 'FrameNo' and 'start' columns when the data was loading. <br />
# Now, we'll split the dataset into train, validation, and test sets:
#
# - The validation set is used during model fitting to evaluate the loss and other evaluation metrics.
# - The test set is unused during the training phase and is used at the end to evaluate how well the model generalizes to new data (i.e. a holdout set). This is especially important with imbalanced datasets where overfitting is a significant concern from the lack of training data.
#
# We also normalize the input features using the sklearn StandardScaler. StandardScaler is only fit using X_train. As we want to deploy a model, it's critical that you preserve the preprocessing calculations. The easiest way to implement them as layers, and attach them to your model before export.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(resampled_X, resampled_y, test_size=0.2, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

print('Training labels shape:', y_train.shape)
print('Validation labels shape:', y_val.shape)
print('Test labels shape:', y_test.shape, '\n')

print('Training features shape:', X_train.shape)
print('Validation features shape:', X_val.shape)
print('Test features shape:', X_test.shape)
# Out:
# Training labels shape: (303925,)
# Validation labels shape: (75982,)
# Test labels shape: (94977,)
#
# Training features shape: (303925, 26)
# Validation features shape: (75982, 26)
# Test features shape: (94977, 26)

# %% [markdown]
# # 2. Define the Model and Metrics
#
# ## 2.1 Layer Factory

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %% [markdown]
# ## 2.2 Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer

def make_model(metrics, layers, optimizer, input_dim, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %% [markdown]
# # 3. Build the Model
#
# 3.1 Estimate the initial bias
# We're going to keep the initial model's weights in a checkpoint file and load them into each model before training so the model doesn't need to spend the first few epochs just learning that start frames are unlikely. Therefore, we start by estimating the initial bias before defining the model.

# %%
neg, pos = np.bincount(y)

initial_bias = np.log([pos/neg])
initial_bias
# Out:
# array([-1.63158998])

# %% [markdown]
# ## 3.2 Define the Model and Evaluation Metrics
#
# We're using standard evaluation metrics for binary classification problems.
#
# The **make_model** function returns a model based on parameter values. It uses the Layer Factory for creating the model.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(layers, input_dim, loss, optimizer, learning_rate=0.001, metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %%
output_bias = tf.keras.initializers.Constant(initial_bias)
input_dim = X_train.shape[1]
output_size = 1

units = 32
activation = 'tanh'
kernel_initializer = 'he_uniform'
output_activation = 'sigmoid'
optimizer = 'Adam'
learning_rate = 1e-4

LAYERS = [ 
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':64, 'activation': 'relu', 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':64, 'activation': 'relu', 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':output_size, 'activation': output_activation, 'bias_initializer': initial_bias }
]

model = make_model(layers=LAYERS, input_dim=input_dim, loss='binary_crossentropy', optimizer=optimizer, learning_rate=learning_rate, output_bias=output_bias)

model.predict(X_train[:10])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                864
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,305
# Trainable params: 10,305
# Non-trainable params: 0
# _________________________________________________________________
# None
# array([[0.44398734],
#        [0.48111823],
#        [0.5453278 ],
#        [0.51143444],
#        [0.529503  ],
#        [0.5142208 ],
#        [0.5229022 ],
#        [0.48539072],
#        [0.39866734],
#        [0.47962365]], dtype=float32)

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.7099

# %%
initial_weights = os.path.join(tempfile.mkdtemp(), 'initial_weights')
model.save_weights(initial_weights)

# %% [markdown]
# ## 3.3 Add Class Weights

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

print('Weight for class 0:', class_weights[0])
print('Weight for class 1:', class_weights[1])
# Out:
# Weight for class 0: 0.9988070512146388
# Weight for class 1: 1.001195801846081

# %% [markdown]
# # 4. MLflow Experimentation
# ## 4.1 Define learning parameters for all models

# %%
from keras.callbacks import EarlyStopping

EPOCHS = 500
BATCH_SIZE = 5000

early_stopping = EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ## 4.2 Define Experimentation Configurations
# The Model signature in MLflow defines the schema of a model's inputs and outputs.

# %%
from mlflow.models.signature import ModelSignature
from mlflow.types.schema import Schema, ColSpec

input_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
])
output_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# %% [markdown]
# ## 4.3 Functions used in the experimentation
#
# For creating plots and others.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

def plot_loss(history, label, n):
  plt.semilogy(history.epoch, history.history['loss'],
               color=colors[n], label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               color=colors[n], label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('True Negatives: ', cm[0][0])
    print('False Positives: ', cm[0][1])
    print('False Negatives: ', cm[1][0])
    print('True Positives: ', cm[1][1])
    print('Total: ', np.sum(cm[1]))


def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# ## 4.4 Start run
# Starting a run which fits the model according to chosen parameter values, then makes predictions and saves selected values to MLflow dashboard.

# %%
model_name = 'cut_stop_posenet'

with mlflow.start_run(run_name=model_name) as run:

    run_id = run.info.run_id

    model = make_model(metrics=METRICS, 
                        layers=LAYERS, 
                        loss='binary_crossentropy', 
                        optimizer=optimizer, 
                        learning_rate=learning_rate, 
                        output_bias=initial_bias, 
                        input_dim=input_dim)
    model.load_weights(initial_weights)
    model.layers[-1].bias.assign([0.0])
    
    with tf.device('/CPU:0'):
        history = model.fit(
            x=X_train, 
            y=y_train, 
            class_weight=class_weight_dict, 
            validation_data=(X_val, y_val), 
            shuffle=True, 
            epochs=EPOCHS, 
            verbose=1,
            batch_size=BATCH_SIZE, 
            callbacks=[early_stopping])

        # Plot training history
        plot_loss(history, "Bias", 0)
        plt.savefig("loss.jpg")
        mlflow.log_artifact("loss.jpg")
        plt.show()
        
        # Plot and log metrics
        predictions_train = model.predict(X_train)
        predictions_test = model.predict(X_test)

        plot_metrics(history)
        plt.savefig("metrics.jpg")
        mlflow.log_artifact("metrics.jpg")
        plt.show()

        # Confusion matrix
        results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
        for name, value in zip(model.metrics_names, results):
            print(name, ': ', value, '/n')
        plot_cm(y_test, predictions_test)
        plt.savefig("cm.jpg")
        mlflow.log_artifact("cm.jpg")
        plt.show()

        # ROC Curve
        plot_roc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("roc.jpg")
        mlflow.log_artifact("roc.jpg")
        plt.show()

        # Precision-Recall Curve (PRC)
        plot_prc("Train Predictions", y_train, predictions_train, color=colors[0])
        plot_prc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("prc.jpg")
        mlflow.log_artifact("prc.jpg")
        plt.show()
        
        # Log model, scaler, model parameters to MLflow
        mlflow.log_param("units", units)
        mlflow.log_param("activation", activation)
        mlflow.log_param("kernel_initializer", kernel_initializer)
        mlflow.log_param("output activation", output_activation)
        mlflow.log_param("optimizer", optimizer)
        mlflow.log_param("learning rate", learning_rate)
        mlflow.log_param("batch size", BATCH_SIZE)
        mlflow.log_metric("accuracy", results[5])
        mlflow.log_metric("average precision score", results[6])
        mlflow.log_metric("recall", results[7])
        mlflow.log_metric("auc", results[8])

        mlflow.keras.log_model(model, model_name, signature=signature)
        mlflow.sklearn.log_model(scaler, 'InputScaler')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 32)                864
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 10,305
# Trainable params: 10,305
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\angel\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/500
# 61/61 [==============================] - 3s 27ms/step - loss: 0.6609 - tp: 113578.0000 - fp: 95656.0000 - tn: 208632.0000 - fn: 189984.0000 - accuracy: 0.5301 - precision: 0.5428 - recall: 0.3742 - auc: 0.5652 - prc: 0.5624 - val_loss: 0.6094 - val_tp: 26622.0000 - val_fp: 7320.0000 - val_tn: 30684.0000 - val_fn: 11356.0000 - val_accuracy: 0.7542 - val_precision: 0.7843 - val_recall: 0.7010 - val_auc: 0.8397 - val_prc: 0.8348
# Epoch 2/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5524 - tp: 107365.0000 - fp: 29628.0000 - tn: 122516.0000 - fn: 44416.0000 - accuracy: 0.7564 - precision: 0.7837 - recall: 0.7074 - auc: 0.8461 - prc: 0.8385 - val_loss: 0.4961 - val_tp: 26488.0000 - val_fp: 6681.0000 - val_tn: 31323.0000 - val_fn: 11490.0000 - val_accuracy: 0.7609 - val_precision: 0.7986 - val_recall: 0.6975 - val_auc: 0.8612 - val_prc: 0.8550
# Epoch 3/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4695 - tp: 107487.0000 - fp: 26897.0000 - tn: 125247.0000 - fn: 44294.0000 - accuracy: 0.7658 - precision: 0.7998 - recall: 0.7082 - auc: 0.8621 - prc: 0.8544 - val_loss: 0.4506 - val_tp: 27421.0000 - val_fp: 6876.0000 - val_tn: 31128.0000 - val_fn: 10557.0000 - val_accuracy: 0.7706 - val_precision: 0.7995 - val_recall: 0.7220 - val_auc: 0.8670 - val_prc: 0.8606
# Epoch 4/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4449 - tp: 109139.0000 - fp: 27553.0000 - tn: 124591.0000 - fn: 42642.0000 - accuracy: 0.7690 - precision: 0.7984 - recall: 0.7191 - auc: 0.8684 - prc: 0.8619 - val_loss: 0.4374 - val_tp: 27465.0000 - val_fp: 6892.0000 - val_tn: 31112.0000 - val_fn: 10513.0000 - val_accuracy: 0.7709 - val_precision: 0.7994 - val_recall: 0.7232 - val_auc: 0.8718 - val_prc: 0.8652
# Epoch 5/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4350 - tp: 110226.0000 - fp: 28450.0000 - tn: 123694.0000 - fn: 41555.0000 - accuracy: 0.7697 - precision: 0.7948 - recall: 0.7262 - auc: 0.8726 - prc: 0.8664 - val_loss: 0.4297 - val_tp: 27742.0000 - val_fp: 7083.0000 - val_tn: 30921.0000 - val_fn: 10236.0000 - val_accuracy: 0.7721 - val_precision: 0.7966 - val_recall: 0.7305 - val_auc: 0.8751 - val_prc: 0.8694
# Epoch 6/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4281 - tp: 111461.0000 - fp: 29150.0000 - tn: 122994.0000 - fn: 40320.0000 - accuracy: 0.7714 - precision: 0.7927 - recall: 0.7344 - auc: 0.8759 - prc: 0.8702 - val_loss: 0.4235 - val_tp: 28282.0000 - val_fp: 7507.0000 - val_tn: 30497.0000 - val_fn: 9696.0000 - val_accuracy: 0.7736 - val_precision: 0.7902 - val_recall: 0.7447 - val_auc: 0.8784 - val_prc: 0.8729
# Epoch 7/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4223 - tp: 112959.0000 - fp: 29662.0000 - tn: 122482.0000 - fn: 38822.0000 - accuracy: 0.7747 - precision: 0.7920 - recall: 0.7442 - auc: 0.8789 - prc: 0.8730 - val_loss: 0.4182 - val_tp: 27962.0000 - val_fp: 6971.0000 - val_tn: 31033.0000 - val_fn: 10016.0000 - val_accuracy: 0.7764 - val_precision: 0.8004 - val_recall: 0.7363 - val_auc: 0.8811 - val_prc: 0.8753
# Epoch 8/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4168 - tp: 113927.0000 - fp: 29951.0000 - tn: 122193.0000 - fn: 37854.0000 - accuracy: 0.7769 - precision: 0.7918 - recall: 0.7506 - auc: 0.8820 - prc: 0.8768 - val_loss: 0.4131 - val_tp: 29010.0000 - val_fp: 7631.0000 - val_tn: 30373.0000 - val_fn: 8968.0000 - val_accuracy: 0.7815 - val_precision: 0.7917 - val_recall: 0.7639 - val_auc: 0.8840 - val_prc: 0.8792
# Epoch 9/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4117 - tp: 116111.0000 - fp: 30966.0000 - tn: 121178.0000 - fn: 35670.0000 - accuracy: 0.7807 - precision: 0.7895 - recall: 0.7650 - auc: 0.8849 - prc: 0.8804 - val_loss: 0.4080 - val_tp: 29561.0000 - val_fp: 8107.0000 - val_tn: 29897.0000 - val_fn: 8417.0000 - val_accuracy: 0.7825 - val_precision: 0.7848 - val_recall: 0.7784 - val_auc: 0.8872 - val_prc: 0.8828
# Epoch 10/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4067 - tp: 117299.0000 - fp: 30990.0000 - tn: 121154.0000 - fn: 34482.0000 - accuracy: 0.7846 - precision: 0.7910 - recall: 0.7728 - auc: 0.8880 - prc: 0.8837 - val_loss: 0.4031 - val_tp: 29585.0000 - val_fp: 7818.0000 - val_tn: 30186.0000 - val_fn: 8393.0000 - val_accuracy: 0.7866 - val_precision: 0.7910 - val_recall: 0.7790 - val_auc: 0.8903 - val_prc: 0.8861
# Epoch 11/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4019 - tp: 119137.0000 - fp: 31210.0000 - tn: 120934.0000 - fn: 32644.0000 - accuracy: 0.7899 - precision: 0.7924 - recall: 0.7849 - auc: 0.8911 - prc: 0.8872 - val_loss: 0.3987 - val_tp: 30398.0000 - val_fp: 8160.0000 - val_tn: 29844.0000 - val_fn: 7580.0000 - val_accuracy: 0.7928 - val_precision: 0.7884 - val_recall: 0.8004 - val_auc: 0.8930 - val_prc: 0.8891
# Epoch 12/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3971 - tp: 120098.0000 - fp: 30864.0000 - tn: 121280.0000 - fn: 31683.0000 - accuracy: 0.7942 - precision: 0.7956 - recall: 0.7913 - auc: 0.8941 - prc: 0.8905 - val_loss: 0.3940 - val_tp: 30561.0000 - val_fp: 8116.0000 - val_tn: 29888.0000 - val_fn: 7417.0000 - val_accuracy: 0.7956 - val_precision: 0.7902 - val_recall: 0.8047 - val_auc: 0.8957 - val_prc: 0.8925
# Epoch 13/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3925 - tp: 120835.0000 - fp: 29972.0000 - tn: 122172.0000 - fn: 30946.0000 - accuracy: 0.7996 - precision: 0.8013 - recall: 0.7961 - auc: 0.8970 - prc: 0.8937 - val_loss: 0.3897 - val_tp: 30910.0000 - val_fp: 7991.0000 - val_tn: 30013.0000 - val_fn: 7068.0000 - val_accuracy: 0.8018 - val_precision: 0.7946 - val_recall: 0.8139 - val_auc: 0.8988 - val_prc: 0.8955
# Epoch 14/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3880 - tp: 121369.0000 - fp: 29439.0000 - tn: 122705.0000 - fn: 30412.0000 - accuracy: 0.8031 - precision: 0.8048 - recall: 0.7996 - auc: 0.8997 - prc: 0.8965 - val_loss: 0.3853 - val_tp: 30455.0000 - val_fp: 7294.0000 - val_tn: 30710.0000 - val_fn: 7523.0000 - val_accuracy: 0.8050 - val_precision: 0.8068 - val_recall: 0.8019 - val_auc: 0.9012 - val_prc: 0.8984
# Epoch 15/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3836 - tp: 121930.0000 - fp: 29017.0000 - tn: 123127.0000 - fn: 29851.0000 - accuracy: 0.8063 - precision: 0.8078 - recall: 0.8033 - auc: 0.9021 - prc: 0.8994 - val_loss: 0.3812 - val_tp: 30190.0000 - val_fp: 6984.0000 - val_tn: 31020.0000 - val_fn: 7788.0000 - val_accuracy: 0.8056 - val_precision: 0.8121 - val_recall: 0.7949 - val_auc: 0.9032 - val_prc: 0.9010
# Epoch 16/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3795 - tp: 122776.0000 - fp: 28969.0000 - tn: 123175.0000 - fn: 29005.0000 - accuracy: 0.8092 - precision: 0.8091 - recall: 0.8089 - auc: 0.9044 - prc: 0.9020 - val_loss: 0.3778 - val_tp: 30922.0000 - val_fp: 7468.0000 - val_tn: 30536.0000 - val_fn: 7056.0000 - val_accuracy: 0.8088 - val_precision: 0.8055 - val_recall: 0.8142 - val_auc: 0.9049 - val_prc: 0.9030
# Epoch 17/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3753 - tp: 123083.0000 - fp: 28436.0000 - tn: 123708.0000 - fn: 28698.0000 - accuracy: 0.8120 - precision: 0.8123 - recall: 0.8109 - auc: 0.9066 - prc: 0.9044 - val_loss: 0.3731 - val_tp: 31452.0000 - val_fp: 7669.0000 - val_tn: 30335.0000 - val_fn: 6526.0000 - val_accuracy: 0.8132 - val_precision: 0.8040 - val_recall: 0.8282 - val_auc: 0.9080 - val_prc: 0.9060
# Epoch 18/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3713 - tp: 123835.0000 - fp: 28114.0000 - tn: 124030.0000 - fn: 27946.0000 - accuracy: 0.8155 - precision: 0.8150 - recall: 0.8159 - auc: 0.9089 - prc: 0.9070 - val_loss: 0.3689 - val_tp: 31087.0000 - val_fp: 7100.0000 - val_tn: 30904.0000 - val_fn: 6891.0000 - val_accuracy: 0.8159 - val_precision: 0.8141 - val_recall: 0.8186 - val_auc: 0.9098 - val_prc: 0.9083
# Epoch 19/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3674 - tp: 124318.0000 - fp: 27832.0000 - tn: 124312.0000 - fn: 27463.0000 - accuracy: 0.8181 - precision: 0.8171 - recall: 0.8191 - auc: 0.9109 - prc: 0.9092 - val_loss: 0.3652 - val_tp: 31291.0000 - val_fp: 7005.0000 - val_tn: 30999.0000 - val_fn: 6687.0000 - val_accuracy: 0.8198 - val_precision: 0.8171 - val_recall: 0.8239 - val_auc: 0.9120 - val_prc: 0.9106
# Epoch 20/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3635 - tp: 124747.0000 - fp: 27525.0000 - tn: 124619.0000 - fn: 27034.0000 - accuracy: 0.8205 - precision: 0.8192 - recall: 0.8219 - auc: 0.9130 - prc: 0.9115 - val_loss: 0.3613 - val_tp: 31313.0000 - val_fp: 6929.0000 - val_tn: 31075.0000 - val_fn: 6665.0000 - val_accuracy: 0.8211 - val_precision: 0.8188 - val_recall: 0.8245 - val_auc: 0.9141 - val_prc: 0.9127
# Epoch 21/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3598 - tp: 125107.0000 - fp: 27147.0000 - tn: 124997.0000 - fn: 26674.0000 - accuracy: 0.8229 - precision: 0.8217 - recall: 0.8243 - auc: 0.9149 - prc: 0.9135 - val_loss: 0.3577 - val_tp: 31571.0000 - val_fp: 6987.0000 - val_tn: 31017.0000 - val_fn: 6407.0000 - val_accuracy: 0.8237 - val_precision: 0.8188 - val_recall: 0.8313 - val_auc: 0.9159 - val_prc: 0.9146
# Epoch 22/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3562 - tp: 125559.0000 - fp: 26886.0000 - tn: 125258.0000 - fn: 26222.0000 - accuracy: 0.8253 - precision: 0.8236 - recall: 0.8272 - auc: 0.9169 - prc: 0.9156 - val_loss: 0.3542 - val_tp: 31817.0000 - val_fp: 7263.0000 - val_tn: 30741.0000 - val_fn: 6161.0000 - val_accuracy: 0.8233 - val_precision: 0.8142 - val_recall: 0.8378 - val_auc: 0.9174 - val_prc: 0.9168
# Epoch 23/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3523 - tp: 125872.0000 - fp: 26584.0000 - tn: 125560.0000 - fn: 25909.0000 - accuracy: 0.8273 - precision: 0.8256 - recall: 0.8293 - auc: 0.9188 - prc: 0.9177 - val_loss: 0.3504 - val_tp: 31401.0000 - val_fp: 6625.0000 - val_tn: 31379.0000 - val_fn: 6577.0000 - val_accuracy: 0.8262 - val_precision: 0.8258 - val_recall: 0.8268 - val_auc: 0.9194 - val_prc: 0.9188
# Epoch 24/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3486 - tp: 126202.0000 - fp: 26165.0000 - tn: 125979.0000 - fn: 25579.0000 - accuracy: 0.8297 - precision: 0.8283 - recall: 0.8315 - auc: 0.9208 - prc: 0.9197 - val_loss: 0.3470 - val_tp: 30951.0000 - val_fp: 5986.0000 - val_tn: 32018.0000 - val_fn: 7027.0000 - val_accuracy: 0.8287 - val_precision: 0.8379 - val_recall: 0.8150 - val_auc: 0.9211 - val_prc: 0.9204
# Epoch 25/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3449 - tp: 126596.0000 - fp: 25928.0000 - tn: 126216.0000 - fn: 25185.0000 - accuracy: 0.8318 - precision: 0.8300 - recall: 0.8341 - auc: 0.9227 - prc: 0.9216 - val_loss: 0.3424 - val_tp: 31661.0000 - val_fp: 6280.0000 - val_tn: 31724.0000 - val_fn: 6317.0000 - val_accuracy: 0.8342 - val_precision: 0.8345 - val_recall: 0.8337 - val_auc: 0.9237 - val_prc: 0.9229
# Epoch 26/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3411 - tp: 127120.0000 - fp: 25627.0000 - tn: 126517.0000 - fn: 24661.0000 - accuracy: 0.8345 - precision: 0.8322 - recall: 0.8375 - auc: 0.9246 - prc: 0.9236 - val_loss: 0.3391 - val_tp: 31731.0000 - val_fp: 6239.0000 - val_tn: 31765.0000 - val_fn: 6247.0000 - val_accuracy: 0.8357 - val_precision: 0.8357 - val_recall: 0.8355 - val_auc: 0.9255 - val_prc: 0.9247
# Epoch 27/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3377 - tp: 127223.0000 - fp: 25314.0000 - tn: 126830.0000 - fn: 24558.0000 - accuracy: 0.8359 - precision: 0.8340 - recall: 0.8382 - auc: 0.9263 - prc: 0.9253 - val_loss: 0.3361 - val_tp: 31234.0000 - val_fp: 5601.0000 - val_tn: 32403.0000 - val_fn: 6744.0000 - val_accuracy: 0.8375 - val_precision: 0.8479 - val_recall: 0.8224 - val_auc: 0.9269 - val_prc: 0.9260
# Epoch 28/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3342 - tp: 127733.0000 - fp: 24997.0000 - tn: 127147.0000 - fn: 24048.0000 - accuracy: 0.8386 - precision: 0.8363 - recall: 0.8416 - auc: 0.9280 - prc: 0.9270 - val_loss: 0.3321 - val_tp: 32545.0000 - val_fp: 6708.0000 - val_tn: 31296.0000 - val_fn: 5433.0000 - val_accuracy: 0.8402 - val_precision: 0.8291 - val_recall: 0.8569 - val_auc: 0.9292 - val_prc: 0.9282
# Epoch 29/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3308 - tp: 128067.0000 - fp: 24607.0000 - tn: 127537.0000 - fn: 23714.0000 - accuracy: 0.8410 - precision: 0.8388 - recall: 0.8438 - auc: 0.9298 - prc: 0.9287 - val_loss: 0.3298 - val_tp: 31359.0000 - val_fp: 5434.0000 - val_tn: 32570.0000 - val_fn: 6619.0000 - val_accuracy: 0.8414 - val_precision: 0.8523 - val_recall: 0.8257 - val_auc: 0.9300 - val_prc: 0.9293
# Epoch 30/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3277 - tp: 128175.0000 - fp: 24031.0000 - tn: 128113.0000 - fn: 23606.0000 - accuracy: 0.8433 - precision: 0.8421 - recall: 0.8445 - auc: 0.9313 - prc: 0.9302 - val_loss: 0.3256 - val_tp: 31874.0000 - val_fp: 5492.0000 - val_tn: 32512.0000 - val_fn: 6104.0000 - val_accuracy: 0.8474 - val_precision: 0.8530 - val_recall: 0.8393 - val_auc: 0.9326 - val_prc: 0.9312
# Epoch 31/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3242 - tp: 128419.0000 - fp: 23417.0000 - tn: 128727.0000 - fn: 23362.0000 - accuracy: 0.8461 - precision: 0.8458 - recall: 0.8461 - auc: 0.9329 - prc: 0.9317 - val_loss: 0.3225 - val_tp: 32822.0000 - val_fp: 6448.0000 - val_tn: 31556.0000 - val_fn: 5156.0000 - val_accuracy: 0.8473 - val_precision: 0.8358 - val_recall: 0.8642 - val_auc: 0.9338 - val_prc: 0.9326
# Epoch 32/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3214 - tp: 128916.0000 - fp: 23345.0000 - tn: 128799.0000 - fn: 22865.0000 - accuracy: 0.8480 - precision: 0.8467 - recall: 0.8494 - auc: 0.9342 - prc: 0.9329 - val_loss: 0.3196 - val_tp: 31761.0000 - val_fp: 5244.0000 - val_tn: 32760.0000 - val_fn: 6217.0000 - val_accuracy: 0.8492 - val_precision: 0.8583 - val_recall: 0.8363 - val_auc: 0.9349 - val_prc: 0.9337
# Epoch 33/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3182 - tp: 129039.0000 - fp: 22787.0000 - tn: 129357.0000 - fn: 22742.0000 - accuracy: 0.8502 - precision: 0.8499 - recall: 0.8502 - auc: 0.9357 - prc: 0.9344 - val_loss: 0.3165 - val_tp: 32582.0000 - val_fp: 5877.0000 - val_tn: 32127.0000 - val_fn: 5396.0000 - val_accuracy: 0.8516 - val_precision: 0.8472 - val_recall: 0.8579 - val_auc: 0.9362 - val_prc: 0.9351
# Epoch 34/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3158 - tp: 129308.0000 - fp: 22574.0000 - tn: 129570.0000 - fn: 22473.0000 - accuracy: 0.8518 - precision: 0.8514 - recall: 0.8519 - auc: 0.9367 - prc: 0.9353 - val_loss: 0.3140 - val_tp: 32790.0000 - val_fp: 5930.0000 - val_tn: 32074.0000 - val_fn: 5188.0000 - val_accuracy: 0.8537 - val_precision: 0.8468 - val_recall: 0.8634 - val_auc: 0.9376 - val_prc: 0.9360
# Epoch 35/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3130 - tp: 129368.0000 - fp: 22125.0000 - tn: 130019.0000 - fn: 22413.0000 - accuracy: 0.8535 - precision: 0.8540 - recall: 0.8523 - auc: 0.9380 - prc: 0.9365 - val_loss: 0.3114 - val_tp: 32698.0000 - val_fp: 5661.0000 - val_tn: 32343.0000 - val_fn: 5280.0000 - val_accuracy: 0.8560 - val_precision: 0.8524 - val_recall: 0.8610 - val_auc: 0.9387 - val_prc: 0.9371
# Epoch 36/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3107 - tp: 129794.0000 - fp: 22056.0000 - tn: 130088.0000 - fn: 21987.0000 - accuracy: 0.8551 - precision: 0.8548 - recall: 0.8551 - auc: 0.9389 - prc: 0.9374 - val_loss: 0.3085 - val_tp: 32784.0000 - val_fp: 5613.0000 - val_tn: 32391.0000 - val_fn: 5194.0000 - val_accuracy: 0.8578 - val_precision: 0.8538 - val_recall: 0.8632 - val_auc: 0.9400 - val_prc: 0.9383
# Epoch 37/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3081 - tp: 129863.0000 - fp: 21682.0000 - tn: 130462.0000 - fn: 21918.0000 - accuracy: 0.8565 - precision: 0.8569 - recall: 0.8556 - auc: 0.9401 - prc: 0.9385 - val_loss: 0.3062 - val_tp: 32445.0000 - val_fp: 5347.0000 - val_tn: 32657.0000 - val_fn: 5533.0000 - val_accuracy: 0.8568 - val_precision: 0.8585 - val_recall: 0.8543 - val_auc: 0.9409 - val_prc: 0.9394
# Epoch 38/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3063 - tp: 130044.0000 - fp: 21679.0000 - tn: 130465.0000 - fn: 21737.0000 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8568 - auc: 0.9407 - prc: 0.9392 - val_loss: 0.3046 - val_tp: 32745.0000 - val_fp: 5659.0000 - val_tn: 32345.0000 - val_fn: 5233.0000 - val_accuracy: 0.8567 - val_precision: 0.8526 - val_recall: 0.8622 - val_auc: 0.9414 - val_prc: 0.9399
# Epoch 39/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3041 - tp: 130226.0000 - fp: 21288.0000 - tn: 130856.0000 - fn: 21555.0000 - accuracy: 0.8590 - precision: 0.8595 - recall: 0.8580 - auc: 0.9417 - prc: 0.9401 - val_loss: 0.3029 - val_tp: 32569.0000 - val_fp: 5361.0000 - val_tn: 32643.0000 - val_fn: 5409.0000 - val_accuracy: 0.8583 - val_precision: 0.8587 - val_recall: 0.8576 - val_auc: 0.9421 - val_prc: 0.9405
# Epoch 40/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3020 - tp: 130574.0000 - fp: 21345.0000 - tn: 130799.0000 - fn: 21207.0000 - accuracy: 0.8600 - precision: 0.8595 - recall: 0.8603 - auc: 0.9426 - prc: 0.9409 - val_loss: 0.2999 - val_tp: 32727.0000 - val_fp: 5233.0000 - val_tn: 32771.0000 - val_fn: 5251.0000 - val_accuracy: 0.8620 - val_precision: 0.8621 - val_recall: 0.8617 - val_auc: 0.9435 - val_prc: 0.9417
# Epoch 41/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3003 - tp: 130739.0000 - fp: 21188.0000 - tn: 130956.0000 - fn: 21042.0000 - accuracy: 0.8611 - precision: 0.8605 - recall: 0.8614 - auc: 0.9433 - prc: 0.9416 - val_loss: 0.2987 - val_tp: 33034.0000 - val_fp: 5677.0000 - val_tn: 32327.0000 - val_fn: 4944.0000 - val_accuracy: 0.8602 - val_precision: 0.8533 - val_recall: 0.8698 - val_auc: 0.9440 - val_prc: 0.9424
# Epoch 42/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2983 - tp: 130928.0000 - fp: 21062.0000 - tn: 131082.0000 - fn: 20853.0000 - accuracy: 0.8621 - precision: 0.8614 - recall: 0.8626 - auc: 0.9441 - prc: 0.9424 - val_loss: 0.2965 - val_tp: 32915.0000 - val_fp: 5477.0000 - val_tn: 32527.0000 - val_fn: 5063.0000 - val_accuracy: 0.8613 - val_precision: 0.8573 - val_recall: 0.8667 - val_auc: 0.9448 - val_prc: 0.9431
# Epoch 43/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2965 - tp: 131134.0000 - fp: 20873.0000 - tn: 131271.0000 - fn: 20647.0000 - accuracy: 0.8634 - precision: 0.8627 - recall: 0.8640 - auc: 0.9448 - prc: 0.9431 - val_loss: 0.2948 - val_tp: 32669.0000 - val_fp: 5069.0000 - val_tn: 32935.0000 - val_fn: 5309.0000 - val_accuracy: 0.8634 - val_precision: 0.8657 - val_recall: 0.8602 - val_auc: 0.9455 - val_prc: 0.9436
# Epoch 44/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2948 - tp: 131123.0000 - fp: 20623.0000 - tn: 131521.0000 - fn: 20658.0000 - accuracy: 0.8642 - precision: 0.8641 - recall: 0.8639 - auc: 0.9455 - prc: 0.9437 - val_loss: 0.2938 - val_tp: 33540.0000 - val_fp: 5967.0000 - val_tn: 32037.0000 - val_fn: 4438.0000 - val_accuracy: 0.8631 - val_precision: 0.8490 - val_recall: 0.8831 - val_auc: 0.9463 - val_prc: 0.9444
# Epoch 45/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2932 - tp: 131547.0000 - fp: 20810.0000 - tn: 131334.0000 - fn: 20234.0000 - accuracy: 0.8650 - precision: 0.8634 - recall: 0.8667 - auc: 0.9461 - prc: 0.9443 - val_loss: 0.2924 - val_tp: 32519.0000 - val_fp: 4817.0000 - val_tn: 33187.0000 - val_fn: 5459.0000 - val_accuracy: 0.8648 - val_precision: 0.8710 - val_recall: 0.8563 - val_auc: 0.9463 - val_prc: 0.9446
# Epoch 46/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2912 - tp: 131481.0000 - fp: 20473.0000 - tn: 131671.0000 - fn: 20300.0000 - accuracy: 0.8658 - precision: 0.8653 - recall: 0.8663 - auc: 0.9469 - prc: 0.9451 - val_loss: 0.2907 - val_tp: 32256.0000 - val_fp: 4459.0000 - val_tn: 33545.0000 - val_fn: 5722.0000 - val_accuracy: 0.8660 - val_precision: 0.8786 - val_recall: 0.8493 - val_auc: 0.9472 - val_prc: 0.9455
# Epoch 47/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2901 - tp: 131642.0000 - fp: 20424.0000 - tn: 131720.0000 - fn: 20139.0000 - accuracy: 0.8665 - precision: 0.8657 - recall: 0.8673 - auc: 0.9473 - prc: 0.9455 - val_loss: 0.2882 - val_tp: 32899.0000 - val_fp: 4997.0000 - val_tn: 33007.0000 - val_fn: 5079.0000 - val_accuracy: 0.8674 - val_precision: 0.8681 - val_recall: 0.8663 - val_auc: 0.9480 - val_prc: 0.9458
# Epoch 48/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2887 - tp: 131945.0000 - fp: 20436.0000 - tn: 131708.0000 - fn: 19836.0000 - accuracy: 0.8675 - precision: 0.8659 - recall: 0.8693 - auc: 0.9478 - prc: 0.9459 - val_loss: 0.2882 - val_tp: 32265.0000 - val_fp: 4224.0000 - val_tn: 33780.0000 - val_fn: 5713.0000 - val_accuracy: 0.8692 - val_precision: 0.8842 - val_recall: 0.8496 - val_auc: 0.9484 - val_prc: 0.9464
# Epoch 49/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2873 - tp: 132027.0000 - fp: 20221.0000 - tn: 131923.0000 - fn: 19754.0000 - accuracy: 0.8685 - precision: 0.8672 - recall: 0.8699 - auc: 0.9484 - prc: 0.9465 - val_loss: 0.2858 - val_tp: 32622.0000 - val_fp: 4539.0000 - val_tn: 33465.0000 - val_fn: 5356.0000 - val_accuracy: 0.8698 - val_precision: 0.8779 - val_recall: 0.8590 - val_auc: 0.9491 - val_prc: 0.9471
# Epoch 50/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2859 - tp: 132019.0000 - fp: 19955.0000 - tn: 132189.0000 - fn: 19762.0000 - accuracy: 0.8693 - precision: 0.8687 - recall: 0.8698 - auc: 0.9489 - prc: 0.9469 - val_loss: 0.2857 - val_tp: 33595.0000 - val_fp: 5526.0000 - val_tn: 32478.0000 - val_fn: 4383.0000 - val_accuracy: 0.8696 - val_precision: 0.8587 - val_recall: 0.8846 - val_auc: 0.9492 - val_prc: 0.9470
# Epoch 51/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2849 - tp: 132259.0000 - fp: 20008.0000 - tn: 132136.0000 - fn: 19522.0000 - accuracy: 0.8699 - precision: 0.8686 - recall: 0.8714 - auc: 0.9492 - prc: 0.9473 - val_loss: 0.2848 - val_tp: 33638.0000 - val_fp: 5589.0000 - val_tn: 32415.0000 - val_fn: 4340.0000 - val_accuracy: 0.8693 - val_precision: 0.8575 - val_recall: 0.8857 - val_auc: 0.9495 - val_prc: 0.9474
# Epoch 52/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2836 - tp: 132536.0000 - fp: 20060.0000 - tn: 132084.0000 - fn: 19245.0000 - accuracy: 0.8707 - precision: 0.8685 - recall: 0.8732 - auc: 0.9498 - prc: 0.9477 - val_loss: 0.2821 - val_tp: 33207.0000 - val_fp: 4932.0000 - val_tn: 33072.0000 - val_fn: 4771.0000 - val_accuracy: 0.8723 - val_precision: 0.8707 - val_recall: 0.8744 - val_auc: 0.9504 - val_prc: 0.9481
# Epoch 53/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2821 - tp: 132550.0000 - fp: 19747.0000 - tn: 132397.0000 - fn: 19231.0000 - accuracy: 0.8718 - precision: 0.8703 - recall: 0.8733 - auc: 0.9504 - prc: 0.9483 - val_loss: 0.2815 - val_tp: 32810.0000 - val_fp: 4564.0000 - val_tn: 33440.0000 - val_fn: 5168.0000 - val_accuracy: 0.8719 - val_precision: 0.8779 - val_recall: 0.8639 - val_auc: 0.9507 - val_prc: 0.9487
# Epoch 54/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2813 - tp: 132671.0000 - fp: 19863.0000 - tn: 132281.0000 - fn: 19110.0000 - accuracy: 0.8718 - precision: 0.8698 - recall: 0.8741 - auc: 0.9506 - prc: 0.9486 - val_loss: 0.2813 - val_tp: 32908.0000 - val_fp: 4714.0000 - val_tn: 33290.0000 - val_fn: 5070.0000 - val_accuracy: 0.8712 - val_precision: 0.8747 - val_recall: 0.8665 - val_auc: 0.9506 - val_prc: 0.9483
# Epoch 55/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2798 - tp: 132622.0000 - fp: 19653.0000 - tn: 132491.0000 - fn: 19159.0000 - accuracy: 0.8723 - precision: 0.8709 - recall: 0.8738 - auc: 0.9512 - prc: 0.9491 - val_loss: 0.2799 - val_tp: 32784.0000 - val_fp: 4577.0000 - val_tn: 33427.0000 - val_fn: 5194.0000 - val_accuracy: 0.8714 - val_precision: 0.8775 - val_recall: 0.8632 - val_auc: 0.9512 - val_prc: 0.9490
# Epoch 56/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2791 - tp: 132857.0000 - fp: 19555.0000 - tn: 132589.0000 - fn: 18924.0000 - accuracy: 0.8734 - precision: 0.8717 - recall: 0.8753 - auc: 0.9514 - prc: 0.9493 - val_loss: 0.2781 - val_tp: 33576.0000 - val_fp: 5111.0000 - val_tn: 32893.0000 - val_fn: 4402.0000 - val_accuracy: 0.8748 - val_precision: 0.8679 - val_recall: 0.8841 - val_auc: 0.9519 - val_prc: 0.9495
# Epoch 57/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2780 - tp: 133064.0000 - fp: 19609.0000 - tn: 132535.0000 - fn: 18717.0000 - accuracy: 0.8739 - precision: 0.8716 - recall: 0.8767 - auc: 0.9518 - prc: 0.9497 - val_loss: 0.2782 - val_tp: 33416.0000 - val_fp: 5098.0000 - val_tn: 32906.0000 - val_fn: 4562.0000 - val_accuracy: 0.8729 - val_precision: 0.8676 - val_recall: 0.8799 - val_auc: 0.9518 - val_prc: 0.9496
# Epoch 58/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2770 - tp: 133319.0000 - fp: 19645.0000 - tn: 132499.0000 - fn: 18462.0000 - accuracy: 0.8746 - precision: 0.8716 - recall: 0.8784 - auc: 0.9522 - prc: 0.9500 - val_loss: 0.2777 - val_tp: 33062.0000 - val_fp: 4697.0000 - val_tn: 33307.0000 - val_fn: 4916.0000 - val_accuracy: 0.8735 - val_precision: 0.8756 - val_recall: 0.8706 - val_auc: 0.9518 - val_prc: 0.9496
# Epoch 59/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2758 - tp: 133246.0000 - fp: 19407.0000 - tn: 132737.0000 - fn: 18535.0000 - accuracy: 0.8752 - precision: 0.8729 - recall: 0.8779 - auc: 0.9526 - prc: 0.9504 - val_loss: 0.2765 - val_tp: 34091.0000 - val_fp: 5617.0000 - val_tn: 32387.0000 - val_fn: 3887.0000 - val_accuracy: 0.8749 - val_precision: 0.8585 - val_recall: 0.8977 - val_auc: 0.9526 - val_prc: 0.9502
# Epoch 60/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2750 - tp: 133555.0000 - fp: 19494.0000 - tn: 132650.0000 - fn: 18226.0000 - accuracy: 0.8759 - precision: 0.8726 - recall: 0.8799 - auc: 0.9529 - prc: 0.9507 - val_loss: 0.2745 - val_tp: 32598.0000 - val_fp: 4074.0000 - val_tn: 33930.0000 - val_fn: 5380.0000 - val_accuracy: 0.8756 - val_precision: 0.8889 - val_recall: 0.8583 - val_auc: 0.9535 - val_prc: 0.9510
# Epoch 61/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2743 - tp: 133430.0000 - fp: 19270.0000 - tn: 132874.0000 - fn: 18351.0000 - accuracy: 0.8762 - precision: 0.8738 - recall: 0.8791 - auc: 0.9531 - prc: 0.9508 - val_loss: 0.2747 - val_tp: 34348.0000 - val_fp: 5690.0000 - val_tn: 32314.0000 - val_fn: 3630.0000 - val_accuracy: 0.8773 - val_precision: 0.8579 - val_recall: 0.9044 - val_auc: 0.9537 - val_prc: 0.9515
# Epoch 62/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2731 - tp: 133719.0000 - fp: 19307.0000 - tn: 132837.0000 - fn: 18062.0000 - accuracy: 0.8770 - precision: 0.8738 - recall: 0.8810 - auc: 0.9536 - prc: 0.9514 - val_loss: 0.2726 - val_tp: 33602.0000 - val_fp: 4913.0000 - val_tn: 33091.0000 - val_fn: 4376.0000 - val_accuracy: 0.8777 - val_precision: 0.8724 - val_recall: 0.8848 - val_auc: 0.9538 - val_prc: 0.9513
# Epoch 63/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2721 - tp: 133967.0000 - fp: 19215.0000 - tn: 132929.0000 - fn: 17814.0000 - accuracy: 0.8782 - precision: 0.8746 - recall: 0.8826 - auc: 0.9540 - prc: 0.9517 - val_loss: 0.2713 - val_tp: 33399.0000 - val_fp: 4622.0000 - val_tn: 33382.0000 - val_fn: 4579.0000 - val_accuracy: 0.8789 - val_precision: 0.8784 - val_recall: 0.8794 - val_auc: 0.9543 - val_prc: 0.9519
# Epoch 64/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2714 - tp: 133971.0000 - fp: 19156.0000 - tn: 132988.0000 - fn: 17810.0000 - accuracy: 0.8784 - precision: 0.8749 - recall: 0.8827 - auc: 0.9542 - prc: 0.9519 - val_loss: 0.2715 - val_tp: 33212.0000 - val_fp: 4472.0000 - val_tn: 33532.0000 - val_fn: 4766.0000 - val_accuracy: 0.8784 - val_precision: 0.8813 - val_recall: 0.8745 - val_auc: 0.9542 - val_prc: 0.9517
# Epoch 65/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2707 - tp: 133953.0000 - fp: 18998.0000 - tn: 133146.0000 - fn: 17828.0000 - accuracy: 0.8788 - precision: 0.8758 - recall: 0.8825 - auc: 0.9544 - prc: 0.9522 - val_loss: 0.2695 - val_tp: 33860.0000 - val_fp: 4946.0000 - val_tn: 33058.0000 - val_fn: 4118.0000 - val_accuracy: 0.8807 - val_precision: 0.8725 - val_recall: 0.8916 - val_auc: 0.9550 - val_prc: 0.9526
# Epoch 66/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2697 - tp: 134304.0000 - fp: 19179.0000 - tn: 132965.0000 - fn: 17477.0000 - accuracy: 0.8794 - precision: 0.8750 - recall: 0.8849 - auc: 0.9548 - prc: 0.9524 - val_loss: 0.2691 - val_tp: 33178.0000 - val_fp: 4388.0000 - val_tn: 33616.0000 - val_fn: 4800.0000 - val_accuracy: 0.8791 - val_precision: 0.8832 - val_recall: 0.8736 - val_auc: 0.9551 - val_prc: 0.9527
# Epoch 67/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2690 - tp: 134259.0000 - fp: 18912.0000 - tn: 133232.0000 - fn: 17522.0000 - accuracy: 0.8801 - precision: 0.8765 - recall: 0.8846 - auc: 0.9550 - prc: 0.9528 - val_loss: 0.2683 - val_tp: 33771.0000 - val_fp: 4780.0000 - val_tn: 33224.0000 - val_fn: 4207.0000 - val_accuracy: 0.8817 - val_precision: 0.8760 - val_recall: 0.8892 - val_auc: 0.9554 - val_prc: 0.9527
# Epoch 68/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2681 - tp: 134370.0000 - fp: 19027.0000 - tn: 133117.0000 - fn: 17411.0000 - accuracy: 0.8801 - precision: 0.8760 - recall: 0.8853 - auc: 0.9553 - prc: 0.9530 - val_loss: 0.2668 - val_tp: 33807.0000 - val_fp: 4793.0000 - val_tn: 33211.0000 - val_fn: 4171.0000 - val_accuracy: 0.8820 - val_precision: 0.8758 - val_recall: 0.8902 - val_auc: 0.9559 - val_prc: 0.9535
# Epoch 69/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2674 - tp: 134531.0000 - fp: 18968.0000 - tn: 133176.0000 - fn: 17250.0000 - accuracy: 0.8808 - precision: 0.8764 - recall: 0.8863 - auc: 0.9555 - prc: 0.9531 - val_loss: 0.2668 - val_tp: 33462.0000 - val_fp: 4457.0000 - val_tn: 33547.0000 - val_fn: 4516.0000 - val_accuracy: 0.8819 - val_precision: 0.8825 - val_recall: 0.8811 - val_auc: 0.9559 - val_prc: 0.9535
# Epoch 70/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2667 - tp: 134585.0000 - fp: 18944.0000 - tn: 133200.0000 - fn: 17196.0000 - accuracy: 0.8811 - precision: 0.8766 - recall: 0.8867 - auc: 0.9558 - prc: 0.9535 - val_loss: 0.2660 - val_tp: 34182.0000 - val_fp: 5055.0000 - val_tn: 32949.0000 - val_fn: 3796.0000 - val_accuracy: 0.8835 - val_precision: 0.8712 - val_recall: 0.9000 - val_auc: 0.9562 - val_prc: 0.9538
# Epoch 71/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2658 - tp: 134740.0000 - fp: 18824.0000 - tn: 133320.0000 - fn: 17041.0000 - accuracy: 0.8820 - precision: 0.8774 - recall: 0.8877 - auc: 0.9561 - prc: 0.9537 - val_loss: 0.2651 - val_tp: 33452.0000 - val_fp: 4432.0000 - val_tn: 33572.0000 - val_fn: 4526.0000 - val_accuracy: 0.8821 - val_precision: 0.8830 - val_recall: 0.8808 - val_auc: 0.9564 - val_prc: 0.9540
# Epoch 72/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2653 - tp: 134663.0000 - fp: 18799.0000 - tn: 133345.0000 - fn: 17118.0000 - accuracy: 0.8818 - precision: 0.8775 - recall: 0.8872 - auc: 0.9563 - prc: 0.9539 - val_loss: 0.2650 - val_tp: 33785.0000 - val_fp: 4743.0000 - val_tn: 33261.0000 - val_fn: 4193.0000 - val_accuracy: 0.8824 - val_precision: 0.8769 - val_recall: 0.8896 - val_auc: 0.9563 - val_prc: 0.9539
# Epoch 73/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2645 - tp: 134881.0000 - fp: 18877.0000 - tn: 133267.0000 - fn: 16900.0000 - accuracy: 0.8823 - precision: 0.8772 - recall: 0.8887 - auc: 0.9566 - prc: 0.9541 - val_loss: 0.2642 - val_tp: 33946.0000 - val_fp: 4827.0000 - val_tn: 33177.0000 - val_fn: 4032.0000 - val_accuracy: 0.8834 - val_precision: 0.8755 - val_recall: 0.8938 - val_auc: 0.9567 - val_prc: 0.9538
# Epoch 74/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2639 - tp: 134897.0000 - fp: 18740.0000 - tn: 133404.0000 - fn: 16884.0000 - accuracy: 0.8828 - precision: 0.8780 - recall: 0.8888 - auc: 0.9567 - prc: 0.9543 - val_loss: 0.2630 - val_tp: 33838.0000 - val_fp: 4654.0000 - val_tn: 33350.0000 - val_fn: 4140.0000 - val_accuracy: 0.8843 - val_precision: 0.8791 - val_recall: 0.8910 - val_auc: 0.9571 - val_prc: 0.9545
# Epoch 75/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2632 - tp: 134856.0000 - fp: 18719.0000 - tn: 133425.0000 - fn: 16925.0000 - accuracy: 0.8827 - precision: 0.8781 - recall: 0.8885 - auc: 0.9570 - prc: 0.9545 - val_loss: 0.2638 - val_tp: 34146.0000 - val_fp: 4987.0000 - val_tn: 33017.0000 - val_fn: 3832.0000 - val_accuracy: 0.8839 - val_precision: 0.8726 - val_recall: 0.8991 - val_auc: 0.9568 - val_prc: 0.9540
# Epoch 76/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2630 - tp: 135027.0000 - fp: 18727.0000 - tn: 133417.0000 - fn: 16754.0000 - accuracy: 0.8833 - precision: 0.8782 - recall: 0.8896 - auc: 0.9570 - prc: 0.9545 - val_loss: 0.2627 - val_tp: 33840.0000 - val_fp: 4737.0000 - val_tn: 33267.0000 - val_fn: 4138.0000 - val_accuracy: 0.8832 - val_precision: 0.8772 - val_recall: 0.8910 - val_auc: 0.9572 - val_prc: 0.9548
# Epoch 77/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2619 - tp: 135176.0000 - fp: 18737.0000 - tn: 133407.0000 - fn: 16605.0000 - accuracy: 0.8837 - precision: 0.8783 - recall: 0.8906 - auc: 0.9574 - prc: 0.9549 - val_loss: 0.2611 - val_tp: 33703.0000 - val_fp: 4491.0000 - val_tn: 33513.0000 - val_fn: 4275.0000 - val_accuracy: 0.8846 - val_precision: 0.8824 - val_recall: 0.8874 - val_auc: 0.9578 - val_prc: 0.9554
# Epoch 78/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2611 - tp: 135093.0000 - fp: 18509.0000 - tn: 133635.0000 - fn: 16688.0000 - accuracy: 0.8842 - precision: 0.8795 - recall: 0.8901 - auc: 0.9577 - prc: 0.9551 - val_loss: 0.2615 - val_tp: 34641.0000 - val_fp: 5337.0000 - val_tn: 32667.0000 - val_fn: 3337.0000 - val_accuracy: 0.8858 - val_precision: 0.8665 - val_recall: 0.9121 - val_auc: 0.9579 - val_prc: 0.9555
# Epoch 79/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2608 - tp: 135355.0000 - fp: 18715.0000 - tn: 133429.0000 - fn: 16426.0000 - accuracy: 0.8844 - precision: 0.8785 - recall: 0.8918 - auc: 0.9577 - prc: 0.9553 - val_loss: 0.2597 - val_tp: 34017.0000 - val_fp: 4693.0000 - val_tn: 33311.0000 - val_fn: 3961.0000 - val_accuracy: 0.8861 - val_precision: 0.8788 - val_recall: 0.8957 - val_auc: 0.9582 - val_prc: 0.9557
# Epoch 80/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2601 - tp: 135295.0000 - fp: 18554.0000 - tn: 133590.0000 - fn: 16486.0000 - accuracy: 0.8847 - precision: 0.8794 - recall: 0.8914 - auc: 0.9580 - prc: 0.9555 - val_loss: 0.2627 - val_tp: 34251.0000 - val_fp: 5269.0000 - val_tn: 32735.0000 - val_fn: 3727.0000 - val_accuracy: 0.8816 - val_precision: 0.8667 - val_recall: 0.9019 - val_auc: 0.9572 - val_prc: 0.9549
# Epoch 81/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2595 - tp: 135555.0000 - fp: 18625.0000 - tn: 133519.0000 - fn: 16226.0000 - accuracy: 0.8853 - precision: 0.8792 - recall: 0.8931 - auc: 0.9582 - prc: 0.9557 - val_loss: 0.2590 - val_tp: 33799.0000 - val_fp: 4501.0000 - val_tn: 33503.0000 - val_fn: 4179.0000 - val_accuracy: 0.8858 - val_precision: 0.8825 - val_recall: 0.8900 - val_auc: 0.9584 - val_prc: 0.9560
# Epoch 82/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2589 - tp: 135507.0000 - fp: 18477.0000 - tn: 133667.0000 - fn: 16274.0000 - accuracy: 0.8857 - precision: 0.8800 - recall: 0.8928 - auc: 0.9584 - prc: 0.9558 - val_loss: 0.2588 - val_tp: 33541.0000 - val_fp: 4194.0000 - val_tn: 33810.0000 - val_fn: 4437.0000 - val_accuracy: 0.8864 - val_precision: 0.8889 - val_recall: 0.8832 - val_auc: 0.9586 - val_prc: 0.9560
# Epoch 83/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2580 - tp: 135576.0000 - fp: 18400.0000 - tn: 133744.0000 - fn: 16205.0000 - accuracy: 0.8861 - precision: 0.8805 - recall: 0.8932 - auc: 0.9587 - prc: 0.9562 - val_loss: 0.2580 - val_tp: 34020.0000 - val_fp: 4687.0000 - val_tn: 33317.0000 - val_fn: 3958.0000 - val_accuracy: 0.8862 - val_precision: 0.8789 - val_recall: 0.8958 - val_auc: 0.9587 - val_prc: 0.9561
# Epoch 84/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2573 - tp: 135585.0000 - fp: 18405.0000 - tn: 133739.0000 - fn: 16196.0000 - accuracy: 0.8862 - precision: 0.8805 - recall: 0.8933 - auc: 0.9589 - prc: 0.9564 - val_loss: 0.2572 - val_tp: 33974.0000 - val_fp: 4591.0000 - val_tn: 33413.0000 - val_fn: 4004.0000 - val_accuracy: 0.8869 - val_precision: 0.8810 - val_recall: 0.8946 - val_auc: 0.9590 - val_prc: 0.9566
# Epoch 85/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2574 - tp: 135593.0000 - fp: 18382.0000 - tn: 133762.0000 - fn: 16188.0000 - accuracy: 0.8863 - precision: 0.8806 - recall: 0.8933 - auc: 0.9588 - prc: 0.9563 - val_loss: 0.2582 - val_tp: 33724.0000 - val_fp: 4439.0000 - val_tn: 33565.0000 - val_fn: 4254.0000 - val_accuracy: 0.8856 - val_precision: 0.8837 - val_recall: 0.8880 - val_auc: 0.9585 - val_prc: 0.9559
# Epoch 86/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2563 - tp: 135788.0000 - fp: 18359.0000 - tn: 133785.0000 - fn: 15993.0000 - accuracy: 0.8870 - precision: 0.8809 - recall: 0.8946 - auc: 0.9592 - prc: 0.9566 - val_loss: 0.2570 - val_tp: 34096.0000 - val_fp: 4802.0000 - val_tn: 33202.0000 - val_fn: 3882.0000 - val_accuracy: 0.8857 - val_precision: 0.8765 - val_recall: 0.8978 - val_auc: 0.9590 - val_prc: 0.9564
# Epoch 87/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2560 - tp: 135788.0000 - fp: 18358.0000 - tn: 133786.0000 - fn: 15993.0000 - accuracy: 0.8870 - precision: 0.8809 - recall: 0.8946 - auc: 0.9593 - prc: 0.9567 - val_loss: 0.2565 - val_tp: 34377.0000 - val_fp: 4998.0000 - val_tn: 33006.0000 - val_fn: 3601.0000 - val_accuracy: 0.8868 - val_precision: 0.8731 - val_recall: 0.9052 - val_auc: 0.9592 - val_prc: 0.9565
# Epoch 88/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2550 - tp: 135842.0000 - fp: 18234.0000 - tn: 133910.0000 - fn: 15939.0000 - accuracy: 0.8876 - precision: 0.8817 - recall: 0.8950 - auc: 0.9596 - prc: 0.9571 - val_loss: 0.2561 - val_tp: 34635.0000 - val_fp: 5057.0000 - val_tn: 32947.0000 - val_fn: 3343.0000 - val_accuracy: 0.8894 - val_precision: 0.8726 - val_recall: 0.9120 - val_auc: 0.9594 - val_prc: 0.9567
# Epoch 89/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2544 - tp: 135994.0000 - fp: 18164.0000 - tn: 133980.0000 - fn: 15787.0000 - accuracy: 0.8883 - precision: 0.8822 - recall: 0.8960 - auc: 0.9598 - prc: 0.9572 - val_loss: 0.2544 - val_tp: 34188.0000 - val_fp: 4623.0000 - val_tn: 33381.0000 - val_fn: 3790.0000 - val_accuracy: 0.8893 - val_precision: 0.8809 - val_recall: 0.9002 - val_auc: 0.9598 - val_prc: 0.9567
# Epoch 90/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2542 - tp: 135957.0000 - fp: 18230.0000 - tn: 133914.0000 - fn: 15824.0000 - accuracy: 0.8880 - precision: 0.8818 - recall: 0.8957 - auc: 0.9598 - prc: 0.9573 - val_loss: 0.2542 - val_tp: 33739.0000 - val_fp: 4283.0000 - val_tn: 33721.0000 - val_fn: 4239.0000 - val_accuracy: 0.8878 - val_precision: 0.8874 - val_recall: 0.8884 - val_auc: 0.9600 - val_prc: 0.9575
# Epoch 91/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2530 - tp: 135991.0000 - fp: 18114.0000 - tn: 134030.0000 - fn: 15790.0000 - accuracy: 0.8884 - precision: 0.8825 - recall: 0.8960 - auc: 0.9603 - prc: 0.9578 - val_loss: 0.2548 - val_tp: 34488.0000 - val_fp: 5082.0000 - val_tn: 32922.0000 - val_fn: 3490.0000 - val_accuracy: 0.8872 - val_precision: 0.8716 - val_recall: 0.9081 - val_auc: 0.9599 - val_prc: 0.9569
# Epoch 92/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2527 - tp: 136015.0000 - fp: 18109.0000 - tn: 134035.0000 - fn: 15766.0000 - accuracy: 0.8885 - precision: 0.8825 - recall: 0.8961 - auc: 0.9604 - prc: 0.9578 - val_loss: 0.2526 - val_tp: 34004.0000 - val_fp: 4429.0000 - val_tn: 33575.0000 - val_fn: 3974.0000 - val_accuracy: 0.8894 - val_precision: 0.8848 - val_recall: 0.8954 - val_auc: 0.9604 - val_prc: 0.9580
# Epoch 93/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2522 - tp: 136091.0000 - fp: 18171.0000 - tn: 133973.0000 - fn: 15690.0000 - accuracy: 0.8886 - precision: 0.8822 - recall: 0.8966 - auc: 0.9605 - prc: 0.9580 - val_loss: 0.2518 - val_tp: 34095.0000 - val_fp: 4485.0000 - val_tn: 33519.0000 - val_fn: 3883.0000 - val_accuracy: 0.8899 - val_precision: 0.8837 - val_recall: 0.8978 - val_auc: 0.9606 - val_prc: 0.9578
# Epoch 94/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2517 - tp: 136033.0000 - fp: 17956.0000 - tn: 134188.0000 - fn: 15748.0000 - accuracy: 0.8891 - precision: 0.8834 - recall: 0.8962 - auc: 0.9607 - prc: 0.9582 - val_loss: 0.2533 - val_tp: 34233.0000 - val_fp: 4709.0000 - val_tn: 33295.0000 - val_fn: 3745.0000 - val_accuracy: 0.8887 - val_precision: 0.8791 - val_recall: 0.9014 - val_auc: 0.9601 - val_prc: 0.9572
# Epoch 95/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2512 - tp: 136163.0000 - fp: 18029.0000 - tn: 134115.0000 - fn: 15618.0000 - accuracy: 0.8893 - precision: 0.8831 - recall: 0.8971 - auc: 0.9608 - prc: 0.9582 - val_loss: 0.2513 - val_tp: 34418.0000 - val_fp: 4838.0000 - val_tn: 33166.0000 - val_fn: 3560.0000 - val_accuracy: 0.8895 - val_precision: 0.8768 - val_recall: 0.9063 - val_auc: 0.9608 - val_prc: 0.9579
# Epoch 96/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2508 - tp: 136254.0000 - fp: 17981.0000 - tn: 134163.0000 - fn: 15527.0000 - accuracy: 0.8897 - precision: 0.8834 - recall: 0.8977 - auc: 0.9609 - prc: 0.9583 - val_loss: 0.2510 - val_tp: 34201.0000 - val_fp: 4599.0000 - val_tn: 33405.0000 - val_fn: 3777.0000 - val_accuracy: 0.8898 - val_precision: 0.8815 - val_recall: 0.9005 - val_auc: 0.9608 - val_prc: 0.9582
# Epoch 97/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2502 - tp: 136238.0000 - fp: 17910.0000 - tn: 134234.0000 - fn: 15543.0000 - accuracy: 0.8899 - precision: 0.8838 - recall: 0.8976 - auc: 0.9611 - prc: 0.9586 - val_loss: 0.2508 - val_tp: 34524.0000 - val_fp: 4923.0000 - val_tn: 33081.0000 - val_fn: 3454.0000 - val_accuracy: 0.8898 - val_precision: 0.8752 - val_recall: 0.9091 - val_auc: 0.9611 - val_prc: 0.9582
# Epoch 98/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2494 - tp: 136391.0000 - fp: 17930.0000 - tn: 134214.0000 - fn: 15390.0000 - accuracy: 0.8904 - precision: 0.8838 - recall: 0.8986 - auc: 0.9614 - prc: 0.9589 - val_loss: 0.2506 - val_tp: 34198.0000 - val_fp: 4494.0000 - val_tn: 33510.0000 - val_fn: 3780.0000 - val_accuracy: 0.8911 - val_precision: 0.8839 - val_recall: 0.9005 - val_auc: 0.9609 - val_prc: 0.9583
# Epoch 99/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2486 - tp: 136338.0000 - fp: 17697.0000 - tn: 134447.0000 - fn: 15443.0000 - accuracy: 0.8910 - precision: 0.8851 - recall: 0.8983 - auc: 0.9617 - prc: 0.9592 - val_loss: 0.2497 - val_tp: 34113.0000 - val_fp: 4450.0000 - val_tn: 33554.0000 - val_fn: 3865.0000 - val_accuracy: 0.8906 - val_precision: 0.8846 - val_recall: 0.8982 - val_auc: 0.9613 - val_prc: 0.9586
# Epoch 100/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2485 - tp: 136438.0000 - fp: 17909.0000 - tn: 134235.0000 - fn: 15343.0000 - accuracy: 0.8906 - precision: 0.8840 - recall: 0.8989 - auc: 0.9616 - prc: 0.9591 - val_loss: 0.2483 - val_tp: 34050.0000 - val_fp: 4352.0000 - val_tn: 33652.0000 - val_fn: 3928.0000 - val_accuracy: 0.8910 - val_precision: 0.8867 - val_recall: 0.8966 - val_auc: 0.9617 - val_prc: 0.9591
# Epoch 101/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2482 - tp: 136340.0000 - fp: 17765.0000 - tn: 134379.0000 - fn: 15441.0000 - accuracy: 0.8907 - precision: 0.8847 - recall: 0.8983 - auc: 0.9618 - prc: 0.9593 - val_loss: 0.2481 - val_tp: 34505.0000 - val_fp: 4725.0000 - val_tn: 33279.0000 - val_fn: 3473.0000 - val_accuracy: 0.8921 - val_precision: 0.8796 - val_recall: 0.9086 - val_auc: 0.9618 - val_prc: 0.9592
# Epoch 102/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2477 - tp: 136401.0000 - fp: 17683.0000 - tn: 134461.0000 - fn: 15380.0000 - accuracy: 0.8912 - precision: 0.8852 - recall: 0.8987 - auc: 0.9619 - prc: 0.9594 - val_loss: 0.2483 - val_tp: 34866.0000 - val_fp: 5135.0000 - val_tn: 32869.0000 - val_fn: 3112.0000 - val_accuracy: 0.8915 - val_precision: 0.8716 - val_recall: 0.9181 - val_auc: 0.9620 - val_prc: 0.9592
# Epoch 103/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2472 - tp: 136457.0000 - fp: 17733.0000 - tn: 134411.0000 - fn: 15324.0000 - accuracy: 0.8912 - precision: 0.8850 - recall: 0.8990 - auc: 0.9621 - prc: 0.9596 - val_loss: 0.2474 - val_tp: 34212.0000 - val_fp: 4491.0000 - val_tn: 33513.0000 - val_fn: 3766.0000 - val_accuracy: 0.8913 - val_precision: 0.8840 - val_recall: 0.9008 - val_auc: 0.9620 - val_prc: 0.9592
# Epoch 104/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2463 - tp: 136524.0000 - fp: 17621.0000 - tn: 134523.0000 - fn: 15257.0000 - accuracy: 0.8918 - precision: 0.8857 - recall: 0.8995 - auc: 0.9623 - prc: 0.9599 - val_loss: 0.2474 - val_tp: 34805.0000 - val_fp: 5016.0000 - val_tn: 32988.0000 - val_fn: 3173.0000 - val_accuracy: 0.8922 - val_precision: 0.8740 - val_recall: 0.9165 - val_auc: 0.9622 - val_prc: 0.9594
# Epoch 105/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2463 - tp: 136445.0000 - fp: 17581.0000 - tn: 134563.0000 - fn: 15336.0000 - accuracy: 0.8917 - precision: 0.8859 - recall: 0.8990 - auc: 0.9623 - prc: 0.9599 - val_loss: 0.2468 - val_tp: 34634.0000 - val_fp: 4878.0000 - val_tn: 33126.0000 - val_fn: 3344.0000 - val_accuracy: 0.8918 - val_precision: 0.8765 - val_recall: 0.9119 - val_auc: 0.9623 - val_prc: 0.9595
# Epoch 106/500
# ...
# Epoch 311/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1947 - tp: 141281.0000 - fp: 13941.0000 - tn: 138203.0000 - fn: 10500.0000 - accuracy: 0.9196 - precision: 0.9102 - recall: 0.9308 - auc: 0.9762 - prc: 0.9739 - val_loss: 0.1979 - val_tp: 35581.0000 - val_fp: 3732.0000 - val_tn: 34272.0000 - val_fn: 2397.0000 - val_accuracy: 0.9193 - val_precision: 0.9051 - val_recall: 0.9369 - val_auc: 0.9753 - val_prc: 0.9723
# Epoch 312/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1948 - tp: 141173.0000 - fp: 13999.0000 - tn: 138145.0000 - fn: 10608.0000 - accuracy: 0.9190 - precision: 0.9098 - recall: 0.9301 - auc: 0.9762 - prc: 0.9737 - val_loss: 0.1976 - val_tp: 34972.0000 - val_fp: 3150.0000 - val_tn: 34854.0000 - val_fn: 3006.0000 - val_accuracy: 0.9190 - val_precision: 0.9174 - val_recall: 0.9208 - val_auc: 0.9755 - val_prc: 0.9727
# Epoch 313/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1939 - tp: 141376.0000 - fp: 13944.0000 - tn: 138200.0000 - fn: 10405.0000 - accuracy: 0.9199 - precision: 0.9102 - recall: 0.9314 - auc: 0.9764 - prc: 0.9741 - val_loss: 0.1980 - val_tp: 35418.0000 - val_fp: 3725.0000 - val_tn: 34279.0000 - val_fn: 2560.0000 - val_accuracy: 0.9173 - val_precision: 0.9048 - val_recall: 0.9326 - val_auc: 0.9753 - val_prc: 0.9724
# Epoch 314/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1941 - tp: 141287.0000 - fp: 13816.0000 - tn: 138328.0000 - fn: 10494.0000 - accuracy: 0.9200 - precision: 0.9109 - recall: 0.9309 - auc: 0.9764 - prc: 0.9740 - val_loss: 0.1973 - val_tp: 35336.0000 - val_fp: 3539.0000 - val_tn: 34465.0000 - val_fn: 2642.0000 - val_accuracy: 0.9187 - val_precision: 0.9090 - val_recall: 0.9304 - val_auc: 0.9754 - val_prc: 0.9723
# Epoch 315/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1940 - tp: 141376.0000 - fp: 13999.0000 - tn: 138145.0000 - fn: 10405.0000 - accuracy: 0.9197 - precision: 0.9099 - recall: 0.9314 - auc: 0.9763 - prc: 0.9740 - val_loss: 0.1973 - val_tp: 34839.0000 - val_fp: 3059.0000 - val_tn: 34945.0000 - val_fn: 3139.0000 - val_accuracy: 0.9184 - val_precision: 0.9193 - val_recall: 0.9173 - val_auc: 0.9756 - val_prc: 0.9727
# Epoch 316/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1942 - tp: 141375.0000 - fp: 13943.0000 - tn: 138201.0000 - fn: 10406.0000 - accuracy: 0.9199 - precision: 0.9102 - recall: 0.9314 - auc: 0.9763 - prc: 0.9740 - val_loss: 0.1964 - val_tp: 35336.0000 - val_fp: 3434.0000 - val_tn: 34570.0000 - val_fn: 2642.0000 - val_accuracy: 0.9200 - val_precision: 0.9114 - val_recall: 0.9304 - val_auc: 0.9757 - val_prc: 0.9728
# Epoch 317/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1938 - tp: 141408.0000 - fp: 13881.0000 - tn: 138263.0000 - fn: 10373.0000 - accuracy: 0.9202 - precision: 0.9106 - recall: 0.9317 - auc: 0.9764 - prc: 0.9740 - val_loss: 0.1962 - val_tp: 35284.0000 - val_fp: 3397.0000 - val_tn: 34607.0000 - val_fn: 2694.0000 - val_accuracy: 0.9198 - val_precision: 0.9122 - val_recall: 0.9291 - val_auc: 0.9758 - val_prc: 0.9729
# Epoch 318/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1929 - tp: 141400.0000 - fp: 13815.0000 - tn: 138329.0000 - fn: 10381.0000 - accuracy: 0.9204 - precision: 0.9110 - recall: 0.9316 - auc: 0.9766 - prc: 0.9743 - val_loss: 0.1978 - val_tp: 35241.0000 - val_fp: 3412.0000 - val_tn: 34592.0000 - val_fn: 2737.0000 - val_accuracy: 0.9191 - val_precision: 0.9117 - val_recall: 0.9279 - val_auc: 0.9754 - val_prc: 0.9724
# Epoch 319/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1936 - tp: 141456.0000 - fp: 13969.0000 - tn: 138175.0000 - fn: 10325.0000 - accuracy: 0.9201 - precision: 0.9101 - recall: 0.9320 - auc: 0.9765 - prc: 0.9741 - val_loss: 0.1962 - val_tp: 35131.0000 - val_fp: 3309.0000 - val_tn: 34695.0000 - val_fn: 2847.0000 - val_accuracy: 0.9190 - val_precision: 0.9139 - val_recall: 0.9250 - val_auc: 0.9757 - val_prc: 0.9728
# Epoch 320/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1943 - tp: 141184.0000 - fp: 13867.0000 - tn: 138277.0000 - fn: 10597.0000 - accuracy: 0.9195 - precision: 0.9106 - recall: 0.9302 - auc: 0.9763 - prc: 0.9740 - val_loss: 0.2007 - val_tp: 36210.0000 - val_fp: 4477.0000 - val_tn: 33527.0000 - val_fn: 1768.0000 - val_accuracy: 0.9178 - val_precision: 0.8900 - val_recall: 0.9534 - val_auc: 0.9755 - val_prc: 0.9722
# Epoch 321/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1936 - tp: 141479.0000 - fp: 13864.0000 - tn: 138280.0000 - fn: 10302.0000 - accuracy: 0.9205 - precision: 0.9108 - recall: 0.9321 - auc: 0.9765 - prc: 0.9741 - val_loss: 0.1970 - val_tp: 35008.0000 - val_fp: 3244.0000 - val_tn: 34760.0000 - val_fn: 2970.0000 - val_accuracy: 0.9182 - val_precision: 0.9152 - val_recall: 0.9218 - val_auc: 0.9757 - val_prc: 0.9729
# Epoch 322/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1928 - tp: 141426.0000 - fp: 13859.0000 - tn: 138285.0000 - fn: 10355.0000 - accuracy: 0.9203 - precision: 0.9108 - recall: 0.9318 - auc: 0.9766 - prc: 0.9743 - val_loss: 0.1956 - val_tp: 35017.0000 - val_fp: 3159.0000 - val_tn: 34845.0000 - val_fn: 2961.0000 - val_accuracy: 0.9195 - val_precision: 0.9173 - val_recall: 0.9220 - val_auc: 0.9760 - val_prc: 0.9731
# Epoch 323/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1931 - tp: 141359.0000 - fp: 13826.0000 - tn: 138318.0000 - fn: 10422.0000 - accuracy: 0.9202 - precision: 0.9109 - recall: 0.9313 - auc: 0.9766 - prc: 0.9742 - val_loss: 0.1958 - val_tp: 35618.0000 - val_fp: 3753.0000 - val_tn: 34251.0000 - val_fn: 2360.0000 - val_accuracy: 0.9195 - val_precision: 0.9047 - val_recall: 0.9379 - val_auc: 0.9758 - val_prc: 0.9727
# Epoch 324/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1942 - tp: 141348.0000 - fp: 13963.0000 - tn: 138181.0000 - fn: 10433.0000 - accuracy: 0.9197 - precision: 0.9101 - recall: 0.9313 - auc: 0.9763 - prc: 0.9739 - val_loss: 0.1965 - val_tp: 35195.0000 - val_fp: 3420.0000 - val_tn: 34584.0000 - val_fn: 2783.0000 - val_accuracy: 0.9184 - val_precision: 0.9114 - val_recall: 0.9267 - val_auc: 0.9756 - val_prc: 0.9729
# Epoch 325/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1926 - tp: 141403.0000 - fp: 13721.0000 - tn: 138423.0000 - fn: 10378.0000 - accuracy: 0.9207 - precision: 0.9115 - recall: 0.9316 - auc: 0.9767 - prc: 0.9743 - val_loss: 0.1971 - val_tp: 35638.0000 - val_fp: 3739.0000 - val_tn: 34265.0000 - val_fn: 2340.0000 - val_accuracy: 0.9200 - val_precision: 0.9050 - val_recall: 0.9384 - val_auc: 0.9756 - val_prc: 0.9723
# Epoch 326/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1927 - tp: 141527.0000 - fp: 13868.0000 - tn: 138276.0000 - fn: 10254.0000 - accuracy: 0.9206 - precision: 0.9108 - recall: 0.9324 - auc: 0.9766 - prc: 0.9743 - val_loss: 0.1958 - val_tp: 35463.0000 - val_fp: 3551.0000 - val_tn: 34453.0000 - val_fn: 2515.0000 - val_accuracy: 0.9202 - val_precision: 0.9090 - val_recall: 0.9338 - val_auc: 0.9758 - val_prc: 0.9728
# Epoch 327/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1920 - tp: 141553.0000 - fp: 13720.0000 - tn: 138424.0000 - fn: 10228.0000 - accuracy: 0.9212 - precision: 0.9116 - recall: 0.9326 - auc: 0.9768 - prc: 0.9745 - val_loss: 0.1955 - val_tp: 35764.0000 - val_fp: 3808.0000 - val_tn: 34196.0000 - val_fn: 2214.0000 - val_accuracy: 0.9207 - val_precision: 0.9038 - val_recall: 0.9417 - val_auc: 0.9761 - val_prc: 0.9728
# Epoch 328/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1922 - tp: 141497.0000 - fp: 13797.0000 - tn: 138347.0000 - fn: 10284.0000 - accuracy: 0.9208 - precision: 0.9112 - recall: 0.9322 - auc: 0.9768 - prc: 0.9745 - val_loss: 0.1971 - val_tp: 34961.0000 - val_fp: 3146.0000 - val_tn: 34858.0000 - val_fn: 3017.0000 - val_accuracy: 0.9189 - val_precision: 0.9174 - val_recall: 0.9206 - val_auc: 0.9756 - val_prc: 0.9726
# Epoch 329/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1927 - tp: 141444.0000 - fp: 13814.0000 - tn: 138330.0000 - fn: 10337.0000 - accuracy: 0.9205 - precision: 0.9110 - recall: 0.9319 - auc: 0.9766 - prc: 0.9743 - val_loss: 0.1959 - val_tp: 34899.0000 - val_fp: 3027.0000 - val_tn: 34977.0000 - val_fn: 3079.0000 - val_accuracy: 0.9196 - val_precision: 0.9202 - val_recall: 0.9189 - val_auc: 0.9760 - val_prc: 0.9731
# Epoch 330/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1922 - tp: 141470.0000 - fp: 13731.0000 - tn: 138413.0000 - fn: 10311.0000 - accuracy: 0.9209 - precision: 0.9115 - recall: 0.9321 - auc: 0.9768 - prc: 0.9744 - val_loss: 0.1945 - val_tp: 35456.0000 - val_fp: 3522.0000 - val_tn: 34482.0000 - val_fn: 2522.0000 - val_accuracy: 0.9205 - val_precision: 0.9096 - val_recall: 0.9336 - val_auc: 0.9762 - val_prc: 0.9732
# Epoch 331/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1918 - tp: 141567.0000 - fp: 13769.0000 - tn: 138375.0000 - fn: 10214.0000 - accuracy: 0.9211 - precision: 0.9114 - recall: 0.9327 - auc: 0.9769 - prc: 0.9746 - val_loss: 0.1944 - val_tp: 35628.0000 - val_fp: 3630.0000 - val_tn: 34374.0000 - val_fn: 2350.0000 - val_accuracy: 0.9213 - val_precision: 0.9075 - val_recall: 0.9381 - val_auc: 0.9761 - val_prc: 0.9729
# Epoch 332/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1921 - tp: 141532.0000 - fp: 13742.0000 - tn: 138402.0000 - fn: 10249.0000 - accuracy: 0.9211 - precision: 0.9115 - recall: 0.9325 - auc: 0.9768 - prc: 0.9744 - val_loss: 0.1952 - val_tp: 35057.0000 - val_fp: 3140.0000 - val_tn: 34864.0000 - val_fn: 2921.0000 - val_accuracy: 0.9202 - val_precision: 0.9178 - val_recall: 0.9231 - val_auc: 0.9760 - val_prc: 0.9730
# Epoch 333/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1916 - tp: 141530.0000 - fp: 13733.0000 - tn: 138411.0000 - fn: 10251.0000 - accuracy: 0.9211 - precision: 0.9116 - recall: 0.9325 - auc: 0.9769 - prc: 0.9746 - val_loss: 0.1961 - val_tp: 34906.0000 - val_fp: 3036.0000 - val_tn: 34968.0000 - val_fn: 3072.0000 - val_accuracy: 0.9196 - val_precision: 0.9200 - val_recall: 0.9191 - val_auc: 0.9760 - val_prc: 0.9733
# Epoch 334/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1916 - tp: 141578.0000 - fp: 13700.0000 - tn: 138444.0000 - fn: 10203.0000 - accuracy: 0.9214 - precision: 0.9118 - recall: 0.9328 - auc: 0.9769 - prc: 0.9745 - val_loss: 0.1943 - val_tp: 35081.0000 - val_fp: 3144.0000 - val_tn: 34860.0000 - val_fn: 2897.0000 - val_accuracy: 0.9205 - val_precision: 0.9178 - val_recall: 0.9237 - val_auc: 0.9763 - val_prc: 0.9734
# Epoch 335/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1911 - tp: 141653.0000 - fp: 13703.0000 - tn: 138441.0000 - fn: 10128.0000 - accuracy: 0.9216 - precision: 0.9118 - recall: 0.9333 - auc: 0.9770 - prc: 0.9746 - val_loss: 0.1950 - val_tp: 35655.0000 - val_fp: 3678.0000 - val_tn: 34326.0000 - val_fn: 2323.0000 - val_accuracy: 0.9210 - val_precision: 0.9065 - val_recall: 0.9388 - val_auc: 0.9761 - val_prc: 0.9728
# Epoch 336/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1913 - tp: 141649.0000 - fp: 13784.0000 - tn: 138360.0000 - fn: 10132.0000 - accuracy: 0.9213 - precision: 0.9113 - recall: 0.9332 - auc: 0.9770 - prc: 0.9746 - val_loss: 0.1947 - val_tp: 34861.0000 - val_fp: 3039.0000 - val_tn: 34965.0000 - val_fn: 3117.0000 - val_accuracy: 0.9190 - val_precision: 0.9198 - val_recall: 0.9179 - val_auc: 0.9762 - val_prc: 0.9732
# Epoch 337/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1916 - tp: 141459.0000 - fp: 13700.0000 - tn: 138444.0000 - fn: 10322.0000 - accuracy: 0.9210 - precision: 0.9117 - recall: 0.9320 - auc: 0.9769 - prc: 0.9745 - val_loss: 0.1948 - val_tp: 35687.0000 - val_fp: 3770.0000 - val_tn: 34234.0000 - val_fn: 2291.0000 - val_accuracy: 0.9202 - val_precision: 0.9045 - val_recall: 0.9397 - val_auc: 0.9760 - val_prc: 0.9728
# Epoch 338/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1912 - tp: 141613.0000 - fp: 13712.0000 - tn: 138432.0000 - fn: 10168.0000 - accuracy: 0.9214 - precision: 0.9117 - recall: 0.9330 - auc: 0.9770 - prc: 0.9746 - val_loss: 0.1944 - val_tp: 35522.0000 - val_fp: 3538.0000 - val_tn: 34466.0000 - val_fn: 2456.0000 - val_accuracy: 0.9211 - val_precision: 0.9094 - val_recall: 0.9353 - val_auc: 0.9762 - val_prc: 0.9731
# Epoch 339/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1908 - tp: 141596.0000 - fp: 13625.0000 - tn: 138519.0000 - fn: 10185.0000 - accuracy: 0.9217 - precision: 0.9122 - recall: 0.9329 - auc: 0.9771 - prc: 0.9747 - val_loss: 0.1935 - val_tp: 35364.0000 - val_fp: 3415.0000 - val_tn: 34589.0000 - val_fn: 2614.0000 - val_accuracy: 0.9207 - val_precision: 0.9119 - val_recall: 0.9312 - val_auc: 0.9763 - val_prc: 0.9732
# Epoch 340/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1906 - tp: 141595.0000 - fp: 13603.0000 - tn: 138541.0000 - fn: 10186.0000 - accuracy: 0.9217 - precision: 0.9124 - recall: 0.9329 - auc: 0.9771 - prc: 0.9748 - val_loss: 0.1954 - val_tp: 35908.0000 - val_fp: 4061.0000 - val_tn: 33943.0000 - val_fn: 2070.0000 - val_accuracy: 0.9193 - val_precision: 0.8984 - val_recall: 0.9455 - val_auc: 0.9762 - val_prc: 0.9731
# Epoch 341/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1907 - tp: 141596.0000 - fp: 13672.0000 - tn: 138472.0000 - fn: 10185.0000 - accuracy: 0.9215 - precision: 0.9119 - recall: 0.9329 - auc: 0.9771 - prc: 0.9748 - val_loss: 0.1949 - val_tp: 35764.0000 - val_fp: 3781.0000 - val_tn: 34223.0000 - val_fn: 2214.0000 - val_accuracy: 0.9211 - val_precision: 0.9044 - val_recall: 0.9417 - val_auc: 0.9761 - val_prc: 0.9729
# Epoch 342/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1903 - tp: 141720.0000 - fp: 13624.0000 - tn: 138520.0000 - fn: 10061.0000 - accuracy: 0.9221 - precision: 0.9123 - recall: 0.9337 - auc: 0.9772 - prc: 0.9748 - val_loss: 0.1932 - val_tp: 35386.0000 - val_fp: 3365.0000 - val_tn: 34639.0000 - val_fn: 2592.0000 - val_accuracy: 0.9216 - val_precision: 0.9132 - val_recall: 0.9317 - val_auc: 0.9764 - val_prc: 0.9732
# Epoch 343/500
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1902 - tp: 141700.0000 - fp: 13712.0000 - tn: 138432.0000 - fn: 10081.0000 - accuracy: 0.9217 - precision: 0.9118 - recall: 0.9336 - auc: 0.9772 - prc: 0.9749 - val_loss: 0.1952 - val_tp: 34709.0000 - val_fp: 2876.0000 - val_tn: 35128.0000 - val_fn: 3269.0000 - val_accuracy: 0.9191 - val_precision: 0.9235 - val_recall: 0.9139 - val_auc: 0.9763 - val_prc: 0.9733
# Epoch 344/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1911 - tp: 141454.0000 - fp: 13630.0000 - tn: 138514.0000 - fn: 10327.0000 - accuracy: 0.9212 - precision: 0.9121 - recall: 0.9320 - auc: 0.9770 - prc: 0.9747 - val_loss: 0.1928 - val_tp: 35571.0000 - val_fp: 3519.0000 - val_tn: 34485.0000 - val_fn: 2407.0000 - val_accuracy: 0.9220 - val_precision: 0.9100 - val_recall: 0.9366 - val_auc: 0.9764 - val_prc: 0.9733
# Restoring model weights from the end of the best epoch.
# Epoch 00344: early stopping
# loss :  0.19185538589954376 /n
# tp :  43955.0 /n
# fp :  3921.0 /n
# tn :  43373.0 /n
# fn :  3728.0 /n
# accuracy :  0.9194647073745728 /n
# precision :  0.9181009531021118 /n
# recall :  0.9218170046806335 /n
# auc :  0.9769722819328308 /n
# prc :  0.9747359156608582 /n
# True Negatives:  43373
# False Positives:  3921
# False Negatives:  3728
# True Positives:  43955
# Total:  47683
# INFO:tensorflow:Assets written to: C:\Users\angel\AppData\Local\Temp\tmphz_b4c8k\model\data\model\assets

# %% [markdown]
# ## 5. Register Model

# %%
model_uri = "runs:/{}/{}".format(run.info.run_id, model_name)
mv = mlflow.register_model(model_uri, model_name)
print("Name: {}".format(mv.name))
print("Version: {}".format(mv.version))
# Out:
# Successfully registered model 'cut_stop_posenet'.
# 2021/05/17 21:28:29 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: cut_stop_posenet, version 1
# Name: cut_stop_posenet
# Version: 1
# Created version '1' of model 'cut_stop_posenet'.
