# %% [markdown]
# # Model to Classify Stop positions in PoseNet dataset
#
# Section for configurations and imports.

# %%
import os 
import tempfile

import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow import keras

# MLflow dashboard
import mlflow
mlflow.set_tracking_uri('http://35.228.45.76:5000')
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='../../keys/mlflow-312506-8cfad529f4fd.json'

# Import data augmentation
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from augmentation.methods import *

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
random_state = 47
np.random.seed(random_state)

# %%
physical_devices = tf.config.experimental.list_physical_devices( 'GPU' )
print( 'Num GPUs Available: ', len( physical_devices ) )
if len( physical_devices ) > 0:
    tf.config.experimental.set_memory_growth( physical_devices[0], True )
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # 1. Data Preparation
# ## 1.1 Load Kinect files
#
# These files are marked start and stop frames in one-hot encoding. <br />
# We're only interested in the 'start' column.

# %%
data_path = '../../datasets/marked_start_end/'

df = None

# %%
for file in os.listdir(data_path):
    if file.endswith('.csv') and 'kinect' not in file:
        try:
            dataset = pd.read_csv(data_path + file)
            dataset.drop(columns=['FrameNo'], inplace=True)
            dataset.drop(columns=['start'], inplace=True)

            if df is None:
                df = dataset
            else:
                df = pd.concat((df, dataset), ignore_index=True)

        except IOError as e:
            print('Error in reading file: ', e)

print(df.shape)
# Out:
# (38488, 27)

# %% [markdown]
# ## 1.2 Data Augmentation
#
# ### Mirror X coordinate

# %%
df = mirror(df,'x', append=True)
print(df.shape)
# Out:
# (76976, 27)

# %% [markdown]
# ## 1.3 Check Class Imbalance
#
# This shows the small fraction of start frames.

# %%
X = df.drop(columns=['end'])
y = df['end']

# %%
print(
    'Total: {}\n\nNone: {} ({:.2f}% of total)\nEnd: {} ({:.2f}% of total)\n'
    .format(
      len(y), 
      len(y.values[y.values == 0]),
      len(y.values[y.values == 0]) / len(y),
      len(y.values[y.values == 1]),
      len(y.values[y.values == 1]) / len(y)
    )
  )
# Out:
# Total: 76976
#
# None: 62682 (0.81% of total)
# End: 14294 (0.19% of total)

# %% [markdown]
# ## 1.4 Oversample the minority class

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=random_state) # Perform oversamling using SMOTE
resampled_X, resampled_y = sm.fit_resample(X, y)

print(resampled_X.shape)
print(resampled_y.shape)
# Out:
# (125364, 26)
# (125364,)

# %%
print(
    'Total: {}\n\nNone: {} ({:.2f}% of total)\nEnd: {} ({:.2f}% of total)\n'
    .format(
      len(resampled_y), 
      len(resampled_y.values[resampled_y.values == 0]),
      len(resampled_y.values[resampled_y.values == 0]) / len(resampled_y),
      len(resampled_y.values[resampled_y.values == 1]),
      len(resampled_y.values[resampled_y.values == 1]) / len(resampled_y)
    )
  )
# Out:
# Total: 125364
#
# None: 62682 (0.50% of total)
# End: 62682 (0.50% of total)

# %% [markdown]
# ## 1.5 Split and normalize the data
#
# We already dropped the 'FrameNo' and 'start' columns when the data was loading. <br />
# Now, we'll split the dataset into train, validation, and test sets:
#
# - The validation set is used during model fitting to evaluate the loss and other evaluation metrics.
# - The test set is unused during the training phase and is used at the end to evaluate how well the model generalizes to new data (i.e. a holdout set). This is especially important with imbalanced datasets where overfitting is a significant concern from the lack of training data.
#
# We also normalize the input features using the sklearn StandardScaler. StandardScaler is only fit using X_train. As we want to deploy a model, it's critical that you preserve the preprocessing calculations. The easiest way to implement them as layers, and attach them to your model before export.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(resampled_X, resampled_y, test_size=0.2, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

print('Training labels shape:', y_train.shape)
print('Validation labels shape:', y_val.shape)
print('Test labels shape:', y_test.shape, '\n')

print('Training features shape:', X_train.shape)
print('Validation features shape:', X_val.shape)
print('Test features shape:', X_test.shape)
# Out:
# Training labels shape: (80232,)
# Validation labels shape: (20059,)
# Test labels shape: (25073,)
#
# Training features shape: (80232, 26)
# Validation features shape: (20059, 26)
# Test features shape: (25073, 26)

# %% [markdown]
# # 2. Define the Model and Metrics
#
# ## 2.1 Layer Factory

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %% [markdown]
# ## 2.2 Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer

def make_model(metrics, layers, optimizer, input_dim, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %% [markdown]
# # 3. Build the Model
#
# 3.1 Estimate the initial bias
# We're going to keep the initial model's weights in a checkpoint file and load them into each model before training so the model doesn't need to spend the first few epochs just learning that start frames are unlikely. Therefore, we start by estimating the initial bias before defining the model.

# %%
neg, pos = np.bincount(y)

initial_bias = np.log([pos/neg])
initial_bias
# Out:
# array([-1.47823446])

# %% [markdown]
# ## 3.2 Define the Model and Evaluation Metrics
#
# We're using standard evaluation metrics for binary classification problems.
#
# The **make_model** function returns a model based on parameter values. It uses the Layer Factory for creating the model.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(layers, input_dim, loss, optimizer, learning_rate=0.001, metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %%
output_bias = tf.keras.initializers.Constant(initial_bias)
input_dim = X_train.shape[1]
output_size = 1

units = 32
activation = 'tanh'
kernel_initializer = 'he_uniform'
output_activation = 'sigmoid'
optimizer = 'Adam'
learning_rate = 1e-4

LAYERS = [ 
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':64, 'activation': 'relu', 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':64, 'activation': 'relu', 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':output_size, 'activation': output_activation, 'bias_initializer': initial_bias }
]

model = make_model(layers=LAYERS, input_dim=input_dim, loss='binary_crossentropy', optimizer=optimizer, learning_rate=learning_rate, output_bias=output_bias)

model.predict(X_train[:10])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                864
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,305
# Trainable params: 10,305
# Non-trainable params: 0
# _________________________________________________________________
# None
# array([[0.43594423],
#        [0.5035709 ],
#        [0.42934975],
#        [0.4400295 ],
#        [0.59637856],
#        [0.5520672 ],
#        [0.43286434],
#        [0.5935793 ],
#        [0.4248675 ],
#        [0.6566592 ]], dtype=float32)

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.6914

# %%
initial_weights = os.path.join(tempfile.mkdtemp(), 'initial_weights')
model.save_weights(initial_weights)

# %% [markdown]
# ## 3.3 Add Class Weights

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

print('Weight for class 0:', class_weights[0])
print('Weight for class 1:', class_weights[1])
# Out:
# Weight for class 0: 1.0009481511053446
# Weight for class 1: 0.9990536434726304

# %% [markdown]
# # 4. MLflow Experimentation
# ## 4.1 Define learning parameters for all models

# %%
from keras.callbacks import EarlyStopping

EPOCHS = 500
BATCH_SIZE = 5000

early_stopping = EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ## 4.2 Define Experimentation Configurations
# The Model signature in MLflow defines the schema of a model's inputs and outputs.

# %%
from mlflow.models.signature import ModelSignature
from mlflow.types.schema import Schema, ColSpec

input_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "leftShoulder_x"),
    ColSpec("double", "leftShoulder_y"),
    ColSpec("double", "leftElbow_x"),
    ColSpec("double", "leftElbow_y"),
    ColSpec("double", "rightShoulder_x"),
    ColSpec("double", "rightShoulder_y"),
    ColSpec("double", "rightElbow_x"),
    ColSpec("double", "rightElbow_y"),
    ColSpec("double", "leftHand_x"),
    ColSpec("double", "leftHand_y"),
    ColSpec("double", "rightHand_x"),
    ColSpec("double", "rightHand_y"),
    ColSpec("double", "leftHip_x"),
    ColSpec("double", "leftHip_y"),
    ColSpec("double", "rightHip_x"),
    ColSpec("double", "rightHip_y"),
    ColSpec("double", "leftKnee_x"),
    ColSpec("double", "leftKnee_y"),
    ColSpec("double", "rightKnee_x"),
    ColSpec("double", "rightKnee_y"),
    ColSpec("double", "leftFoot_x"),
    ColSpec("double", "leftFoot_y"),
    ColSpec("double", "rightFoot_x"),
    ColSpec("double", "rightFoot_y"),
])
output_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "leftShoulder_x"),
    ColSpec("double", "leftShoulder_y"),
    ColSpec("double", "leftElbow_x"),
    ColSpec("double", "leftElbow_y"),
    ColSpec("double", "rightShoulder_x"),
    ColSpec("double", "rightShoulder_y"),
    ColSpec("double", "rightElbow_x"),
    ColSpec("double", "rightElbow_y"),
    ColSpec("double", "leftHand_x"),
    ColSpec("double", "leftHand_y"),
    ColSpec("double", "rightHand_x"),
    ColSpec("double", "rightHand_y"),
    ColSpec("double", "leftHip_x"),
    ColSpec("double", "leftHip_y"),
    ColSpec("double", "rightHip_x"),
    ColSpec("double", "rightHip_y"),
    ColSpec("double", "leftKnee_x"),
    ColSpec("double", "leftKnee_y"),
    ColSpec("double", "rightKnee_x"),
    ColSpec("double", "rightKnee_y"),
    ColSpec("double", "leftFoot_x"),
    ColSpec("double", "leftFoot_y"),
    ColSpec("double", "rightFoot_x"),
    ColSpec("double", "rightFoot_y"),
])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# %% [markdown]
# ## 4.3 Functions used in the experimentation
#
# For creating plots and others.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

def plot_loss(history, label, n):
  plt.semilogy(history.epoch, history.history['loss'],
               color=colors[n], label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               color=colors[n], label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('True Negatives: ', cm[0][0])
    print('False Positives: ', cm[0][1])
    print('False Negatives: ', cm[1][0])
    print('True Positives: ', cm[1][1])
    print('Total: ', np.sum(cm[1]))


def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# ## 4.4 Start run
# Starting a run which fits the model according to chosen parameter values, then makes predictions and saves selected values to MLflow dashboard.

# %%
model_name = 'cut_stop_posenet'

with mlflow.start_run(run_name=model_name) as run:

    run_id = run.info.run_id

    model = make_model(metrics=METRICS, 
                        layers=LAYERS, 
                        loss='binary_crossentropy', 
                        optimizer=optimizer, 
                        learning_rate=learning_rate, 
                        output_bias=initial_bias, 
                        input_dim=input_dim)
    model.load_weights(initial_weights)
    model.layers[-1].bias.assign([0.0])
    
    with tf.device('/CPU:0'):
        history = model.fit(
            x=X_train, 
            y=y_train, 
            class_weight=class_weight_dict, 
            validation_data=(X_val, y_val), 
            shuffle=True, 
            epochs=EPOCHS, 
            verbose=1,
            batch_size=BATCH_SIZE, 
            callbacks=[early_stopping])

        # Plot training history
        plot_loss(history, "Bias", 0)
        plt.savefig("loss.jpg")
        mlflow.log_artifact("loss.jpg")
        plt.show()
        
        # Plot and log metrics
        predictions_train = model.predict(X_train)
        predictions_test = model.predict(X_test)

        plot_metrics(history)
        plt.savefig("metrics.jpg")
        mlflow.log_artifact("metrics.jpg")
        plt.show()

        # Confusion matrix
        results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
        for name, value in zip(model.metrics_names, results):
            print(name, ': ', value, '/n')
        plot_cm(y_test, predictions_test)
        plt.savefig("cm.jpg")
        mlflow.log_artifact("cm.jpg")
        plt.show()

        # ROC Curve
        plot_roc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("roc.jpg")
        mlflow.log_artifact("roc.jpg")
        plt.show()

        # Precision-Recall Curve (PRC)
        plot_prc("Train Predictions", y_train, predictions_train, color=colors[0])
        plot_prc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("prc.jpg")
        mlflow.log_artifact("prc.jpg")
        plt.show()
        
        # Log model, scaler, model parameters to MLflow
        mlflow.log_param("units", units)
        mlflow.log_param("activation", activation)
        mlflow.log_param("kernel_initializer", kernel_initializer)
        mlflow.log_param("output activation", output_activation)
        mlflow.log_param("optimizer", optimizer)
        mlflow.log_param("learning rate", learning_rate)
        mlflow.log_param("batch size", BATCH_SIZE)
        mlflow.log_metric("accuracy", results[5])
        mlflow.log_metric("average precision score", results[6])
        mlflow.log_metric("recall", results[7])
        mlflow.log_metric("auc", results[8])

        mlflow.keras.log_model(model, model_name, signature=signature)
        mlflow.sklearn.log_model(scaler, 'InputScaler')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 32)                864
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 10,305
# Trainable params: 10,305
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\angel\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/500
# 17/17 [==============================] - 3s 63ms/step - loss: 0.6726 - tp: 50470.0000 - fp: 40690.0000 - tn: 39466.0000 - fn: 29838.0000 - accuracy: 0.5605 - precision: 0.5536 - recall: 0.6285 - auc: 0.5816 - prc: 0.5729 - val_loss: 0.6521 - val_tp: 5309.0000 - val_fp: 2820.0000 - val_tn: 7211.0000 - val_fn: 4719.0000 - val_accuracy: 0.6242 - val_precision: 0.6531 - val_recall: 0.5294 - val_auc: 0.6812 - val_prc: 0.7278
# Epoch 2/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6413 - tp: 19332.0000 - fp: 6349.0000 - tn: 33729.0000 - fn: 20822.0000 - accuracy: 0.6613 - precision: 0.7528 - recall: 0.4814 - auc: 0.7023 - prc: 0.7528 - val_loss: 0.6273 - val_tp: 4682.0000 - val_fp: 1126.0000 - val_tn: 8905.0000 - val_fn: 5346.0000 - val_accuracy: 0.6774 - val_precision: 0.8061 - val_recall: 0.4669 - val_auc: 0.7195 - val_prc: 0.7715
# Epoch 3/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.6197 - tp: 18705.0000 - fp: 4845.0000 - tn: 35233.0000 - fn: 21449.0000 - accuracy: 0.6723 - precision: 0.7943 - recall: 0.4658 - auc: 0.7213 - prc: 0.7704 - val_loss: 0.6091 - val_tp: 4774.0000 - val_fp: 1281.0000 - val_tn: 8750.0000 - val_fn: 5254.0000 - val_accuracy: 0.6742 - val_precision: 0.7884 - val_recall: 0.4761 - val_auc: 0.7362 - val_prc: 0.7812
# Epoch 4/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.6040 - tp: 19039.0000 - fp: 5314.0000 - tn: 34764.0000 - fn: 21115.0000 - accuracy: 0.6706 - precision: 0.7818 - recall: 0.4741 - auc: 0.7407 - prc: 0.7815 - val_loss: 0.5961 - val_tp: 4823.0000 - val_fp: 1334.0000 - val_tn: 8697.0000 - val_fn: 5205.0000 - val_accuracy: 0.6740 - val_precision: 0.7833 - val_recall: 0.4810 - val_auc: 0.7547 - val_prc: 0.7900
# Epoch 5/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5930 - tp: 19128.0000 - fp: 5460.0000 - tn: 34618.0000 - fn: 21026.0000 - accuracy: 0.6699 - precision: 0.7779 - recall: 0.4764 - auc: 0.7595 - prc: 0.7909 - val_loss: 0.5870 - val_tp: 4858.0000 - val_fp: 1351.0000 - val_tn: 8680.0000 - val_fn: 5170.0000 - val_accuracy: 0.6749 - val_precision: 0.7824 - val_recall: 0.4844 - val_auc: 0.7664 - val_prc: 0.7958
# Epoch 6/500
# 17/17 [==============================] - 0s 18ms/step - loss: 0.5851 - tp: 19394.0000 - fp: 5538.0000 - tn: 34540.0000 - fn: 20760.0000 - accuracy: 0.6722 - precision: 0.7779 - recall: 0.4830 - auc: 0.7675 - prc: 0.7953 - val_loss: 0.5801 - val_tp: 4898.0000 - val_fp: 1376.0000 - val_tn: 8655.0000 - val_fn: 5130.0000 - val_accuracy: 0.6757 - val_precision: 0.7807 - val_recall: 0.4884 - val_auc: 0.7727 - val_prc: 0.7988
# Epoch 7/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5788 - tp: 19540.0000 - fp: 5593.0000 - tn: 34485.0000 - fn: 20614.0000 - accuracy: 0.6734 - precision: 0.7775 - recall: 0.4866 - auc: 0.7750 - prc: 0.7989 - val_loss: 0.5743 - val_tp: 4904.0000 - val_fp: 1378.0000 - val_tn: 8653.0000 - val_fn: 5124.0000 - val_accuracy: 0.6759 - val_precision: 0.7806 - val_recall: 0.4890 - val_auc: 0.7809 - val_prc: 0.8028
# Epoch 8/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5732 - tp: 19566.0000 - fp: 5563.0000 - tn: 34515.0000 - fn: 20588.0000 - accuracy: 0.6741 - precision: 0.7786 - recall: 0.4873 - auc: 0.7833 - prc: 0.8031 - val_loss: 0.5687 - val_tp: 4958.0000 - val_fp: 1394.0000 - val_tn: 8637.0000 - val_fn: 5070.0000 - val_accuracy: 0.6778 - val_precision: 0.7805 - val_recall: 0.4944 - val_auc: 0.7889 - val_prc: 0.8067
# Epoch 9/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5676 - tp: 19818.0000 - fp: 5698.0000 - tn: 34380.0000 - fn: 20336.0000 - accuracy: 0.6755 - precision: 0.7767 - recall: 0.4935 - auc: 0.7907 - prc: 0.8069 - val_loss: 0.5630 - val_tp: 4988.0000 - val_fp: 1405.0000 - val_tn: 8626.0000 - val_fn: 5040.0000 - val_accuracy: 0.6787 - val_precision: 0.7802 - val_recall: 0.4974 - val_auc: 0.7961 - val_prc: 0.8105
# Epoch 10/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5619 - tp: 19823.0000 - fp: 5616.0000 - tn: 34462.0000 - fn: 20331.0000 - accuracy: 0.6766 - precision: 0.7792 - recall: 0.4937 - auc: 0.7985 - prc: 0.8111 - val_loss: 0.5569 - val_tp: 5019.0000 - val_fp: 1397.0000 - val_tn: 8634.0000 - val_fn: 5009.0000 - val_accuracy: 0.6806 - val_precision: 0.7823 - val_recall: 0.5005 - val_auc: 0.8038 - val_prc: 0.8149
# Epoch 11/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5557 - tp: 20079.0000 - fp: 5622.0000 - tn: 34456.0000 - fn: 20075.0000 - accuracy: 0.6797 - precision: 0.7813 - recall: 0.5000 - auc: 0.8061 - prc: 0.8156 - val_loss: 0.5502 - val_tp: 5027.0000 - val_fp: 1360.0000 - val_tn: 8671.0000 - val_fn: 5001.0000 - val_accuracy: 0.6829 - val_precision: 0.7871 - val_recall: 0.5013 - val_auc: 0.8104 - val_prc: 0.8191
# Epoch 12/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5487 - tp: 20143.0000 - fp: 5373.0000 - tn: 34705.0000 - fn: 20011.0000 - accuracy: 0.6836 - precision: 0.7894 - recall: 0.5016 - auc: 0.8115 - prc: 0.8193 - val_loss: 0.5428 - val_tp: 5150.0000 - val_fp: 1328.0000 - val_tn: 8703.0000 - val_fn: 4878.0000 - val_accuracy: 0.6906 - val_precision: 0.7950 - val_recall: 0.5136 - val_auc: 0.8175 - val_prc: 0.8239
# Epoch 13/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5410 - tp: 20691.0000 - fp: 5361.0000 - tn: 34717.0000 - fn: 19463.0000 - accuracy: 0.6906 - precision: 0.7942 - recall: 0.5153 - auc: 0.8188 - prc: 0.8245 - val_loss: 0.5346 - val_tp: 5156.0000 - val_fp: 1272.0000 - val_tn: 8759.0000 - val_fn: 4872.0000 - val_accuracy: 0.6937 - val_precision: 0.8021 - val_recall: 0.5142 - val_auc: 0.8239 - val_prc: 0.8290
# Epoch 14/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5326 - tp: 20922.0000 - fp: 5285.0000 - tn: 34793.0000 - fn: 19232.0000 - accuracy: 0.6944 - precision: 0.7983 - recall: 0.5210 - auc: 0.8244 - prc: 0.8294 - val_loss: 0.5257 - val_tp: 5478.0000 - val_fp: 1385.0000 - val_tn: 8646.0000 - val_fn: 4550.0000 - val_accuracy: 0.7041 - val_precision: 0.7982 - val_recall: 0.5463 - val_auc: 0.8315 - val_prc: 0.8349
# Epoch 15/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5235 - tp: 22024.0000 - fp: 5621.0000 - tn: 34457.0000 - fn: 18130.0000 - accuracy: 0.7040 - precision: 0.7967 - recall: 0.5485 - auc: 0.8309 - prc: 0.8345 - val_loss: 0.5164 - val_tp: 5581.0000 - val_fp: 1364.0000 - val_tn: 8667.0000 - val_fn: 4447.0000 - val_accuracy: 0.7103 - val_precision: 0.8036 - val_recall: 0.5565 - val_auc: 0.8358 - val_prc: 0.8393
# Epoch 16/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.5139 - tp: 23223.0000 - fp: 5920.0000 - tn: 34158.0000 - fn: 16931.0000 - accuracy: 0.7152 - precision: 0.7969 - recall: 0.5783 - auc: 0.8358 - prc: 0.8392 - val_loss: 0.5067 - val_tp: 5809.0000 - val_fp: 1461.0000 - val_tn: 8570.0000 - val_fn: 4219.0000 - val_accuracy: 0.7168 - val_precision: 0.7990 - val_recall: 0.5793 - val_auc: 0.8417 - val_prc: 0.8436
# Epoch 17/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.5043 - tp: 24081.0000 - fp: 6123.0000 - tn: 33955.0000 - fn: 16073.0000 - accuracy: 0.7234 - precision: 0.7973 - recall: 0.5997 - auc: 0.8414 - prc: 0.8437 - val_loss: 0.4969 - val_tp: 6317.0000 - val_fp: 1630.0000 - val_tn: 8401.0000 - val_fn: 3711.0000 - val_accuracy: 0.7337 - val_precision: 0.7949 - val_recall: 0.6299 - val_auc: 0.8471 - val_prc: 0.8486
# Epoch 18/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4951 - tp: 25370.0000 - fp: 6622.0000 - tn: 33456.0000 - fn: 14784.0000 - accuracy: 0.7332 - precision: 0.7930 - recall: 0.6318 - auc: 0.8449 - prc: 0.8471 - val_loss: 0.4878 - val_tp: 6478.0000 - val_fp: 1684.0000 - val_tn: 8347.0000 - val_fn: 3550.0000 - val_accuracy: 0.7391 - val_precision: 0.7937 - val_recall: 0.6460 - val_auc: 0.8506 - val_prc: 0.8520
# Epoch 19/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4859 - tp: 26097.0000 - fp: 6922.0000 - tn: 33156.0000 - fn: 14057.0000 - accuracy: 0.7385 - precision: 0.7904 - recall: 0.6499 - auc: 0.8497 - prc: 0.8510 - val_loss: 0.4791 - val_tp: 6608.0000 - val_fp: 1733.0000 - val_tn: 8298.0000 - val_fn: 3420.0000 - val_accuracy: 0.7431 - val_precision: 0.7922 - val_recall: 0.6590 - val_auc: 0.8543 - val_prc: 0.8550
# Epoch 20/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4779 - tp: 26738.0000 - fp: 7328.0000 - tn: 32750.0000 - fn: 13416.0000 - accuracy: 0.7414 - precision: 0.7849 - recall: 0.6659 - auc: 0.8531 - prc: 0.8541 - val_loss: 0.4712 - val_tp: 6845.0000 - val_fp: 1902.0000 - val_tn: 8129.0000 - val_fn: 3183.0000 - val_accuracy: 0.7465 - val_precision: 0.7826 - val_recall: 0.6826 - val_auc: 0.8578 - val_prc: 0.8581
# Epoch 21/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4703 - tp: 27268.0000 - fp: 7596.0000 - tn: 32482.0000 - fn: 12886.0000 - accuracy: 0.7447 - precision: 0.7821 - recall: 0.6791 - auc: 0.8566 - prc: 0.8572 - val_loss: 0.4641 - val_tp: 6827.0000 - val_fp: 1844.0000 - val_tn: 8187.0000 - val_fn: 3201.0000 - val_accuracy: 0.7485 - val_precision: 0.7873 - val_recall: 0.6808 - val_auc: 0.8606 - val_prc: 0.8607
# Epoch 22/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4635 - tp: 27567.0000 - fp: 7681.0000 - tn: 32397.0000 - fn: 12587.0000 - accuracy: 0.7474 - precision: 0.7821 - recall: 0.6865 - auc: 0.8596 - prc: 0.8598 - val_loss: 0.4577 - val_tp: 7019.0000 - val_fp: 1973.0000 - val_tn: 8058.0000 - val_fn: 3009.0000 - val_accuracy: 0.7516 - val_precision: 0.7806 - val_recall: 0.6999 - val_auc: 0.8637 - val_prc: 0.8635
# Epoch 23/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4574 - tp: 27948.0000 - fp: 7959.0000 - tn: 32119.0000 - fn: 12206.0000 - accuracy: 0.7487 - precision: 0.7783 - recall: 0.6960 - auc: 0.8628 - prc: 0.8624 - val_loss: 0.4517 - val_tp: 6930.0000 - val_fp: 1882.0000 - val_tn: 8149.0000 - val_fn: 3098.0000 - val_accuracy: 0.7517 - val_precision: 0.7864 - val_recall: 0.6911 - val_auc: 0.8669 - val_prc: 0.8658
# Epoch 24/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4520 - tp: 28156.0000 - fp: 8128.0000 - tn: 31950.0000 - fn: 11998.0000 - accuracy: 0.7492 - precision: 0.7760 - recall: 0.7012 - auc: 0.8649 - prc: 0.8642 - val_loss: 0.4461 - val_tp: 6999.0000 - val_fp: 1922.0000 - val_tn: 8109.0000 - val_fn: 3029.0000 - val_accuracy: 0.7532 - val_precision: 0.7846 - val_recall: 0.6979 - val_auc: 0.8693 - val_prc: 0.8677
# Epoch 25/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4463 - tp: 28398.0000 - fp: 8219.0000 - tn: 31859.0000 - fn: 11756.0000 - accuracy: 0.7510 - precision: 0.7755 - recall: 0.7072 - auc: 0.8678 - prc: 0.8661 - val_loss: 0.4415 - val_tp: 7280.0000 - val_fp: 2150.0000 - val_tn: 7881.0000 - val_fn: 2748.0000 - val_accuracy: 0.7558 - val_precision: 0.7720 - val_recall: 0.7260 - val_auc: 0.8708 - val_prc: 0.8689
# Epoch 26/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4414 - tp: 28963.0000 - fp: 8631.0000 - tn: 31447.0000 - fn: 11191.0000 - accuracy: 0.7529 - precision: 0.7704 - recall: 0.7213 - auc: 0.8698 - prc: 0.8678 - val_loss: 0.4363 - val_tp: 7353.0000 - val_fp: 2215.0000 - val_tn: 7816.0000 - val_fn: 2675.0000 - val_accuracy: 0.7562 - val_precision: 0.7685 - val_recall: 0.7332 - val_auc: 0.8736 - val_prc: 0.8710
# Epoch 27/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4370 - tp: 29268.0000 - fp: 8831.0000 - tn: 31247.0000 - fn: 10886.0000 - accuracy: 0.7543 - precision: 0.7682 - recall: 0.7289 - auc: 0.8720 - prc: 0.8695 - val_loss: 0.4318 - val_tp: 7413.0000 - val_fp: 2194.0000 - val_tn: 7837.0000 - val_fn: 2615.0000 - val_accuracy: 0.7603 - val_precision: 0.7716 - val_recall: 0.7392 - val_auc: 0.8762 - val_prc: 0.8730
# Epoch 28/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4328 - tp: 29404.0000 - fp: 8761.0000 - tn: 31317.0000 - fn: 10750.0000 - accuracy: 0.7568 - precision: 0.7704 - recall: 0.7323 - auc: 0.8741 - prc: 0.8714 - val_loss: 0.4282 - val_tp: 7843.0000 - val_fp: 2456.0000 - val_tn: 7575.0000 - val_fn: 2185.0000 - val_accuracy: 0.7686 - val_precision: 0.7615 - val_recall: 0.7821 - val_auc: 0.8785 - val_prc: 0.8750
# Epoch 29/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4290 - tp: 30100.0000 - fp: 9035.0000 - tn: 31043.0000 - fn: 10054.0000 - accuracy: 0.7621 - precision: 0.7691 - recall: 0.7496 - auc: 0.8760 - prc: 0.8730 - val_loss: 0.4245 - val_tp: 8024.0000 - val_fp: 2533.0000 - val_tn: 7498.0000 - val_fn: 2004.0000 - val_accuracy: 0.7738 - val_precision: 0.7601 - val_recall: 0.8002 - val_auc: 0.8807 - val_prc: 0.8771
# Epoch 30/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4252 - tp: 30835.0000 - fp: 9233.0000 - tn: 30845.0000 - fn: 9319.0000 - accuracy: 0.7688 - precision: 0.7696 - recall: 0.7679 - auc: 0.8780 - prc: 0.8749 - val_loss: 0.4200 - val_tp: 7789.0000 - val_fp: 2321.0000 - val_tn: 7710.0000 - val_fn: 2239.0000 - val_accuracy: 0.7727 - val_precision: 0.7704 - val_recall: 0.7767 - val_auc: 0.8825 - val_prc: 0.8785
# Epoch 31/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4212 - tp: 30712.0000 - fp: 8934.0000 - tn: 31144.0000 - fn: 9442.0000 - accuracy: 0.7710 - precision: 0.7747 - recall: 0.7649 - auc: 0.8802 - prc: 0.8769 - val_loss: 0.4162 - val_tp: 7643.0000 - val_fp: 2147.0000 - val_tn: 7884.0000 - val_fn: 2385.0000 - val_accuracy: 0.7741 - val_precision: 0.7807 - val_recall: 0.7622 - val_auc: 0.8842 - val_prc: 0.8802
# Epoch 32/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4174 - tp: 30769.0000 - fp: 8728.0000 - tn: 31350.0000 - fn: 9385.0000 - accuracy: 0.7742 - precision: 0.7790 - recall: 0.7663 - auc: 0.8824 - prc: 0.8791 - val_loss: 0.4127 - val_tp: 7822.0000 - val_fp: 2231.0000 - val_tn: 7800.0000 - val_fn: 2206.0000 - val_accuracy: 0.7788 - val_precision: 0.7781 - val_recall: 0.7800 - val_auc: 0.8864 - val_prc: 0.8824
# Epoch 33/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4139 - tp: 31292.0000 - fp: 8904.0000 - tn: 31174.0000 - fn: 8862.0000 - accuracy: 0.7786 - precision: 0.7785 - recall: 0.7793 - auc: 0.8842 - prc: 0.8810 - val_loss: 0.4098 - val_tp: 7663.0000 - val_fp: 2100.0000 - val_tn: 7931.0000 - val_fn: 2365.0000 - val_accuracy: 0.7774 - val_precision: 0.7849 - val_recall: 0.7642 - val_auc: 0.8872 - val_prc: 0.8834
# Epoch 34/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.4111 - tp: 31425.0000 - fp: 8857.0000 - tn: 31221.0000 - fn: 8729.0000 - accuracy: 0.7808 - precision: 0.7801 - recall: 0.7826 - auc: 0.8858 - prc: 0.8827 - val_loss: 0.4063 - val_tp: 8083.0000 - val_fp: 2302.0000 - val_tn: 7729.0000 - val_fn: 1945.0000 - val_accuracy: 0.7883 - val_precision: 0.7783 - val_recall: 0.8060 - val_auc: 0.8899 - val_prc: 0.8861
# Epoch 35/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4074 - tp: 31986.0000 - fp: 9017.0000 - tn: 31061.0000 - fn: 8168.0000 - accuracy: 0.7858 - precision: 0.7801 - recall: 0.7966 - auc: 0.8883 - prc: 0.8851 - val_loss: 0.4028 - val_tp: 8153.0000 - val_fp: 2289.0000 - val_tn: 7742.0000 - val_fn: 1875.0000 - val_accuracy: 0.7924 - val_precision: 0.7808 - val_recall: 0.8130 - val_auc: 0.8922 - val_prc: 0.8884
# Epoch 36/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.4040 - tp: 32224.0000 - fp: 8959.0000 - tn: 31119.0000 - fn: 7930.0000 - accuracy: 0.7895 - precision: 0.7825 - recall: 0.8025 - auc: 0.8904 - prc: 0.8873 - val_loss: 0.3995 - val_tp: 8123.0000 - val_fp: 2243.0000 - val_tn: 7788.0000 - val_fn: 1905.0000 - val_accuracy: 0.7932 - val_precision: 0.7836 - val_recall: 0.8100 - val_auc: 0.8940 - val_prc: 0.8903
# Epoch 37/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.4009 - tp: 32332.0000 - fp: 8803.0000 - tn: 31275.0000 - fn: 7822.0000 - accuracy: 0.7928 - precision: 0.7860 - recall: 0.8052 - auc: 0.8924 - prc: 0.8894 - val_loss: 0.3968 - val_tp: 7746.0000 - val_fp: 1909.0000 - val_tn: 8122.0000 - val_fn: 2282.0000 - val_accuracy: 0.7911 - val_precision: 0.8023 - val_recall: 0.7724 - val_auc: 0.8956 - val_prc: 0.8920
# Epoch 38/500
# 17/17 [==============================] - 0s 17ms/step - loss: 0.3980 - tp: 32244.0000 - fp: 8608.0000 - tn: 31470.0000 - fn: 7910.0000 - accuracy: 0.7941 - precision: 0.7893 - recall: 0.8030 - auc: 0.8938 - prc: 0.8911 - val_loss: 0.3930 - val_tp: 8077.0000 - val_fp: 2103.0000 - val_tn: 7928.0000 - val_fn: 1951.0000 - val_accuracy: 0.7979 - val_precision: 0.7934 - val_recall: 0.8054 - val_auc: 0.8978 - val_prc: 0.8944
# Epoch 39/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3947 - tp: 32901.0000 - fp: 8927.0000 - tn: 31151.0000 - fn: 7253.0000 - accuracy: 0.7983 - precision: 0.7866 - recall: 0.8194 - auc: 0.8959 - prc: 0.8934 - val_loss: 0.3905 - val_tp: 8146.0000 - val_fp: 2094.0000 - val_tn: 7937.0000 - val_fn: 1882.0000 - val_accuracy: 0.8018 - val_precision: 0.7955 - val_recall: 0.8123 - val_auc: 0.8990 - val_prc: 0.8961
# Epoch 40/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3916 - tp: 32671.0000 - fp: 8487.0000 - tn: 31591.0000 - fn: 7483.0000 - accuracy: 0.8010 - precision: 0.7938 - recall: 0.8136 - auc: 0.8979 - prc: 0.8957 - val_loss: 0.3871 - val_tp: 8435.0000 - val_fp: 2208.0000 - val_tn: 7823.0000 - val_fn: 1593.0000 - val_accuracy: 0.8105 - val_precision: 0.7925 - val_recall: 0.8411 - val_auc: 0.9018 - val_prc: 0.8988
# Epoch 41/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.3883 - tp: 33267.0000 - fp: 8724.0000 - tn: 31354.0000 - fn: 6887.0000 - accuracy: 0.8054 - precision: 0.7922 - recall: 0.8285 - auc: 0.9003 - prc: 0.8982 - val_loss: 0.3839 - val_tp: 8400.0000 - val_fp: 2184.0000 - val_tn: 7847.0000 - val_fn: 1628.0000 - val_accuracy: 0.8100 - val_precision: 0.7937 - val_recall: 0.8377 - val_auc: 0.9033 - val_prc: 0.9005
# Epoch 42/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3853 - tp: 33264.0000 - fp: 8538.0000 - tn: 31540.0000 - fn: 6890.0000 - accuracy: 0.8077 - precision: 0.7958 - recall: 0.8284 - auc: 0.9019 - prc: 0.9000 - val_loss: 0.3816 - val_tp: 8454.0000 - val_fp: 2213.0000 - val_tn: 7818.0000 - val_fn: 1574.0000 - val_accuracy: 0.8112 - val_precision: 0.7925 - val_recall: 0.8430 - val_auc: 0.9041 - val_prc: 0.9016
# Epoch 43/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3824 - tp: 33257.0000 - fp: 8361.0000 - tn: 31717.0000 - fn: 6897.0000 - accuracy: 0.8098 - precision: 0.7991 - recall: 0.8282 - auc: 0.9032 - prc: 0.9015 - val_loss: 0.3778 - val_tp: 8316.0000 - val_fp: 2044.0000 - val_tn: 7987.0000 - val_fn: 1712.0000 - val_accuracy: 0.8128 - val_precision: 0.8027 - val_recall: 0.8293 - val_auc: 0.9064 - val_prc: 0.9043
# Epoch 44/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3791 - tp: 33190.0000 - fp: 8189.0000 - tn: 31889.0000 - fn: 6964.0000 - accuracy: 0.8111 - precision: 0.8021 - recall: 0.8266 - auc: 0.9050 - prc: 0.9037 - val_loss: 0.3748 - val_tp: 8337.0000 - val_fp: 2004.0000 - val_tn: 8027.0000 - val_fn: 1691.0000 - val_accuracy: 0.8158 - val_precision: 0.8062 - val_recall: 0.8314 - val_auc: 0.9080 - val_prc: 0.9061
# Epoch 45/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3760 - tp: 33374.0000 - fp: 8216.0000 - tn: 31862.0000 - fn: 6780.0000 - accuracy: 0.8131 - precision: 0.8025 - recall: 0.8312 - auc: 0.9068 - prc: 0.9058 - val_loss: 0.3719 - val_tp: 8469.0000 - val_fp: 2070.0000 - val_tn: 7961.0000 - val_fn: 1559.0000 - val_accuracy: 0.8191 - val_precision: 0.8036 - val_recall: 0.8445 - val_auc: 0.9096 - val_prc: 0.9078
# Epoch 46/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3733 - tp: 33597.0000 - fp: 8203.0000 - tn: 31875.0000 - fn: 6557.0000 - accuracy: 0.8160 - precision: 0.8038 - recall: 0.8367 - auc: 0.9083 - prc: 0.9076 - val_loss: 0.3689 - val_tp: 8464.0000 - val_fp: 2078.0000 - val_tn: 7953.0000 - val_fn: 1564.0000 - val_accuracy: 0.8184 - val_precision: 0.8029 - val_recall: 0.8440 - val_auc: 0.9112 - val_prc: 0.9099
# Epoch 47/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3704 - tp: 33591.0000 - fp: 8145.0000 - tn: 31933.0000 - fn: 6563.0000 - accuracy: 0.8167 - precision: 0.8048 - recall: 0.8366 - auc: 0.9099 - prc: 0.9095 - val_loss: 0.3659 - val_tp: 8347.0000 - val_fp: 1930.0000 - val_tn: 8101.0000 - val_fn: 1681.0000 - val_accuracy: 0.8200 - val_precision: 0.8122 - val_recall: 0.8324 - val_auc: 0.9128 - val_prc: 0.9117
# Epoch 48/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3673 - tp: 33602.0000 - fp: 8070.0000 - tn: 32008.0000 - fn: 6552.0000 - accuracy: 0.8178 - precision: 0.8063 - recall: 0.8368 - auc: 0.9115 - prc: 0.9113 - val_loss: 0.3632 - val_tp: 8388.0000 - val_fp: 1947.0000 - val_tn: 8084.0000 - val_fn: 1640.0000 - val_accuracy: 0.8212 - val_precision: 0.8116 - val_recall: 0.8365 - val_auc: 0.9138 - val_prc: 0.9131
# Epoch 49/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3647 - tp: 33471.0000 - fp: 7797.0000 - tn: 32281.0000 - fn: 6683.0000 - accuracy: 0.8195 - precision: 0.8111 - recall: 0.8336 - auc: 0.9126 - prc: 0.9127 - val_loss: 0.3606 - val_tp: 8599.0000 - val_fp: 2112.0000 - val_tn: 7919.0000 - val_fn: 1429.0000 - val_accuracy: 0.8235 - val_precision: 0.8028 - val_recall: 0.8575 - val_auc: 0.9158 - val_prc: 0.9153
# Epoch 50/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3624 - tp: 33956.0000 - fp: 8241.0000 - tn: 31837.0000 - fn: 6198.0000 - accuracy: 0.8200 - precision: 0.8047 - recall: 0.8456 - auc: 0.9139 - prc: 0.9143 - val_loss: 0.3577 - val_tp: 8358.0000 - val_fp: 1855.0000 - val_tn: 8176.0000 - val_fn: 1670.0000 - val_accuracy: 0.8243 - val_precision: 0.8184 - val_recall: 0.8335 - val_auc: 0.9165 - val_prc: 0.9163
# Epoch 51/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3598 - tp: 33446.0000 - fp: 7729.0000 - tn: 32349.0000 - fn: 6708.0000 - accuracy: 0.8201 - precision: 0.8123 - recall: 0.8329 - auc: 0.9147 - prc: 0.9154 - val_loss: 0.3554 - val_tp: 8363.0000 - val_fp: 1842.0000 - val_tn: 8189.0000 - val_fn: 1665.0000 - val_accuracy: 0.8252 - val_precision: 0.8195 - val_recall: 0.8340 - val_auc: 0.9181 - val_prc: 0.9180
# Epoch 52/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3569 - tp: 33868.0000 - fp: 7843.0000 - tn: 32235.0000 - fn: 6286.0000 - accuracy: 0.8239 - precision: 0.8120 - recall: 0.8435 - auc: 0.9171 - prc: 0.9179 - val_loss: 0.3531 - val_tp: 8479.0000 - val_fp: 1946.0000 - val_tn: 8085.0000 - val_fn: 1549.0000 - val_accuracy: 0.8258 - val_precision: 0.8133 - val_recall: 0.8455 - val_auc: 0.9189 - val_prc: 0.9195
# Epoch 53/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3544 - tp: 33723.0000 - fp: 7735.0000 - tn: 32343.0000 - fn: 6431.0000 - accuracy: 0.8234 - precision: 0.8134 - recall: 0.8398 - auc: 0.9177 - prc: 0.9188 - val_loss: 0.3500 - val_tp: 8525.0000 - val_fp: 1936.0000 - val_tn: 8095.0000 - val_fn: 1503.0000 - val_accuracy: 0.8286 - val_precision: 0.8149 - val_recall: 0.8501 - val_auc: 0.9208 - val_prc: 0.9214
# Epoch 54/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3515 - tp: 33901.0000 - fp: 7689.0000 - tn: 32389.0000 - fn: 6253.0000 - accuracy: 0.8262 - precision: 0.8151 - recall: 0.8443 - auc: 0.9197 - prc: 0.9211 - val_loss: 0.3479 - val_tp: 8621.0000 - val_fp: 2011.0000 - val_tn: 8020.0000 - val_fn: 1407.0000 - val_accuracy: 0.8296 - val_precision: 0.8109 - val_recall: 0.8597 - val_auc: 0.9220 - val_prc: 0.9230
# Epoch 55/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3497 - tp: 34027.0000 - fp: 7793.0000 - tn: 32285.0000 - fn: 6127.0000 - accuracy: 0.8265 - precision: 0.8137 - recall: 0.8474 - auc: 0.9203 - prc: 0.9220 - val_loss: 0.3454 - val_tp: 8570.0000 - val_fp: 1960.0000 - val_tn: 8071.0000 - val_fn: 1458.0000 - val_accuracy: 0.8296 - val_precision: 0.8139 - val_recall: 0.8546 - val_auc: 0.9230 - val_prc: 0.9241
# Epoch 56/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3468 - tp: 33810.0000 - fp: 7527.0000 - tn: 32551.0000 - fn: 6344.0000 - accuracy: 0.8271 - precision: 0.8179 - recall: 0.8420 - auc: 0.9217 - prc: 0.9235 - val_loss: 0.3441 - val_tp: 8326.0000 - val_fp: 1730.0000 - val_tn: 8301.0000 - val_fn: 1702.0000 - val_accuracy: 0.8289 - val_precision: 0.8280 - val_recall: 0.8303 - val_auc: 0.9229 - val_prc: 0.9242
# Epoch 57/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3447 - tp: 33846.0000 - fp: 7374.0000 - tn: 32704.0000 - fn: 6308.0000 - accuracy: 0.8295 - precision: 0.8211 - recall: 0.8429 - auc: 0.9228 - prc: 0.9246 - val_loss: 0.3415 - val_tp: 8388.0000 - val_fp: 1771.0000 - val_tn: 8260.0000 - val_fn: 1640.0000 - val_accuracy: 0.8300 - val_precision: 0.8257 - val_recall: 0.8365 - val_auc: 0.9247 - val_prc: 0.9262
# Epoch 58/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3422 - tp: 33966.0000 - fp: 7445.0000 - tn: 32633.0000 - fn: 6188.0000 - accuracy: 0.8301 - precision: 0.8202 - recall: 0.8459 - auc: 0.9241 - prc: 0.9261 - val_loss: 0.3387 - val_tp: 8473.0000 - val_fp: 1801.0000 - val_tn: 8230.0000 - val_fn: 1555.0000 - val_accuracy: 0.8327 - val_precision: 0.8247 - val_recall: 0.8449 - val_auc: 0.9262 - val_prc: 0.9277
# Epoch 59/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3397 - tp: 33896.0000 - fp: 7285.0000 - tn: 32793.0000 - fn: 6258.0000 - accuracy: 0.8312 - precision: 0.8231 - recall: 0.8442 - auc: 0.9254 - prc: 0.9275 - val_loss: 0.3364 - val_tp: 8425.0000 - val_fp: 1761.0000 - val_tn: 8270.0000 - val_fn: 1603.0000 - val_accuracy: 0.8323 - val_precision: 0.8271 - val_recall: 0.8401 - val_auc: 0.9269 - val_prc: 0.9287
# Epoch 60/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3374 - tp: 33901.0000 - fp: 7198.0000 - tn: 32880.0000 - fn: 6253.0000 - accuracy: 0.8323 - precision: 0.8249 - recall: 0.8443 - auc: 0.9265 - prc: 0.9287 - val_loss: 0.3342 - val_tp: 8663.0000 - val_fp: 1977.0000 - val_tn: 8054.0000 - val_fn: 1365.0000 - val_accuracy: 0.8334 - val_precision: 0.8142 - val_recall: 0.8639 - val_auc: 0.9286 - val_prc: 0.9305
# Epoch 61/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3356 - tp: 33970.0000 - fp: 7238.0000 - tn: 32840.0000 - fn: 6184.0000 - accuracy: 0.8327 - precision: 0.8244 - recall: 0.8460 - auc: 0.9271 - prc: 0.9294 - val_loss: 0.3338 - val_tp: 8762.0000 - val_fp: 2068.0000 - val_tn: 7963.0000 - val_fn: 1266.0000 - val_accuracy: 0.8338 - val_precision: 0.8090 - val_recall: 0.8738 - val_auc: 0.9288 - val_prc: 0.9309
# Epoch 62/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3351 - tp: 34128.0000 - fp: 7433.0000 - tn: 32645.0000 - fn: 6026.0000 - accuracy: 0.8322 - precision: 0.8212 - recall: 0.8499 - auc: 0.9271 - prc: 0.9297 - val_loss: 0.3308 - val_tp: 8271.0000 - val_fp: 1553.0000 - val_tn: 8478.0000 - val_fn: 1757.0000 - val_accuracy: 0.8350 - val_precision: 0.8419 - val_recall: 0.8248 - val_auc: 0.9298 - val_prc: 0.9320
# Epoch 63/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3313 - tp: 34066.0000 - fp: 7175.0000 - tn: 32903.0000 - fn: 6088.0000 - accuracy: 0.8347 - precision: 0.8260 - recall: 0.8484 - auc: 0.9292 - prc: 0.9318 - val_loss: 0.3281 - val_tp: 8456.0000 - val_fp: 1693.0000 - val_tn: 8338.0000 - val_fn: 1572.0000 - val_accuracy: 0.8372 - val_precision: 0.8332 - val_recall: 0.8432 - val_auc: 0.9311 - val_prc: 0.9333
# Epoch 64/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3298 - tp: 33910.0000 - fp: 7005.0000 - tn: 33073.0000 - fn: 6244.0000 - accuracy: 0.8349 - precision: 0.8288 - recall: 0.8445 - auc: 0.9298 - prc: 0.9323 - val_loss: 0.3260 - val_tp: 8518.0000 - val_fp: 1751.0000 - val_tn: 8280.0000 - val_fn: 1510.0000 - val_accuracy: 0.8374 - val_precision: 0.8295 - val_recall: 0.8494 - val_auc: 0.9319 - val_prc: 0.9342
# Epoch 65/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3277 - tp: 33905.0000 - fp: 6950.0000 - tn: 33128.0000 - fn: 6249.0000 - accuracy: 0.8355 - precision: 0.8299 - recall: 0.8444 - auc: 0.9305 - prc: 0.9332 - val_loss: 0.3244 - val_tp: 8447.0000 - val_fp: 1685.0000 - val_tn: 8346.0000 - val_fn: 1581.0000 - val_accuracy: 0.8372 - val_precision: 0.8337 - val_recall: 0.8423 - val_auc: 0.9327 - val_prc: 0.9349
# Epoch 66/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3259 - tp: 33985.0000 - fp: 6870.0000 - tn: 33208.0000 - fn: 6169.0000 - accuracy: 0.8375 - precision: 0.8318 - recall: 0.8464 - auc: 0.9318 - prc: 0.9344 - val_loss: 0.3235 - val_tp: 8582.0000 - val_fp: 1825.0000 - val_tn: 8206.0000 - val_fn: 1446.0000 - val_accuracy: 0.8369 - val_precision: 0.8246 - val_recall: 0.8558 - val_auc: 0.9326 - val_prc: 0.9351
# Epoch 67/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3242 - tp: 34153.0000 - fp: 7043.0000 - tn: 33035.0000 - fn: 6001.0000 - accuracy: 0.8374 - precision: 0.8290 - recall: 0.8506 - auc: 0.9322 - prc: 0.9349 - val_loss: 0.3219 - val_tp: 8334.0000 - val_fp: 1556.0000 - val_tn: 8475.0000 - val_fn: 1694.0000 - val_accuracy: 0.8380 - val_precision: 0.8427 - val_recall: 0.8311 - val_auc: 0.9339 - val_prc: 0.9362
# Epoch 68/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3229 - tp: 33797.0000 - fp: 6539.0000 - tn: 33539.0000 - fn: 6357.0000 - accuracy: 0.8393 - precision: 0.8379 - recall: 0.8417 - auc: 0.9329 - prc: 0.9356 - val_loss: 0.3205 - val_tp: 8818.0000 - val_fp: 2008.0000 - val_tn: 8023.0000 - val_fn: 1210.0000 - val_accuracy: 0.8396 - val_precision: 0.8145 - val_recall: 0.8793 - val_auc: 0.9349 - val_prc: 0.9375
# Epoch 69/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3208 - tp: 34262.0000 - fp: 7015.0000 - tn: 33063.0000 - fn: 5892.0000 - accuracy: 0.8391 - precision: 0.8301 - recall: 0.8533 - auc: 0.9338 - prc: 0.9365 - val_loss: 0.3174 - val_tp: 8466.0000 - val_fp: 1632.0000 - val_tn: 8399.0000 - val_fn: 1562.0000 - val_accuracy: 0.8408 - val_precision: 0.8384 - val_recall: 0.8442 - val_auc: 0.9355 - val_prc: 0.9379
# Epoch 70/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3192 - tp: 33925.0000 - fp: 6540.0000 - tn: 33538.0000 - fn: 6229.0000 - accuracy: 0.8408 - precision: 0.8384 - recall: 0.8449 - auc: 0.9345 - prc: 0.9373 - val_loss: 0.3163 - val_tp: 8493.0000 - val_fp: 1664.0000 - val_tn: 8367.0000 - val_fn: 1535.0000 - val_accuracy: 0.8405 - val_precision: 0.8362 - val_recall: 0.8469 - val_auc: 0.9356 - val_prc: 0.9383
# Epoch 71/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3176 - tp: 33913.0000 - fp: 6506.0000 - tn: 33572.0000 - fn: 6241.0000 - accuracy: 0.8411 - precision: 0.8390 - recall: 0.8446 - auc: 0.9350 - prc: 0.9379 - val_loss: 0.3152 - val_tp: 8576.0000 - val_fp: 1723.0000 - val_tn: 8308.0000 - val_fn: 1452.0000 - val_accuracy: 0.8417 - val_precision: 0.8327 - val_recall: 0.8552 - val_auc: 0.9361 - val_prc: 0.9387
# Epoch 72/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3168 - tp: 34170.0000 - fp: 6836.0000 - tn: 33242.0000 - fn: 5984.0000 - accuracy: 0.8402 - precision: 0.8333 - recall: 0.8510 - auc: 0.9350 - prc: 0.9379 - val_loss: 0.3147 - val_tp: 8392.0000 - val_fp: 1469.0000 - val_tn: 8562.0000 - val_fn: 1636.0000 - val_accuracy: 0.8452 - val_precision: 0.8510 - val_recall: 0.8369 - val_auc: 0.9370 - val_prc: 0.9392
# Epoch 73/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3152 - tp: 34046.0000 - fp: 6464.0000 - tn: 33614.0000 - fn: 6108.0000 - accuracy: 0.8433 - precision: 0.8404 - recall: 0.8479 - auc: 0.9361 - prc: 0.9389 - val_loss: 0.3126 - val_tp: 8735.0000 - val_fp: 1850.0000 - val_tn: 8181.0000 - val_fn: 1293.0000 - val_accuracy: 0.8433 - val_precision: 0.8252 - val_recall: 0.8711 - val_auc: 0.9375 - val_prc: 0.9401
# Epoch 74/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3130 - tp: 34195.0000 - fp: 6574.0000 - tn: 33504.0000 - fn: 5959.0000 - accuracy: 0.8438 - precision: 0.8388 - recall: 0.8516 - auc: 0.9372 - prc: 0.9398 - val_loss: 0.3105 - val_tp: 8415.0000 - val_fp: 1519.0000 - val_tn: 8512.0000 - val_fn: 1613.0000 - val_accuracy: 0.8439 - val_precision: 0.8471 - val_recall: 0.8392 - val_auc: 0.9380 - val_prc: 0.9405
# Epoch 75/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3114 - tp: 34138.0000 - fp: 6451.0000 - tn: 33627.0000 - fn: 6016.0000 - accuracy: 0.8446 - precision: 0.8411 - recall: 0.8502 - auc: 0.9376 - prc: 0.9403 - val_loss: 0.3089 - val_tp: 8520.0000 - val_fp: 1574.0000 - val_tn: 8457.0000 - val_fn: 1508.0000 - val_accuracy: 0.8464 - val_precision: 0.8441 - val_recall: 0.8496 - val_auc: 0.9389 - val_prc: 0.9413
# Epoch 76/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3098 - tp: 34191.0000 - fp: 6368.0000 - tn: 33710.0000 - fn: 5963.0000 - accuracy: 0.8463 - precision: 0.8430 - recall: 0.8515 - auc: 0.9383 - prc: 0.9410 - val_loss: 0.3085 - val_tp: 8275.0000 - val_fp: 1349.0000 - val_tn: 8682.0000 - val_fn: 1753.0000 - val_accuracy: 0.8454 - val_precision: 0.8598 - val_recall: 0.8252 - val_auc: 0.9392 - val_prc: 0.9417
# Epoch 77/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3089 - tp: 33949.0000 - fp: 6124.0000 - tn: 33954.0000 - fn: 6205.0000 - accuracy: 0.8463 - precision: 0.8472 - recall: 0.8455 - auc: 0.9385 - prc: 0.9413 - val_loss: 0.3092 - val_tp: 8903.0000 - val_fp: 1990.0000 - val_tn: 8041.0000 - val_fn: 1125.0000 - val_accuracy: 0.8447 - val_precision: 0.8173 - val_recall: 0.8878 - val_auc: 0.9396 - val_prc: 0.9421
# Epoch 78/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3085 - tp: 34446.0000 - fp: 6603.0000 - tn: 33475.0000 - fn: 5708.0000 - accuracy: 0.8466 - precision: 0.8391 - recall: 0.8578 - auc: 0.9387 - prc: 0.9414 - val_loss: 0.3071 - val_tp: 8188.0000 - val_fp: 1283.0000 - val_tn: 8748.0000 - val_fn: 1840.0000 - val_accuracy: 0.8443 - val_precision: 0.8645 - val_recall: 0.8165 - val_auc: 0.9395 - val_prc: 0.9422
# Epoch 79/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3075 - tp: 33971.0000 - fp: 6101.0000 - tn: 33977.0000 - fn: 6183.0000 - accuracy: 0.8469 - precision: 0.8477 - recall: 0.8460 - auc: 0.9390 - prc: 0.9417 - val_loss: 0.3048 - val_tp: 8857.0000 - val_fp: 1824.0000 - val_tn: 8207.0000 - val_fn: 1171.0000 - val_accuracy: 0.8507 - val_precision: 0.8292 - val_recall: 0.8832 - val_auc: 0.9414 - val_prc: 0.9435
# Epoch 80/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3056 - tp: 34340.0000 - fp: 6403.0000 - tn: 33675.0000 - fn: 5814.0000 - accuracy: 0.8477 - precision: 0.8428 - recall: 0.8552 - auc: 0.9398 - prc: 0.9424 - val_loss: 0.3032 - val_tp: 8568.0000 - val_fp: 1545.0000 - val_tn: 8486.0000 - val_fn: 1460.0000 - val_accuracy: 0.8502 - val_precision: 0.8472 - val_recall: 0.8544 - val_auc: 0.9411 - val_prc: 0.9435
# Epoch 81/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3050 - tp: 34451.0000 - fp: 6366.0000 - tn: 33712.0000 - fn: 5703.0000 - accuracy: 0.8496 - precision: 0.8440 - recall: 0.8580 - auc: 0.9402 - prc: 0.9427 - val_loss: 0.3023 - val_tp: 8635.0000 - val_fp: 1631.0000 - val_tn: 8400.0000 - val_fn: 1393.0000 - val_accuracy: 0.8492 - val_precision: 0.8411 - val_recall: 0.8611 - val_auc: 0.9411 - val_prc: 0.9437
# Epoch 82/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.3029 - tp: 34289.0000 - fp: 6195.0000 - tn: 33883.0000 - fn: 5865.0000 - accuracy: 0.8497 - precision: 0.8470 - recall: 0.8539 - auc: 0.9411 - prc: 0.9437 - val_loss: 0.3008 - val_tp: 8432.0000 - val_fp: 1416.0000 - val_tn: 8615.0000 - val_fn: 1596.0000 - val_accuracy: 0.8498 - val_precision: 0.8562 - val_recall: 0.8408 - val_auc: 0.9419 - val_prc: 0.9444
# Epoch 83/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3022 - tp: 34110.0000 - fp: 6016.0000 - tn: 34062.0000 - fn: 6044.0000 - accuracy: 0.8497 - precision: 0.8501 - recall: 0.8495 - auc: 0.9411 - prc: 0.9438 - val_loss: 0.2997 - val_tp: 8780.0000 - val_fp: 1689.0000 - val_tn: 8342.0000 - val_fn: 1248.0000 - val_accuracy: 0.8536 - val_precision: 0.8387 - val_recall: 0.8755 - val_auc: 0.9431 - val_prc: 0.9452
# Epoch 84/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3005 - tp: 34329.0000 - fp: 6105.0000 - tn: 33973.0000 - fn: 5825.0000 - accuracy: 0.8513 - precision: 0.8490 - recall: 0.8549 - auc: 0.9421 - prc: 0.9446 - val_loss: 0.2997 - val_tp: 8676.0000 - val_fp: 1610.0000 - val_tn: 8421.0000 - val_fn: 1352.0000 - val_accuracy: 0.8523 - val_precision: 0.8435 - val_recall: 0.8652 - val_auc: 0.9422 - val_prc: 0.9448
# Epoch 85/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.3001 - tp: 34446.0000 - fp: 6181.0000 - tn: 33897.0000 - fn: 5708.0000 - accuracy: 0.8518 - precision: 0.8479 - recall: 0.8578 - auc: 0.9422 - prc: 0.9448 - val_loss: 0.2967 - val_tp: 8648.0000 - val_fp: 1527.0000 - val_tn: 8504.0000 - val_fn: 1380.0000 - val_accuracy: 0.8551 - val_precision: 0.8499 - val_recall: 0.8624 - val_auc: 0.9439 - val_prc: 0.9461
# Epoch 86/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2977 - tp: 34389.0000 - fp: 6021.0000 - tn: 34057.0000 - fn: 5765.0000 - accuracy: 0.8531 - precision: 0.8510 - recall: 0.8564 - auc: 0.9433 - prc: 0.9457 - val_loss: 0.3000 - val_tp: 8969.0000 - val_fp: 1928.0000 - val_tn: 8103.0000 - val_fn: 1059.0000 - val_accuracy: 0.8511 - val_precision: 0.8231 - val_recall: 0.8944 - val_auc: 0.9434 - val_prc: 0.9459
# Epoch 87/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2986 - tp: 34567.0000 - fp: 6250.0000 - tn: 33828.0000 - fn: 5587.0000 - accuracy: 0.8525 - precision: 0.8469 - recall: 0.8609 - auc: 0.9426 - prc: 0.9453 - val_loss: 0.2958 - val_tp: 8391.0000 - val_fp: 1281.0000 - val_tn: 8750.0000 - val_fn: 1637.0000 - val_accuracy: 0.8545 - val_precision: 0.8676 - val_recall: 0.8368 - val_auc: 0.9443 - val_prc: 0.9466
# Epoch 88/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2960 - tp: 34338.0000 - fp: 5842.0000 - tn: 34236.0000 - fn: 5816.0000 - accuracy: 0.8547 - precision: 0.8546 - recall: 0.8552 - auc: 0.9438 - prc: 0.9463 - val_loss: 0.2937 - val_tp: 8555.0000 - val_fp: 1422.0000 - val_tn: 8609.0000 - val_fn: 1473.0000 - val_accuracy: 0.8557 - val_precision: 0.8575 - val_recall: 0.8531 - val_auc: 0.9449 - val_prc: 0.9472
# Epoch 89/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2954 - tp: 34226.0000 - fp: 5789.0000 - tn: 34289.0000 - fn: 5928.0000 - accuracy: 0.8540 - precision: 0.8553 - recall: 0.8524 - auc: 0.9440 - prc: 0.9465 - val_loss: 0.2927 - val_tp: 8653.0000 - val_fp: 1537.0000 - val_tn: 8494.0000 - val_fn: 1375.0000 - val_accuracy: 0.8548 - val_precision: 0.8492 - val_recall: 0.8629 - val_auc: 0.9451 - val_prc: 0.9475
# Epoch 90/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2937 - tp: 34416.0000 - fp: 5781.0000 - tn: 34297.0000 - fn: 5738.0000 - accuracy: 0.8564 - precision: 0.8562 - recall: 0.8571 - auc: 0.9449 - prc: 0.9473 - val_loss: 0.2917 - val_tp: 8643.0000 - val_fp: 1508.0000 - val_tn: 8523.0000 - val_fn: 1385.0000 - val_accuracy: 0.8558 - val_precision: 0.8514 - val_recall: 0.8619 - val_auc: 0.9456 - val_prc: 0.9478
# Epoch 91/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2930 - tp: 34602.0000 - fp: 6015.0000 - tn: 34063.0000 - fn: 5552.0000 - accuracy: 0.8558 - precision: 0.8519 - recall: 0.8617 - auc: 0.9449 - prc: 0.9473 - val_loss: 0.2914 - val_tp: 8513.0000 - val_fp: 1347.0000 - val_tn: 8684.0000 - val_fn: 1515.0000 - val_accuracy: 0.8573 - val_precision: 0.8634 - val_recall: 0.8489 - val_auc: 0.9459 - val_prc: 0.9480
# Epoch 92/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2919 - tp: 34450.0000 - fp: 5727.0000 - tn: 34351.0000 - fn: 5704.0000 - accuracy: 0.8575 - precision: 0.8575 - recall: 0.8579 - auc: 0.9455 - prc: 0.9479 - val_loss: 0.2901 - val_tp: 8803.0000 - val_fp: 1590.0000 - val_tn: 8441.0000 - val_fn: 1225.0000 - val_accuracy: 0.8597 - val_precision: 0.8470 - val_recall: 0.8778 - val_auc: 0.9467 - val_prc: 0.9487
# Epoch 93/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2917 - tp: 34646.0000 - fp: 5959.0000 - tn: 34119.0000 - fn: 5508.0000 - accuracy: 0.8571 - precision: 0.8532 - recall: 0.8628 - auc: 0.9455 - prc: 0.9477 - val_loss: 0.2898 - val_tp: 8382.0000 - val_fp: 1279.0000 - val_tn: 8752.0000 - val_fn: 1646.0000 - val_accuracy: 0.8542 - val_precision: 0.8676 - val_recall: 0.8359 - val_auc: 0.9463 - val_prc: 0.9486
# Epoch 94/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2902 - tp: 34397.0000 - fp: 5627.0000 - tn: 34451.0000 - fn: 5757.0000 - accuracy: 0.8581 - precision: 0.8594 - recall: 0.8566 - auc: 0.9461 - prc: 0.9484 - val_loss: 0.2888 - val_tp: 8872.0000 - val_fp: 1665.0000 - val_tn: 8366.0000 - val_fn: 1156.0000 - val_accuracy: 0.8594 - val_precision: 0.8420 - val_recall: 0.8847 - val_auc: 0.9472 - val_prc: 0.9493
# Epoch 95/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2887 - tp: 34528.0000 - fp: 5706.0000 - tn: 34372.0000 - fn: 5626.0000 - accuracy: 0.8588 - precision: 0.8582 - recall: 0.8599 - auc: 0.9467 - prc: 0.9490 - val_loss: 0.2865 - val_tp: 8642.0000 - val_fp: 1454.0000 - val_tn: 8577.0000 - val_fn: 1386.0000 - val_accuracy: 0.8584 - val_precision: 0.8560 - val_recall: 0.8618 - val_auc: 0.9476 - val_prc: 0.9498
# Epoch 96/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2877 - tp: 34510.0000 - fp: 5605.0000 - tn: 34473.0000 - fn: 5644.0000 - accuracy: 0.8598 - precision: 0.8603 - recall: 0.8594 - auc: 0.9472 - prc: 0.9495 - val_loss: 0.2855 - val_tp: 8645.0000 - val_fp: 1419.0000 - val_tn: 8612.0000 - val_fn: 1383.0000 - val_accuracy: 0.8603 - val_precision: 0.8590 - val_recall: 0.8621 - val_auc: 0.9480 - val_prc: 0.9501
# Epoch 97/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2872 - tp: 34622.0000 - fp: 5725.0000 - tn: 34353.0000 - fn: 5532.0000 - accuracy: 0.8597 - precision: 0.8581 - recall: 0.8622 - auc: 0.9472 - prc: 0.9495 - val_loss: 0.2865 - val_tp: 8493.0000 - val_fp: 1254.0000 - val_tn: 8777.0000 - val_fn: 1535.0000 - val_accuracy: 0.8610 - val_precision: 0.8713 - val_recall: 0.8469 - val_auc: 0.9477 - val_prc: 0.9498
# Epoch 98/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2863 - tp: 34454.0000 - fp: 5463.0000 - tn: 34615.0000 - fn: 5700.0000 - accuracy: 0.8609 - precision: 0.8631 - recall: 0.8580 - auc: 0.9476 - prc: 0.9500 - val_loss: 0.2838 - val_tp: 8632.0000 - val_fp: 1411.0000 - val_tn: 8620.0000 - val_fn: 1396.0000 - val_accuracy: 0.8601 - val_precision: 0.8595 - val_recall: 0.8608 - val_auc: 0.9484 - val_prc: 0.9507
# Epoch 99/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2851 - tp: 34585.0000 - fp: 5631.0000 - tn: 34447.0000 - fn: 5569.0000 - accuracy: 0.8604 - precision: 0.8600 - recall: 0.8613 - auc: 0.9479 - prc: 0.9503 - val_loss: 0.2827 - val_tp: 8738.0000 - val_fp: 1464.0000 - val_tn: 8567.0000 - val_fn: 1290.0000 - val_accuracy: 0.8627 - val_precision: 0.8565 - val_recall: 0.8714 - val_auc: 0.9492 - val_prc: 0.9512
# Epoch 100/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2839 - tp: 34729.0000 - fp: 5609.0000 - tn: 34469.0000 - fn: 5425.0000 - accuracy: 0.8625 - precision: 0.8609 - recall: 0.8649 - auc: 0.9486 - prc: 0.9508 - val_loss: 0.2840 - val_tp: 8809.0000 - val_fp: 1546.0000 - val_tn: 8485.0000 - val_fn: 1219.0000 - val_accuracy: 0.8622 - val_precision: 0.8507 - val_recall: 0.8784 - val_auc: 0.9484 - val_prc: 0.9507
# Epoch 101/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2843 - tp: 34591.0000 - fp: 5507.0000 - tn: 34571.0000 - fn: 5563.0000 - accuracy: 0.8620 - precision: 0.8627 - recall: 0.8615 - auc: 0.9482 - prc: 0.9505 - val_loss: 0.2827 - val_tp: 8606.0000 - val_fp: 1343.0000 - val_tn: 8688.0000 - val_fn: 1422.0000 - val_accuracy: 0.8622 - val_precision: 0.8650 - val_recall: 0.8582 - val_auc: 0.9489 - val_prc: 0.9509
# Epoch 102/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2829 - tp: 34736.0000 - fp: 5616.0000 - tn: 34462.0000 - fn: 5418.0000 - accuracy: 0.8625 - precision: 0.8608 - recall: 0.8651 - auc: 0.9489 - prc: 0.9512 - val_loss: 0.2803 - val_tp: 8625.0000 - val_fp: 1366.0000 - val_tn: 8665.0000 - val_fn: 1403.0000 - val_accuracy: 0.8620 - val_precision: 0.8633 - val_recall: 0.8601 - val_auc: 0.9499 - val_prc: 0.9520
# Epoch 103/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2814 - tp: 34682.0000 - fp: 5486.0000 - tn: 34592.0000 - fn: 5472.0000 - accuracy: 0.8634 - precision: 0.8634 - recall: 0.8637 - auc: 0.9495 - prc: 0.9517 - val_loss: 0.2795 - val_tp: 8664.0000 - val_fp: 1373.0000 - val_tn: 8658.0000 - val_fn: 1364.0000 - val_accuracy: 0.8636 - val_precision: 0.8632 - val_recall: 0.8640 - val_auc: 0.9504 - val_prc: 0.9523
# Epoch 104/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2806 - tp: 34633.0000 - fp: 5386.0000 - tn: 34692.0000 - fn: 5521.0000 - accuracy: 0.8641 - precision: 0.8654 - recall: 0.8625 - auc: 0.9498 - prc: 0.9520 - val_loss: 0.2794 - val_tp: 8835.0000 - val_fp: 1508.0000 - val_tn: 8523.0000 - val_fn: 1193.0000 - val_accuracy: 0.8653 - val_precision: 0.8542 - val_recall: 0.8810 - val_auc: 0.9505 - val_prc: 0.9524
# Epoch 105/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2798 - tp: 34593.0000 - fp: 5406.0000 - tn: 34672.0000 - fn: 5561.0000 - accuracy: 0.8633 - precision: 0.8648 - recall: 0.8615 - auc: 0.9500 - prc: 0.9522 - val_loss: 0.2781 - val_tp: 8803.0000 - val_fp: 1506.0000 - val_tn: 8525.0000 - val_fn: 1225.0000 - val_accuracy: 0.8639 - val_precision: 0.8539 - val_recall: 0.8778 - val_auc: 0.9510 - val_prc: 0.9529
# Epoch 106/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2793 - tp: 34989.0000 - fp: 5615.0000 - tn: 34463.0000 - fn: 5165.0000 - accuracy: 0.8656 - precision: 0.8617 - recall: 0.8714 - auc: 0.9504 - prc: 0.9525 - val_loss: 0.2771 - val_tp: 8584.0000 - val_fp: 1252.0000 - val_tn: 8779.0000 - val_fn: 1444.0000 - val_accuracy: 0.8656 - val_precision: 0.8727 - val_recall: 0.8560 - val_auc: 0.9514 - val_prc: 0.9533
# Epoch 107/500
# ...
# Epoch 302/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2101 - tp: 36792.0000 - fp: 3983.0000 - tn: 36095.0000 - fn: 3362.0000 - accuracy: 0.9085 - precision: 0.9023 - recall: 0.9163 - auc: 0.9726 - prc: 0.9727 - val_loss: 0.2117 - val_tp: 9015.0000 - val_fp: 845.0000 - val_tn: 9186.0000 - val_fn: 1013.0000 - val_accuracy: 0.9074 - val_precision: 0.9143 - val_recall: 0.8990 - val_auc: 0.9727 - val_prc: 0.9721
# Epoch 303/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2087 - tp: 36640.0000 - fp: 3871.0000 - tn: 36207.0000 - fn: 3514.0000 - accuracy: 0.9080 - precision: 0.9044 - recall: 0.9125 - auc: 0.9731 - prc: 0.9732 - val_loss: 0.2100 - val_tp: 9129.0000 - val_fp: 939.0000 - val_tn: 9092.0000 - val_fn: 899.0000 - val_accuracy: 0.9084 - val_precision: 0.9067 - val_recall: 0.9104 - val_auc: 0.9728 - val_prc: 0.9719
# Epoch 304/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2085 - tp: 36760.0000 - fp: 3911.0000 - tn: 36167.0000 - fn: 3394.0000 - accuracy: 0.9090 - precision: 0.9038 - recall: 0.9155 - auc: 0.9731 - prc: 0.9733 - val_loss: 0.2118 - val_tp: 9158.0000 - val_fp: 997.0000 - val_tn: 9034.0000 - val_fn: 870.0000 - val_accuracy: 0.9069 - val_precision: 0.9018 - val_recall: 0.9132 - val_auc: 0.9723 - val_prc: 0.9712
# Epoch 305/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2091 - tp: 36720.0000 - fp: 3891.0000 - tn: 36187.0000 - fn: 3434.0000 - accuracy: 0.9087 - precision: 0.9042 - recall: 0.9145 - auc: 0.9729 - prc: 0.9730 - val_loss: 0.2103 - val_tp: 9154.0000 - val_fp: 978.0000 - val_tn: 9053.0000 - val_fn: 874.0000 - val_accuracy: 0.9077 - val_precision: 0.9035 - val_recall: 0.9128 - val_auc: 0.9728 - val_prc: 0.9721
# Epoch 306/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2079 - tp: 36885.0000 - fp: 3986.0000 - tn: 36092.0000 - fn: 3269.0000 - accuracy: 0.9096 - precision: 0.9025 - recall: 0.9186 - auc: 0.9733 - prc: 0.9733 - val_loss: 0.2093 - val_tp: 9243.0000 - val_fp: 1012.0000 - val_tn: 9019.0000 - val_fn: 785.0000 - val_accuracy: 0.9104 - val_precision: 0.9013 - val_recall: 0.9217 - val_auc: 0.9730 - val_prc: 0.9722
# Epoch 307/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2080 - tp: 36742.0000 - fp: 3904.0000 - tn: 36174.0000 - fn: 3412.0000 - accuracy: 0.9088 - precision: 0.9040 - recall: 0.9150 - auc: 0.9733 - prc: 0.9733 - val_loss: 0.2099 - val_tp: 9316.0000 - val_fp: 1119.0000 - val_tn: 8912.0000 - val_fn: 712.0000 - val_accuracy: 0.9087 - val_precision: 0.8928 - val_recall: 0.9290 - val_auc: 0.9730 - val_prc: 0.9720
# Epoch 308/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2076 - tp: 36805.0000 - fp: 3926.0000 - tn: 36152.0000 - fn: 3349.0000 - accuracy: 0.9093 - precision: 0.9036 - recall: 0.9166 - auc: 0.9733 - prc: 0.9735 - val_loss: 0.2094 - val_tp: 9233.0000 - val_fp: 1002.0000 - val_tn: 9029.0000 - val_fn: 795.0000 - val_accuracy: 0.9104 - val_precision: 0.9021 - val_recall: 0.9207 - val_auc: 0.9730 - val_prc: 0.9719
# Epoch 309/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2067 - tp: 36863.0000 - fp: 3893.0000 - tn: 36185.0000 - fn: 3291.0000 - accuracy: 0.9105 - precision: 0.9045 - recall: 0.9180 - auc: 0.9736 - prc: 0.9736 - val_loss: 0.2092 - val_tp: 9182.0000 - val_fp: 961.0000 - val_tn: 9070.0000 - val_fn: 846.0000 - val_accuracy: 0.9099 - val_precision: 0.9053 - val_recall: 0.9156 - val_auc: 0.9731 - val_prc: 0.9722
# Epoch 310/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2067 - tp: 36827.0000 - fp: 3861.0000 - tn: 36217.0000 - fn: 3327.0000 - accuracy: 0.9104 - precision: 0.9051 - recall: 0.9171 - auc: 0.9736 - prc: 0.9737 - val_loss: 0.2109 - val_tp: 9134.0000 - val_fp: 965.0000 - val_tn: 9066.0000 - val_fn: 894.0000 - val_accuracy: 0.9073 - val_precision: 0.9044 - val_recall: 0.9108 - val_auc: 0.9725 - val_prc: 0.9716
# Epoch 311/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2084 - tp: 36688.0000 - fp: 3877.0000 - tn: 36201.0000 - fn: 3466.0000 - accuracy: 0.9085 - precision: 0.9044 - recall: 0.9137 - auc: 0.9731 - prc: 0.9733 - val_loss: 0.2087 - val_tp: 9226.0000 - val_fp: 1028.0000 - val_tn: 9003.0000 - val_fn: 802.0000 - val_accuracy: 0.9088 - val_precision: 0.8997 - val_recall: 0.9200 - val_auc: 0.9731 - val_prc: 0.9722
# Epoch 312/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2066 - tp: 36851.0000 - fp: 3888.0000 - tn: 36190.0000 - fn: 3303.0000 - accuracy: 0.9104 - precision: 0.9046 - recall: 0.9177 - auc: 0.9736 - prc: 0.9736 - val_loss: 0.2090 - val_tp: 9206.0000 - val_fp: 987.0000 - val_tn: 9044.0000 - val_fn: 822.0000 - val_accuracy: 0.9098 - val_precision: 0.9032 - val_recall: 0.9180 - val_auc: 0.9731 - val_prc: 0.9722
# Epoch 313/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2064 - tp: 36753.0000 - fp: 3822.0000 - tn: 36256.0000 - fn: 3401.0000 - accuracy: 0.9100 - precision: 0.9058 - recall: 0.9153 - auc: 0.9736 - prc: 0.9736 - val_loss: 0.2102 - val_tp: 9357.0000 - val_fp: 1141.0000 - val_tn: 8890.0000 - val_fn: 671.0000 - val_accuracy: 0.9097 - val_precision: 0.8913 - val_recall: 0.9331 - val_auc: 0.9730 - val_prc: 0.9719
# Epoch 314/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2066 - tp: 36871.0000 - fp: 3884.0000 - tn: 36194.0000 - fn: 3283.0000 - accuracy: 0.9107 - precision: 0.9047 - recall: 0.9182 - auc: 0.9736 - prc: 0.9736 - val_loss: 0.2101 - val_tp: 9028.0000 - val_fp: 879.0000 - val_tn: 9152.0000 - val_fn: 1000.0000 - val_accuracy: 0.9063 - val_precision: 0.9113 - val_recall: 0.9003 - val_auc: 0.9730 - val_prc: 0.9725
# Epoch 315/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2069 - tp: 36761.0000 - fp: 3879.0000 - tn: 36199.0000 - fn: 3393.0000 - accuracy: 0.9094 - precision: 0.9046 - recall: 0.9155 - auc: 0.9734 - prc: 0.9735 - val_loss: 0.2091 - val_tp: 9313.0000 - val_fp: 1071.0000 - val_tn: 8960.0000 - val_fn: 715.0000 - val_accuracy: 0.9110 - val_precision: 0.8969 - val_recall: 0.9287 - val_auc: 0.9733 - val_prc: 0.9723
# Epoch 316/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2063 - tp: 36825.0000 - fp: 3898.0000 - tn: 36180.0000 - fn: 3329.0000 - accuracy: 0.9099 - precision: 0.9043 - recall: 0.9171 - auc: 0.9737 - prc: 0.9738 - val_loss: 0.2105 - val_tp: 9437.0000 - val_fp: 1221.0000 - val_tn: 8810.0000 - val_fn: 591.0000 - val_accuracy: 0.9097 - val_precision: 0.8854 - val_recall: 0.9411 - val_auc: 0.9734 - val_prc: 0.9724
# Epoch 317/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2065 - tp: 36913.0000 - fp: 3943.0000 - tn: 36135.0000 - fn: 3241.0000 - accuracy: 0.9105 - precision: 0.9035 - recall: 0.9193 - auc: 0.9737 - prc: 0.9737 - val_loss: 0.2081 - val_tp: 9297.0000 - val_fp: 1067.0000 - val_tn: 8964.0000 - val_fn: 731.0000 - val_accuracy: 0.9104 - val_precision: 0.8970 - val_recall: 0.9271 - val_auc: 0.9734 - val_prc: 0.9724
# Epoch 318/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2063 - tp: 36907.0000 - fp: 3961.0000 - tn: 36117.0000 - fn: 3247.0000 - accuracy: 0.9102 - precision: 0.9031 - recall: 0.9191 - auc: 0.9737 - prc: 0.9737 - val_loss: 0.2081 - val_tp: 9116.0000 - val_fp: 906.0000 - val_tn: 9125.0000 - val_fn: 912.0000 - val_accuracy: 0.9094 - val_precision: 0.9096 - val_recall: 0.9091 - val_auc: 0.9735 - val_prc: 0.9725
# Epoch 319/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2052 - tp: 36957.0000 - fp: 3931.0000 - tn: 36147.0000 - fn: 3197.0000 - accuracy: 0.9112 - precision: 0.9039 - recall: 0.9204 - auc: 0.9740 - prc: 0.9740 - val_loss: 0.2098 - val_tp: 9028.0000 - val_fp: 857.0000 - val_tn: 9174.0000 - val_fn: 1000.0000 - val_accuracy: 0.9074 - val_precision: 0.9133 - val_recall: 0.9003 - val_auc: 0.9732 - val_prc: 0.9725
# Epoch 320/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2053 - tp: 36822.0000 - fp: 3818.0000 - tn: 36260.0000 - fn: 3332.0000 - accuracy: 0.9109 - precision: 0.9061 - recall: 0.9170 - auc: 0.9740 - prc: 0.9740 - val_loss: 0.2087 - val_tp: 9119.0000 - val_fp: 906.0000 - val_tn: 9125.0000 - val_fn: 909.0000 - val_accuracy: 0.9095 - val_precision: 0.9096 - val_recall: 0.9094 - val_auc: 0.9732 - val_prc: 0.9722
# Epoch 321/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2059 - tp: 36809.0000 - fp: 3855.0000 - tn: 36223.0000 - fn: 3345.0000 - accuracy: 0.9103 - precision: 0.9052 - recall: 0.9167 - auc: 0.9738 - prc: 0.9738 - val_loss: 0.2088 - val_tp: 9043.0000 - val_fp: 855.0000 - val_tn: 9176.0000 - val_fn: 985.0000 - val_accuracy: 0.9083 - val_precision: 0.9136 - val_recall: 0.9018 - val_auc: 0.9733 - val_prc: 0.9724
# Epoch 322/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2064 - tp: 36787.0000 - fp: 3902.0000 - tn: 36176.0000 - fn: 3367.0000 - accuracy: 0.9094 - precision: 0.9041 - recall: 0.9161 - auc: 0.9736 - prc: 0.9736 - val_loss: 0.2082 - val_tp: 9033.0000 - val_fp: 854.0000 - val_tn: 9177.0000 - val_fn: 995.0000 - val_accuracy: 0.9078 - val_precision: 0.9136 - val_recall: 0.9008 - val_auc: 0.9736 - val_prc: 0.9730
# Epoch 323/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2057 - tp: 36727.0000 - fp: 3840.0000 - tn: 36238.0000 - fn: 3427.0000 - accuracy: 0.9094 - precision: 0.9053 - recall: 0.9147 - auc: 0.9738 - prc: 0.9738 - val_loss: 0.2079 - val_tp: 9291.0000 - val_fp: 1066.0000 - val_tn: 8965.0000 - val_fn: 737.0000 - val_accuracy: 0.9101 - val_precision: 0.8971 - val_recall: 0.9265 - val_auc: 0.9735 - val_prc: 0.9726
# Epoch 324/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2049 - tp: 36823.0000 - fp: 3801.0000 - tn: 36277.0000 - fn: 3331.0000 - accuracy: 0.9111 - precision: 0.9064 - recall: 0.9170 - auc: 0.9740 - prc: 0.9741 - val_loss: 0.2105 - val_tp: 9421.0000 - val_fp: 1201.0000 - val_tn: 8830.0000 - val_fn: 607.0000 - val_accuracy: 0.9099 - val_precision: 0.8869 - val_recall: 0.9395 - val_auc: 0.9733 - val_prc: 0.9723
# Epoch 325/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2055 - tp: 36847.0000 - fp: 3914.0000 - tn: 36164.0000 - fn: 3307.0000 - accuracy: 0.9100 - precision: 0.9040 - recall: 0.9176 - auc: 0.9739 - prc: 0.9739 - val_loss: 0.2092 - val_tp: 9399.0000 - val_fp: 1190.0000 - val_tn: 8841.0000 - val_fn: 629.0000 - val_accuracy: 0.9093 - val_precision: 0.8876 - val_recall: 0.9373 - val_auc: 0.9735 - val_prc: 0.9725
# Epoch 326/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2048 - tp: 36937.0000 - fp: 3930.0000 - tn: 36148.0000 - fn: 3217.0000 - accuracy: 0.9109 - precision: 0.9038 - recall: 0.9199 - auc: 0.9741 - prc: 0.9742 - val_loss: 0.2071 - val_tp: 9071.0000 - val_fp: 858.0000 - val_tn: 9173.0000 - val_fn: 957.0000 - val_accuracy: 0.9095 - val_precision: 0.9136 - val_recall: 0.9046 - val_auc: 0.9739 - val_prc: 0.9732
# Epoch 327/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2048 - tp: 36804.0000 - fp: 3814.0000 - tn: 36264.0000 - fn: 3350.0000 - accuracy: 0.9107 - precision: 0.9061 - recall: 0.9166 - auc: 0.9741 - prc: 0.9741 - val_loss: 0.2071 - val_tp: 9192.0000 - val_fp: 971.0000 - val_tn: 9060.0000 - val_fn: 836.0000 - val_accuracy: 0.9099 - val_precision: 0.9045 - val_recall: 0.9166 - val_auc: 0.9735 - val_prc: 0.9725
# Epoch 328/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2040 - tp: 36879.0000 - fp: 3836.0000 - tn: 36242.0000 - fn: 3275.0000 - accuracy: 0.9114 - precision: 0.9058 - recall: 0.9184 - auc: 0.9743 - prc: 0.9742 - val_loss: 0.2106 - val_tp: 9314.0000 - val_fp: 1108.0000 - val_tn: 8923.0000 - val_fn: 714.0000 - val_accuracy: 0.9092 - val_precision: 0.8937 - val_recall: 0.9288 - val_auc: 0.9729 - val_prc: 0.9721
# Epoch 329/500
# 17/17 [==============================] - 0s 16ms/step - loss: 0.2050 - tp: 36831.0000 - fp: 3822.0000 - tn: 36256.0000 - fn: 3323.0000 - accuracy: 0.9109 - precision: 0.9060 - recall: 0.9172 - auc: 0.9740 - prc: 0.9740 - val_loss: 0.2110 - val_tp: 9472.0000 - val_fp: 1286.0000 - val_tn: 8745.0000 - val_fn: 556.0000 - val_accuracy: 0.9082 - val_precision: 0.8805 - val_recall: 0.9446 - val_auc: 0.9736 - val_prc: 0.9726
# Epoch 330/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2045 - tp: 36880.0000 - fp: 3879.0000 - tn: 36199.0000 - fn: 3274.0000 - accuracy: 0.9108 - precision: 0.9048 - recall: 0.9185 - auc: 0.9741 - prc: 0.9740 - val_loss: 0.2093 - val_tp: 9471.0000 - val_fp: 1245.0000 - val_tn: 8786.0000 - val_fn: 557.0000 - val_accuracy: 0.9102 - val_precision: 0.8838 - val_recall: 0.9445 - val_auc: 0.9739 - val_prc: 0.9729
# Epoch 331/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2045 - tp: 37014.0000 - fp: 3971.0000 - tn: 36107.0000 - fn: 3140.0000 - accuracy: 0.9114 - precision: 0.9031 - recall: 0.9218 - auc: 0.9741 - prc: 0.9741 - val_loss: 0.2081 - val_tp: 9157.0000 - val_fp: 952.0000 - val_tn: 9079.0000 - val_fn: 871.0000 - val_accuracy: 0.9091 - val_precision: 0.9058 - val_recall: 0.9131 - val_auc: 0.9733 - val_prc: 0.9723
# Epoch 332/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2044 - tp: 36803.0000 - fp: 3816.0000 - tn: 36262.0000 - fn: 3351.0000 - accuracy: 0.9107 - precision: 0.9061 - recall: 0.9165 - auc: 0.9741 - prc: 0.9740 - val_loss: 0.2092 - val_tp: 9383.0000 - val_fp: 1186.0000 - val_tn: 8845.0000 - val_fn: 645.0000 - val_accuracy: 0.9087 - val_precision: 0.8878 - val_recall: 0.9357 - val_auc: 0.9734 - val_prc: 0.9724
# Epoch 333/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2040 - tp: 36946.0000 - fp: 3851.0000 - tn: 36227.0000 - fn: 3208.0000 - accuracy: 0.9120 - precision: 0.9056 - recall: 0.9201 - auc: 0.9742 - prc: 0.9743 - val_loss: 0.2064 - val_tp: 9240.0000 - val_fp: 1028.0000 - val_tn: 9003.0000 - val_fn: 788.0000 - val_accuracy: 0.9095 - val_precision: 0.8999 - val_recall: 0.9214 - val_auc: 0.9738 - val_prc: 0.9728
# Epoch 334/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.2029 - tp: 37058.0000 - fp: 3882.0000 - tn: 36196.0000 - fn: 3096.0000 - accuracy: 0.9130 - precision: 0.9052 - recall: 0.9229 - auc: 0.9746 - prc: 0.9746 - val_loss: 0.2084 - val_tp: 8982.0000 - val_fp: 850.0000 - val_tn: 9181.0000 - val_fn: 1046.0000 - val_accuracy: 0.9055 - val_precision: 0.9135 - val_recall: 0.8957 - val_auc: 0.9736 - val_prc: 0.9732
# Epoch 335/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2044 - tp: 36866.0000 - fp: 3932.0000 - tn: 36146.0000 - fn: 3288.0000 - accuracy: 0.9100 - precision: 0.9036 - recall: 0.9181 - auc: 0.9741 - prc: 0.9741 - val_loss: 0.2058 - val_tp: 9288.0000 - val_fp: 1027.0000 - val_tn: 9004.0000 - val_fn: 740.0000 - val_accuracy: 0.9119 - val_precision: 0.9004 - val_recall: 0.9262 - val_auc: 0.9740 - val_prc: 0.9730
# Epoch 336/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.2032 - tp: 36894.0000 - fp: 3807.0000 - tn: 36271.0000 - fn: 3260.0000 - accuracy: 0.9119 - precision: 0.9065 - recall: 0.9188 - auc: 0.9745 - prc: 0.9746 - val_loss: 0.2057 - val_tp: 9363.0000 - val_fp: 1101.0000 - val_tn: 8930.0000 - val_fn: 665.0000 - val_accuracy: 0.9120 - val_precision: 0.8948 - val_recall: 0.9337 - val_auc: 0.9742 - val_prc: 0.9732
# Restoring model weights from the end of the best epoch.
# Epoch 00336: early stopping
# loss :  0.21136543154716492 /n
# tp :  11316.0 /n
# fp :  1072.0 /n
# tn :  11501.0 /n
# fn :  1184.0 /n
# accuracy :  0.9100227355957031 /n
# precision :  0.9134646654129028 /n
# recall :  0.9052799940109253 /n
# auc :  0.9725505709648132 /n
# prc :  0.9719568490982056 /n
# True Negatives:  11501
# False Positives:  1072
# False Negatives:  1184
# True Positives:  11316
# Total:  12500
# INFO:tensorflow:Assets written to: C:\Users\angel\AppData\Local\Temp\tmp_oium9j0\model\data\model\assets

# %% [markdown]
# ## 5. Register Model

# %%
model_uri = "runs:/{}/{}".format(run.info.run_id, model_name)
mv = mlflow.register_model(model_uri, model_name)
print("Name: {}".format(mv.name))
print("Version: {}".format(mv.version))
# Out:
# Successfully registered model 'cut_stop_posenet'.
# 2021/05/17 20:35:17 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: cut_stop_posenet, version 1
# Name: cut_stop_posenet
# Version: 1
# Created version '1' of model 'cut_stop_posenet'.
