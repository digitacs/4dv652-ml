# %% [markdown]
# # Dense Model for Kinect data
#
# We've trained a classifier from Keras Sequential class with Dense layers to categorize good and bad exercises from Kinect data. This data was preprocessed according to the Notebook **data_preparation_problemA_kinect.ipynb**.
#
# ## Section for Configurations and Imports

# %%
import os 
import tempfile

import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow import keras

# MLflow dashboard
import mlflow
mlflow.set_tracking_uri('http://35.228.45.76:5000')
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='../../mlflow-312506-8cfad529f4fd.json'

# Import data augmentation
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from augmentation.methods import *

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
random_state = 47
np.random.seed(random_state)

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ## 1. Load Prepared Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/digitacs/4dv652-ml/main/datasets/all_good_bad_problemA_kinect/good_bad_kinect.csv')

df.fillna(0, inplace=True) # Replace NaN with 0

df.shape
# Out:
# (152880, 40)

# %% [markdown]
# ## 2. Split into sets for training, validation, and testing + use and save scaler

# %%
X = df.drop(columns=['quality'])
y = df['quality']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

print('Training features shape:', X_train.shape)
print('Training labels shape:', y_train.shape, '\n')

print('Validation features shape:', X_val.shape)
print('Validation labels shape:', y_val.shape, '\n')

print('Test features shape:', X_test.shape)
print('Test labels shape:', y_test.shape, '\n')
# Out:
# Training features shape: (110073, 39)
# Training labels shape: (110073,)
#
# Validation features shape: (27519, 39)
# Validation labels shape: (27519,)
#
# Test features shape: (15288, 39)
# Test labels shape: (15288,)

# %% [markdown]
# ## 3. Define the Model
#
# The model will be created using the make_model function that uses a Layer Factory so we can experiment with different layer configurations.
#
# We're using standard evaluation metrics for binary classification problems to evaulate model performance.
#
# ### 3.1 Layer factory

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %% [markdown]
# ### 3.2 Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer

METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(layers, input_dim, loss, optimizer, learning_rate=0.001, metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %% [markdown]
# ## 4. MLflow Experimentation
#
# ### 4.1 Configurations

# %%
from mlflow.models.signature import ModelSignature
from mlflow.types.schema import Schema, ColSpec

input_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "head_z"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_shoulder_z"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "left_elbow_z"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_shoulder_z"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "right_elbow_z"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "left_hand_z"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "right_hand_z"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "left_hip_z"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "right_hip_z"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "left_knee_z"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "right_knee_z"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "left_foot_z"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
    ColSpec("double", "right_foot_z"),
])
output_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "head_z"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_shoulder_z"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "left_elbow_z"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_shoulder_z"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "right_elbow_z"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "left_hand_z"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "right_hand_z"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "left_hip_z"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "right_hip_z"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "left_knee_z"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "right_knee_z"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "left_foot_z"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
    ColSpec("double", "right_foot_z"),
])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# %% [markdown]
# ### 4.2 Helper functions

# %%
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

def plot_loss(history, label, n):
  plt.semilogy(history.epoch, history.history['loss'],
               color=colors[n], label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               color=colors[n], label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('True Negatives: ', cm[0][0])
    print('False Positives: ', cm[0][1])
    print('False Negatives: ', cm[1][0])
    print('True Positives: ', cm[1][1])
    print('Total: ', np.sum(cm[1]))


def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# ### 4.3 Configurations

# %%
EPOCHS = 500
BATCH_SIZE = 2050

input_dim = X_train.shape[1]
output_size = 1

units = 64
activation = 'relu'
kernel_initializer = 'he_uniform'
output_activation = 'sigmoid'
optimizer = 'Adam'
learning_rate = 1e-3

LAYERS = [ 
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':56, 'activation': activation },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':output_size, 'activation': output_activation }
]

# %% [markdown]
# ### 4.4 Start Run

# %%
model_name = 'dense_model_kinect'

with mlflow.start_run(run_name=model_name) as run:

    run_id = run.info.run_id

    model = make_model(metrics=METRICS, 
                        layers=LAYERS, 
                        loss='binary_crossentropy', 
                        optimizer=optimizer, 
                        learning_rate=learning_rate, 
                        input_dim=input_dim)
    
    with tf.device('/CPU:0'):
        history = model.fit(
            x=X_train, 
            y=y_train, 
            validation_data=(X_val, y_val), 
            shuffle=True, 
            epochs=EPOCHS, 
            verbose=1,
            batch_size=BATCH_SIZE, 
            callbacks=[early_stopping])

        # Plot training history
        plot_loss(history, "Bias", 0)
        plt.savefig("loss.jpg")
        mlflow.log_artifact("loss.jpg")
        plt.show()
        
        # Plot and log metrics
        predictions_train = model.predict(X_train)
        predictions_test = model.predict(X_test)

        plot_metrics(history)
        plt.savefig("metrics.jpg")
        mlflow.log_artifact("metrics.jpg")
        plt.show()

        # Confusion matrix
        results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
        for name, value in zip(model.metrics_names, results):
            print(name, ': ', value, '/n')
        plot_cm(y_test, predictions_test)
        plt.savefig("cm.jpg")
        mlflow.log_artifact("cm.jpg")
        plt.show()

        # ROC Curve
        plot_roc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("roc.jpg")
        mlflow.log_artifact("roc.jpg")
        plt.show()

        # Precision-Recall Curve (PRC)
        plot_prc("Train Predictions", y_train, predictions_train, color=colors[0])
        plot_prc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("prc.jpg")
        mlflow.log_artifact("prc.jpg")
        plt.show()
        
        # Log model, scaler, model parameters to MLflow
        mlflow.log_param("units", units)
        mlflow.log_param("activation", activation)
        mlflow.log_param("kernel_initializer", kernel_initializer)
        mlflow.log_param("output activation", output_activation)
        mlflow.log_param("optimizer", optimizer)
        mlflow.log_param("learning rate", learning_rate)
        mlflow.log_param("batch size", BATCH_SIZE)
        mlflow.log_metric("accuracy", results[5])
        mlflow.log_metric("average precision score", results[6])
        mlflow.log_metric("recall", results[7])
        mlflow.log_metric("auc", results[8])

        mlflow.keras.log_model(model, model_name, signature=signature)
        mlflow.sklearn.log_model(scaler, 'InputScaler')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                2560
# _________________________________________________________________
# dense_5 (Dense)              (None, 56)                3640
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                3648
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 9,913
# Trainable params: 9,913
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 54/54 [==============================] - 3s 26ms/step - loss: 0.5682 - tp: 73678.0000 - fp: 27739.0000 - tn: 6613.0000 - fn: 2043.0000 - accuracy: 0.7294 - precision: 0.7265 - recall: 0.9730 - auc: 0.6772 - prc: 0.8001 - val_loss: 0.4732 - val_tp: 18955.0000 - val_fp: 5285.0000 - val_tn: 3188.0000 - val_fn: 91.0000 - val_accuracy: 0.8046 - val_precision: 0.7820 - val_recall: 0.9952 - val_auc: 0.8111 - val_prc: 0.8809
# Epoch 2/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.4053 - tp: 75009.0000 - fp: 16905.0000 - tn: 17447.0000 - fn: 712.0000 - accuracy: 0.8400 - precision: 0.8161 - recall: 0.9906 - auc: 0.8589 - prc: 0.9121 - val_loss: 0.3450 - val_tp: 18788.0000 - val_fp: 3332.0000 - val_tn: 5141.0000 - val_fn: 258.0000 - val_accuracy: 0.8695 - val_precision: 0.8494 - val_recall: 0.9865 - val_auc: 0.8963 - val_prc: 0.9378
# Epoch 3/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.3152 - tp: 74542.0000 - fp: 11939.0000 - tn: 22413.0000 - fn: 1179.0000 - accuracy: 0.8808 - precision: 0.8619 - recall: 0.9844 - auc: 0.9102 - prc: 0.9451 - val_loss: 0.2847 - val_tp: 18773.0000 - val_fp: 2539.0000 - val_tn: 5934.0000 - val_fn: 273.0000 - val_accuracy: 0.8978 - val_precision: 0.8809 - val_recall: 0.9857 - val_auc: 0.9246 - val_prc: 0.9535
# Epoch 4/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2728 - tp: 74589.0000 - fp: 9988.0000 - tn: 24364.0000 - fn: 1132.0000 - accuracy: 0.8990 - precision: 0.8819 - recall: 0.9851 - auc: 0.9304 - prc: 0.9577 - val_loss: 0.2552 - val_tp: 18768.0000 - val_fp: 2348.0000 - val_tn: 6125.0000 - val_fn: 278.0000 - val_accuracy: 0.9046 - val_precision: 0.8888 - val_recall: 0.9854 - val_auc: 0.9397 - val_prc: 0.9643
# Epoch 5/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2489 - tp: 74598.0000 - fp: 8937.0000 - tn: 25415.0000 - fn: 1123.0000 - accuracy: 0.9086 - precision: 0.8930 - recall: 0.9852 - auc: 0.9409 - prc: 0.9646 - val_loss: 0.2398 - val_tp: 18675.0000 - val_fp: 1921.0000 - val_tn: 6552.0000 - val_fn: 371.0000 - val_accuracy: 0.9167 - val_precision: 0.9067 - val_recall: 0.9805 - val_auc: 0.9457 - val_prc: 0.9672
# Epoch 6/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2334 - tp: 74486.0000 - fp: 8175.0000 - tn: 26177.0000 - fn: 1235.0000 - accuracy: 0.9145 - precision: 0.9011 - recall: 0.9837 - auc: 0.9474 - prc: 0.9690 - val_loss: 0.2245 - val_tp: 18703.0000 - val_fp: 1902.0000 - val_tn: 6571.0000 - val_fn: 343.0000 - val_accuracy: 0.9184 - val_precision: 0.9077 - val_recall: 0.9820 - val_auc: 0.9510 - val_prc: 0.9712
# Epoch 7/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2198 - tp: 74479.0000 - fp: 7590.0000 - tn: 26762.0000 - fn: 1242.0000 - accuracy: 0.9198 - precision: 0.9075 - recall: 0.9836 - auc: 0.9536 - prc: 0.9732 - val_loss: 0.2143 - val_tp: 18813.0000 - val_fp: 1985.0000 - val_tn: 6488.0000 - val_fn: 233.0000 - val_accuracy: 0.9194 - val_precision: 0.9046 - val_recall: 0.9878 - val_auc: 0.9562 - val_prc: 0.9751
# Epoch 8/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2106 - tp: 74390.0000 - fp: 7265.0000 - tn: 27087.0000 - fn: 1331.0000 - accuracy: 0.9219 - precision: 0.9110 - recall: 0.9824 - auc: 0.9575 - prc: 0.9756 - val_loss: 0.2132 - val_tp: 18815.0000 - val_fp: 2005.0000 - val_tn: 6468.0000 - val_fn: 231.0000 - val_accuracy: 0.9187 - val_precision: 0.9037 - val_recall: 0.9879 - val_auc: 0.9579 - val_prc: 0.9763
# Epoch 9/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.2009 - tp: 74439.0000 - fp: 6920.0000 - tn: 27432.0000 - fn: 1282.0000 - accuracy: 0.9255 - precision: 0.9149 - recall: 0.9831 - auc: 0.9615 - prc: 0.9784 - val_loss: 0.1969 - val_tp: 18656.0000 - val_fp: 1610.0000 - val_tn: 6863.0000 - val_fn: 390.0000 - val_accuracy: 0.9273 - val_precision: 0.9206 - val_recall: 0.9795 - val_auc: 0.9636 - val_prc: 0.9805
# Epoch 10/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1909 - tp: 74452.0000 - fp: 6553.0000 - tn: 27799.0000 - fn: 1269.0000 - accuracy: 0.9289 - precision: 0.9191 - recall: 0.9832 - auc: 0.9658 - prc: 0.9810 - val_loss: 0.1912 - val_tp: 18715.0000 - val_fp: 1674.0000 - val_tn: 6799.0000 - val_fn: 331.0000 - val_accuracy: 0.9271 - val_precision: 0.9179 - val_recall: 0.9826 - val_auc: 0.9649 - val_prc: 0.9810
# Epoch 11/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1822 - tp: 74502.0000 - fp: 6237.0000 - tn: 28115.0000 - fn: 1219.0000 - accuracy: 0.9323 - precision: 0.9228 - recall: 0.9839 - auc: 0.9689 - prc: 0.9829 - val_loss: 0.1791 - val_tp: 18659.0000 - val_fp: 1411.0000 - val_tn: 7062.0000 - val_fn: 387.0000 - val_accuracy: 0.9347 - val_precision: 0.9297 - val_recall: 0.9797 - val_auc: 0.9695 - val_prc: 0.9835
# Epoch 12/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1758 - tp: 74461.0000 - fp: 6033.0000 - tn: 28319.0000 - fn: 1260.0000 - accuracy: 0.9337 - precision: 0.9251 - recall: 0.9834 - auc: 0.9713 - prc: 0.9844 - val_loss: 0.1770 - val_tp: 18731.0000 - val_fp: 1537.0000 - val_tn: 6936.0000 - val_fn: 315.0000 - val_accuracy: 0.9327 - val_precision: 0.9242 - val_recall: 0.9835 - val_auc: 0.9707 - val_prc: 0.9843
# Epoch 13/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1690 - tp: 74453.0000 - fp: 5677.0000 - tn: 28675.0000 - fn: 1268.0000 - accuracy: 0.9369 - precision: 0.9292 - recall: 0.9833 - auc: 0.9735 - prc: 0.9857 - val_loss: 0.1761 - val_tp: 18895.0000 - val_fp: 1745.0000 - val_tn: 6728.0000 - val_fn: 151.0000 - val_accuracy: 0.9311 - val_precision: 0.9155 - val_recall: 0.9921 - val_auc: 0.9745 - val_prc: 0.9863
# Epoch 14/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1669 - tp: 74435.0000 - fp: 5527.0000 - tn: 28825.0000 - fn: 1286.0000 - accuracy: 0.9381 - precision: 0.9309 - recall: 0.9830 - auc: 0.9737 - prc: 0.9858 - val_loss: 0.1650 - val_tp: 18814.0000 - val_fp: 1526.0000 - val_tn: 6947.0000 - val_fn: 232.0000 - val_accuracy: 0.9361 - val_precision: 0.9250 - val_recall: 0.9878 - val_auc: 0.9757 - val_prc: 0.9873
# Epoch 15/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1587 - tp: 74540.0000 - fp: 5338.0000 - tn: 29014.0000 - fn: 1181.0000 - accuracy: 0.9408 - precision: 0.9332 - recall: 0.9844 - auc: 0.9767 - prc: 0.9875 - val_loss: 0.1627 - val_tp: 18512.0000 - val_fp: 1102.0000 - val_tn: 7371.0000 - val_fn: 534.0000 - val_accuracy: 0.9406 - val_precision: 0.9438 - val_recall: 0.9720 - val_auc: 0.9765 - val_prc: 0.9876
# Epoch 16/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1550 - tp: 74482.0000 - fp: 5141.0000 - tn: 29211.0000 - fn: 1239.0000 - accuracy: 0.9420 - precision: 0.9354 - recall: 0.9836 - auc: 0.9777 - prc: 0.9880 - val_loss: 0.1523 - val_tp: 18643.0000 - val_fp: 1128.0000 - val_tn: 7345.0000 - val_fn: 403.0000 - val_accuracy: 0.9444 - val_precision: 0.9429 - val_recall: 0.9788 - val_auc: 0.9785 - val_prc: 0.9888
# Epoch 17/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1479 - tp: 74555.0000 - fp: 4893.0000 - tn: 29459.0000 - fn: 1166.0000 - accuracy: 0.9450 - precision: 0.9384 - recall: 0.9846 - auc: 0.9799 - prc: 0.9893 - val_loss: 0.1489 - val_tp: 18722.0000 - val_fp: 1189.0000 - val_tn: 7284.0000 - val_fn: 324.0000 - val_accuracy: 0.9450 - val_precision: 0.9403 - val_recall: 0.9830 - val_auc: 0.9787 - val_prc: 0.9887
# Epoch 18/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1440 - tp: 74572.0000 - fp: 4748.0000 - tn: 29604.0000 - fn: 1149.0000 - accuracy: 0.9464 - precision: 0.9401 - recall: 0.9848 - auc: 0.9809 - prc: 0.9898 - val_loss: 0.1446 - val_tp: 18814.0000 - val_fp: 1241.0000 - val_tn: 7232.0000 - val_fn: 232.0000 - val_accuracy: 0.9465 - val_precision: 0.9381 - val_recall: 0.9878 - val_auc: 0.9806 - val_prc: 0.9899
# Epoch 19/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1401 - tp: 74593.0000 - fp: 4595.0000 - tn: 29757.0000 - fn: 1128.0000 - accuracy: 0.9480 - precision: 0.9420 - recall: 0.9851 - auc: 0.9819 - prc: 0.9904 - val_loss: 0.1408 - val_tp: 18726.0000 - val_fp: 1091.0000 - val_tn: 7382.0000 - val_fn: 320.0000 - val_accuracy: 0.9487 - val_precision: 0.9449 - val_recall: 0.9832 - val_auc: 0.9812 - val_prc: 0.9901
# Epoch 20/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1402 - tp: 74504.0000 - fp: 4536.0000 - tn: 29816.0000 - fn: 1217.0000 - accuracy: 0.9477 - precision: 0.9426 - recall: 0.9839 - auc: 0.9819 - prc: 0.9903 - val_loss: 0.1390 - val_tp: 18737.0000 - val_fp: 1099.0000 - val_tn: 7374.0000 - val_fn: 309.0000 - val_accuracy: 0.9488 - val_precision: 0.9446 - val_recall: 0.9838 - val_auc: 0.9816 - val_prc: 0.9904
# Epoch 21/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1333 - tp: 74620.0000 - fp: 4341.0000 - tn: 30011.0000 - fn: 1101.0000 - accuracy: 0.9506 - precision: 0.9450 - recall: 0.9855 - auc: 0.9836 - prc: 0.9913 - val_loss: 0.1354 - val_tp: 18663.0000 - val_fp: 994.0000 - val_tn: 7479.0000 - val_fn: 383.0000 - val_accuracy: 0.9500 - val_precision: 0.9494 - val_recall: 0.9799 - val_auc: 0.9827 - val_prc: 0.9910
# Epoch 22/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1352 - tp: 74515.0000 - fp: 4346.0000 - tn: 30006.0000 - fn: 1206.0000 - accuracy: 0.9496 - precision: 0.9449 - recall: 0.9841 - auc: 0.9833 - prc: 0.9912 - val_loss: 0.1315 - val_tp: 18786.0000 - val_fp: 1050.0000 - val_tn: 7423.0000 - val_fn: 260.0000 - val_accuracy: 0.9524 - val_precision: 0.9471 - val_recall: 0.9863 - val_auc: 0.9840 - val_prc: 0.9918
# Epoch 23/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1272 - tp: 74638.0000 - fp: 4161.0000 - tn: 30191.0000 - fn: 1083.0000 - accuracy: 0.9524 - precision: 0.9472 - recall: 0.9857 - auc: 0.9855 - prc: 0.9923 - val_loss: 0.1300 - val_tp: 18812.0000 - val_fp: 1071.0000 - val_tn: 7402.0000 - val_fn: 234.0000 - val_accuracy: 0.9526 - val_precision: 0.9461 - val_recall: 0.9877 - val_auc: 0.9839 - val_prc: 0.9915
# Epoch 24/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1278 - tp: 74535.0000 - fp: 4127.0000 - tn: 30225.0000 - fn: 1186.0000 - accuracy: 0.9517 - precision: 0.9475 - recall: 0.9843 - auc: 0.9852 - prc: 0.9922 - val_loss: 0.1271 - val_tp: 18804.0000 - val_fp: 1076.0000 - val_tn: 7397.0000 - val_fn: 242.0000 - val_accuracy: 0.9521 - val_precision: 0.9459 - val_recall: 0.9873 - val_auc: 0.9856 - val_prc: 0.9925
# Epoch 25/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1241 - tp: 74612.0000 - fp: 3980.0000 - tn: 30372.0000 - fn: 1109.0000 - accuracy: 0.9538 - precision: 0.9494 - recall: 0.9854 - auc: 0.9860 - prc: 0.9926 - val_loss: 0.1256 - val_tp: 18695.0000 - val_fp: 875.0000 - val_tn: 7598.0000 - val_fn: 351.0000 - val_accuracy: 0.9554 - val_precision: 0.9553 - val_recall: 0.9816 - val_auc: 0.9865 - val_prc: 0.9931
# Epoch 26/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1210 - tp: 74554.0000 - fp: 3829.0000 - tn: 30523.0000 - fn: 1167.0000 - accuracy: 0.9546 - precision: 0.9512 - recall: 0.9846 - auc: 0.9868 - prc: 0.9931 - val_loss: 0.1222 - val_tp: 18781.0000 - val_fp: 988.0000 - val_tn: 7485.0000 - val_fn: 265.0000 - val_accuracy: 0.9545 - val_precision: 0.9500 - val_recall: 0.9861 - val_auc: 0.9865 - val_prc: 0.9928
# Epoch 27/500
# 54/54 [==============================] - 1s 10ms/step - loss: 0.1169 - tp: 74682.0000 - fp: 3762.0000 - tn: 30590.0000 - fn: 1039.0000 - accuracy: 0.9564 - precision: 0.9520 - recall: 0.9863 - auc: 0.9878 - prc: 0.9936 - val_loss: 0.1174 - val_tp: 18792.0000 - val_fp: 927.0000 - val_tn: 7546.0000 - val_fn: 254.0000 - val_accuracy: 0.9571 - val_precision: 0.9530 - val_recall: 0.9867 - val_auc: 0.9874 - val_prc: 0.9935
# Epoch 28/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1136 - tp: 74683.0000 - fp: 3620.0000 - tn: 30732.0000 - fn: 1038.0000 - accuracy: 0.9577 - precision: 0.9538 - recall: 0.9863 - auc: 0.9886 - prc: 0.9940 - val_loss: 0.1170 - val_tp: 18669.0000 - val_fp: 783.0000 - val_tn: 7690.0000 - val_fn: 377.0000 - val_accuracy: 0.9578 - val_precision: 0.9597 - val_recall: 0.9802 - val_auc: 0.9874 - val_prc: 0.9932
# Epoch 29/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1113 - tp: 74688.0000 - fp: 3491.0000 - tn: 30861.0000 - fn: 1033.0000 - accuracy: 0.9589 - precision: 0.9553 - recall: 0.9864 - auc: 0.9889 - prc: 0.9942 - val_loss: 0.1121 - val_tp: 18903.0000 - val_fp: 1017.0000 - val_tn: 7456.0000 - val_fn: 143.0000 - val_accuracy: 0.9578 - val_precision: 0.9489 - val_recall: 0.9925 - val_auc: 0.9891 - val_prc: 0.9942
# Epoch 30/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1086 - tp: 74691.0000 - fp: 3435.0000 - tn: 30917.0000 - fn: 1030.0000 - accuracy: 0.9594 - precision: 0.9560 - recall: 0.9864 - auc: 0.9896 - prc: 0.9946 - val_loss: 0.1101 - val_tp: 18772.0000 - val_fp: 849.0000 - val_tn: 7624.0000 - val_fn: 274.0000 - val_accuracy: 0.9592 - val_precision: 0.9567 - val_recall: 0.9856 - val_auc: 0.9892 - val_prc: 0.9945
# Epoch 31/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1075 - tp: 74662.0000 - fp: 3427.0000 - tn: 30925.0000 - fn: 1059.0000 - accuracy: 0.9592 - precision: 0.9561 - recall: 0.9860 - auc: 0.9898 - prc: 0.9946 - val_loss: 0.1093 - val_tp: 18751.0000 - val_fp: 771.0000 - val_tn: 7702.0000 - val_fn: 295.0000 - val_accuracy: 0.9613 - val_precision: 0.9605 - val_recall: 0.9845 - val_auc: 0.9893 - val_prc: 0.9944
# Epoch 32/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1055 - tp: 74645.0000 - fp: 3327.0000 - tn: 31025.0000 - fn: 1076.0000 - accuracy: 0.9600 - precision: 0.9573 - recall: 0.9858 - auc: 0.9902 - prc: 0.9948 - val_loss: 0.1074 - val_tp: 18770.0000 - val_fp: 804.0000 - val_tn: 7669.0000 - val_fn: 276.0000 - val_accuracy: 0.9608 - val_precision: 0.9589 - val_recall: 0.9855 - val_auc: 0.9901 - val_prc: 0.9949
# Epoch 33/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1021 - tp: 74714.0000 - fp: 3183.0000 - tn: 31169.0000 - fn: 1007.0000 - accuracy: 0.9619 - precision: 0.9591 - recall: 0.9867 - auc: 0.9909 - prc: 0.9953 - val_loss: 0.1043 - val_tp: 18794.0000 - val_fp: 819.0000 - val_tn: 7654.0000 - val_fn: 252.0000 - val_accuracy: 0.9611 - val_precision: 0.9582 - val_recall: 0.9868 - val_auc: 0.9905 - val_prc: 0.9950
# Epoch 34/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.1005 - tp: 74746.0000 - fp: 3142.0000 - tn: 31210.0000 - fn: 975.0000 - accuracy: 0.9626 - precision: 0.9597 - recall: 0.9871 - auc: 0.9913 - prc: 0.9955 - val_loss: 0.1012 - val_tp: 18745.0000 - val_fp: 735.0000 - val_tn: 7738.0000 - val_fn: 301.0000 - val_accuracy: 0.9624 - val_precision: 0.9623 - val_recall: 0.9842 - val_auc: 0.9913 - val_prc: 0.9957
# Epoch 35/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0975 - tp: 74728.0000 - fp: 3043.0000 - tn: 31309.0000 - fn: 993.0000 - accuracy: 0.9633 - precision: 0.9609 - recall: 0.9869 - auc: 0.9918 - prc: 0.9958 - val_loss: 0.0988 - val_tp: 18788.0000 - val_fp: 750.0000 - val_tn: 7723.0000 - val_fn: 258.0000 - val_accuracy: 0.9634 - val_precision: 0.9616 - val_recall: 0.9865 - val_auc: 0.9915 - val_prc: 0.9956
# Epoch 36/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0964 - tp: 74745.0000 - fp: 3016.0000 - tn: 31336.0000 - fn: 976.0000 - accuracy: 0.9637 - precision: 0.9612 - recall: 0.9871 - auc: 0.9919 - prc: 0.9957 - val_loss: 0.1059 - val_tp: 18854.0000 - val_fp: 910.0000 - val_tn: 7563.0000 - val_fn: 192.0000 - val_accuracy: 0.9600 - val_precision: 0.9540 - val_recall: 0.9899 - val_auc: 0.9901 - val_prc: 0.9945
# Epoch 37/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0975 - tp: 74717.0000 - fp: 3013.0000 - tn: 31339.0000 - fn: 1004.0000 - accuracy: 0.9635 - precision: 0.9612 - recall: 0.9867 - auc: 0.9916 - prc: 0.9956 - val_loss: 0.0986 - val_tp: 18830.0000 - val_fp: 805.0000 - val_tn: 7668.0000 - val_fn: 216.0000 - val_accuracy: 0.9629 - val_precision: 0.9590 - val_recall: 0.9887 - val_auc: 0.9913 - val_prc: 0.9955
# Epoch 38/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0938 - tp: 74741.0000 - fp: 2884.0000 - tn: 31468.0000 - fn: 980.0000 - accuracy: 0.9649 - precision: 0.9628 - recall: 0.9871 - auc: 0.9923 - prc: 0.9959 - val_loss: 0.1009 - val_tp: 18853.0000 - val_fp: 887.0000 - val_tn: 7586.0000 - val_fn: 193.0000 - val_accuracy: 0.9608 - val_precision: 0.9551 - val_recall: 0.9899 - val_auc: 0.9915 - val_prc: 0.9956
# Epoch 39/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0917 - tp: 74748.0000 - fp: 2838.0000 - tn: 31514.0000 - fn: 973.0000 - accuracy: 0.9654 - precision: 0.9634 - recall: 0.9872 - auc: 0.9928 - prc: 0.9962 - val_loss: 0.0925 - val_tp: 18807.0000 - val_fp: 737.0000 - val_tn: 7736.0000 - val_fn: 239.0000 - val_accuracy: 0.9645 - val_precision: 0.9623 - val_recall: 0.9875 - val_auc: 0.9926 - val_prc: 0.9962
# Epoch 40/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0892 - tp: 74819.0000 - fp: 2760.0000 - tn: 31592.0000 - fn: 902.0000 - accuracy: 0.9667 - precision: 0.9644 - recall: 0.9881 - auc: 0.9931 - prc: 0.9963 - val_loss: 0.0909 - val_tp: 18833.0000 - val_fp: 717.0000 - val_tn: 7756.0000 - val_fn: 213.0000 - val_accuracy: 0.9662 - val_precision: 0.9633 - val_recall: 0.9888 - val_auc: 0.9928 - val_prc: 0.9962
# Epoch 41/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0891 - tp: 74783.0000 - fp: 2740.0000 - tn: 31612.0000 - fn: 938.0000 - accuracy: 0.9666 - precision: 0.9647 - recall: 0.9876 - auc: 0.9931 - prc: 0.9963 - val_loss: 0.0896 - val_tp: 18866.0000 - val_fp: 738.0000 - val_tn: 7735.0000 - val_fn: 180.0000 - val_accuracy: 0.9666 - val_precision: 0.9624 - val_recall: 0.9905 - val_auc: 0.9928 - val_prc: 0.9961
# Epoch 42/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0887 - tp: 74750.0000 - fp: 2703.0000 - tn: 31649.0000 - fn: 971.0000 - accuracy: 0.9666 - precision: 0.9651 - recall: 0.9872 - auc: 0.9931 - prc: 0.9963 - val_loss: 0.0868 - val_tp: 18839.0000 - val_fp: 686.0000 - val_tn: 7787.0000 - val_fn: 207.0000 - val_accuracy: 0.9675 - val_precision: 0.9649 - val_recall: 0.9891 - val_auc: 0.9937 - val_prc: 0.9969
# Epoch 43/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0849 - tp: 74818.0000 - fp: 2611.0000 - tn: 31741.0000 - fn: 903.0000 - accuracy: 0.9681 - precision: 0.9663 - recall: 0.9881 - auc: 0.9937 - prc: 0.9967 - val_loss: 0.0858 - val_tp: 18797.0000 - val_fp: 644.0000 - val_tn: 7829.0000 - val_fn: 249.0000 - val_accuracy: 0.9675 - val_precision: 0.9669 - val_recall: 0.9869 - val_auc: 0.9937 - val_prc: 0.9967
# Epoch 44/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0845 - tp: 74788.0000 - fp: 2576.0000 - tn: 31776.0000 - fn: 933.0000 - accuracy: 0.9681 - precision: 0.9667 - recall: 0.9877 - auc: 0.9938 - prc: 0.9967 - val_loss: 0.0902 - val_tp: 18870.0000 - val_fp: 774.0000 - val_tn: 7699.0000 - val_fn: 176.0000 - val_accuracy: 0.9655 - val_precision: 0.9606 - val_recall: 0.9908 - val_auc: 0.9932 - val_prc: 0.9964
# Epoch 45/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0869 - tp: 74727.0000 - fp: 2644.0000 - tn: 31708.0000 - fn: 994.0000 - accuracy: 0.9669 - precision: 0.9658 - recall: 0.9869 - auc: 0.9933 - prc: 0.9964 - val_loss: 0.0882 - val_tp: 18748.0000 - val_fp: 629.0000 - val_tn: 7844.0000 - val_fn: 298.0000 - val_accuracy: 0.9663 - val_precision: 0.9675 - val_recall: 0.9844 - val_auc: 0.9933 - val_prc: 0.9965
# Epoch 46/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0821 - tp: 74810.0000 - fp: 2493.0000 - tn: 31859.0000 - fn: 911.0000 - accuracy: 0.9691 - precision: 0.9678 - recall: 0.9880 - auc: 0.9941 - prc: 0.9968 - val_loss: 0.0844 - val_tp: 18847.0000 - val_fp: 647.0000 - val_tn: 7826.0000 - val_fn: 199.0000 - val_accuracy: 0.9693 - val_precision: 0.9668 - val_recall: 0.9896 - val_auc: 0.9935 - val_prc: 0.9965
# Epoch 47/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0809 - tp: 74814.0000 - fp: 2418.0000 - tn: 31934.0000 - fn: 907.0000 - accuracy: 0.9698 - precision: 0.9687 - recall: 0.9880 - auc: 0.9942 - prc: 0.9970 - val_loss: 0.0991 - val_tp: 18891.0000 - val_fp: 878.0000 - val_tn: 7595.0000 - val_fn: 155.0000 - val_accuracy: 0.9625 - val_precision: 0.9556 - val_recall: 0.9919 - val_auc: 0.9928 - val_prc: 0.9961
# Epoch 48/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0781 - tp: 74895.0000 - fp: 2371.0000 - tn: 31981.0000 - fn: 826.0000 - accuracy: 0.9710 - precision: 0.9693 - recall: 0.9891 - auc: 0.9947 - prc: 0.9971 - val_loss: 0.0785 - val_tp: 18828.0000 - val_fp: 573.0000 - val_tn: 7900.0000 - val_fn: 218.0000 - val_accuracy: 0.9713 - val_precision: 0.9705 - val_recall: 0.9886 - val_auc: 0.9945 - val_prc: 0.9971
# Epoch 49/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0743 - tp: 74929.0000 - fp: 2274.0000 - tn: 32078.0000 - fn: 792.0000 - accuracy: 0.9721 - precision: 0.9705 - recall: 0.9895 - auc: 0.9953 - prc: 0.9975 - val_loss: 0.0781 - val_tp: 18790.0000 - val_fp: 529.0000 - val_tn: 7944.0000 - val_fn: 256.0000 - val_accuracy: 0.9715 - val_precision: 0.9726 - val_recall: 0.9866 - val_auc: 0.9947 - val_prc: 0.9972
# Epoch 50/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0766 - tp: 74832.0000 - fp: 2229.0000 - tn: 32123.0000 - fn: 889.0000 - accuracy: 0.9717 - precision: 0.9711 - recall: 0.9883 - auc: 0.9949 - prc: 0.9973 - val_loss: 0.0913 - val_tp: 18903.0000 - val_fp: 798.0000 - val_tn: 7675.0000 - val_fn: 143.0000 - val_accuracy: 0.9658 - val_precision: 0.9595 - val_recall: 0.9925 - val_auc: 0.9928 - val_prc: 0.9958
# Epoch 51/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0761 - tp: 74896.0000 - fp: 2305.0000 - tn: 32047.0000 - fn: 825.0000 - accuracy: 0.9716 - precision: 0.9701 - recall: 0.9891 - auc: 0.9948 - prc: 0.9971 - val_loss: 0.0799 - val_tp: 18942.0000 - val_fp: 732.0000 - val_tn: 7741.0000 - val_fn: 104.0000 - val_accuracy: 0.9696 - val_precision: 0.9628 - val_recall: 0.9945 - val_auc: 0.9952 - val_prc: 0.9974
# Epoch 52/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0742 - tp: 74897.0000 - fp: 2213.0000 - tn: 32139.0000 - fn: 824.0000 - accuracy: 0.9724 - precision: 0.9713 - recall: 0.9891 - auc: 0.9951 - prc: 0.9973 - val_loss: 0.0853 - val_tp: 18653.0000 - val_fp: 497.0000 - val_tn: 7976.0000 - val_fn: 393.0000 - val_accuracy: 0.9677 - val_precision: 0.9740 - val_recall: 0.9794 - val_auc: 0.9939 - val_prc: 0.9968
# Epoch 53/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0716 - tp: 74918.0000 - fp: 2168.0000 - tn: 32184.0000 - fn: 803.0000 - accuracy: 0.9730 - precision: 0.9719 - recall: 0.9894 - auc: 0.9955 - prc: 0.9976 - val_loss: 0.0755 - val_tp: 18829.0000 - val_fp: 564.0000 - val_tn: 7909.0000 - val_fn: 217.0000 - val_accuracy: 0.9716 - val_precision: 0.9709 - val_recall: 0.9886 - val_auc: 0.9947 - val_prc: 0.9971
# Epoch 54/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0754 - tp: 74810.0000 - fp: 2235.0000 - tn: 32117.0000 - fn: 911.0000 - accuracy: 0.9714 - precision: 0.9710 - recall: 0.9880 - auc: 0.9948 - prc: 0.9972 - val_loss: 0.0714 - val_tp: 18891.0000 - val_fp: 611.0000 - val_tn: 7862.0000 - val_fn: 155.0000 - val_accuracy: 0.9722 - val_precision: 0.9687 - val_recall: 0.9919 - val_auc: 0.9957 - val_prc: 0.9977
# Epoch 55/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0699 - tp: 74925.0000 - fp: 2082.0000 - tn: 32270.0000 - fn: 796.0000 - accuracy: 0.9739 - precision: 0.9730 - recall: 0.9895 - auc: 0.9957 - prc: 0.9977 - val_loss: 0.0743 - val_tp: 18876.0000 - val_fp: 596.0000 - val_tn: 7877.0000 - val_fn: 170.0000 - val_accuracy: 0.9722 - val_precision: 0.9694 - val_recall: 0.9911 - val_auc: 0.9949 - val_prc: 0.9971
# Epoch 56/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0707 - tp: 74867.0000 - fp: 2084.0000 - tn: 32268.0000 - fn: 854.0000 - accuracy: 0.9733 - precision: 0.9729 - recall: 0.9887 - auc: 0.9955 - prc: 0.9976 - val_loss: 0.0704 - val_tp: 18960.0000 - val_fp: 646.0000 - val_tn: 7827.0000 - val_fn: 86.0000 - val_accuracy: 0.9734 - val_precision: 0.9671 - val_recall: 0.9955 - val_auc: 0.9957 - val_prc: 0.9975
# Epoch 57/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0683 - tp: 74956.0000 - fp: 2032.0000 - tn: 32320.0000 - fn: 765.0000 - accuracy: 0.9746 - precision: 0.9736 - recall: 0.9899 - auc: 0.9958 - prc: 0.9977 - val_loss: 0.0848 - val_tp: 18570.0000 - val_fp: 361.0000 - val_tn: 8112.0000 - val_fn: 476.0000 - val_accuracy: 0.9696 - val_precision: 0.9809 - val_recall: 0.9750 - val_auc: 0.9948 - val_prc: 0.9973
# Epoch 58/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0702 - tp: 74896.0000 - fp: 1986.0000 - tn: 32366.0000 - fn: 825.0000 - accuracy: 0.9745 - precision: 0.9742 - recall: 0.9891 - auc: 0.9955 - prc: 0.9975 - val_loss: 0.0707 - val_tp: 18892.0000 - val_fp: 587.0000 - val_tn: 7886.0000 - val_fn: 154.0000 - val_accuracy: 0.9731 - val_precision: 0.9699 - val_recall: 0.9919 - val_auc: 0.9958 - val_prc: 0.9977
# Epoch 59/500
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0679 - tp: 74918.0000 - fp: 1946.0000 - tn: 32406.0000 - fn: 803.0000 - accuracy: 0.9750 - precision: 0.9747 - recall: 0.9894 - auc: 0.9958 - prc: 0.9977 - val_loss: 0.0682 - val_tp: 18907.0000 - val_fp: 581.0000 - val_tn: 7892.0000 - val_fn: 139.0000 - val_accuracy: 0.9738 - val_precision: 0.9702 - val_recall: 0.9927 - val_auc: 0.9961 - val_prc: 0.9978
# Epoch 60/500
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0643 - tp: 75009.0000 - fp: 1880.0000 - tn: 32472.0000 - fn: 712.0000 - accuracy: 0.9765 - precision: 0.9755 - recall: 0.9906 - auc: 0.9962 - prc: 0.9979 - val_loss: 0.0752 - val_tp: 18632.0000 - val_fp: 387.0000 - val_tn: 8086.0000 - val_fn: 414.0000 - val_accuracy: 0.9709 - val_precision: 0.9797 - val_recall: 0.9783 - val_auc: 0.9955 - val_prc: 0.9977
# Epoch 61/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0639 - tp: 74985.0000 - fp: 1854.0000 - tn: 32498.0000 - fn: 736.0000 - accuracy: 0.9765 - precision: 0.9759 - recall: 0.9903 - auc: 0.9963 - prc: 0.9980 - val_loss: 0.0652 - val_tp: 18838.0000 - val_fp: 432.0000 - val_tn: 8041.0000 - val_fn: 208.0000 - val_accuracy: 0.9767 - val_precision: 0.9776 - val_recall: 0.9891 - val_auc: 0.9962 - val_prc: 0.9979
# Epoch 62/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0671 - tp: 74894.0000 - fp: 1903.0000 - tn: 32449.0000 - fn: 827.0000 - accuracy: 0.9752 - precision: 0.9752 - recall: 0.9891 - auc: 0.9959 - prc: 0.9978 - val_loss: 0.1056 - val_tp: 18969.0000 - val_fp: 906.0000 - val_tn: 7567.0000 - val_fn: 77.0000 - val_accuracy: 0.9643 - val_precision: 0.9544 - val_recall: 0.9960 - val_auc: 0.9923 - val_prc: 0.9951
# Epoch 63/500
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0672 - tp: 74911.0000 - fp: 1942.0000 - tn: 32410.0000 - fn: 810.0000 - accuracy: 0.9750 - precision: 0.9747 - recall: 0.9893 - auc: 0.9958 - prc: 0.9977 - val_loss: 0.0682 - val_tp: 18880.0000 - val_fp: 549.0000 - val_tn: 7924.0000 - val_fn: 166.0000 - val_accuracy: 0.9740 - val_precision: 0.9717 - val_recall: 0.9913 - val_auc: 0.9959 - val_prc: 0.9978
# Epoch 64/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0618 - tp: 74983.0000 - fp: 1766.0000 - tn: 32586.0000 - fn: 738.0000 - accuracy: 0.9773 - precision: 0.9770 - recall: 0.9903 - auc: 0.9965 - prc: 0.9980 - val_loss: 0.0795 - val_tp: 18959.0000 - val_fp: 730.0000 - val_tn: 7743.0000 - val_fn: 87.0000 - val_accuracy: 0.9703 - val_precision: 0.9629 - val_recall: 0.9954 - val_auc: 0.9953 - val_prc: 0.9972
# Epoch 65/500
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0665 - tp: 74905.0000 - fp: 1891.0000 - tn: 32461.0000 - fn: 816.0000 - accuracy: 0.9754 - precision: 0.9754 - recall: 0.9892 - auc: 0.9959 - prc: 0.9977 - val_loss: 0.0636 - val_tp: 18820.0000 - val_fp: 382.0000 - val_tn: 8091.0000 - val_fn: 226.0000 - val_accuracy: 0.9779 - val_precision: 0.9801 - val_recall: 0.9881 - val_auc: 0.9962 - val_prc: 0.9979
# Epoch 66/500
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0611 - tp: 75014.0000 - fp: 1761.0000 - tn: 32591.0000 - fn: 707.0000 - accuracy: 0.9776 - precision: 0.9771 - recall: 0.9907 - auc: 0.9965 - prc: 0.9981 - val_loss: 0.0681 - val_tp: 18940.0000 - val_fp: 592.0000 - val_tn: 7881.0000 - val_fn: 106.0000 - val_accuracy: 0.9746 - val_precision: 0.9697 - val_recall: 0.9944 - val_auc: 0.9958 - val_prc: 0.9975
# Epoch 67/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0578 - tp: 75077.0000 - fp: 1665.0000 - tn: 32687.0000 - fn: 644.0000 - accuracy: 0.9790 - precision: 0.9783 - recall: 0.9915 - auc: 0.9970 - prc: 0.9984 - val_loss: 0.0625 - val_tp: 18872.0000 - val_fp: 466.0000 - val_tn: 8007.0000 - val_fn: 174.0000 - val_accuracy: 0.9767 - val_precision: 0.9759 - val_recall: 0.9909 - val_auc: 0.9964 - val_prc: 0.9980
# Epoch 68/500
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0585 - tp: 75035.0000 - fp: 1680.0000 - tn: 32672.0000 - fn: 686.0000 - accuracy: 0.9785 - precision: 0.9781 - recall: 0.9909 - auc: 0.9969 - prc: 0.9983 - val_loss: 0.0660 - val_tp: 18733.0000 - val_fp: 289.0000 - val_tn: 8184.0000 - val_fn: 313.0000 - val_accuracy: 0.9781 - val_precision: 0.9848 - val_recall: 0.9836 - val_auc: 0.9965 - val_prc: 0.9982
# Epoch 69/500
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0588 - tp: 75013.0000 - fp: 1680.0000 - tn: 32672.0000 - fn: 708.0000 - accuracy: 0.9783 - precision: 0.9781 - recall: 0.9906 - auc: 0.9968 - prc: 0.9983 - val_loss: 0.0673 - val_tp: 18929.0000 - val_fp: 594.0000 - val_tn: 7879.0000 - val_fn: 117.0000 - val_accuracy: 0.9742 - val_precision: 0.9696 - val_recall: 0.9939 - val_auc: 0.9962 - val_prc: 0.9978
# Epoch 70/500
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0580 - tp: 75037.0000 - fp: 1654.0000 - tn: 32698.0000 - fn: 684.0000 - accuracy: 0.9788 - precision: 0.9784 - recall: 0.9910 - auc: 0.9969 - prc: 0.9983 - val_loss: 0.0568 - val_tp: 18925.0000 - val_fp: 464.0000 - val_tn: 8009.0000 - val_fn: 121.0000 - val_accuracy: 0.9787 - val_precision: 0.9761 - val_recall: 0.9936 - val_auc: 0.9971 - val_prc: 0.9984
# Epoch 71/500
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0571 - tp: 75065.0000 - fp: 1616.0000 - tn: 32736.0000 - fn: 656.0000 - accuracy: 0.9794 - precision: 0.9789 - recall: 0.9913 - auc: 0.9971 - prc: 0.9984 - val_loss: 0.0626 - val_tp: 18788.0000 - val_fp: 379.0000 - val_tn: 8094.0000 - val_fn: 258.0000 - val_accuracy: 0.9769 - val_precision: 0.9802 - val_recall: 0.9865 - val_auc: 0.9963 - val_prc: 0.9980
# Epoch 72/500
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0552 - tp: 75093.0000 - fp: 1572.0000 - tn: 32780.0000 - fn: 628.0000 - accuracy: 0.9800 - precision: 0.9795 - recall: 0.9917 - auc: 0.9972 - prc: 0.9984 - val_loss: 0.0572 - val_tp: 18897.0000 - val_fp: 446.0000 - val_tn: 8027.0000 - val_fn: 149.0000 - val_accuracy: 0.9784 - val_precision: 0.9769 - val_recall: 0.9922 - val_auc: 0.9970 - val_prc: 0.9983
# Epoch 73/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0529 - tp: 75112.0000 - fp: 1503.0000 - tn: 32849.0000 - fn: 609.0000 - accuracy: 0.9808 - precision: 0.9804 - recall: 0.9920 - auc: 0.9975 - prc: 0.9986 - val_loss: 0.0581 - val_tp: 18834.0000 - val_fp: 361.0000 - val_tn: 8112.0000 - val_fn: 212.0000 - val_accuracy: 0.9792 - val_precision: 0.9812 - val_recall: 0.9889 - val_auc: 0.9969 - val_prc: 0.9983
# Epoch 74/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0545 - tp: 75118.0000 - fp: 1529.0000 - tn: 32823.0000 - fn: 603.0000 - accuracy: 0.9806 - precision: 0.9801 - recall: 0.9920 - auc: 0.9973 - prc: 0.9985 - val_loss: 0.0555 - val_tp: 18922.0000 - val_fp: 439.0000 - val_tn: 8034.0000 - val_fn: 124.0000 - val_accuracy: 0.9795 - val_precision: 0.9773 - val_recall: 0.9935 - val_auc: 0.9971 - val_prc: 0.9983
# Epoch 75/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0524 - tp: 75133.0000 - fp: 1506.0000 - tn: 32846.0000 - fn: 588.0000 - accuracy: 0.9810 - precision: 0.9803 - recall: 0.9922 - auc: 0.9974 - prc: 0.9986 - val_loss: 0.0611 - val_tp: 18740.0000 - val_fp: 274.0000 - val_tn: 8199.0000 - val_fn: 306.0000 - val_accuracy: 0.9789 - val_precision: 0.9856 - val_recall: 0.9839 - val_auc: 0.9969 - val_prc: 0.9983
# Epoch 76/500
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0526 - tp: 75101.0000 - fp: 1461.0000 - tn: 32891.0000 - fn: 620.0000 - accuracy: 0.9811 - precision: 0.9809 - recall: 0.9918 - auc: 0.9975 - prc: 0.9986 - val_loss: 0.0530 - val_tp: 18877.0000 - val_fp: 383.0000 - val_tn: 8090.0000 - val_fn: 169.0000 - val_accuracy: 0.9799 - val_precision: 0.9801 - val_recall: 0.9911 - val_auc: 0.9975 - val_prc: 0.9986
# Epoch 77/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0521 - tp: 75109.0000 - fp: 1475.0000 - tn: 32877.0000 - fn: 612.0000 - accuracy: 0.9810 - precision: 0.9807 - recall: 0.9919 - auc: 0.9975 - prc: 0.9986 - val_loss: 0.0603 - val_tp: 18945.0000 - val_fp: 526.0000 - val_tn: 7947.0000 - val_fn: 101.0000 - val_accuracy: 0.9772 - val_precision: 0.9730 - val_recall: 0.9947 - val_auc: 0.9969 - val_prc: 0.9982
# Epoch 78/500
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0530 - tp: 75093.0000 - fp: 1512.0000 - tn: 32840.0000 - fn: 628.0000 - accuracy: 0.9806 - precision: 0.9803 - recall: 0.9917 - auc: 0.9974 - prc: 0.9986 - val_loss: 0.0597 - val_tp: 18764.0000 - val_fp: 294.0000 - val_tn: 8179.0000 - val_fn: 282.0000 - val_accuracy: 0.9791 - val_precision: 0.9846 - val_recall: 0.9852 - val_auc: 0.9967 - val_prc: 0.9982
# Epoch 79/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0523 - tp: 75086.0000 - fp: 1457.0000 - tn: 32895.0000 - fn: 635.0000 - accuracy: 0.9810 - precision: 0.9810 - recall: 0.9916 - auc: 0.9974 - prc: 0.9985 - val_loss: 0.0546 - val_tp: 18954.0000 - val_fp: 466.0000 - val_tn: 8007.0000 - val_fn: 92.0000 - val_accuracy: 0.9797 - val_precision: 0.9760 - val_recall: 0.9952 - val_auc: 0.9971 - val_prc: 0.9982
# Epoch 80/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0508 - tp: 75122.0000 - fp: 1436.0000 - tn: 32916.0000 - fn: 599.0000 - accuracy: 0.9815 - precision: 0.9812 - recall: 0.9921 - auc: 0.9975 - prc: 0.9986 - val_loss: 0.0538 - val_tp: 18967.0000 - val_fp: 500.0000 - val_tn: 7973.0000 - val_fn: 79.0000 - val_accuracy: 0.9790 - val_precision: 0.9743 - val_recall: 0.9959 - val_auc: 0.9977 - val_prc: 0.9987
# Epoch 81/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0494 - tp: 75130.0000 - fp: 1399.0000 - tn: 32953.0000 - fn: 591.0000 - accuracy: 0.9819 - precision: 0.9817 - recall: 0.9922 - auc: 0.9977 - prc: 0.9987 - val_loss: 0.0622 - val_tp: 18636.0000 - val_fp: 184.0000 - val_tn: 8289.0000 - val_fn: 410.0000 - val_accuracy: 0.9784 - val_precision: 0.9902 - val_recall: 0.9785 - val_auc: 0.9975 - val_prc: 0.9987
# Epoch 82/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0505 - tp: 75122.0000 - fp: 1384.0000 - tn: 32968.0000 - fn: 599.0000 - accuracy: 0.9820 - precision: 0.9819 - recall: 0.9921 - auc: 0.9976 - prc: 0.9987 - val_loss: 0.0513 - val_tp: 18875.0000 - val_fp: 349.0000 - val_tn: 8124.0000 - val_fn: 171.0000 - val_accuracy: 0.9811 - val_precision: 0.9818 - val_recall: 0.9910 - val_auc: 0.9973 - val_prc: 0.9984
# Epoch 83/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0470 - tp: 75179.0000 - fp: 1289.0000 - tn: 33063.0000 - fn: 542.0000 - accuracy: 0.9834 - precision: 0.9831 - recall: 0.9928 - auc: 0.9979 - prc: 0.9988 - val_loss: 0.0640 - val_tp: 18772.0000 - val_fp: 295.0000 - val_tn: 8178.0000 - val_fn: 274.0000 - val_accuracy: 0.9793 - val_precision: 0.9845 - val_recall: 0.9856 - val_auc: 0.9960 - val_prc: 0.9976
# Epoch 84/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0478 - tp: 75134.0000 - fp: 1317.0000 - tn: 33035.0000 - fn: 587.0000 - accuracy: 0.9827 - precision: 0.9828 - recall: 0.9922 - auc: 0.9979 - prc: 0.9988 - val_loss: 0.0492 - val_tp: 18924.0000 - val_fp: 379.0000 - val_tn: 8094.0000 - val_fn: 122.0000 - val_accuracy: 0.9818 - val_precision: 0.9804 - val_recall: 0.9936 - val_auc: 0.9979 - val_prc: 0.9989
# Epoch 85/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0460 - tp: 75210.0000 - fp: 1320.0000 - tn: 33032.0000 - fn: 511.0000 - accuracy: 0.9834 - precision: 0.9828 - recall: 0.9933 - auc: 0.9980 - prc: 0.9989 - val_loss: 0.0543 - val_tp: 18812.0000 - val_fp: 288.0000 - val_tn: 8185.0000 - val_fn: 234.0000 - val_accuracy: 0.9810 - val_precision: 0.9849 - val_recall: 0.9877 - val_auc: 0.9973 - val_prc: 0.9986
# Epoch 86/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0453 - tp: 75171.0000 - fp: 1237.0000 - tn: 33115.0000 - fn: 550.0000 - accuracy: 0.9838 - precision: 0.9838 - recall: 0.9927 - auc: 0.9981 - prc: 0.9989 - val_loss: 0.0502 - val_tp: 18860.0000 - val_fp: 299.0000 - val_tn: 8174.0000 - val_fn: 186.0000 - val_accuracy: 0.9824 - val_precision: 0.9844 - val_recall: 0.9902 - val_auc: 0.9976 - val_prc: 0.9988
# Epoch 87/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0616 - tp: 74785.0000 - fp: 1589.0000 - tn: 32763.0000 - fn: 936.0000 - accuracy: 0.9771 - precision: 0.9792 - recall: 0.9876 - auc: 0.9962 - prc: 0.9978 - val_loss: 0.0545 - val_tp: 18936.0000 - val_fp: 455.0000 - val_tn: 8018.0000 - val_fn: 110.0000 - val_accuracy: 0.9795 - val_precision: 0.9765 - val_recall: 0.9942 - val_auc: 0.9975 - val_prc: 0.9987
# Epoch 88/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0450 - tp: 75201.0000 - fp: 1284.0000 - tn: 33068.0000 - fn: 520.0000 - accuracy: 0.9836 - precision: 0.9832 - recall: 0.9931 - auc: 0.9982 - prc: 0.9990 - val_loss: 0.0464 - val_tp: 18908.0000 - val_fp: 300.0000 - val_tn: 8173.0000 - val_fn: 138.0000 - val_accuracy: 0.9841 - val_precision: 0.9844 - val_recall: 0.9928 - val_auc: 0.9979 - val_prc: 0.9988
# Epoch 89/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0449 - tp: 75155.0000 - fp: 1208.0000 - tn: 33144.0000 - fn: 566.0000 - accuracy: 0.9839 - precision: 0.9842 - recall: 0.9925 - auc: 0.9981 - prc: 0.9990 - val_loss: 0.0482 - val_tp: 18913.0000 - val_fp: 334.0000 - val_tn: 8139.0000 - val_fn: 133.0000 - val_accuracy: 0.9830 - val_precision: 0.9826 - val_recall: 0.9930 - val_auc: 0.9978 - val_prc: 0.9987
# Epoch 90/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0460 - tp: 75167.0000 - fp: 1249.0000 - tn: 33103.0000 - fn: 554.0000 - accuracy: 0.9836 - precision: 0.9837 - recall: 0.9927 - auc: 0.9979 - prc: 0.9988 - val_loss: 0.0518 - val_tp: 18906.0000 - val_fp: 394.0000 - val_tn: 8079.0000 - val_fn: 140.0000 - val_accuracy: 0.9806 - val_precision: 0.9796 - val_recall: 0.9926 - val_auc: 0.9976 - val_prc: 0.9987
# Epoch 91/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0457 - tp: 75165.0000 - fp: 1260.0000 - tn: 33092.0000 - fn: 556.0000 - accuracy: 0.9835 - precision: 0.9835 - recall: 0.9927 - auc: 0.9980 - prc: 0.9988 - val_loss: 0.0491 - val_tp: 18940.0000 - val_fp: 385.0000 - val_tn: 8088.0000 - val_fn: 106.0000 - val_accuracy: 0.9822 - val_precision: 0.9801 - val_recall: 0.9944 - val_auc: 0.9978 - val_prc: 0.9988
# Epoch 92/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0425 - tp: 75228.0000 - fp: 1199.0000 - tn: 33153.0000 - fn: 493.0000 - accuracy: 0.9846 - precision: 0.9843 - recall: 0.9935 - auc: 0.9983 - prc: 0.9991 - val_loss: 0.0460 - val_tp: 18881.0000 - val_fp: 302.0000 - val_tn: 8171.0000 - val_fn: 165.0000 - val_accuracy: 0.9830 - val_precision: 0.9843 - val_recall: 0.9913 - val_auc: 0.9979 - val_prc: 0.9989
# Epoch 93/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0431 - tp: 75197.0000 - fp: 1169.0000 - tn: 33183.0000 - fn: 524.0000 - accuracy: 0.9846 - precision: 0.9847 - recall: 0.9931 - auc: 0.9983 - prc: 0.9991 - val_loss: 0.0497 - val_tp: 18928.0000 - val_fp: 381.0000 - val_tn: 8092.0000 - val_fn: 118.0000 - val_accuracy: 0.9819 - val_precision: 0.9803 - val_recall: 0.9938 - val_auc: 0.9977 - val_prc: 0.9988
# Epoch 94/500
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0447 - tp: 75173.0000 - fp: 1239.0000 - tn: 33113.0000 - fn: 548.0000 - accuracy: 0.9838 - precision: 0.9838 - recall: 0.9928 - auc: 0.9981 - prc: 0.9989 - val_loss: 0.0488 - val_tp: 18938.0000 - val_fp: 385.0000 - val_tn: 8088.0000 - val_fn: 108.0000 - val_accuracy: 0.9821 - val_precision: 0.9801 - val_recall: 0.9943 - val_auc: 0.9976 - val_prc: 0.9986
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# loss :  0.050168536603450775 /n
# tp :  10501.0 /n
# fp :  205.0 /n
# tn :  4516.0 /n
# fn :  66.0 /n
# accuracy :  0.9822736978530884 /n
# precision :  0.9808518290519714 /n
# recall :  0.9937541484832764 /n
# auc :  0.9968056678771973 /n
# prc :  0.9978166818618774 /n
# True Negatives:  4517
# False Positives:  204
# False Negatives:  66
# True Positives:  10501
# Total:  10567
# INFO:tensorflow:Assets written to: C:\Users\angel\AppData\Local\Temp\tmptimuy4ko\model\data\model\assets

# %% [markdown]
# ## 5. Register Model

# %%
model_uri = "runs:/{}/{}".format(run.info.run_id, model_name)
mv = mlflow.register_model(model_uri, model_name)
print("Name: {}".format(mv.name))
print("Version: {}".format(mv.version))
# Out:
# Successfully registered model 'dense_model_kinect'.
# 2021/05/16 17:23:11 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: dense_model_kinect, version 1
# Name: dense_model_kinect
# Version: 1
# Created version '1' of model 'dense_model_kinect'.
