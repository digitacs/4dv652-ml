# %% [markdown]
# # Model to Classify Stop/End positions in Kinect dataset
#
# Section for configurations and imports.

# %%
import os 
import tempfile

import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow import keras

# MLflow dashboard
import mlflow
mlflow.set_tracking_uri('http://35.228.45.76:5000')
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='../../mlflow-312506-8cfad529f4fd.json'

# Import data augmentation
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from augmentation.methods import *

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
random_state = 47
np.random.seed(random_state)

# %%
physical_devices = tf.config.experimental.list_physical_devices( 'GPU' )
print( 'Num GPUs Available: ', len( physical_devices ) )
if len( physical_devices ) > 0:
    tf.config.experimental.set_memory_growth( physical_devices[0], True )
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # 1. Data Preparation
#
# ## 1.1 Load Kinect files with marked start and stop frames in one-hot encoding. We're only interested in the 'start' column.

# %%
data_path = '../../datasets/marked_start_end/'

df = None

# %%
for file in os.listdir(data_path):
    if file.endswith('.csv') and 'kinect' in file:
        try:
            dataset = pd.read_csv(data_path + file)
            dataset.drop(columns=['FrameNo'], inplace=True)
            dataset.drop(columns=['start'], inplace=True)

            if df is None:
                df = dataset
            else:
                df = pd.concat((df, dataset), ignore_index=True)

        except IOError as e:
            print('Error in reading file: ', e)

print(df.shape)
# Out:
# (37782, 40)

# %% [markdown]
# ## 1.2 Data Augmentation

# %%
df = mirror(df,'x', append=True)
print(df.shape)
# Out:
# (75564, 40)

# %% [markdown]
# ## 1.3 Check Class Imbalance
#
# This shows the small fraction of start frames.

# %%
X = df.drop(columns=['end'])
y = df['end']

# %%
print(
    'Total: {}\n\nNone: {} ({:.2f}% of total)\nStop: {} ({:.2f}% of total)\n'
    .format(
      len(y), 
      len(y.values[y.values == 0]),
      len(y.values[y.values == 0]) / len(y),
      len(y.values[y.values == 1]),
      len(y.values[y.values == 1]) / len(y)
    )
  )
# Out:
# Total: 75564
#
# None: 61490 (0.81% of total)
# Stop: 14074 (0.19% of total)

# %% [markdown]
# ## 1.3 Oversample the minority class

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=random_state) # Perform oversamling using SMOTE
resampled_X, resampled_y = sm.fit_resample(X, y)

print(resampled_X.shape)
print(resampled_y.shape)
# Out:
# (122980, 39)
# (122980,)

# %% [markdown]
# ## 1.5 Split and normalize the data
#
# We already dropped the 'FrameNo' and 'end' columns when the data was loading. <br />
# Now, we'll split the dataset into train, validation, and test sets:
#
# - The validation set is used during model fitting to evaluate the loss and other evaluation metrics.
# - The test set is unused during the training phase and is used at the end to evaluate how well the model generalizes to new data (i.e. a holdout set). This is especially important with imbalanced datasets where overfitting is a significant concern from the lack of training data.
#
# We also normalize the input features using the sklearn StandardScaler. StandardScaler is only fit using X_train. As we want to deploy a model, it's critical that you preserve the preprocessing calculations. The easiest way to implement them as layers, and attach them to your model before export.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(resampled_X, resampled_y, test_size=0.2, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

print('Training labels shape:', y_train.shape)
print('Validation labels shape:', y_val.shape)
print('Test labels shape:', y_test.shape, '\n')

print('Training features shape:', X_train.shape)
print('Validation features shape:', X_val.shape)
print('Test features shape:', X_test.shape)
# Out:
# Training labels shape: (78707,)
# Validation labels shape: (19677,)
# Test labels shape: (24596,)
#
# Training features shape: (78707, 39)
# Validation features shape: (19677, 39)
# Test features shape: (24596, 39)

# %% [markdown]
# # 2. Define the Model and Metrics

# %% [markdown]
# ## 2.1 Layer factory

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %% [markdown]
# ## 2.2 Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer

def make_model(metrics, layers, optimizer, input_dim, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %% [markdown]
# # 3. Build the Model
#
# ## 3.1 Estimate the initial bias
#
# We're going to keep the initial model's weights in a checkpoint file and load them into each model before training so the model doesn't need to spend the first few epochs just learning that start frames are unlikely. Therefore, we start by estimating the initial bias before defining the model.

# %%
neg, pos = np.bincount(y)

initial_bias = np.log([pos/neg])
initial_bias
# Out:
# array([-1.47454544])

# %% [markdown]
# ## 3.2 Define the Model and Evaluation Metrics
#
# We're using standard evaluation metrics for binary classification problems.
#
# The **make_model** function returns a model based on parameter values. It uses the Layer Factory for creating the model.

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(layers, input_dim, loss, optimizer, learning_rate=0.001, metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %%
output_bias = tf.keras.initializers.Constant(initial_bias)
input_dim = X_train.shape[1]
output_size = 1

units = 64
activation = 'relu'
kernel_initializer = 'he_uniform'
output_activation = 'sigmoid'
optimizer = 'Adam'
learning_rate = 1e-3

LAYERS = [ 
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':32, 'activation': 'tanh', 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':output_size, 'activation': output_activation, 'bias_initializer': initial_bias }
]

model = make_model(layers=LAYERS, input_dim=input_dim, loss='binary_crossentropy', optimizer=optimizer, learning_rate=learning_rate, output_bias=output_bias)

model.predict(X_train[:10])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                2560
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 6,817
# Trainable params: 6,817
# Non-trainable params: 0
# _________________________________________________________________
# None
# array([[0.40374184],
#        [0.48027697],
#        [0.47676936],
#        [0.49379098],
#        [0.44336858],
#        [0.40571442],
#        [0.41810864],
#        [0.44689962],
#        [0.52346665],
#        [0.46380597]], dtype=float32)

# %%
results = model.evaluate(X_train, y_train, batch_size=2048, verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.6965

# %%
initial_weights = os.path.join(tempfile.mkdtemp(), 'initial_weights')
model.save_weights(initial_weights)

# %% [markdown]
# ## 3.3 Add Class Weights

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

print('Weight for class 0:', class_weights[0])
print('Weight for class 1:', class_weights[1])
# Out:
# Weight for class 0: 1.0016161873250191
# Weight for class 1: 0.9983890199660045

# %% [markdown]
# # 4. MLflow Experimentation
#
# ## 4.1 Define learning parameters for all models

# %%
from keras.callbacks import EarlyStopping

EPOCHS = 500
BATCH_SIZE = 2050

early_stopping = EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ## 4.2 Define Experimentation Configurations
#
# The Model signature in MLflow defines the schema of a model's inputs and outputs.

# %%
from mlflow.models.signature import ModelSignature
from mlflow.types.schema import Schema, ColSpec

input_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "head_z"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_shoulder_z"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "left_elbow_z"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_shoulder_z"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "right_elbow_z"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "left_hand_z"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "right_hand_z"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "left_hip_z"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "right_hip_z"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "left_knee_z"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "right_knee_z"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "left_foot_z"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
    ColSpec("double", "right_foot_z"),
])
output_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "head_z"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_shoulder_z"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "left_elbow_z"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_shoulder_z"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "right_elbow_z"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "left_hand_z"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "right_hand_z"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "left_hip_z"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "right_hip_z"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "left_knee_z"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "right_knee_z"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "left_foot_z"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
    ColSpec("double", "right_foot_z"),
])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# %% [markdown]
# ## 4.3 Functions used in the experimentation
#
# For creating plots and others.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

def plot_loss(history, label, n):
  plt.semilogy(history.epoch, history.history['loss'],
               color=colors[n], label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               color=colors[n], label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('True Negatives: ', cm[0][0])
  print('False Positives: ', cm[0][1])
  print('False Negatives: ', cm[1][0])
  print('True Positives: ', cm[1][1])
  print('Total: ', np.sum(cm[1]))


def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = roc_curve(labels, predictions)

  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# ## 4.4 Start run
#
# Starting a run which fits the model according to chosen parameter values, then makes predictions and saves selected values to MLflow dashboard.

# %%
model_name = 'cut_stop_kinect'

with mlflow.start_run(run_name=model_name) as run:

    run_id = run.info.run_id

    model = make_model(metrics=METRICS, 
                        layers=LAYERS, 
                        loss='binary_crossentropy', 
                        optimizer=optimizer, 
                        learning_rate=learning_rate, 
                        output_bias=initial_bias, 
                        input_dim=input_dim)
    model.load_weights(initial_weights)
    model.layers[-1].bias.assign([0.0])
    
    with tf.device('/CPU:0'):
        history = model.fit(
            x=X_train, 
            y=y_train, 
            class_weight=class_weight_dict, 
            validation_data=(X_val, y_val), 
            shuffle=True, 
            epochs=EPOCHS, 
            verbose=1,
            batch_size=BATCH_SIZE, 
            callbacks=[early_stopping])

        # Plot training history
        plot_loss(history, "Bias", 0)
        plt.savefig("loss.jpg")
        mlflow.log_artifact("loss.jpg")
        plt.show()
        
        # Plot and log metrics
        predictions_train = model.predict(X_train)
        predictions_test = model.predict(X_test)

        plot_metrics(history)
        plt.savefig("metrics.jpg")
        mlflow.log_artifact("metrics.jpg")
        plt.show()

        # Confusion matrix
        results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
        for name, value in zip(model.metrics_names, results):
            print(name, ': ', value, '/n')
        plot_cm(y_test, predictions_test)
        plt.savefig("cm.jpg")
        mlflow.log_artifact("cm.jpg")
        plt.show()

        # ROC Curve
        plot_roc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("roc.jpg")
        mlflow.log_artifact("roc.jpg")
        plt.show()

        # Precision-Recall Curve (PRC)
        plot_prc("Train Predictions", y_train, predictions_train, color=colors[0])
        plot_prc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("prc.jpg")
        mlflow.log_artifact("prc.jpg")
        plt.show()
        
        # Log model, scaler, model parameters to MLflow
        mlflow.log_param("units", units)
        mlflow.log_param("activation", activation)
        mlflow.log_param("kernel_initializer", kernel_initializer)
        mlflow.log_param("output activation", output_activation)
        mlflow.log_param("optimizer", optimizer)
        mlflow.log_param("learning rate", learning_rate)
        mlflow.log_param("batch size", BATCH_SIZE)
        mlflow.log_metric("accuracy", results[5])
        mlflow.log_metric("average precision score", results[6])
        mlflow.log_metric("recall", results[7])
        mlflow.log_metric("auc", results[8])

        mlflow.keras.log_model(model, model_name, signature=signature)
        mlflow.sklearn.log_model(scaler, 'InputScaler')
# Out:
# 41.0000 - val_accuracy: 0.9795 - val_precision: 0.9736 - val_recall: 0.9857 - val_auc: 0.9977 - val_prc: 0.9976
# Epoch 90/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0499 - tp: 38807.0000 - fp: 854.0000 - tn: 38436.0000 - fn: 610.0000 - accuracy: 0.9814 - precision: 0.9785 - recall: 0.9845 - auc: 0.9983 - prc: 0.9981 - val_loss: 0.0556 - val_tp: 9756.0000 - val_fp: 313.0000 - val_tn: 9521.0000 - val_fn: 87.0000 - val_accuracy: 0.9797 - val_precision: 0.9689 - val_recall: 0.9912 - val_auc: 0.9979 - val_prc: 0.9977
# Epoch 91/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0484 - tp: 38794.0000 - fp: 794.0000 - tn: 38496.0000 - fn: 623.0000 - accuracy: 0.9820 - precision: 0.9799 - recall: 0.9842 - auc: 0.9984 - prc: 0.9984 - val_loss: 0.0524 - val_tp: 9656.0000 - val_fp: 189.0000 - val_tn: 9645.0000 - val_fn: 187.0000 - val_accuracy: 0.9809 - val_precision: 0.9808 - val_recall: 0.9810 - val_auc: 0.9980 - val_prc: 0.9981
# Epoch 92/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0476 - tp: 38835.0000 - fp: 795.0000 - tn: 38495.0000 - fn: 582.0000 - accuracy: 0.9825 - precision: 0.9799 - recall: 0.9852 - auc: 0.9985 - prc: 0.9984 - val_loss: 0.0514 - val_tp: 9678.0000 - val_fp: 189.0000 - val_tn: 9645.0000 - val_fn: 165.0000 - val_accuracy: 0.9820 - val_precision: 0.9808 - val_recall: 0.9832 - val_auc: 0.9980 - val_prc: 0.9980
# Epoch 93/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0493 - tp: 38781.0000 - fp: 816.0000 - tn: 38474.0000 - fn: 636.0000 - accuracy: 0.9816 - precision: 0.9794 - recall: 0.9839 - auc: 0.9983 - prc: 0.9981 - val_loss: 0.0546 - val_tp: 9651.0000 - val_fp: 230.0000 - val_tn: 9604.0000 - val_fn: 192.0000 - val_accuracy: 0.9786 - val_precision: 0.9767 - val_recall: 0.9805 - val_auc: 0.9978 - val_prc: 0.9976
# Epoch 94/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0495 - tp: 38792.0000 - fp: 839.0000 - tn: 38451.0000 - fn: 625.0000 - accuracy: 0.9814 - precision: 0.9788 - recall: 0.9841 - auc: 0.9983 - prc: 0.9981 - val_loss: 0.0522 - val_tp: 9650.0000 - val_fp: 172.0000 - val_tn: 9662.0000 - val_fn: 193.0000 - val_accuracy: 0.9815 - val_precision: 0.9825 - val_recall: 0.9804 - val_auc: 0.9980 - val_prc: 0.9981
# Epoch 95/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0470 - tp: 38848.0000 - fp: 802.0000 - tn: 38488.0000 - fn: 569.0000 - accuracy: 0.9826 - precision: 0.9798 - recall: 0.9856 - auc: 0.9985 - prc: 0.9984 - val_loss: 0.0531 - val_tp: 9605.0000 - val_fp: 139.0000 - val_tn: 9695.0000 - val_fn: 238.0000 - val_accuracy: 0.9808 - val_precision: 0.9857 - val_recall: 0.9758 - val_auc: 0.9981 - val_prc: 0.9981
# Epoch 96/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0505 - tp: 38763.0000 - fp: 842.0000 - tn: 38448.0000 - fn: 654.0000 - accuracy: 0.9810 - precision: 0.9787 - recall: 0.9834 - auc: 0.9982 - prc: 0.9980 - val_loss: 0.0612 - val_tp: 9509.0000 - val_fp: 131.0000 - val_tn: 9703.0000 - val_fn: 334.0000 - val_accuracy: 0.9764 - val_precision: 0.9864 - val_recall: 0.9661 - val_auc: 0.9978 - val_prc: 0.9979
# Epoch 97/500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0491 - tp: 38826.0000 - fp: 829.0000 - tn: 38461.0000 - fn: 591.0000 - accuracy: 0.9820 - precision: 0.9791 - recall: 0.9850 - auc: 0.9983 - prc: 0.9981 - val_loss: 0.0563 - val_tp: 9752.0000 - val_fp: 333.0000 - val_tn: 9501.0000 - val_fn: 91.0000 - val_accuracy: 0.9785 - val_precision: 0.9670 - val_recall: 0.9908 - val_auc: 0.9979 - val_prc: 0.9976
# Epoch 98/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0515 - tp: 38769.0000 - fp: 857.0000 - tn: 38433.0000 - fn: 648.0000 - accuracy: 0.9809 - precision: 0.9784 - recall: 0.9836 - auc: 0.9981 - prc: 0.9979 - val_loss: 0.0505 - val_tp: 9706.0000 - val_fp: 215.0000 - val_tn: 9619.0000 - val_fn: 137.0000 - val_accuracy: 0.9821 - val_precision: 0.9783 - val_recall: 0.9861 - val_auc: 0.9981 - val_prc: 0.9981
# Epoch 99/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0478 - tp: 38840.0000 - fp: 794.0000 - tn: 38496.0000 - fn: 577.0000 - accuracy: 0.9826 - precision: 0.9800 - recall: 0.9854 - auc: 0.9984 - prc: 0.9983 - val_loss: 0.0553 - val_tp: 9550.0000 - val_fp: 160.0000 - val_tn: 9674.0000 - val_fn: 293.0000 - val_accuracy: 0.9770 - val_precision: 0.9835 - val_recall: 0.9702 - val_auc: 0.9980 - val_prc: 0.9981
# Epoch 100/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0453 - tp: 38884.0000 - fp: 766.0000 - tn: 38524.0000 - fn: 533.0000 - accuracy: 0.9835 - precision: 0.9807 - recall: 0.9865 - auc: 0.9986 - prc: 0.9985 - val_loss: 0.0484 - val_tp: 9673.0000 - val_fp: 179.0000 - val_tn: 9655.0000 - val_fn: 170.0000 - val_accuracy: 0.9823 - val_precision: 0.9818 - val_recall: 0.9827 - val_auc: 0.9983 - val_prc: 0.9983
# Epoch 101/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0470 - tp: 38825.0000 - fp: 779.0000 - tn: 38511.0000 - fn: 592.0000 - accuracy: 0.9826 - precision: 0.9803 - recall: 0.9850 - auc: 0.9985 - prc: 0.9983 - val_loss: 0.0502 - val_tp: 9708.0000 - val_fp: 225.0000 - val_tn: 9609.0000 - val_fn: 135.0000 - val_accuracy: 0.9817 - val_precision: 0.9773 - val_recall: 0.9863 - val_auc: 0.9982 - val_prc: 0.9981
# Epoch 102/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0456 - tp: 38868.0000 - fp: 754.0000 - tn: 38536.0000 - fn: 549.0000 - accuracy: 0.9834 - precision: 0.9810 - recall: 0.9861 - auc: 0.9985 - prc: 0.9984 - val_loss: 0.0532 - val_tp: 9772.0000 - val_fp: 319.0000 - val_tn: 9515.0000 - val_fn: 71.0000 - val_accuracy: 0.9802 - val_precision: 0.9684 - val_recall: 0.9928 - val_auc: 0.9981 - val_prc: 0.9979
# Epoch 103/500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0445 - tp: 38891.0000 - fp: 768.0000 - tn: 38522.0000 - fn: 526.0000 - accuracy: 0.9836 - precision: 0.9806 - recall: 0.9867 - auc: 0.9986 - prc: 0.9985 - val_loss: 0.0514 - val_tp: 9749.0000 - val_fp: 282.0000 - val_tn: 9552.0000 - val_fn: 94.0000 - val_accuracy: 0.9809 - val_precision: 0.9719 - val_recall: 0.9905 - val_auc: 0.9981 - val_prc: 0.9979
# Epoch 104/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0478 - tp: 38788.0000 - fp: 808.0000 - tn: 38482.0000 - fn: 629.0000 - accuracy: 0.9817 - precision: 0.9796 - recall: 0.9840 - auc: 0.9984 - prc: 0.9982 - val_loss: 0.0502 - val_tp: 9735.0000 - val_fp: 250.0000 - val_tn: 9584.0000 - val_fn: 108.0000 - val_accuracy: 0.9818 - val_precision: 0.9750 - val_recall: 0.9890 - val_auc: 0.9981 - val_prc: 0.9981
# Epoch 105/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0476 - tp: 38838.0000 - fp: 807.0000 - tn: 38483.0000 - fn: 579.0000 - accuracy: 0.9824 - precision: 0.9796 - recall: 0.9853 - auc: 0.9984 - prc: 0.9981 - val_loss: 0.0553 - val_tp: 9738.0000 - val_fp: 296.0000 - val_tn: 9538.0000 - val_fn: 105.0000 - val_accuracy: 0.9796 - val_precision: 0.9705 - val_recall: 0.9893 - val_auc: 0.9980 - val_prc: 0.9979
# Epoch 106/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0435 - tp: 38889.0000 - fp: 739.0000 - tn: 38551.0000 - fn: 528.0000 - accuracy: 0.9839 - precision: 0.9814 - recall: 0.9866 - auc: 0.9987 - prc: 0.9986 - val_loss: 0.0531 - val_tp: 9600.0000 - val_fp: 169.0000 - val_tn: 9665.0000 - val_fn: 243.0000 - val_accuracy: 0.9791 - val_precision: 0.9827 - val_recall: 0.9753 - val_auc: 0.9981 - val_prc: 0.9982
# Epoch 107/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0473 - tp: 38802.0000 - fp: 807.0000 - tn: 38483.0000 - fn: 615.0000 - accuracy: 0.9819 - precision: 0.9796 - recall: 0.9844 - auc: 0.9984 - prc: 0.9983 - val_loss: 0.0511 - val_tp: 9681.0000 - val_fp: 212.0000 - val_tn: 9622.0000 - val_fn: 162.0000 - val_accuracy: 0.9810 - val_precision: 0.9786 - val_recall: 0.9835 - val_auc: 0.9981 - val_prc: 0.9981
# Epoch 108/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0445 - tp: 38878.0000 - fp: 746.0000 - tn: 38544.0000 - fn: 539.0000 - accuracy: 0.9837 - precision: 0.9812 - recall: 0.9863 - auc: 0.9986 - prc: 0.9985 - val_loss: 0.0494 - val_tp: 9666.0000 - val_fp: 181.0000 - val_tn: 9653.0000 - val_fn: 177.0000 - val_accuracy: 0.9818 - val_precision: 0.9816 - val_recall: 0.9820 - val_auc: 0.9982 - val_prc: 0.9981
# Epoch 109/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0448 - tp: 38842.0000 - fp: 758.0000 - tn: 38532.0000 - fn: 575.0000 - accuracy: 0.9831 - precision: 0.9809 - recall: 0.9854 - auc: 0.9986 - prc: 0.9984 - val_loss: 0.0465 - val_tp: 9712.0000 - val_fp: 184.0000 - val_tn: 9650.0000 - val_fn: 131.0000 - val_accuracy: 0.9840 - val_precision: 0.9814 - val_recall: 0.9867 - val_auc: 0.9983 - val_prc: 0.9984
# Epoch 110/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0447 - tp: 38859.0000 - fp: 738.0000 - tn: 38552.0000 - fn: 558.0000 - accuracy: 0.9835 - precision: 0.9814 - recall: 0.9858 - auc: 0.9986 - prc: 0.9985 - val_loss: 0.0623 - val_tp: 9800.0000 - val_fp: 414.0000 - val_tn: 9420.0000 - val_fn: 43.0000 - val_accuracy: 0.9768 - val_precision: 0.9595 - val_recall: 0.9956 - val_auc: 0.9981 - val_prc: 0.9977
# Epoch 111/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0431 - tp: 38892.0000 - fp: 716.0000 - tn: 38574.0000 - fn: 525.0000 - accuracy: 0.9842 - precision: 0.9819 - recall: 0.9867 - auc: 0.9986 - prc: 0.9984 - val_loss: 0.0492 - val_tp: 9766.0000 - val_fp: 268.0000 - val_tn: 9566.0000 - val_fn: 77.0000 - val_accuracy: 0.9825 - val_precision: 0.9733 - val_recall: 0.9922 - val_auc: 0.9984 - val_prc: 0.9982
# Epoch 112/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0430 - tp: 38894.0000 - fp: 712.0000 - tn: 38578.0000 - fn: 523.0000 - accuracy: 0.9843 - precision: 0.9820 - recall: 0.9867 - auc: 0.9987 - prc: 0.9985 - val_loss: 0.0500 - val_tp: 9587.0000 - val_fp: 117.0000 - val_tn: 9717.0000 - val_fn: 256.0000 - val_accuracy: 0.9810 - val_precision: 0.9879 - val_recall: 0.9740 - val_auc: 0.9985 - val_prc: 0.9985
# Epoch 113/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0417 - tp: 38895.0000 - fp: 673.0000 - tn: 38617.0000 - fn: 522.0000 - accuracy: 0.9848 - precision: 0.9830 - recall: 0.9868 - auc: 0.9988 - prc: 0.9987 - val_loss: 0.0493 - val_tp: 9771.0000 - val_fp: 281.0000 - val_tn: 9553.0000 - val_fn: 72.0000 - val_accuracy: 0.9821 - val_precision: 0.9720 - val_recall: 0.9927 - val_auc: 0.9982 - val_prc: 0.9979
# Epoch 114/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0415 - tp: 38936.0000 - fp: 693.0000 - tn: 38597.0000 - fn: 481.0000 - accuracy: 0.9851 - precision: 0.9825 - recall: 0.9878 - auc: 0.9988 - prc: 0.9986 - val_loss: 0.0481 - val_tp: 9720.0000 - val_fp: 232.0000 - val_tn: 9602.0000 - val_fn: 123.0000 - val_accuracy: 0.9820 - val_precision: 0.9767 - val_recall: 0.9875 - val_auc: 0.9981 - val_prc: 0.9979
# Epoch 115/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0434 - tp: 38884.0000 - fp: 724.0000 - tn: 38566.0000 - fn: 533.0000 - accuracy: 0.9840 - precision: 0.9817 - recall: 0.9865 - auc: 0.9986 - prc: 0.9985 - val_loss: 0.0485 - val_tp: 9691.0000 - val_fp: 208.0000 - val_tn: 9626.0000 - val_fn: 152.0000 - val_accuracy: 0.9817 - val_precision: 0.9790 - val_recall: 0.9846 - val_auc: 0.9982 - val_prc: 0.9981
# Epoch 116/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0427 - tp: 38897.0000 - fp: 737.0000 - tn: 38553.0000 - fn: 520.0000 - accuracy: 0.9840 - precision: 0.9814 - recall: 0.9868 - auc: 0.9987 - prc: 0.9987 - val_loss: 0.0464 - val_tp: 9752.0000 - val_fp: 231.0000 - val_tn: 9603.0000 - val_fn: 91.0000 - val_accuracy: 0.9836 - val_precision: 0.9769 - val_recall: 0.9908 - val_auc: 0.9984 - val_prc: 0.9983
# Epoch 117/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0408 - tp: 38941.0000 - fp: 675.0000 - tn: 38615.0000 - fn: 476.0000 - accuracy: 0.9854 - precision: 0.9830 - recall: 0.9879 - auc: 0.9988 - prc: 0.9987 - val_loss: 0.0450 - val_tp: 9740.0000 - val_fp: 203.0000 - val_tn: 9631.0000 - val_fn: 103.0000 - val_accuracy: 0.9844 - val_precision: 0.9796 - val_recall: 0.9895 - val_auc: 0.9985 - val_prc: 0.9985
# Epoch 118/500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0417 - tp: 38925.0000 - fp: 725.0000 - tn: 38565.0000 - fn: 492.0000 - accuracy: 0.9845 - precision: 0.9817 - recall: 0.9875 - auc: 0.9987 - prc: 0.9985 - val_loss: 0.0469 - val_tp: 9615.0000 - val_fp: 135.0000 - val_tn: 9699.0000 - val_fn: 228.0000 - val_accuracy: 0.9816 - val_precision: 0.9862 - val_recall: 0.9768 - val_auc: 0.9984 - val_prc: 0.9985
# Epoch 119/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0408 - tp: 38926.0000 - fp: 671.0000 - tn: 38619.0000 - fn: 491.0000 - accuracy: 0.9852 - precision: 0.9831 - recall: 0.9875 - auc: 0.9988 - prc: 0.9987 - val_loss: 0.0492 - val_tp: 9779.0000 - val_fp: 309.0000 - val_tn: 9525.0000 - val_fn: 64.0000 - val_accuracy: 0.9810 - val_precision: 0.9694 - val_recall: 0.9935 - val_auc: 0.9985 - val_prc: 0.9981
# Epoch 120/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0445 - tp: 38848.0000 - fp: 749.0000 - tn: 38541.0000 - fn: 569.0000 - accuracy: 0.9833 - precision: 0.9811 - recall: 0.9856 - auc: 0.9986 - prc: 0.9984 - val_loss: 0.0445 - val_tp: 9722.0000 - val_fp: 206.0000 - val_tn: 9628.0000 - val_fn: 121.0000 - val_accuracy: 0.9834 - val_precision: 0.9793 - val_recall: 0.9877 - val_auc: 0.9986 - val_prc: 0.9985
# Epoch 121/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0479 - tp: 38779.0000 - fp: 808.0000 - tn: 38482.0000 - fn: 638.0000 - accuracy: 0.9816 - precision: 0.9796 - recall: 0.9838 - auc: 0.9984 - prc: 0.9982 - val_loss: 0.0613 - val_tp: 9390.0000 - val_fp: 84.0000 - val_tn: 9750.0000 - val_fn: 453.0000 - val_accuracy: 0.9727 - val_precision: 0.9911 - val_recall: 0.9540 - val_auc: 0.9985 - val_prc: 0.9985
# Epoch 122/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0411 - tp: 38923.0000 - fp: 672.0000 - tn: 38618.0000 - fn: 494.0000 - accuracy: 0.9852 - precision: 0.9830 - recall: 0.9875 - auc: 0.9988 - prc: 0.9987 - val_loss: 0.0482 - val_tp: 9714.0000 - val_fp: 235.0000 - val_tn: 9599.0000 - val_fn: 129.0000 - val_accuracy: 0.9815 - val_precision: 0.9764 - val_recall: 0.9869 - val_auc: 0.9981 - val_prc: 0.9977
# Epoch 123/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0436 - tp: 38885.0000 - fp: 742.0000 - tn: 38548.0000 - fn: 532.0000 - accuracy: 0.9838 - precision: 0.9813 - recall: 0.9865 - auc: 0.9986 - prc: 0.9984 - val_loss: 0.0521 - val_tp: 9658.0000 - val_fp: 227.0000 - val_tn: 9607.0000 - val_fn: 185.0000 - val_accuracy: 0.9791 - val_precision: 0.9770 - val_recall: 0.9812 - val_auc: 0.9979 - val_prc: 0.9976
# Epoch 124/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0410 - tp: 38906.0000 - fp: 675.0000 - tn: 38615.0000 - fn: 511.0000 - accuracy: 0.9849 - precision: 0.9829 - recall: 0.9870 - auc: 0.9988 - prc: 0.9986 - val_loss: 0.0529 - val_tp: 9787.0000 - val_fp: 338.0000 - val_tn: 9496.0000 - val_fn: 56.0000 - val_accuracy: 0.9800 - val_precision: 0.9666 - val_recall: 0.9943 - val_auc: 0.9983 - val_prc: 0.9980
# Epoch 125/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0394 - tp: 38955.0000 - fp: 688.0000 - tn: 38602.0000 - fn: 462.0000 - accuracy: 0.9854 - precision: 0.9826 - recall: 0.9883 - auc: 0.9989 - prc: 0.9988 - val_loss: 0.0435 - val_tp: 9702.0000 - val_fp: 168.0000 - val_tn: 9666.0000 - val_fn: 141.0000 - val_accuracy: 0.9843 - val_precision: 0.9830 - val_recall: 0.9857 - val_auc: 0.9987 - val_prc: 0.9986
# Epoch 126/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0380 - tp: 38943.0000 - fp: 634.0000 - tn: 38656.0000 - fn: 474.0000 - accuracy: 0.9859 - precision: 0.9840 - recall: 0.9880 - auc: 0.9990 - prc: 0.9988 - val_loss: 0.0510 - val_tp: 9802.0000 - val_fp: 331.0000 - val_tn: 9503.0000 - val_fn: 41.0000 - val_accuracy: 0.9811 - val_precision: 0.9673 - val_recall: 0.9958 - val_auc: 0.9983 - val_prc: 0.9977
# Epoch 127/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0410 - tp: 38909.0000 - fp: 703.0000 - tn: 38587.0000 - fn: 508.0000 - accuracy: 0.9846 - precision: 0.9823 - recall: 0.9871 - auc: 0.9988 - prc: 0.9986 - val_loss: 0.0578 - val_tp: 9494.0000 - val_fp: 115.0000 - val_tn: 9719.0000 - val_fn: 349.0000 - val_accuracy: 0.9764 - val_precision: 0.9880 - val_recall: 0.9645 - val_auc: 0.9982 - val_prc: 0.9982
# Epoch 128/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0449 - tp: 38842.0000 - fp: 754.0000 - tn: 38536.0000 - fn: 575.0000 - accuracy: 0.9831 - precision: 0.9810 - recall: 0.9854 - auc: 0.9985 - prc: 0.9983 - val_loss: 0.0470 - val_tp: 9637.0000 - val_fp: 143.0000 - val_tn: 9691.0000 - val_fn: 206.0000 - val_accuracy: 0.9823 - val_precision: 0.9854 - val_recall: 0.9791 - val_auc: 0.9985 - val_prc: 0.9985
# Epoch 129/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0395 - tp: 38927.0000 - fp: 656.0000 - tn: 38634.0000 - fn: 490.0000 - accuracy: 0.9854 - precision: 0.9834 - recall: 0.9876 - auc: 0.9989 - prc: 0.9987 - val_loss: 0.0496 - val_tp: 9730.0000 - val_fp: 262.0000 - val_tn: 9572.0000 - val_fn: 113.0000 - val_accuracy: 0.9809 - val_precision: 0.9738 - val_recall: 0.9885 - val_auc: 0.9980 - val_prc: 0.9977
# Epoch 130/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0389 - tp: 38965.0000 - fp: 676.0000 - tn: 38614.0000 - fn: 452.0000 - accuracy: 0.9857 - precision: 0.9829 - recall: 0.9885 - auc: 0.9989 - prc: 0.9987 - val_loss: 0.0449 - val_tp: 9759.0000 - val_fp: 252.0000 - val_tn: 9582.0000 - val_fn: 84.0000 - val_accuracy: 0.9829 - val_precision: 0.9748 - val_recall: 0.9915 - val_auc: 0.9983 - val_prc: 0.9980
# Epoch 131/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0388 - tp: 38959.0000 - fp: 646.0000 - tn: 38644.0000 - fn: 458.0000 - accuracy: 0.9860 - precision: 0.9837 - recall: 0.9884 - auc: 0.9989 - prc: 0.9988 - val_loss: 0.0452 - val_tp: 9768.0000 - val_fp: 260.0000 - val_tn: 9574.0000 - val_fn: 75.0000 - val_accuracy: 0.9830 - val_precision: 0.9741 - val_recall: 0.9924 - val_auc: 0.9985 - val_prc: 0.9983
# Epoch 132/500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0386 - tp: 38941.0000 - fp: 663.0000 - tn: 38627.0000 - fn: 476.0000 - accuracy: 0.9855 - precision: 0.9833 - recall: 0.9879 - auc: 0.9989 - prc: 0.9988 - val_loss: 0.0742 - val_tp: 9780.0000 - val_fp: 517.0000 - val_tn: 9317.0000 - val_fn: 63.0000 - val_accuracy: 0.9705 - val_precision: 0.9498 - val_recall: 0.9936 - val_auc: 0.9977 - val_prc: 0.9969
# Epoch 133/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0451 - tp: 38835.0000 - fp: 771.0000 - tn: 38519.0000 - fn: 582.0000 - accuracy: 0.9828 - precision: 0.9805 - recall: 0.9852 - auc: 0.9986 - prc: 0.9984 - val_loss: 0.0421 - val_tp: 9733.0000 - val_fp: 191.0000 - val_tn: 9643.0000 - val_fn: 110.0000 - val_accuracy: 0.9847 - val_precision: 0.9808 - val_recall: 0.9888 - val_auc: 0.9987 - val_prc: 0.9986
# Epoch 134/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0372 - tp: 38983.0000 - fp: 624.0000 - tn: 38666.0000 - fn: 434.0000 - accuracy: 0.9866 - precision: 0.9842 - recall: 0.9890 - auc: 0.9990 - prc: 0.9989 - val_loss: 0.0412 - val_tp: 9724.0000 - val_fp: 167.0000 - val_tn: 9667.0000 - val_fn: 119.0000 - val_accuracy: 0.9855 - val_precision: 0.9831 - val_recall: 0.9879 - val_auc: 0.9985 - val_prc: 0.9983
# Epoch 135/500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0374 - tp: 38958.0000 - fp: 618.0000 - tn: 38672.0000 - fn: 459.0000 - accuracy: 0.9863 - precision: 0.9844 - recall: 0.9884 - auc: 0.9990 - prc: 0.9988 - val_loss: 0.0454 - val_tp: 9773.0000 - val_fp: 272.0000 - val_tn: 9562.0000 - val_fn: 70.0000 - val_accuracy: 0.9826 - val_precision: 0.9729 - val_recall: 0.9929 - val_auc: 0.9985 - val_prc: 0.9981
# Restoring model weights from the end of the best epoch.
# Epoch 00135: early stopping
# loss :  0.0460425540804863 /n
# tp :  12061.0 /n
# fp :  220.0 /n
# tn :  12146.0 /n
# fn :  169.0 /n
# accuracy :  0.9841844439506531 /n
# precision :  0.9820861220359802 /n
# recall :  0.9861814975738525 /n
# auc :  0.9984470009803772 /n
# prc :  0.9983872175216675 /n
# True Negatives:  12146
# False Positives:  220
# False Negatives:  169
# True Positives:  12061
# Total:  12230
# INFO:tensorflow:Assets written to: C:\Users\angel\AppData\Local\Temp\tmpktaqq6n4\model\data\model\assets

# %% [markdown]
# ## 5. Register Model

# %%
model_uri = "runs:/{}/{}".format(run.info.run_id, model_name)
mv = mlflow.register_model(model_uri, model_name)
print("Name: {}".format(mv.name))
print("Version: {}".format(mv.version))
# Out:
# Successfully registered model 'cut_stop_kinect'.
# 2021/05/16 12:53:08 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: cut_stop_kinect, version 1
# Name: cut_stop_kinect
# Version: 1
# Created version '1' of model 'cut_stop_kinect'.
