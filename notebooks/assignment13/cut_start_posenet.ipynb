# %% [markdown]
# # Model to Classify Start positions in PoseNet dataset
#
# Section for configurations and imports.

# %%
import os 
import tempfile

import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow import keras

# MLflow dashboard
import mlflow
mlflow.set_tracking_uri('http://35.228.45.76:5000')
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='./mlflow-312506-8cfad529f4fd.json'

# Import data augmentation
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from augmentation.methods import *

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
random_state = 47
np.random.seed(random_state)

# %%
physical_devices = tf.config.experimental.list_physical_devices( 'GPU' )
print( 'Num GPUs Available: ', len( physical_devices ) )
if len( physical_devices ) > 0:
    tf.config.experimental.set_memory_growth( physical_devices[0], True )
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # 1. Data Preparation
# ## 1.1 Load Kinect files
#
# These files are marked start and stop frames in one-hot encoding. <br />
# We're only interested in the 'start' column.

# %%
data_path = '../../datasets/marked_start_end/'

df = None

# %%
for file in os.listdir(data_path):
    if file.endswith('.csv') and 'kinect' not in file:
        try:
            dataset = pd.read_csv(data_path + file)
            dataset.drop(columns=['FrameNo'], inplace=True)
            dataset.drop(columns=['end'], inplace=True)

            if df is None:
                df = dataset
            else:
                df = pd.concat((df, dataset), ignore_index=True)

        except IOError as e:
            print('Error in reading file: ', e)

print(df.shape)
# Out:
# (38488, 27)

# %% [markdown]
# ## 1.2 Data Augmentation
#
# ### Mirror X coordinate

# %%
df = mirror(df,'x', append=True)
print(df.shape)
# Out:
# (76976, 27)

# %% [markdown]
# ## 1.3 Check Class Imbalance
#
# This shows the small fraction of start frames.

# %%
X = df.drop(columns=['start'])
y = df['start']

# %%
print(
    'Total: {}\n\nStart: {} ({:.2f}% of total)\nNone: {} ({:.2f}% of total)\n'
    .format(
      len(y), 
      len(y.values[y.values == 1]),
      len(y.values[y.values == 1]) / len(y),
      len(y.values[y.values == 0]),
      len(y.values[y.values == 0]) / len(y)
    )
  )
# Out:
# Total: 76976
#
# Start: 16216 (0.21% of total)
# None: 60760 (0.79% of total)

# %% [markdown]
# ## 1.4 Oversample the minority class

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=random_state) # Perform oversamling using SMOTE
resampled_X, resampled_y = sm.fit_resample(X, y)

print(resampled_X.shape)
print(resampled_y.shape)
# Out:
# (121520, 26)
# (121520,)

# %%
print(
    'Total: {}\n\nStart: {} ({:.2f}% of total)\nNone: {} ({:.2f}% of total)\n'
    .format(
      len(resampled_y), 
      len(resampled_y.values[resampled_y.values == 1]),
      len(resampled_y.values[resampled_y.values == 1]) / len(resampled_y),
      len(resampled_y.values[resampled_y.values == 0]),
      len(resampled_y.values[resampled_y.values == 0]) / len(resampled_y)
    )
  )
# Out:
# Total: 121520
#
# Start: 60760 (0.50% of total)
# None: 60760 (0.50% of total)

# %% [markdown]
# ## 1.5 Split and normalize the data
#
# We already dropped the 'FrameNo' and 'start' columns when the data was loading. <br />
# Now, we'll split the dataset into train, validation, and test sets:
#
# - The validation set is used during model fitting to evaluate the loss and other evaluation metrics.
# - The test set is unused during the training phase and is used at the end to evaluate how well the model generalizes to new data (i.e. a holdout set). This is especially important with imbalanced datasets where overfitting is a significant concern from the lack of training data.
#
# We also normalize the input features using the sklearn StandardScaler. StandardScaler is only fit using X_train. As we want to deploy a model, it's critical that you preserve the preprocessing calculations. The easiest way to implement them as layers, and attach them to your model before export.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

print('Training labels shape:', y_train.shape)
print('Validation labels shape:', y_val.shape)
print('Test labels shape:', y_test.shape, '\n')

print('Training features shape:', X_train.shape)
print('Validation features shape:', X_val.shape)
print('Test features shape:', X_test.shape)
# Out:
# Training labels shape: (49264,)
# Validation labels shape: (12316,)
# Test labels shape: (15396,)
#
# Training features shape: (49264, 26)
# Validation features shape: (12316, 26)
# Test features shape: (15396, 26)

# %% [markdown]
# # 2. Define the Model and Metrics

# %% [markdown]
# ## 2.1 Layer Factory

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %% [markdown]
# ## 2.2 Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer

def make_model(metrics, layers, optimizer, input_dim, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %% [markdown]
# # 3. Build the Model
#
# 3.1 Estimate the initial bias
# We're going to keep the initial model's weights in a checkpoint file and load them into each model before training so the model doesn't need to spend the first few epochs just learning that start frames are unlikely. Therefore, we start by estimating the initial bias before defining the model.

# %%
neg, pos = np.bincount(y)

initial_bias = np.log([pos/neg])
initial_bias
# Out:
# array([-1.32093327])

# %% [markdown]
# ## 3.2 Define the Model and Evaluation Metrics
#
# We're using standard evaluation metrics for binary classification problems.
#
# The **make_model** function returns a model based on parameter values. It uses the Layer Factory for creating the model.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(layers, input_dim, loss, optimizer, learning_rate=0.001, metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %%
output_bias = tf.keras.initializers.Constant(initial_bias)
input_dim = X_train.shape[1]
output_size = 1

units = 32
activation = 'tanh'
kernel_initializer = 'he_uniform'
output_activation = 'sigmoid'
optimizer = 'Adam'
learning_rate = 1e-3

LAYERS = [ 
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':64, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':64, 'activation': 'relu', 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':output_size, 'activation': output_activation, 'bias_initializer': initial_bias }
]

model = make_model(layers=LAYERS, input_dim=input_dim, loss='binary_crossentropy', optimizer=optimizer, learning_rate=learning_rate, output_bias=output_bias)

model.predict(X_train[:10])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                864
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,305
# Trainable params: 10,305
# Non-trainable params: 0
# _________________________________________________________________
# None
# array([[0.46714032],
#        [0.49963406],
#        [0.47899735],
#        [0.5014355 ],
#        [0.4967124 ],
#        [0.49563217],
#        [0.5279651 ],
#        [0.4467004 ],
#        [0.5323334 ],
#        [0.4955653 ]], dtype=float32)

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.6934

# %%
initial_weights = os.path.join(tempfile.mkdtemp(), 'initial_weights')
model.save_weights(initial_weights)

# %% [markdown]
# ## 3.3 Add Class Weights

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

print('Weight for class 0:', class_weights[0])
print('Weight for class 1:', class_weights[1])
# Out:
# Weight for class 0: 0.6338814689003834
# Weight for class 1: 2.367323402210476

# %% [markdown]
# # 4. MLflow Experimentation
# ## 4.1 Define learning parameters for all models

# %%
from keras.callbacks import EarlyStopping

EPOCHS = 500
BATCH_SIZE = 5000

early_stopping = EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ## 4.2 Define Experimentation Configurations
# The Model signature in MLflow defines the schema of a model's inputs and outputs.

# %%
from mlflow.models.signature import ModelSignature
from mlflow.types.schema import Schema, ColSpec

input_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "leftShoulder_x"),
    ColSpec("double", "leftShoulder_y"),
    ColSpec("double", "leftElbow_x"),
    ColSpec("double", "leftElbow_y"),
    ColSpec("double", "rightShoulder_x"),
    ColSpec("double", "rightShoulder_y"),
    ColSpec("double", "rightElbow_x"),
    ColSpec("double", "rightElbow_y"),
    ColSpec("double", "leftHand_x"),
    ColSpec("double", "leftHand_y"),
    ColSpec("double", "rightHand_x"),
    ColSpec("double", "rightHand_y"),
    ColSpec("double", "leftHip_x"),
    ColSpec("double", "leftHip_y"),
    ColSpec("double", "rightHip_x"),
    ColSpec("double", "rightHip_y"),
    ColSpec("double", "leftKnee_x"),
    ColSpec("double", "leftKnee_y"),
    ColSpec("double", "rightKnee_x"),
    ColSpec("double", "rightKnee_y"),
    ColSpec("double", "leftFoot_x"),
    ColSpec("double", "leftFoot_y"),
    ColSpec("double", "rightFoot_x"),
    ColSpec("double", "rightFoot_y"),
])
output_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "leftShoulder_x"),
    ColSpec("double", "leftShoulder_y"),
    ColSpec("double", "leftElbow_x"),
    ColSpec("double", "leftElbow_y"),
    ColSpec("double", "rightShoulder_x"),
    ColSpec("double", "rightShoulder_y"),
    ColSpec("double", "rightElbow_x"),
    ColSpec("double", "rightElbow_y"),
    ColSpec("double", "leftHand_x"),
    ColSpec("double", "leftHand_y"),
    ColSpec("double", "rightHand_x"),
    ColSpec("double", "rightHand_y"),
    ColSpec("double", "leftHip_x"),
    ColSpec("double", "leftHip_y"),
    ColSpec("double", "rightHip_x"),
    ColSpec("double", "rightHip_y"),
    ColSpec("double", "leftKnee_x"),
    ColSpec("double", "leftKnee_y"),
    ColSpec("double", "rightKnee_x"),
    ColSpec("double", "rightKnee_y"),
    ColSpec("double", "leftFoot_x"),
    ColSpec("double", "leftFoot_y"),
    ColSpec("double", "rightFoot_x"),
    ColSpec("double", "rightFoot_y"),
])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# %% [markdown]
# ## 4.3 Functions used in the experimentation
#
# For creating plots and others.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

def plot_loss(history, label, n):
  plt.semilogy(history.epoch, history.history['loss'],
               color=colors[n], label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               color=colors[n], label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('True Negatives: ', cm[0][0])
    print('False Positives: ', cm[0][1])
    print('False Negatives: ', cm[1][0])
    print('True Positives: ', cm[1][1])
    print('Total: ', np.sum(cm[1]))


def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# ## 4.4 Start run
# Starting a run which fits the model according to chosen parameter values, then makes predictions and saves selected values to MLflow dashboard.

# %%
model_name = 'cut_start_posenet'

with mlflow.start_run(run_name=model_name) as run:

    run_id = run.info.run_id

    model = make_model(metrics=METRICS, 
                        layers=LAYERS, 
                        loss='binary_crossentropy', 
                        optimizer=optimizer, 
                        learning_rate=learning_rate, 
                        output_bias=initial_bias, 
                        input_dim=input_dim)
    model.load_weights(initial_weights)
    model.layers[-1].bias.assign([0.0])
    
    with tf.device('/CPU:0'):
        history = model.fit(
            x=X_train, 
            y=y_train, 
            class_weight=class_weight_dict, 
            validation_data=(X_val, y_val), 
            shuffle=True, 
            epochs=EPOCHS, 
            verbose=1,
            batch_size=BATCH_SIZE, 
            callbacks=[early_stopping])

        # Plot training history
        plot_loss(history, "Bias", 0)
        plt.savefig("loss.jpg")
        mlflow.log_artifact("loss.jpg")
        plt.show()
        
        # Plot and log metrics
        predictions_train = model.predict(X_train)
        predictions_test = model.predict(X_test)

        plot_metrics(history)
        plt.savefig("metrics.jpg")
        mlflow.log_artifact("metrics.jpg")
        plt.show()

        # Confusion matrix
        results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
        for name, value in zip(model.metrics_names, results):
            print(name, ': ', value, '/n')
        plot_cm(y_test, predictions_test)
        plt.savefig("cm.jpg")
        mlflow.log_artifact("cm.jpg")
        plt.show()

        # ROC Curve
        plot_roc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("roc.jpg")
        mlflow.log_artifact("roc.jpg")
        plt.show()

        # Precision-Recall Curve (PRC)
        plot_prc("Train Predictions", y_train, predictions_train, color=colors[0])
        plot_prc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("prc.jpg")
        mlflow.log_artifact("prc.jpg")
        plt.show()
        
        # Log model, scaler, model parameters to MLflow
        mlflow.log_param("units", units)
        mlflow.log_param("activation", activation)
        mlflow.log_param("kernel_initializer", kernel_initializer)
        mlflow.log_param("output activation", output_activation)
        mlflow.log_param("optimizer", optimizer)
        mlflow.log_param("learning rate", learning_rate)
        mlflow.log_param("batch size", BATCH_SIZE)
        mlflow.log_metric("accuracy", results[5])
        mlflow.log_metric("average precision score", results[6])
        mlflow.log_metric("recall", results[7])
        mlflow.log_metric("auc", results[8])

        mlflow.keras.log_model(model, model_name, signature=signature)
        mlflow.sklearn.log_model(scaler, 'InputScaler')
# Out:
# : 0.9186 - val_auc: 0.9664 - val_prc: 0.8866
# Epoch 76/500
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2257 - tp: 9599.0000 - fp: 4403.0000 - tn: 34456.0000 - fn: 806.0000 - accuracy: 0.8943 - precision: 0.6855 - recall: 0.9225 - auc: 0.9680 - prc: 0.8932 - val_loss: 0.2453 - val_tp: 2384.0000 - val_fp: 1127.0000 - val_tn: 8584.0000 - val_fn: 221.0000 - val_accuracy: 0.8905 - val_precision: 0.6790 - val_recall: 0.9152 - val_auc: 0.9647 - val_prc: 0.8829
# Epoch 77/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2268 - tp: 9574.0000 - fp: 4343.0000 - tn: 34516.0000 - fn: 831.0000 - accuracy: 0.8950 - precision: 0.6879 - recall: 0.9201 - auc: 0.9675 - prc: 0.8915 - val_loss: 0.2439 - val_tp: 2404.0000 - val_fp: 1089.0000 - val_tn: 8622.0000 - val_fn: 201.0000 - val_accuracy: 0.8953 - val_precision: 0.6882 - val_recall: 0.9228 - val_auc: 0.9661 - val_prc: 0.8891
# Epoch 78/500
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2245 - tp: 9615.0000 - fp: 4433.0000 - tn: 34426.0000 - fn: 790.0000 - accuracy: 0.8940 - precision: 0.6844 - recall: 0.9241 - auc: 0.9683 - prc: 0.8939 - val_loss: 0.2263 - val_tp: 2321.0000 - val_fp: 917.0000 - val_tn: 8794.0000 - val_fn: 284.0000 - val_accuracy: 0.9025 - val_precision: 0.7168 - val_recall: 0.8910 - val_auc: 0.9662 - val_prc: 0.8876
# Epoch 79/500
# 10/10 [==============================] - 0s 16ms/step - loss: 0.2270 - tp: 9512.0000 - fp: 4290.0000 - tn: 34569.0000 - fn: 893.0000 - accuracy: 0.8948 - precision: 0.6892 - recall: 0.9142 - auc: 0.9674 - prc: 0.8903 - val_loss: 0.2699 - val_tp: 2444.0000 - val_fp: 1328.0000 - val_tn: 8383.0000 - val_fn: 161.0000 - val_accuracy: 0.8791 - val_precision: 0.6479 - val_recall: 0.9382 - val_auc: 0.9659 - val_prc: 0.8844
# Epoch 80/500
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2272 - tp: 9567.0000 - fp: 4497.0000 - tn: 34362.0000 - fn: 838.0000 - accuracy: 0.8917 - precision: 0.6802 - recall: 0.9195 - auc: 0.9673 - prc: 0.8905 - val_loss: 0.2626 - val_tp: 2447.0000 - val_fp: 1293.0000 - val_tn: 8418.0000 - val_fn: 158.0000 - val_accuracy: 0.8822 - val_precision: 0.6543 - val_recall: 0.9393 - val_auc: 0.9662 - val_prc: 0.8851
# Epoch 81/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2227 - tp: 9601.0000 - fp: 4364.0000 - tn: 34495.0000 - fn: 804.0000 - accuracy: 0.8951 - precision: 0.6875 - recall: 0.9227 - auc: 0.9687 - prc: 0.8962 - val_loss: 0.2277 - val_tp: 2394.0000 - val_fp: 986.0000 - val_tn: 8725.0000 - val_fn: 211.0000 - val_accuracy: 0.9028 - val_precision: 0.7083 - val_recall: 0.9190 - val_auc: 0.9684 - val_prc: 0.8930
# Epoch 82/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2207 - tp: 9620.0000 - fp: 4238.0000 - tn: 34621.0000 - fn: 785.0000 - accuracy: 0.8980 - precision: 0.6942 - recall: 0.9246 - auc: 0.9695 - prc: 0.8978 - val_loss: 0.2315 - val_tp: 2365.0000 - val_fp: 991.0000 - val_tn: 8720.0000 - val_fn: 240.0000 - val_accuracy: 0.9000 - val_precision: 0.7047 - val_recall: 0.9079 - val_auc: 0.9664 - val_prc: 0.8883
# Epoch 83/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2202 - tp: 9605.0000 - fp: 4232.0000 - tn: 34627.0000 - fn: 800.0000 - accuracy: 0.8979 - precision: 0.6942 - recall: 0.9231 - auc: 0.9694 - prc: 0.8977 - val_loss: 0.2420 - val_tp: 2393.0000 - val_fp: 1108.0000 - val_tn: 8603.0000 - val_fn: 212.0000 - val_accuracy: 0.8928 - val_precision: 0.6835 - val_recall: 0.9186 - val_auc: 0.9677 - val_prc: 0.8923
# Epoch 84/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2199 - tp: 9655.0000 - fp: 4325.0000 - tn: 34534.0000 - fn: 750.0000 - accuracy: 0.8970 - precision: 0.6906 - recall: 0.9279 - auc: 0.9695 - prc: 0.8988 - val_loss: 0.2254 - val_tp: 2380.0000 - val_fp: 934.0000 - val_tn: 8777.0000 - val_fn: 225.0000 - val_accuracy: 0.9059 - val_precision: 0.7182 - val_recall: 0.9136 - val_auc: 0.9681 - val_prc: 0.8939
# Epoch 85/500
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2190 - tp: 9639.0000 - fp: 4321.0000 - tn: 34538.0000 - fn: 766.0000 - accuracy: 0.8967 - precision: 0.6905 - recall: 0.9264 - auc: 0.9697 - prc: 0.8975 - val_loss: 0.1973 - val_tp: 2240.0000 - val_fp: 638.0000 - val_tn: 9073.0000 - val_fn: 365.0000 - val_accuracy: 0.9186 - val_precision: 0.7783 - val_recall: 0.8599 - val_auc: 0.9692 - val_prc: 0.8967
# Epoch 86/500
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2207 - tp: 9568.0000 - fp: 4117.0000 - tn: 34742.0000 - fn: 837.0000 - accuracy: 0.8994 - precision: 0.6992 - recall: 0.9196 - auc: 0.9693 - prc: 0.8981 - val_loss: 0.2365 - val_tp: 2382.0000 - val_fp: 999.0000 - val_tn: 8712.0000 - val_fn: 223.0000 - val_accuracy: 0.9008 - val_precision: 0.7045 - val_recall: 0.9144 - val_auc: 0.9679 - val_prc: 0.8936
# Epoch 87/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2175 - tp: 9618.0000 - fp: 4160.0000 - tn: 34699.0000 - fn: 787.0000 - accuracy: 0.8996 - precision: 0.6981 - recall: 0.9244 - auc: 0.9701 - prc: 0.8995 - val_loss: 0.2405 - val_tp: 2418.0000 - val_fp: 1117.0000 - val_tn: 8594.0000 - val_fn: 187.0000 - val_accuracy: 0.8941 - val_precision: 0.6840 - val_recall: 0.9282 - val_auc: 0.9682 - val_prc: 0.8924
# Epoch 88/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2153 - tp: 9620.0000 - fp: 4110.0000 - tn: 34749.0000 - fn: 785.0000 - accuracy: 0.9006 - precision: 0.7007 - recall: 0.9246 - auc: 0.9708 - prc: 0.9013 - val_loss: 0.2268 - val_tp: 2388.0000 - val_fp: 955.0000 - val_tn: 8756.0000 - val_fn: 217.0000 - val_accuracy: 0.9048 - val_precision: 0.7143 - val_recall: 0.9167 - val_auc: 0.9689 - val_prc: 0.8948
# Epoch 89/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2133 - tp: 9665.0000 - fp: 4190.0000 - tn: 34669.0000 - fn: 740.0000 - accuracy: 0.8999 - precision: 0.6976 - recall: 0.9289 - auc: 0.9715 - prc: 0.9036 - val_loss: 0.2342 - val_tp: 2409.0000 - val_fp: 1024.0000 - val_tn: 8687.0000 - val_fn: 196.0000 - val_accuracy: 0.9009 - val_precision: 0.7017 - val_recall: 0.9248 - val_auc: 0.9693 - val_prc: 0.8954
# Epoch 90/500
# 10/10 [==============================] - 0s 15ms/step - loss: 0.2153 - tp: 9627.0000 - fp: 4070.0000 - tn: 34789.0000 - fn: 778.0000 - accuracy: 0.9016 - precision: 0.7029 - recall: 0.9252 - auc: 0.9707 - prc: 0.9001 - val_loss: 0.2238 - val_tp: 2368.0000 - val_fp: 925.0000 - val_tn: 8786.0000 - val_fn: 237.0000 - val_accuracy: 0.9057 - val_precision: 0.7191 - val_recall: 0.9090 - val_auc: 0.9690 - val_prc: 0.8951
# Epoch 91/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2178 - tp: 9627.0000 - fp: 4126.0000 - tn: 34733.0000 - fn: 778.0000 - accuracy: 0.9005 - precision: 0.7000 - recall: 0.9252 - auc: 0.9701 - prc: 0.8985 - val_loss: 0.2316 - val_tp: 2383.0000 - val_fp: 1028.0000 - val_tn: 8683.0000 - val_fn: 222.0000 - val_accuracy: 0.8985 - val_precision: 0.6986 - val_recall: 0.9148 - val_auc: 0.9673 - val_prc: 0.8889
# Epoch 92/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2158 - tp: 9617.0000 - fp: 4054.0000 - tn: 34805.0000 - fn: 788.0000 - accuracy: 0.9017 - precision: 0.7035 - recall: 0.9243 - auc: 0.9706 - prc: 0.9007 - val_loss: 0.2504 - val_tp: 2393.0000 - val_fp: 1091.0000 - val_tn: 8620.0000 - val_fn: 212.0000 - val_accuracy: 0.8942 - val_precision: 0.6869 - val_recall: 0.9186 - val_auc: 0.9668 - val_prc: 0.8896
# Epoch 93/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2141 - tp: 9648.0000 - fp: 4139.0000 - tn: 34720.0000 - fn: 757.0000 - accuracy: 0.9006 - precision: 0.6998 - recall: 0.9272 - auc: 0.9710 - prc: 0.9003 - val_loss: 0.2381 - val_tp: 2449.0000 - val_fp: 1132.0000 - val_tn: 8579.0000 - val_fn: 156.0000 - val_accuracy: 0.8954 - val_precision: 0.6839 - val_recall: 0.9401 - val_auc: 0.9705 - val_prc: 0.8986
# Epoch 94/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2108 - tp: 9650.0000 - fp: 3969.0000 - tn: 34890.0000 - fn: 755.0000 - accuracy: 0.9041 - precision: 0.7086 - recall: 0.9274 - auc: 0.9720 - prc: 0.9036 - val_loss: 0.2894 - val_tp: 2496.0000 - val_fp: 1543.0000 - val_tn: 8168.0000 - val_fn: 109.0000 - val_accuracy: 0.8659 - val_precision: 0.6180 - val_recall: 0.9582 - val_auc: 0.9681 - val_prc: 0.8908
# Epoch 95/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2172 - tp: 9611.0000 - fp: 4286.0000 - tn: 34573.0000 - fn: 794.0000 - accuracy: 0.8969 - precision: 0.6916 - recall: 0.9237 - auc: 0.9702 - prc: 0.9002 - val_loss: 0.2406 - val_tp: 2393.0000 - val_fp: 1036.0000 - val_tn: 8675.0000 - val_fn: 212.0000 - val_accuracy: 0.8987 - val_precision: 0.6979 - val_recall: 0.9186 - val_auc: 0.9674 - val_prc: 0.8893
# Epoch 96/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2120 - tp: 9669.0000 - fp: 4034.0000 - tn: 34825.0000 - fn: 736.0000 - accuracy: 0.9032 - precision: 0.7056 - recall: 0.9293 - auc: 0.9717 - prc: 0.9029 - val_loss: 0.2170 - val_tp: 2386.0000 - val_fp: 907.0000 - val_tn: 8804.0000 - val_fn: 219.0000 - val_accuracy: 0.9086 - val_precision: 0.7246 - val_recall: 0.9159 - val_auc: 0.9705 - val_prc: 0.8998
# Epoch 97/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2086 - tp: 9695.0000 - fp: 3984.0000 - tn: 34875.0000 - fn: 710.0000 - accuracy: 0.9047 - precision: 0.7088 - recall: 0.9318 - auc: 0.9727 - prc: 0.9065 - val_loss: 0.2183 - val_tp: 2397.0000 - val_fp: 908.0000 - val_tn: 8803.0000 - val_fn: 208.0000 - val_accuracy: 0.9094 - val_precision: 0.7253 - val_recall: 0.9202 - val_auc: 0.9709 - val_prc: 0.9003
# Epoch 98/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2065 - tp: 9668.0000 - fp: 3825.0000 - tn: 35034.0000 - fn: 737.0000 - accuracy: 0.9074 - precision: 0.7165 - recall: 0.9292 - auc: 0.9731 - prc: 0.9076 - val_loss: 0.2506 - val_tp: 2445.0000 - val_fp: 1215.0000 - val_tn: 8496.0000 - val_fn: 160.0000 - val_accuracy: 0.8884 - val_precision: 0.6680 - val_recall: 0.9386 - val_auc: 0.9687 - val_prc: 0.8936
# Epoch 99/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2083 - tp: 9705.0000 - fp: 4091.0000 - tn: 34768.0000 - fn: 700.0000 - accuracy: 0.9027 - precision: 0.7035 - recall: 0.9327 - auc: 0.9727 - prc: 0.9071 - val_loss: 0.1998 - val_tp: 2319.0000 - val_fp: 711.0000 - val_tn: 9000.0000 - val_fn: 286.0000 - val_accuracy: 0.9190 - val_precision: 0.7653 - val_recall: 0.8902 - val_auc: 0.9707 - val_prc: 0.8988
# Epoch 100/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2094 - tp: 9651.0000 - fp: 3933.0000 - tn: 34926.0000 - fn: 754.0000 - accuracy: 0.9049 - precision: 0.7105 - recall: 0.9275 - auc: 0.9723 - prc: 0.9051 - val_loss: 0.2052 - val_tp: 2327.0000 - val_fp: 770.0000 - val_tn: 8941.0000 - val_fn: 278.0000 - val_accuracy: 0.9149 - val_precision: 0.7514 - val_recall: 0.8933 - val_auc: 0.9700 - val_prc: 0.8988
# Epoch 101/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2087 - tp: 9644.0000 - fp: 3928.0000 - tn: 34931.0000 - fn: 761.0000 - accuracy: 0.9048 - precision: 0.7106 - recall: 0.9269 - auc: 0.9725 - prc: 0.9070 - val_loss: 0.2425 - val_tp: 2438.0000 - val_fp: 1170.0000 - val_tn: 8541.0000 - val_fn: 167.0000 - val_accuracy: 0.8914 - val_precision: 0.6757 - val_recall: 0.9359 - val_auc: 0.9707 - val_prc: 0.9002
# Epoch 102/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2038 - tp: 9694.0000 - fp: 3819.0000 - tn: 35040.0000 - fn: 711.0000 - accuracy: 0.9080 - precision: 0.7174 - recall: 0.9317 - auc: 0.9739 - prc: 0.9099 - val_loss: 0.2347 - val_tp: 2441.0000 - val_fp: 1112.0000 - val_tn: 8599.0000 - val_fn: 164.0000 - val_accuracy: 0.8964 - val_precision: 0.6870 - val_recall: 0.9370 - val_auc: 0.9708 - val_prc: 0.8981
# Epoch 103/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2035 - tp: 9715.0000 - fp: 3882.0000 - tn: 34977.0000 - fn: 690.0000 - accuracy: 0.9072 - precision: 0.7145 - recall: 0.9337 - auc: 0.9739 - prc: 0.9097 - val_loss: 0.2245 - val_tp: 2419.0000 - val_fp: 963.0000 - val_tn: 8748.0000 - val_fn: 186.0000 - val_accuracy: 0.9067 - val_precision: 0.7153 - val_recall: 0.9286 - val_auc: 0.9714 - val_prc: 0.9005
# Epoch 104/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2053 - tp: 9695.0000 - fp: 3958.0000 - tn: 34901.0000 - fn: 710.0000 - accuracy: 0.9052 - precision: 0.7101 - recall: 0.9318 - auc: 0.9732 - prc: 0.9069 - val_loss: 0.2423 - val_tp: 2450.0000 - val_fp: 1147.0000 - val_tn: 8564.0000 - val_fn: 155.0000 - val_accuracy: 0.8943 - val_precision: 0.6811 - val_recall: 0.9405 - val_auc: 0.9710 - val_prc: 0.9004
# Epoch 105/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2050 - tp: 9686.0000 - fp: 3899.0000 - tn: 34960.0000 - fn: 719.0000 - accuracy: 0.9063 - precision: 0.7130 - recall: 0.9309 - auc: 0.9735 - prc: 0.9092 - val_loss: 0.2283 - val_tp: 2404.0000 - val_fp: 973.0000 - val_tn: 8738.0000 - val_fn: 201.0000 - val_accuracy: 0.9047 - val_precision: 0.7119 - val_recall: 0.9228 - val_auc: 0.9701 - val_prc: 0.8976
# Epoch 106/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2047 - tp: 9677.0000 - fp: 3912.0000 - tn: 34947.0000 - fn: 728.0000 - accuracy: 0.9058 - precision: 0.7121 - recall: 0.9300 - auc: 0.9734 - prc: 0.9080 - val_loss: 0.2178 - val_tp: 2374.0000 - val_fp: 893.0000 - val_tn: 8818.0000 - val_fn: 231.0000 - val_accuracy: 0.9087 - val_precision: 0.7267 - val_recall: 0.9113 - val_auc: 0.9710 - val_prc: 0.8994
# Epoch 107/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2049 - tp: 9691.0000 - fp: 3924.0000 - tn: 34935.0000 - fn: 714.0000 - accuracy: 0.9059 - precision: 0.7118 - recall: 0.9314 - auc: 0.9734 - prc: 0.9090 - val_loss: 0.2218 - val_tp: 2400.0000 - val_fp: 950.0000 - val_tn: 8761.0000 - val_fn: 205.0000 - val_accuracy: 0.9062 - val_precision: 0.7164 - val_recall: 0.9213 - val_auc: 0.9698 - val_prc: 0.8934
# Epoch 108/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2023 - tp: 9684.0000 - fp: 3737.0000 - tn: 35122.0000 - fn: 721.0000 - accuracy: 0.9095 - precision: 0.7216 - recall: 0.9307 - auc: 0.9741 - prc: 0.9103 - val_loss: 0.2180 - val_tp: 2394.0000 - val_fp: 892.0000 - val_tn: 8819.0000 - val_fn: 211.0000 - val_accuracy: 0.9104 - val_precision: 0.7285 - val_recall: 0.9190 - val_auc: 0.9709 - val_prc: 0.8991
# Epoch 109/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2047 - tp: 9665.0000 - fp: 3844.0000 - tn: 35015.0000 - fn: 740.0000 - accuracy: 0.9070 - precision: 0.7154 - recall: 0.9289 - auc: 0.9734 - prc: 0.9092 - val_loss: 0.2473 - val_tp: 2466.0000 - val_fp: 1174.0000 - val_tn: 8537.0000 - val_fn: 139.0000 - val_accuracy: 0.8934 - val_precision: 0.6775 - val_recall: 0.9466 - val_auc: 0.9704 - val_prc: 0.8968
# Epoch 110/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2008 - tp: 9710.0000 - fp: 3797.0000 - tn: 35062.0000 - fn: 695.0000 - accuracy: 0.9088 - precision: 0.7189 - recall: 0.9332 - auc: 0.9744 - prc: 0.9110 - val_loss: 0.2359 - val_tp: 2454.0000 - val_fp: 1096.0000 - val_tn: 8615.0000 - val_fn: 151.0000 - val_accuracy: 0.8987 - val_precision: 0.6913 - val_recall: 0.9420 - val_auc: 0.9710 - val_prc: 0.8991
# Epoch 111/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2001 - tp: 9718.0000 - fp: 3831.0000 - tn: 35028.0000 - fn: 687.0000 - accuracy: 0.9083 - precision: 0.7172 - recall: 0.9340 - auc: 0.9747 - prc: 0.9106 - val_loss: 0.2212 - val_tp: 2423.0000 - val_fp: 972.0000 - val_tn: 8739.0000 - val_fn: 182.0000 - val_accuracy: 0.9063 - val_precision: 0.7137 - val_recall: 0.9301 - val_auc: 0.9725 - val_prc: 0.9055
# Epoch 112/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2027 - tp: 9681.0000 - fp: 3824.0000 - tn: 35035.0000 - fn: 724.0000 - accuracy: 0.9077 - precision: 0.7168 - recall: 0.9304 - auc: 0.9738 - prc: 0.9091 - val_loss: 0.2015 - val_tp: 2348.0000 - val_fp: 774.0000 - val_tn: 8937.0000 - val_fn: 257.0000 - val_accuracy: 0.9163 - val_precision: 0.7521 - val_recall: 0.9013 - val_auc: 0.9714 - val_prc: 0.9022
# Epoch 113/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2011 - tp: 9678.0000 - fp: 3689.0000 - tn: 35170.0000 - fn: 727.0000 - accuracy: 0.9104 - precision: 0.7240 - recall: 0.9301 - auc: 0.9744 - prc: 0.9115 - val_loss: 0.2781 - val_tp: 2492.0000 - val_fp: 1434.0000 - val_tn: 8277.0000 - val_fn: 113.0000 - val_accuracy: 0.8744 - val_precision: 0.6347 - val_recall: 0.9566 - val_auc: 0.9707 - val_prc: 0.8994
# Epoch 114/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2070 - tp: 9701.0000 - fp: 4057.0000 - tn: 34802.0000 - fn: 704.0000 - accuracy: 0.9034 - precision: 0.7051 - recall: 0.9323 - auc: 0.9727 - prc: 0.9054 - val_loss: 0.2200 - val_tp: 2396.0000 - val_fp: 945.0000 - val_tn: 8766.0000 - val_fn: 209.0000 - val_accuracy: 0.9063 - val_precision: 0.7172 - val_recall: 0.9198 - val_auc: 0.9706 - val_prc: 0.8986
# Epoch 115/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2065 - tp: 9679.0000 - fp: 3960.0000 - tn: 34899.0000 - fn: 726.0000 - accuracy: 0.9049 - precision: 0.7097 - recall: 0.9302 - auc: 0.9728 - prc: 0.9055 - val_loss: 0.2205 - val_tp: 2390.0000 - val_fp: 961.0000 - val_tn: 8750.0000 - val_fn: 215.0000 - val_accuracy: 0.9045 - val_precision: 0.7132 - val_recall: 0.9175 - val_auc: 0.9701 - val_prc: 0.8973
# Epoch 116/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2027 - tp: 9685.0000 - fp: 3827.0000 - tn: 35032.0000 - fn: 720.0000 - accuracy: 0.9077 - precision: 0.7168 - recall: 0.9308 - auc: 0.9739 - prc: 0.9094 - val_loss: 0.1987 - val_tp: 2326.0000 - val_fp: 725.0000 - val_tn: 8986.0000 - val_fn: 279.0000 - val_accuracy: 0.9185 - val_precision: 0.7624 - val_recall: 0.8929 - val_auc: 0.9722 - val_prc: 0.9048
# Epoch 117/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2013 - tp: 9676.0000 - fp: 3702.0000 - tn: 35157.0000 - fn: 729.0000 - accuracy: 0.9101 - precision: 0.7233 - recall: 0.9299 - auc: 0.9741 - prc: 0.9088 - val_loss: 0.2500 - val_tp: 2439.0000 - val_fp: 1191.0000 - val_tn: 8520.0000 - val_fn: 166.0000 - val_accuracy: 0.8898 - val_precision: 0.6719 - val_recall: 0.9363 - val_auc: 0.9692 - val_prc: 0.8973
# Epoch 118/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2044 - tp: 9688.0000 - fp: 3989.0000 - tn: 34870.0000 - fn: 717.0000 - accuracy: 0.9045 - precision: 0.7083 - recall: 0.9311 - auc: 0.9734 - prc: 0.9080 - val_loss: 0.2236 - val_tp: 2363.0000 - val_fp: 956.0000 - val_tn: 8755.0000 - val_fn: 242.0000 - val_accuracy: 0.9027 - val_precision: 0.7120 - val_recall: 0.9071 - val_auc: 0.9694 - val_prc: 0.8953
# Epoch 119/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2028 - tp: 9653.0000 - fp: 3756.0000 - tn: 35103.0000 - fn: 752.0000 - accuracy: 0.9085 - precision: 0.7199 - recall: 0.9277 - auc: 0.9739 - prc: 0.9106 - val_loss: 0.2602 - val_tp: 2476.0000 - val_fp: 1312.0000 - val_tn: 8399.0000 - val_fn: 129.0000 - val_accuracy: 0.8830 - val_precision: 0.6536 - val_recall: 0.9505 - val_auc: 0.9711 - val_prc: 0.8969
# Epoch 120/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1983 - tp: 9738.0000 - fp: 3824.0000 - tn: 35035.0000 - fn: 667.0000 - accuracy: 0.9088 - precision: 0.7180 - recall: 0.9359 - auc: 0.9751 - prc: 0.9125 - val_loss: 0.2329 - val_tp: 2437.0000 - val_fp: 1078.0000 - val_tn: 8633.0000 - val_fn: 168.0000 - val_accuracy: 0.8988 - val_precision: 0.6933 - val_recall: 0.9355 - val_auc: 0.9723 - val_prc: 0.9054
# Epoch 121/500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1961 - tp: 9710.0000 - fp: 3672.0000 - tn: 35187.0000 - fn: 695.0000 - accuracy: 0.9114 - precision: 0.7256 - recall: 0.9332 - auc: 0.9755 - prc: 0.9139 - val_loss: 0.2562 - val_tp: 2485.0000 - val_fp: 1298.0000 - val_tn: 8413.0000 - val_fn: 120.0000 - val_accuracy: 0.8849 - val_precision: 0.6569 - val_recall: 0.9539 - val_auc: 0.9718 - val_prc: 0.9008
# Restoring model weights from the end of the best epoch.
# Epoch 00121: early stopping
# loss :  0.2290305495262146 /n
# tp :  2951.0 /n
# fp :  1238.0 /n
# tn :  10952.0 /n
# fn :  255.0 /n
# accuracy :  0.9030267596244812 /n
# precision :  0.7044640779495239 /n
# recall :  0.9204616546630859 /n
# auc :  0.9697421789169312 /n
# prc :  0.8989067077636719 /n
# True Negatives:  10952
# False Positives:  1238
# False Negatives:  255
# True Positives:  2951
# Total:  3206
# INFO:tensorflow:Assets written to: C:\Users\angel\AppData\Local\Temp\tmpllohtmdm\model\data\model\assets

# %% [markdown]
# ## 5. Register Model

# %%
model_uri = "runs:/{}/{}".format(run.info.run_id, model_name)
mv = mlflow.register_model(model_uri, model_name)
print("Name: {}".format(mv.name))
print("Version: {}".format(mv.version))
# Out:
# Successfully registered model 'cut_start_posenet'.
# 2021/05/15 20:40:17 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: cut_start_posenet, version 1
# Name: cut_start_posenet
# Version: 1
# Created version '1' of model 'cut_start_posenet'.
