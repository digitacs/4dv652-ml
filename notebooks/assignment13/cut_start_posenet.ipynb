# %% [markdown]
# # Model to Classify Start positions in PoseNet dataset
#
# Section for configurations and imports.

# %%
import os 
import tempfile

import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow import keras

# MLflow dashboard
import mlflow
mlflow.set_tracking_uri('http://35.228.45.76:5000')
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='../../keys/mlflow-312506-8cfad529f4fd.json'

# Import data augmentation
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from augmentation.methods import *

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
random_state = 47
np.random.seed(random_state)

# %%
physical_devices = tf.config.experimental.list_physical_devices( 'GPU' )
print( 'Num GPUs Available: ', len( physical_devices ) )
if len( physical_devices ) > 0:
    tf.config.experimental.set_memory_growth( physical_devices[0], True )
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # 1. Data Preparation
# ## 1.1 Load Kinect files
#
# These files are marked start and stop frames in one-hot encoding. <br />
# We're only interested in the 'start' column.

# %%
data_path = '../../datasets/new_posenet_marked_start_end/'

df = None

# %%
for file in os.listdir(data_path):
    if file.endswith('.csv'):
        try:
            dataset = pd.read_csv(data_path + file)
            dataset.drop(columns=['end'], inplace=True)
            dataset = dataset[dataset.columns.drop(list(dataset.filter(regex='_score')))]
            dataset = dataset[dataset.columns.drop(list(dataset.filter(regex='_eye_')))]
            dataset = dataset[dataset.columns.drop(list(dataset.filter(regex='_ear_')))]
            dataset.rename({'nose_x': 'head_x', 'nose_y': 'head_y'})

            if df is None:
                df = dataset
            else:
                df = pd.concat((df, dataset), ignore_index=True)

        except IOError as e:
            print('Error in reading file: ', e)

print(df.shape)
# Out:
# (141945, 27)

# %% [markdown]
# ## 1.2 Data Augmentation
#
# ### Mirror X coordinate

# %%
df = mirror(df,'x', append=True)
print(df.shape)
# Out:
# (283890, 27)

# %% [markdown]
# ## 1.3 Check Class Imbalance
#
# This shows the small fraction of start frames.

# %%
X = df.drop(columns=['start'])
y = df['start']

# %%
print(
    'Total: {}\n\nStart: {} ({:.2f}% of total)\nNone: {} ({:.2f}% of total)\n'
    .format(
      len(y), 
      len(y.values[y.values == 1]),
      len(y.values[y.values == 1]) / len(y),
      len(y.values[y.values == 0]),
      len(y.values[y.values == 0]) / len(y)
    )
  )
# Out:
# Total: 283890
#
# Start: 58554 (0.21% of total)
# None: 225336 (0.79% of total)

# %% [markdown]
# ## 1.4 Oversample the minority class

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=random_state) # Perform oversamling using SMOTE
resampled_X, resampled_y = sm.fit_resample(X, y)

print(resampled_X.shape)
print(resampled_y.shape)
# Out:
# (450672, 26)
# (450672,)

# %%
print(
    'Total: {}\n\nStart: {} ({:.2f}% of total)\nNone: {} ({:.2f}% of total)\n'
    .format(
      len(resampled_y), 
      len(resampled_y.values[resampled_y.values == 1]),
      len(resampled_y.values[resampled_y.values == 1]) / len(resampled_y),
      len(resampled_y.values[resampled_y.values == 0]),
      len(resampled_y.values[resampled_y.values == 0]) / len(resampled_y)
    )
  )
# Out:
# Total: 450672
#
# Start: 225336 (0.50% of total)
# None: 225336 (0.50% of total)

# %% [markdown]
# ## 1.5 Split and normalize the data
#
# We already dropped the 'FrameNo' and 'start' columns when the data was loading. <br />
# Now, we'll split the dataset into train, validation, and test sets:
#
# - The validation set is used during model fitting to evaluate the loss and other evaluation metrics.
# - The test set is unused during the training phase and is used at the end to evaluate how well the model generalizes to new data (i.e. a holdout set). This is especially important with imbalanced datasets where overfitting is a significant concern from the lack of training data.
#
# We also normalize the input features using the sklearn StandardScaler. StandardScaler is only fit using X_train. As we want to deploy a model, it's critical that you preserve the preprocessing calculations. The easiest way to implement them as layers, and attach them to your model before export.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(resampled_X, resampled_y, test_size=0.2, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

print('Training labels shape:', y_train.shape)
print('Validation labels shape:', y_val.shape)
print('Test labels shape:', y_test.shape, '\n')

print('Training features shape:', X_train.shape)
print('Validation features shape:', X_val.shape)
print('Test features shape:', X_test.shape)
# Out:
# Training labels shape: (288429,)
# Validation labels shape: (72108,)
# Test labels shape: (90135,)
#
# Training features shape: (288429, 26)
# Validation features shape: (72108, 26)
# Test features shape: (90135, 26)

# %% [markdown]
# # 2. Define the Model and Metrics
#
# ## 2.1 Layer Factory

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %% [markdown]
# ## 2.2 Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer

def make_model(metrics, layers, optimizer, input_dim, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %% [markdown]
# # 3. Build the Model
#
# 3.1 Estimate the initial bias
# We're going to keep the initial model's weights in a checkpoint file and load them into each model before training so the model doesn't need to spend the first few epochs just learning that start frames are unlikely. Therefore, we start by estimating the initial bias before defining the model.

# %%
neg, pos = np.bincount(y)

initial_bias = np.log([pos/neg])
initial_bias
# Out:
# array([-1.34764322])

# %% [markdown]
# ## 3.2 Define the Model and Evaluation Metrics
#
# We're using standard evaluation metrics for binary classification problems.
#
# The **make_model** function returns a model based on parameter values. It uses the Layer Factory for creating the model.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(layers, input_dim, loss, optimizer, learning_rate=0.001, metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %%
output_bias = tf.keras.initializers.Constant(initial_bias)
input_dim = X_train.shape[1]
output_size = 1

units = 64
activation = 'relu'
kernel_initializer = 'he_uniform'
output_activation = 'sigmoid'
optimizer = 'Adam'
learning_rate = 1e-3

LAYERS = [ 
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':32, 'activation': 'relu' },
    { 'type': 'Dense', 'nodes':units, 'activation': activation },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':output_size, 'activation': output_activation, 'bias_initializer': initial_bias }
]

model = make_model(layers=LAYERS, input_dim=input_dim, loss='binary_crossentropy', optimizer=optimizer, learning_rate=learning_rate, output_bias=output_bias)

model.predict(X_train[:10])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                1728
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,145
# Trainable params: 10,145
# Non-trainable params: 0
# _________________________________________________________________
# None
# array([[0.5277782 ],
#        [0.47970253],
#        [0.55701905],
#        [0.48909116],
#        [0.5254361 ],
#        [0.46713498],
#        [0.49040127],
#        [0.50610507],
#        [0.47313842],
#        [0.49197888]], dtype=float32)

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.7073

# %%
initial_weights = os.path.join(tempfile.mkdtemp(), 'initial_weights')
model.save_weights(initial_weights)

# %% [markdown]
# ## 3.3 Add Class Weights

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

print('Weight for class 0:', class_weights[0])
print('Weight for class 1:', class_weights[1])
# Out:
# Weight for class 0: 0.9991859047196741
# Weight for class 1: 1.0008154229442667

# %% [markdown]
# # 4. MLflow Experimentation
# ## 4.1 Define learning parameters for all models

# %%
from keras.callbacks import EarlyStopping

EPOCHS = 500
BATCH_SIZE = 6000

early_stopping = EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ## 4.2 Define Experimentation Configurations
# The Model signature in MLflow defines the schema of a model's inputs and outputs.

# %%
from mlflow.models.signature import ModelSignature
from mlflow.types.schema import Schema, ColSpec

input_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
])
output_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "left_shoulder_x"),
    ColSpec("double", "left_shoulder_y"),
    ColSpec("double", "left_elbow_x"),
    ColSpec("double", "left_elbow_y"),
    ColSpec("double", "right_shoulder_x"),
    ColSpec("double", "right_shoulder_y"),
    ColSpec("double", "right_elbow_x"),
    ColSpec("double", "right_elbow_y"),
    ColSpec("double", "left_hand_x"),
    ColSpec("double", "left_hand_y"),
    ColSpec("double", "right_hand_x"),
    ColSpec("double", "right_hand_y"),
    ColSpec("double", "left_hip_x"),
    ColSpec("double", "left_hip_y"),
    ColSpec("double", "right_hip_x"),
    ColSpec("double", "right_hip_y"),
    ColSpec("double", "left_knee_x"),
    ColSpec("double", "left_knee_y"),
    ColSpec("double", "right_knee_x"),
    ColSpec("double", "right_knee_y"),
    ColSpec("double", "left_foot_x"),
    ColSpec("double", "left_foot_y"),
    ColSpec("double", "right_foot_x"),
    ColSpec("double", "right_foot_y"),
])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# %% [markdown]
# ## 4.3 Functions used in the experimentation
#
# For creating plots and others.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

def plot_loss(history, label, n):
  plt.semilogy(history.epoch, history.history['loss'],
               color=colors[n], label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               color=colors[n], label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('True Negatives: ', cm[0][0])
    print('False Positives: ', cm[0][1])
    print('False Negatives: ', cm[1][0])
    print('True Positives: ', cm[1][1])
    print('Total: ', np.sum(cm[1]))


def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# ## 4.4 Start run
# Starting a run which fits the model according to chosen parameter values, then makes predictions and saves selected values to MLflow dashboard.

# %%
model_name = 'cut_start_posenet'

with mlflow.start_run(run_name=model_name) as run:

    run_id = run.info.run_id

    model = make_model(metrics=METRICS, 
                        layers=LAYERS, 
                        loss='binary_crossentropy', 
                        optimizer=optimizer, 
                        learning_rate=learning_rate, 
                        output_bias=initial_bias, 
                        input_dim=input_dim)
    model.load_weights(initial_weights)
    model.layers[-1].bias.assign([0.0])
    
    with tf.device('/CPU:0'):
        history = model.fit(
            x=X_train, 
            y=y_train, 
            class_weight=class_weight_dict, 
            validation_data=(X_val, y_val), 
            shuffle=True, 
            epochs=EPOCHS, 
            verbose=1,
            batch_size=BATCH_SIZE, 
            callbacks=[early_stopping])

        # Plot training history
        plot_loss(history, "Bias", 0)
        plt.savefig("loss.jpg")
        mlflow.log_artifact("loss.jpg")
        plt.show()
        
        # Plot and log metrics
        predictions_train = model.predict(X_train)
        predictions_test = model.predict(X_test)

        plot_metrics(history)
        plt.savefig("metrics.jpg")
        mlflow.log_artifact("metrics.jpg")
        plt.show()

        # Confusion matrix
        results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
        for name, value in zip(model.metrics_names, results):
            print(name, ': ', value, '/n')
        plot_cm(y_test, predictions_test)
        plt.savefig("cm.jpg")
        mlflow.log_artifact("cm.jpg")
        plt.show()

        # ROC Curve
        plot_roc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("roc.jpg")
        mlflow.log_artifact("roc.jpg")
        plt.show()

        # Precision-Recall Curve (PRC)
        plot_prc("Train Predictions", y_train, predictions_train, color=colors[0])
        plot_prc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("prc.jpg")
        mlflow.log_artifact("prc.jpg")
        plt.show()
        
        # Log model, scaler, model parameters to MLflow
        mlflow.log_param("units", units)
        mlflow.log_param("activation", activation)
        mlflow.log_param("kernel_initializer", kernel_initializer)
        mlflow.log_param("output activation", output_activation)
        mlflow.log_param("optimizer", optimizer)
        mlflow.log_param("learning rate", learning_rate)
        mlflow.log_param("batch size", BATCH_SIZE)
        mlflow.log_metric("accuracy", results[5])
        mlflow.log_metric("average precision score", results[6])
        mlflow.log_metric("recall", results[7])
        mlflow.log_metric("auc", results[8])

        mlflow.keras.log_model(model, model_name, signature=signature)
        mlflow.sklearn.log_model(scaler, 'InputScaler')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1728
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,145
# Trainable params: 10,145
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\angel\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/500
# 49/49 [==============================] - 3s 33ms/step - loss: 0.5486 - tp: 174892.0000 - fp: 136862.0000 - tn: 151802.0000 - fn: 113302.0000 - accuracy: 0.5663 - precision: 0.5610 - recall: 0.6069 - auc: 0.6391 - prc: 0.6445 - val_loss: 0.4753 - val_tp: 29901.0000 - val_fp: 11235.0000 - val_tn: 24695.0000 - val_fn: 6277.0000 - val_accuracy: 0.7571 - val_precision: 0.7269 - val_recall: 0.8265 - val_auc: 0.8436 - val_prc: 0.8294
# Epoch 2/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.4667 - tp: 119834.0000 - fp: 44973.0000 - tn: 99359.0000 - fn: 24263.0000 - accuracy: 0.7600 - precision: 0.7271 - recall: 0.8316 - auc: 0.8502 - prc: 0.8407 - val_loss: 0.4553 - val_tp: 27915.0000 - val_fp: 8837.0000 - val_tn: 27093.0000 - val_fn: 8263.0000 - val_accuracy: 0.7629 - val_precision: 0.7596 - val_recall: 0.7716 - val_auc: 0.8599 - val_prc: 0.8542
# Epoch 3/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.4431 - tp: 118086.0000 - fp: 39164.0000 - tn: 105168.0000 - fn: 26011.0000 - accuracy: 0.7740 - precision: 0.7509 - recall: 0.8195 - auc: 0.8680 - prc: 0.8626 - val_loss: 0.4281 - val_tp: 30677.0000 - val_fp: 10100.0000 - val_tn: 25830.0000 - val_fn: 5501.0000 - val_accuracy: 0.7836 - val_precision: 0.7523 - val_recall: 0.8479 - val_auc: 0.8787 - val_prc: 0.8750
# Epoch 4/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.4144 - tp: 119157.0000 - fp: 34376.0000 - tn: 109956.0000 - fn: 24940.0000 - accuracy: 0.7943 - precision: 0.7761 - recall: 0.8269 - auc: 0.8876 - prc: 0.8832 - val_loss: 0.4038 - val_tp: 29263.0000 - val_fp: 7341.0000 - val_tn: 28589.0000 - val_fn: 6915.0000 - val_accuracy: 0.8023 - val_precision: 0.7994 - val_recall: 0.8089 - val_auc: 0.8950 - val_prc: 0.8925
# Epoch 5/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3958 - tp: 118854.0000 - fp: 30820.0000 - tn: 113512.0000 - fn: 25243.0000 - accuracy: 0.8056 - precision: 0.7941 - recall: 0.8248 - auc: 0.8983 - prc: 0.8954 - val_loss: 0.3977 - val_tp: 32176.0000 - val_fp: 10119.0000 - val_tn: 25811.0000 - val_fn: 4002.0000 - val_accuracy: 0.8042 - val_precision: 0.7608 - val_recall: 0.8894 - val_auc: 0.9002 - val_prc: 0.8975
# Epoch 6/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3846 - tp: 119889.0000 - fp: 29829.0000 - tn: 114503.0000 - fn: 24208.0000 - accuracy: 0.8127 - precision: 0.8008 - recall: 0.8320 - auc: 0.9043 - prc: 0.9021 - val_loss: 0.3803 - val_tp: 31566.0000 - val_fp: 8767.0000 - val_tn: 27163.0000 - val_fn: 4612.0000 - val_accuracy: 0.8145 - val_precision: 0.7826 - val_recall: 0.8725 - val_auc: 0.9077 - val_prc: 0.9063
# Epoch 7/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3749 - tp: 120219.0000 - fp: 28555.0000 - tn: 115777.0000 - fn: 23878.0000 - accuracy: 0.8182 - precision: 0.8081 - recall: 0.8343 - auc: 0.9094 - prc: 0.9076 - val_loss: 0.3754 - val_tp: 32396.0000 - val_fp: 9927.0000 - val_tn: 26003.0000 - val_fn: 3782.0000 - val_accuracy: 0.8099 - val_precision: 0.7654 - val_recall: 0.8955 - val_auc: 0.9123 - val_prc: 0.9118
# Epoch 8/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3673 - tp: 120772.0000 - fp: 27900.0000 - tn: 116432.0000 - fn: 23325.0000 - accuracy: 0.8224 - precision: 0.8123 - recall: 0.8381 - auc: 0.9133 - prc: 0.9120 - val_loss: 0.3630 - val_tp: 30464.0000 - val_fp: 7093.0000 - val_tn: 28837.0000 - val_fn: 5714.0000 - val_accuracy: 0.8224 - val_precision: 0.8111 - val_recall: 0.8421 - val_auc: 0.9148 - val_prc: 0.9151
# Epoch 9/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3605 - tp: 120908.0000 - fp: 26702.0000 - tn: 117630.0000 - fn: 23189.0000 - accuracy: 0.8270 - precision: 0.8191 - recall: 0.8391 - auc: 0.9168 - prc: 0.9157 - val_loss: 0.3746 - val_tp: 33112.0000 - val_fp: 10453.0000 - val_tn: 25477.0000 - val_fn: 3066.0000 - val_accuracy: 0.8125 - val_precision: 0.7601 - val_recall: 0.9153 - val_auc: 0.9152 - val_prc: 0.9157
# Epoch 10/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.3585 - tp: 120875.0000 - fp: 26937.0000 - tn: 117395.0000 - fn: 23222.0000 - accuracy: 0.8261 - precision: 0.8178 - recall: 0.8388 - auc: 0.9174 - prc: 0.9165 - val_loss: 0.3533 - val_tp: 28892.0000 - val_fp: 5224.0000 - val_tn: 30706.0000 - val_fn: 7286.0000 - val_accuracy: 0.8265 - val_precision: 0.8469 - val_recall: 0.7986 - val_auc: 0.9211 - val_prc: 0.9216
# Epoch 11/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3498 - tp: 121774.0000 - fp: 25780.0000 - tn: 118552.0000 - fn: 22323.0000 - accuracy: 0.8332 - precision: 0.8253 - recall: 0.8451 - auc: 0.9220 - prc: 0.9212 - val_loss: 0.3468 - val_tp: 29814.0000 - val_fp: 5571.0000 - val_tn: 30359.0000 - val_fn: 6364.0000 - val_accuracy: 0.8345 - val_precision: 0.8426 - val_recall: 0.8241 - val_auc: 0.9240 - val_prc: 0.9233
# Epoch 12/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3475 - tp: 121764.0000 - fp: 25758.0000 - tn: 118574.0000 - fn: 22333.0000 - accuracy: 0.8333 - precision: 0.8254 - recall: 0.8450 - auc: 0.9228 - prc: 0.9220 - val_loss: 0.3601 - val_tp: 27421.0000 - val_fp: 3809.0000 - val_tn: 32121.0000 - val_fn: 8757.0000 - val_accuracy: 0.8257 - val_precision: 0.8780 - val_recall: 0.7579 - val_auc: 0.9236 - val_prc: 0.9241
# Epoch 13/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.3448 - tp: 122072.0000 - fp: 25594.0000 - tn: 118738.0000 - fn: 22025.0000 - accuracy: 0.8349 - precision: 0.8267 - recall: 0.8472 - auc: 0.9240 - prc: 0.9232 - val_loss: 0.3567 - val_tp: 26982.0000 - val_fp: 3531.0000 - val_tn: 32399.0000 - val_fn: 9196.0000 - val_accuracy: 0.8235 - val_precision: 0.8843 - val_recall: 0.7458 - val_auc: 0.9259 - val_prc: 0.9256
# Epoch 14/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.3408 - tp: 122081.0000 - fp: 25052.0000 - tn: 119280.0000 - fn: 22016.0000 - accuracy: 0.8368 - precision: 0.8297 - recall: 0.8472 - auc: 0.9258 - prc: 0.9254 - val_loss: 0.3412 - val_tp: 29241.0000 - val_fp: 4990.0000 - val_tn: 30940.0000 - val_fn: 6937.0000 - val_accuracy: 0.8346 - val_precision: 0.8542 - val_recall: 0.8083 - val_auc: 0.9266 - val_prc: 0.9265
# Epoch 15/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3376 - tp: 122517.0000 - fp: 24890.0000 - tn: 119442.0000 - fn: 21580.0000 - accuracy: 0.8389 - precision: 0.8311 - recall: 0.8502 - auc: 0.9274 - prc: 0.9267 - val_loss: 0.3396 - val_tp: 32588.0000 - val_fp: 8473.0000 - val_tn: 27457.0000 - val_fn: 3590.0000 - val_accuracy: 0.8327 - val_precision: 0.7936 - val_recall: 0.9008 - val_auc: 0.9291 - val_prc: 0.9299
# Epoch 16/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3345 - tp: 122933.0000 - fp: 24894.0000 - tn: 119438.0000 - fn: 21164.0000 - accuracy: 0.8403 - precision: 0.8316 - recall: 0.8531 - auc: 0.9288 - prc: 0.9282 - val_loss: 0.3312 - val_tp: 31125.0000 - val_fp: 6361.0000 - val_tn: 29569.0000 - val_fn: 5053.0000 - val_accuracy: 0.8417 - val_precision: 0.8303 - val_recall: 0.8603 - val_auc: 0.9304 - val_prc: 0.9302
# Epoch 17/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3325 - tp: 122968.0000 - fp: 24589.0000 - tn: 119743.0000 - fn: 21129.0000 - accuracy: 0.8415 - precision: 0.8334 - recall: 0.8534 - auc: 0.9296 - prc: 0.9291 - val_loss: 0.3319 - val_tp: 29102.0000 - val_fp: 4665.0000 - val_tn: 31265.0000 - val_fn: 7076.0000 - val_accuracy: 0.8372 - val_precision: 0.8618 - val_recall: 0.8044 - val_auc: 0.9316 - val_prc: 0.9319
# Epoch 18/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3328 - tp: 122770.0000 - fp: 24621.0000 - tn: 119711.0000 - fn: 21327.0000 - accuracy: 0.8407 - precision: 0.8330 - recall: 0.8520 - auc: 0.9293 - prc: 0.9288 - val_loss: 0.3356 - val_tp: 28544.0000 - val_fp: 4175.0000 - val_tn: 31755.0000 - val_fn: 7634.0000 - val_accuracy: 0.8362 - val_precision: 0.8724 - val_recall: 0.7890 - val_auc: 0.9316 - val_prc: 0.9318
# Epoch 19/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3281 - tp: 123411.0000 - fp: 24298.0000 - tn: 120034.0000 - fn: 20686.0000 - accuracy: 0.8440 - precision: 0.8355 - recall: 0.8564 - auc: 0.9315 - prc: 0.9310 - val_loss: 0.3435 - val_tp: 31612.0000 - val_fp: 7208.0000 - val_tn: 28722.0000 - val_fn: 4566.0000 - val_accuracy: 0.8367 - val_precision: 0.8143 - val_recall: 0.8738 - val_auc: 0.9258 - val_prc: 0.9251
# Epoch 20/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3293 - tp: 123307.0000 - fp: 24471.0000 - tn: 119861.0000 - fn: 20790.0000 - accuracy: 0.8431 - precision: 0.8344 - recall: 0.8557 - auc: 0.9309 - prc: 0.9303 - val_loss: 0.3204 - val_tp: 31489.0000 - val_fp: 6230.0000 - val_tn: 29700.0000 - val_fn: 4689.0000 - val_accuracy: 0.8486 - val_precision: 0.8348 - val_recall: 0.8704 - val_auc: 0.9354 - val_prc: 0.9358
# Epoch 21/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3234 - tp: 123950.0000 - fp: 23990.0000 - tn: 120342.0000 - fn: 20147.0000 - accuracy: 0.8470 - precision: 0.8378 - recall: 0.8602 - auc: 0.9337 - prc: 0.9333 - val_loss: 0.3263 - val_tp: 32433.0000 - val_fp: 7507.0000 - val_tn: 28423.0000 - val_fn: 3745.0000 - val_accuracy: 0.8440 - val_precision: 0.8120 - val_recall: 0.8965 - val_auc: 0.9340 - val_prc: 0.9342
# Epoch 22/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3220 - tp: 124067.0000 - fp: 23904.0000 - tn: 120428.0000 - fn: 20030.0000 - accuracy: 0.8477 - precision: 0.8385 - recall: 0.8610 - auc: 0.9342 - prc: 0.9337 - val_loss: 0.3232 - val_tp: 30537.0000 - val_fp: 5452.0000 - val_tn: 30478.0000 - val_fn: 5641.0000 - val_accuracy: 0.8462 - val_precision: 0.8485 - val_recall: 0.8441 - val_auc: 0.9340 - val_prc: 0.9338
# Epoch 23/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.3197 - tp: 123900.0000 - fp: 23479.0000 - tn: 120853.0000 - fn: 20197.0000 - accuracy: 0.8486 - precision: 0.8407 - recall: 0.8598 - auc: 0.9353 - prc: 0.9348 - val_loss: 0.3218 - val_tp: 30315.0000 - val_fp: 5165.0000 - val_tn: 30765.0000 - val_fn: 5863.0000 - val_accuracy: 0.8471 - val_precision: 0.8544 - val_recall: 0.8379 - val_auc: 0.9344 - val_prc: 0.9346
# Epoch 24/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.3212 - tp: 124010.0000 - fp: 23741.0000 - tn: 120591.0000 - fn: 20087.0000 - accuracy: 0.8480 - precision: 0.8393 - recall: 0.8606 - auc: 0.9345 - prc: 0.9341 - val_loss: 0.3183 - val_tp: 32130.0000 - val_fp: 6669.0000 - val_tn: 29261.0000 - val_fn: 4048.0000 - val_accuracy: 0.8514 - val_precision: 0.8281 - val_recall: 0.8881 - val_auc: 0.9366 - val_prc: 0.9364
# Epoch 25/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.3183 - tp: 124305.0000 - fp: 23411.0000 - tn: 120921.0000 - fn: 19792.0000 - accuracy: 0.8502 - precision: 0.8415 - recall: 0.8626 - auc: 0.9358 - prc: 0.9353 - val_loss: 0.3136 - val_tp: 31917.0000 - val_fp: 6385.0000 - val_tn: 29545.0000 - val_fn: 4261.0000 - val_accuracy: 0.8524 - val_precision: 0.8333 - val_recall: 0.8822 - val_auc: 0.9383 - val_prc: 0.9385
# Epoch 26/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3141 - tp: 124591.0000 - fp: 23037.0000 - tn: 121295.0000 - fn: 19506.0000 - accuracy: 0.8525 - precision: 0.8440 - recall: 0.8646 - auc: 0.9377 - prc: 0.9374 - val_loss: 0.3136 - val_tp: 30787.0000 - val_fp: 5210.0000 - val_tn: 30720.0000 - val_fn: 5391.0000 - val_accuracy: 0.8530 - val_precision: 0.8553 - val_recall: 0.8510 - val_auc: 0.9381 - val_prc: 0.9383
# Epoch 27/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3116 - tp: 125073.0000 - fp: 22692.0000 - tn: 121640.0000 - fn: 19024.0000 - accuracy: 0.8554 - precision: 0.8464 - recall: 0.8680 - auc: 0.9389 - prc: 0.9385 - val_loss: 0.3127 - val_tp: 32548.0000 - val_fp: 6805.0000 - val_tn: 29125.0000 - val_fn: 3630.0000 - val_accuracy: 0.8553 - val_precision: 0.8271 - val_recall: 0.8997 - val_auc: 0.9388 - val_prc: 0.9386
# Epoch 28/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3113 - tp: 125138.0000 - fp: 22783.0000 - tn: 121549.0000 - fn: 18959.0000 - accuracy: 0.8553 - precision: 0.8460 - recall: 0.8684 - auc: 0.9389 - prc: 0.9385 - val_loss: 0.3171 - val_tp: 29896.0000 - val_fp: 4686.0000 - val_tn: 31244.0000 - val_fn: 6282.0000 - val_accuracy: 0.8479 - val_precision: 0.8645 - val_recall: 0.8264 - val_auc: 0.9369 - val_prc: 0.9379
# Epoch 29/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3123 - tp: 124682.0000 - fp: 22732.0000 - tn: 121600.0000 - fn: 19415.0000 - accuracy: 0.8539 - precision: 0.8458 - recall: 0.8653 - auc: 0.9383 - prc: 0.9380 - val_loss: 0.3253 - val_tp: 28771.0000 - val_fp: 3908.0000 - val_tn: 32022.0000 - val_fn: 7407.0000 - val_accuracy: 0.8431 - val_precision: 0.8804 - val_recall: 0.7953 - val_auc: 0.9365 - val_prc: 0.9368
# Epoch 30/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3148 - tp: 124123.0000 - fp: 22966.0000 - tn: 121366.0000 - fn: 19974.0000 - accuracy: 0.8511 - precision: 0.8439 - recall: 0.8614 - auc: 0.9371 - prc: 0.9368 - val_loss: 0.3136 - val_tp: 29777.0000 - val_fp: 4332.0000 - val_tn: 31598.0000 - val_fn: 6401.0000 - val_accuracy: 0.8512 - val_precision: 0.8730 - val_recall: 0.8231 - val_auc: 0.9392 - val_prc: 0.9387
# Epoch 31/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3086 - tp: 125111.0000 - fp: 22320.0000 - tn: 122012.0000 - fn: 18986.0000 - accuracy: 0.8568 - precision: 0.8486 - recall: 0.8682 - auc: 0.9399 - prc: 0.9394 - val_loss: 0.3076 - val_tp: 31372.0000 - val_fp: 5653.0000 - val_tn: 30277.0000 - val_fn: 4806.0000 - val_accuracy: 0.8550 - val_precision: 0.8473 - val_recall: 0.8672 - val_auc: 0.9403 - val_prc: 0.9405
# Epoch 32/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3075 - tp: 125136.0000 - fp: 22453.0000 - tn: 121879.0000 - fn: 18961.0000 - accuracy: 0.8564 - precision: 0.8479 - recall: 0.8684 - auc: 0.9404 - prc: 0.9400 - val_loss: 0.3080 - val_tp: 32542.0000 - val_fp: 6724.0000 - val_tn: 29206.0000 - val_fn: 3636.0000 - val_accuracy: 0.8563 - val_precision: 0.8288 - val_recall: 0.8995 - val_auc: 0.9410 - val_prc: 0.9408
# Epoch 33/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.3055 - tp: 125328.0000 - fp: 22198.0000 - tn: 122134.0000 - fn: 18769.0000 - accuracy: 0.8580 - precision: 0.8495 - recall: 0.8697 - auc: 0.9411 - prc: 0.9408 - val_loss: 0.3198 - val_tp: 29818.0000 - val_fp: 4846.0000 - val_tn: 31084.0000 - val_fn: 6360.0000 - val_accuracy: 0.8446 - val_precision: 0.8602 - val_recall: 0.8242 - val_auc: 0.9356 - val_prc: 0.9367
# Epoch 34/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3061 - tp: 125092.0000 - fp: 22243.0000 - tn: 122089.0000 - fn: 19005.0000 - accuracy: 0.8570 - precision: 0.8490 - recall: 0.8681 - auc: 0.9408 - prc: 0.9405 - val_loss: 0.3061 - val_tp: 30737.0000 - val_fp: 4958.0000 - val_tn: 30972.0000 - val_fn: 5441.0000 - val_accuracy: 0.8558 - val_precision: 0.8611 - val_recall: 0.8496 - val_auc: 0.9411 - val_prc: 0.9416
# Epoch 35/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3031 - tp: 125566.0000 - fp: 22017.0000 - tn: 122315.0000 - fn: 18531.0000 - accuracy: 0.8594 - precision: 0.8508 - recall: 0.8714 - auc: 0.9421 - prc: 0.9418 - val_loss: 0.3074 - val_tp: 31868.0000 - val_fp: 5883.0000 - val_tn: 30047.0000 - val_fn: 4310.0000 - val_accuracy: 0.8586 - val_precision: 0.8442 - val_recall: 0.8809 - val_auc: 0.9406 - val_prc: 0.9406
# Epoch 36/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3019 - tp: 125745.0000 - fp: 21793.0000 - tn: 122539.0000 - fn: 18352.0000 - accuracy: 0.8608 - precision: 0.8523 - recall: 0.8726 - auc: 0.9427 - prc: 0.9423 - val_loss: 0.3131 - val_tp: 31126.0000 - val_fp: 5912.0000 - val_tn: 30018.0000 - val_fn: 5052.0000 - val_accuracy: 0.8480 - val_precision: 0.8404 - val_recall: 0.8604 - val_auc: 0.9374 - val_prc: 0.9384
# Epoch 37/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3035 - tp: 125386.0000 - fp: 22107.0000 - tn: 122225.0000 - fn: 18711.0000 - accuracy: 0.8585 - precision: 0.8501 - recall: 0.8701 - auc: 0.9419 - prc: 0.9416 - val_loss: 0.3008 - val_tp: 31268.0000 - val_fp: 5043.0000 - val_tn: 30887.0000 - val_fn: 4910.0000 - val_accuracy: 0.8620 - val_precision: 0.8611 - val_recall: 0.8643 - val_auc: 0.9430 - val_prc: 0.9429
# Epoch 38/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3010 - tp: 125512.0000 - fp: 21775.0000 - tn: 122557.0000 - fn: 18585.0000 - accuracy: 0.8601 - precision: 0.8522 - recall: 0.8710 - auc: 0.9429 - prc: 0.9425 - val_loss: 0.3016 - val_tp: 30302.0000 - val_fp: 4281.0000 - val_tn: 31649.0000 - val_fn: 5876.0000 - val_accuracy: 0.8591 - val_precision: 0.8762 - val_recall: 0.8376 - val_auc: 0.9436 - val_prc: 0.9434
# Epoch 39/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3010 - tp: 125752.0000 - fp: 21628.0000 - tn: 122704.0000 - fn: 18345.0000 - accuracy: 0.8614 - precision: 0.8533 - recall: 0.8727 - auc: 0.9430 - prc: 0.9427 - val_loss: 0.3126 - val_tp: 31515.0000 - val_fp: 5990.0000 - val_tn: 29940.0000 - val_fn: 4663.0000 - val_accuracy: 0.8523 - val_precision: 0.8403 - val_recall: 0.8711 - val_auc: 0.9378 - val_prc: 0.9380
# Epoch 40/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3021 - tp: 125394.0000 - fp: 21867.0000 - tn: 122465.0000 - fn: 18703.0000 - accuracy: 0.8593 - precision: 0.8515 - recall: 0.8702 - auc: 0.9423 - prc: 0.9420 - val_loss: 0.3004 - val_tp: 33254.0000 - val_fp: 7049.0000 - val_tn: 28881.0000 - val_fn: 2924.0000 - val_accuracy: 0.8617 - val_precision: 0.8251 - val_recall: 0.9192 - val_auc: 0.9452 - val_prc: 0.9453
# Epoch 41/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2991 - tp: 126024.0000 - fp: 21710.0000 - tn: 122622.0000 - fn: 18073.0000 - accuracy: 0.8621 - precision: 0.8530 - recall: 0.8746 - auc: 0.9437 - prc: 0.9435 - val_loss: 0.3016 - val_tp: 29415.0000 - val_fp: 3667.0000 - val_tn: 32263.0000 - val_fn: 6763.0000 - val_accuracy: 0.8554 - val_precision: 0.8892 - val_recall: 0.8131 - val_auc: 0.9451 - val_prc: 0.9452
# Epoch 42/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2979 - tp: 125693.0000 - fp: 21423.0000 - tn: 122909.0000 - fn: 18404.0000 - accuracy: 0.8619 - precision: 0.8544 - recall: 0.8723 - auc: 0.9441 - prc: 0.9438 - val_loss: 0.2936 - val_tp: 33148.0000 - val_fp: 6754.0000 - val_tn: 29176.0000 - val_fn: 3030.0000 - val_accuracy: 0.8643 - val_precision: 0.8307 - val_recall: 0.9162 - val_auc: 0.9473 - val_prc: 0.9474
# Epoch 43/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2954 - tp: 126107.0000 - fp: 21374.0000 - tn: 122958.0000 - fn: 17990.0000 - accuracy: 0.8635 - precision: 0.8551 - recall: 0.8752 - auc: 0.9452 - prc: 0.9451 - val_loss: 0.3010 - val_tp: 31939.0000 - val_fp: 5712.0000 - val_tn: 30218.0000 - val_fn: 4239.0000 - val_accuracy: 0.8620 - val_precision: 0.8483 - val_recall: 0.8828 - val_auc: 0.9428 - val_prc: 0.9423
# Epoch 44/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2950 - tp: 126175.0000 - fp: 21065.0000 - tn: 123267.0000 - fn: 17922.0000 - accuracy: 0.8648 - precision: 0.8569 - recall: 0.8756 - auc: 0.9453 - prc: 0.9452 - val_loss: 0.3085 - val_tp: 31778.0000 - val_fp: 6061.0000 - val_tn: 29869.0000 - val_fn: 4400.0000 - val_accuracy: 0.8549 - val_precision: 0.8398 - val_recall: 0.8784 - val_auc: 0.9393 - val_prc: 0.9387
# Epoch 45/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2959 - tp: 126021.0000 - fp: 21225.0000 - tn: 123107.0000 - fn: 18076.0000 - accuracy: 0.8637 - precision: 0.8559 - recall: 0.8746 - auc: 0.9450 - prc: 0.9446 - val_loss: 0.2971 - val_tp: 32097.0000 - val_fp: 5913.0000 - val_tn: 30017.0000 - val_fn: 4081.0000 - val_accuracy: 0.8614 - val_precision: 0.8444 - val_recall: 0.8872 - val_auc: 0.9442 - val_prc: 0.9441
# Epoch 46/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2967 - tp: 125761.0000 - fp: 21336.0000 - tn: 122996.0000 - fn: 18336.0000 - accuracy: 0.8625 - precision: 0.8550 - recall: 0.8728 - auc: 0.9445 - prc: 0.9443 - val_loss: 0.2950 - val_tp: 30577.0000 - val_fp: 4435.0000 - val_tn: 31495.0000 - val_fn: 5601.0000 - val_accuracy: 0.8608 - val_precision: 0.8733 - val_recall: 0.8452 - val_auc: 0.9456 - val_prc: 0.9457
# Epoch 47/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2935 - tp: 126147.0000 - fp: 20927.0000 - tn: 123405.0000 - fn: 17950.0000 - accuracy: 0.8652 - precision: 0.8577 - recall: 0.8754 - auc: 0.9459 - prc: 0.9457 - val_loss: 0.3026 - val_tp: 32466.0000 - val_fp: 6426.0000 - val_tn: 29504.0000 - val_fn: 3712.0000 - val_accuracy: 0.8594 - val_precision: 0.8348 - val_recall: 0.8974 - val_auc: 0.9436 - val_prc: 0.9443
# Epoch 48/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2923 - tp: 126315.0000 - fp: 20977.0000 - tn: 123355.0000 - fn: 17782.0000 - accuracy: 0.8656 - precision: 0.8576 - recall: 0.8766 - auc: 0.9463 - prc: 0.9462 - val_loss: 0.2956 - val_tp: 32108.0000 - val_fp: 5961.0000 - val_tn: 29969.0000 - val_fn: 4070.0000 - val_accuracy: 0.8609 - val_precision: 0.8434 - val_recall: 0.8875 - val_auc: 0.9450 - val_prc: 0.9455
# Epoch 49/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2912 - tp: 126518.0000 - fp: 20820.0000 - tn: 123512.0000 - fn: 17579.0000 - accuracy: 0.8669 - precision: 0.8587 - recall: 0.8780 - auc: 0.9468 - prc: 0.9465 - val_loss: 0.3193 - val_tp: 26872.0000 - val_fp: 2222.0000 - val_tn: 33708.0000 - val_fn: 9306.0000 - val_accuracy: 0.8401 - val_precision: 0.9236 - val_recall: 0.7428 - val_auc: 0.9474 - val_prc: 0.9477
# Epoch 50/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2946 - tp: 125456.0000 - fp: 20710.0000 - tn: 123622.0000 - fn: 18641.0000 - accuracy: 0.8636 - precision: 0.8583 - recall: 0.8706 - auc: 0.9453 - prc: 0.9452 - val_loss: 0.3132 - val_tp: 29895.0000 - val_fp: 4487.0000 - val_tn: 31443.0000 - val_fn: 6283.0000 - val_accuracy: 0.8506 - val_precision: 0.8695 - val_recall: 0.8263 - val_auc: 0.9398 - val_prc: 0.9402
# Epoch 51/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2923 - tp: 126228.0000 - fp: 20686.0000 - tn: 123646.0000 - fn: 17869.0000 - accuracy: 0.8663 - precision: 0.8592 - recall: 0.8760 - auc: 0.9463 - prc: 0.9460 - val_loss: 0.2889 - val_tp: 31545.0000 - val_fp: 5106.0000 - val_tn: 30824.0000 - val_fn: 4633.0000 - val_accuracy: 0.8649 - val_precision: 0.8607 - val_recall: 0.8719 - val_auc: 0.9474 - val_prc: 0.9479
# Epoch 52/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2886 - tp: 126806.0000 - fp: 20725.0000 - tn: 123607.0000 - fn: 17291.0000 - accuracy: 0.8682 - precision: 0.8595 - recall: 0.8800 - auc: 0.9478 - prc: 0.9476 - val_loss: 0.2962 - val_tp: 32607.0000 - val_fp: 6268.0000 - val_tn: 29662.0000 - val_fn: 3571.0000 - val_accuracy: 0.8636 - val_precision: 0.8388 - val_recall: 0.9013 - val_auc: 0.9448 - val_prc: 0.9448
# Epoch 53/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2884 - tp: 126886.0000 - fp: 20717.0000 - tn: 123615.0000 - fn: 17211.0000 - accuracy: 0.8685 - precision: 0.8596 - recall: 0.8806 - auc: 0.9479 - prc: 0.9477 - val_loss: 0.2844 - val_tp: 32589.0000 - val_fp: 5813.0000 - val_tn: 30117.0000 - val_fn: 3589.0000 - val_accuracy: 0.8696 - val_precision: 0.8486 - val_recall: 0.9008 - val_auc: 0.9496 - val_prc: 0.9497
# Epoch 54/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2857 - tp: 127021.0000 - fp: 20404.0000 - tn: 123928.0000 - fn: 17076.0000 - accuracy: 0.8701 - precision: 0.8616 - recall: 0.8815 - auc: 0.9489 - prc: 0.9488 - val_loss: 0.3062 - val_tp: 34135.0000 - val_fp: 8284.0000 - val_tn: 27646.0000 - val_fn: 2043.0000 - val_accuracy: 0.8568 - val_precision: 0.8047 - val_recall: 0.9435 - val_auc: 0.9487 - val_prc: 0.9491
# Epoch 55/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2901 - tp: 126455.0000 - fp: 20917.0000 - tn: 123415.0000 - fn: 17642.0000 - accuracy: 0.8663 - precision: 0.8581 - recall: 0.8776 - auc: 0.9470 - prc: 0.9468 - val_loss: 0.3119 - val_tp: 33903.0000 - val_fp: 8362.0000 - val_tn: 27568.0000 - val_fn: 2275.0000 - val_accuracy: 0.8525 - val_precision: 0.8022 - val_recall: 0.9371 - val_auc: 0.9453 - val_prc: 0.9454
# Epoch 56/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2879 - tp: 126808.0000 - fp: 20576.0000 - tn: 123756.0000 - fn: 17289.0000 - accuracy: 0.8687 - precision: 0.8604 - recall: 0.8800 - auc: 0.9480 - prc: 0.9478 - val_loss: 0.2852 - val_tp: 32465.0000 - val_fp: 5743.0000 - val_tn: 30187.0000 - val_fn: 3713.0000 - val_accuracy: 0.8689 - val_precision: 0.8497 - val_recall: 0.8974 - val_auc: 0.9493 - val_prc: 0.9493
# Epoch 57/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2843 - tp: 127178.0000 - fp: 20122.0000 - tn: 124210.0000 - fn: 16919.0000 - accuracy: 0.8716 - precision: 0.8634 - recall: 0.8826 - auc: 0.9496 - prc: 0.9494 - val_loss: 0.2904 - val_tp: 30303.0000 - val_fp: 3822.0000 - val_tn: 32108.0000 - val_fn: 5875.0000 - val_accuracy: 0.8655 - val_precision: 0.8880 - val_recall: 0.8376 - val_auc: 0.9489 - val_prc: 0.9491
# Epoch 58/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2836 - tp: 127388.0000 - fp: 20277.0000 - tn: 124055.0000 - fn: 16709.0000 - accuracy: 0.8718 - precision: 0.8627 - recall: 0.8840 - auc: 0.9497 - prc: 0.9496 - val_loss: 0.2818 - val_tp: 32640.0000 - val_fp: 5765.0000 - val_tn: 30165.0000 - val_fn: 3538.0000 - val_accuracy: 0.8710 - val_precision: 0.8499 - val_recall: 0.9022 - val_auc: 0.9507 - val_prc: 0.9510
# Epoch 59/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2851 - tp: 126863.0000 - fp: 20266.0000 - tn: 124066.0000 - fn: 17234.0000 - accuracy: 0.8700 - precision: 0.8623 - recall: 0.8804 - auc: 0.9490 - prc: 0.9489 - val_loss: 0.2830 - val_tp: 31721.0000 - val_fp: 4876.0000 - val_tn: 31054.0000 - val_fn: 4457.0000 - val_accuracy: 0.8706 - val_precision: 0.8668 - val_recall: 0.8768 - val_auc: 0.9498 - val_prc: 0.9502
# Epoch 60/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2837 - tp: 126866.0000 - fp: 19970.0000 - tn: 124362.0000 - fn: 17231.0000 - accuracy: 0.8710 - precision: 0.8640 - recall: 0.8804 - auc: 0.9496 - prc: 0.9494 - val_loss: 0.2808 - val_tp: 32255.0000 - val_fp: 5197.0000 - val_tn: 30733.0000 - val_fn: 3923.0000 - val_accuracy: 0.8735 - val_precision: 0.8612 - val_recall: 0.8916 - val_auc: 0.9508 - val_prc: 0.9511
# Epoch 61/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2812 - tp: 127404.0000 - fp: 19832.0000 - tn: 124500.0000 - fn: 16693.0000 - accuracy: 0.8734 - precision: 0.8653 - recall: 0.8842 - auc: 0.9507 - prc: 0.9504 - val_loss: 0.2968 - val_tp: 29425.0000 - val_fp: 3333.0000 - val_tn: 32597.0000 - val_fn: 6753.0000 - val_accuracy: 0.8601 - val_precision: 0.8983 - val_recall: 0.8133 - val_auc: 0.9482 - val_prc: 0.9480
# Epoch 62/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2815 - tp: 127216.0000 - fp: 19875.0000 - tn: 124457.0000 - fn: 16881.0000 - accuracy: 0.8726 - precision: 0.8649 - recall: 0.8828 - auc: 0.9504 - prc: 0.9502 - val_loss: 0.2918 - val_tp: 29251.0000 - val_fp: 3072.0000 - val_tn: 32858.0000 - val_fn: 6927.0000 - val_accuracy: 0.8613 - val_precision: 0.9050 - val_recall: 0.8085 - val_auc: 0.9506 - val_prc: 0.9506
# Epoch 63/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2830 - tp: 126876.0000 - fp: 19845.0000 - tn: 124487.0000 - fn: 17221.0000 - accuracy: 0.8715 - precision: 0.8647 - recall: 0.8805 - auc: 0.9498 - prc: 0.9497 - val_loss: 0.2870 - val_tp: 31242.0000 - val_fp: 4428.0000 - val_tn: 31502.0000 - val_fn: 4936.0000 - val_accuracy: 0.8701 - val_precision: 0.8759 - val_recall: 0.8636 - val_auc: 0.9489 - val_prc: 0.9485
# Epoch 64/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2812 - tp: 127205.0000 - fp: 19799.0000 - tn: 124533.0000 - fn: 16892.0000 - accuracy: 0.8728 - precision: 0.8653 - recall: 0.8828 - auc: 0.9505 - prc: 0.9503 - val_loss: 0.2996 - val_tp: 29085.0000 - val_fp: 2982.0000 - val_tn: 32948.0000 - val_fn: 7093.0000 - val_accuracy: 0.8603 - val_precision: 0.9070 - val_recall: 0.8039 - val_auc: 0.9492 - val_prc: 0.9499
# Epoch 65/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2796 - tp: 127143.0000 - fp: 19564.0000 - tn: 124768.0000 - fn: 16954.0000 - accuracy: 0.8734 - precision: 0.8666 - recall: 0.8823 - auc: 0.9511 - prc: 0.9510 - val_loss: 0.2850 - val_tp: 33712.0000 - val_fp: 6887.0000 - val_tn: 29043.0000 - val_fn: 2466.0000 - val_accuracy: 0.8703 - val_precision: 0.8304 - val_recall: 0.9318 - val_auc: 0.9519 - val_prc: 0.9519
# Epoch 66/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2792 - tp: 127550.0000 - fp: 19832.0000 - tn: 124500.0000 - fn: 16547.0000 - accuracy: 0.8739 - precision: 0.8654 - recall: 0.8852 - auc: 0.9512 - prc: 0.9510 - val_loss: 0.2897 - val_tp: 31069.0000 - val_fp: 4773.0000 - val_tn: 31157.0000 - val_fn: 5109.0000 - val_accuracy: 0.8630 - val_precision: 0.8668 - val_recall: 0.8588 - val_auc: 0.9468 - val_prc: 0.9470
# Epoch 67/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2770 - tp: 127426.0000 - fp: 19418.0000 - tn: 124914.0000 - fn: 16671.0000 - accuracy: 0.8749 - precision: 0.8678 - recall: 0.8843 - auc: 0.9521 - prc: 0.9518 - val_loss: 0.2855 - val_tp: 32948.0000 - val_fp: 6345.0000 - val_tn: 29585.0000 - val_fn: 3230.0000 - val_accuracy: 0.8672 - val_precision: 0.8385 - val_recall: 0.9107 - val_auc: 0.9493 - val_prc: 0.9495
# Epoch 68/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2773 - tp: 127469.0000 - fp: 19565.0000 - tn: 124767.0000 - fn: 16628.0000 - accuracy: 0.8745 - precision: 0.8669 - recall: 0.8846 - auc: 0.9519 - prc: 0.9517 - val_loss: 0.2946 - val_tp: 33932.0000 - val_fp: 7373.0000 - val_tn: 28557.0000 - val_fn: 2246.0000 - val_accuracy: 0.8666 - val_precision: 0.8215 - val_recall: 0.9379 - val_auc: 0.9509 - val_prc: 0.9507
# Epoch 69/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2819 - tp: 126980.0000 - fp: 19910.0000 - tn: 124422.0000 - fn: 17117.0000 - accuracy: 0.8716 - precision: 0.8645 - recall: 0.8812 - auc: 0.9501 - prc: 0.9497 - val_loss: 0.3033 - val_tp: 28873.0000 - val_fp: 3359.0000 - val_tn: 32571.0000 - val_fn: 7305.0000 - val_accuracy: 0.8521 - val_precision: 0.8958 - val_recall: 0.7981 - val_auc: 0.9463 - val_prc: 0.9470
# Epoch 70/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2778 - tp: 127460.0000 - fp: 19595.0000 - tn: 124737.0000 - fn: 16637.0000 - accuracy: 0.8744 - precision: 0.8668 - recall: 0.8845 - auc: 0.9517 - prc: 0.9514 - val_loss: 0.2971 - val_tp: 31200.0000 - val_fp: 5359.0000 - val_tn: 30571.0000 - val_fn: 4978.0000 - val_accuracy: 0.8566 - val_precision: 0.8534 - val_recall: 0.8624 - val_auc: 0.9438 - val_prc: 0.9442
# Epoch 71/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2784 - tp: 127188.0000 - fp: 19531.0000 - tn: 124801.0000 - fn: 16909.0000 - accuracy: 0.8737 - precision: 0.8669 - recall: 0.8827 - auc: 0.9514 - prc: 0.9512 - val_loss: 0.2927 - val_tp: 29775.0000 - val_fp: 3455.0000 - val_tn: 32475.0000 - val_fn: 6403.0000 - val_accuracy: 0.8633 - val_precision: 0.8960 - val_recall: 0.8230 - val_auc: 0.9490 - val_prc: 0.9491
# Epoch 72/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2841 - tp: 126310.0000 - fp: 19857.0000 - tn: 124475.0000 - fn: 17787.0000 - accuracy: 0.8695 - precision: 0.8641 - recall: 0.8766 - auc: 0.9492 - prc: 0.9490 - val_loss: 0.2773 - val_tp: 33457.0000 - val_fp: 6356.0000 - val_tn: 29574.0000 - val_fn: 2721.0000 - val_accuracy: 0.8741 - val_precision: 0.8404 - val_recall: 0.9248 - val_auc: 0.9536 - val_prc: 0.9537
# Epoch 73/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2734 - tp: 127919.0000 - fp: 19174.0000 - tn: 125158.0000 - fn: 16178.0000 - accuracy: 0.8774 - precision: 0.8696 - recall: 0.8877 - auc: 0.9534 - prc: 0.9531 - val_loss: 0.2891 - val_tp: 28587.0000 - val_fp: 2501.0000 - val_tn: 33429.0000 - val_fn: 7591.0000 - val_accuracy: 0.8600 - val_precision: 0.9196 - val_recall: 0.7902 - val_auc: 0.9537 - val_prc: 0.9537
# Epoch 74/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2787 - tp: 126816.0000 - fp: 19423.0000 - tn: 124909.0000 - fn: 17281.0000 - accuracy: 0.8727 - precision: 0.8672 - recall: 0.8801 - auc: 0.9512 - prc: 0.9509 - val_loss: 0.2925 - val_tp: 34311.0000 - val_fp: 7800.0000 - val_tn: 28130.0000 - val_fn: 1867.0000 - val_accuracy: 0.8659 - val_precision: 0.8148 - val_recall: 0.9484 - val_auc: 0.9532 - val_prc: 0.9531
# Epoch 75/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2752 - tp: 127581.0000 - fp: 19419.0000 - tn: 124913.0000 - fn: 16516.0000 - accuracy: 0.8754 - precision: 0.8679 - recall: 0.8854 - auc: 0.9526 - prc: 0.9523 - val_loss: 0.2749 - val_tp: 32540.0000 - val_fp: 5361.0000 - val_tn: 30569.0000 - val_fn: 3638.0000 - val_accuracy: 0.8752 - val_precision: 0.8586 - val_recall: 0.8994 - val_auc: 0.9530 - val_prc: 0.9529
# Epoch 76/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2736 - tp: 127596.0000 - fp: 19127.0000 - tn: 125205.0000 - fn: 16501.0000 - accuracy: 0.8765 - precision: 0.8696 - recall: 0.8855 - auc: 0.9532 - prc: 0.9528 - val_loss: 0.2713 - val_tp: 31822.0000 - val_fp: 4555.0000 - val_tn: 31375.0000 - val_fn: 4356.0000 - val_accuracy: 0.8764 - val_precision: 0.8748 - val_recall: 0.8796 - val_auc: 0.9541 - val_prc: 0.9543
# Epoch 77/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2706 - tp: 127937.0000 - fp: 18986.0000 - tn: 125346.0000 - fn: 16160.0000 - accuracy: 0.8781 - precision: 0.8708 - recall: 0.8879 - auc: 0.9543 - prc: 0.9540 - val_loss: 0.2845 - val_tp: 29773.0000 - val_fp: 3333.0000 - val_tn: 32597.0000 - val_fn: 6405.0000 - val_accuracy: 0.8650 - val_precision: 0.8993 - val_recall: 0.8230 - val_auc: 0.9515 - val_prc: 0.9516
# Epoch 78/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2744 - tp: 127151.0000 - fp: 19013.0000 - tn: 125319.0000 - fn: 16946.0000 - accuracy: 0.8753 - precision: 0.8699 - recall: 0.8824 - auc: 0.9528 - prc: 0.9524 - val_loss: 0.2939 - val_tp: 32111.0000 - val_fp: 5802.0000 - val_tn: 30128.0000 - val_fn: 4067.0000 - val_accuracy: 0.8631 - val_precision: 0.8470 - val_recall: 0.8876 - val_auc: 0.9460 - val_prc: 0.9462
# Epoch 79/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2726 - tp: 127493.0000 - fp: 18921.0000 - tn: 125411.0000 - fn: 16604.0000 - accuracy: 0.8768 - precision: 0.8708 - recall: 0.8848 - auc: 0.9536 - prc: 0.9532 - val_loss: 0.2791 - val_tp: 30649.0000 - val_fp: 3733.0000 - val_tn: 32197.0000 - val_fn: 5529.0000 - val_accuracy: 0.8716 - val_precision: 0.8914 - val_recall: 0.8472 - val_auc: 0.9522 - val_prc: 0.9517
# Epoch 80/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2696 - tp: 127944.0000 - fp: 18705.0000 - tn: 125627.0000 - fn: 16153.0000 - accuracy: 0.8791 - precision: 0.8725 - recall: 0.8879 - auc: 0.9547 - prc: 0.9543 - val_loss: 0.3017 - val_tp: 31711.0000 - val_fp: 5949.0000 - val_tn: 29981.0000 - val_fn: 4467.0000 - val_accuracy: 0.8555 - val_precision: 0.8420 - val_recall: 0.8765 - val_auc: 0.9425 - val_prc: 0.9420
# Epoch 81/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2728 - tp: 127490.0000 - fp: 19035.0000 - tn: 125297.0000 - fn: 16607.0000 - accuracy: 0.8764 - precision: 0.8701 - recall: 0.8848 - auc: 0.9534 - prc: 0.9528 - val_loss: 0.2813 - val_tp: 33376.0000 - val_fp: 6621.0000 - val_tn: 29309.0000 - val_fn: 2802.0000 - val_accuracy: 0.8693 - val_precision: 0.8345 - val_recall: 0.9225 - val_auc: 0.9525 - val_prc: 0.9526
# Epoch 82/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2700 - tp: 128014.0000 - fp: 18949.0000 - tn: 125383.0000 - fn: 16083.0000 - accuracy: 0.8785 - precision: 0.8711 - recall: 0.8884 - auc: 0.9545 - prc: 0.9541 - val_loss: 0.2800 - val_tp: 32633.0000 - val_fp: 5838.0000 - val_tn: 30092.0000 - val_fn: 3545.0000 - val_accuracy: 0.8699 - val_precision: 0.8482 - val_recall: 0.9020 - val_auc: 0.9513 - val_prc: 0.9517
# Epoch 83/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2695 - tp: 127955.0000 - fp: 18822.0000 - tn: 125510.0000 - fn: 16142.0000 - accuracy: 0.8788 - precision: 0.8718 - recall: 0.8880 - auc: 0.9547 - prc: 0.9542 - val_loss: 0.2722 - val_tp: 31882.0000 - val_fp: 4769.0000 - val_tn: 31161.0000 - val_fn: 4296.0000 - val_accuracy: 0.8743 - val_precision: 0.8699 - val_recall: 0.8813 - val_auc: 0.9532 - val_prc: 0.9532
# Epoch 84/500
# 49/49 [==============================] - 1s 14ms/step - loss: 0.2687 - tp: 127849.0000 - fp: 18811.0000 - tn: 125521.0000 - fn: 16248.0000 - accuracy: 0.8784 - precision: 0.8717 - recall: 0.8872 - auc: 0.9549 - prc: 0.9544 - val_loss: 0.2696 - val_tp: 32781.0000 - val_fp: 5436.0000 - val_tn: 30494.0000 - val_fn: 3397.0000 - val_accuracy: 0.8775 - val_precision: 0.8578 - val_recall: 0.9061 - val_auc: 0.9550 - val_prc: 0.9550
# Epoch 85/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2660 - tp: 128234.0000 - fp: 18647.0000 - tn: 125685.0000 - fn: 15863.0000 - accuracy: 0.8804 - precision: 0.8730 - recall: 0.8899 - auc: 0.9559 - prc: 0.9555 - val_loss: 0.2753 - val_tp: 30825.0000 - val_fp: 3876.0000 - val_tn: 32054.0000 - val_fn: 5353.0000 - val_accuracy: 0.8720 - val_precision: 0.8883 - val_recall: 0.8520 - val_auc: 0.9532 - val_prc: 0.9530
# Epoch 86/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2676 - tp: 128133.0000 - fp: 18644.0000 - tn: 125688.0000 - fn: 15964.0000 - accuracy: 0.8800 - precision: 0.8730 - recall: 0.8892 - auc: 0.9553 - prc: 0.9547 - val_loss: 0.2851 - val_tp: 33881.0000 - val_fp: 7148.0000 - val_tn: 28782.0000 - val_fn: 2297.0000 - val_accuracy: 0.8690 - val_precision: 0.8258 - val_recall: 0.9365 - val_auc: 0.9537 - val_prc: 0.9528
# Epoch 87/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2696 - tp: 127733.0000 - fp: 18891.0000 - tn: 125441.0000 - fn: 16364.0000 - accuracy: 0.8778 - precision: 0.8712 - recall: 0.8864 - auc: 0.9545 - prc: 0.9540 - val_loss: 0.2745 - val_tp: 32198.0000 - val_fp: 5196.0000 - val_tn: 30734.0000 - val_fn: 3980.0000 - val_accuracy: 0.8727 - val_precision: 0.8610 - val_recall: 0.8900 - val_auc: 0.9524 - val_prc: 0.9524
# Epoch 88/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2668 - tp: 128024.0000 - fp: 18831.0000 - tn: 125501.0000 - fn: 16073.0000 - accuracy: 0.8790 - precision: 0.8718 - recall: 0.8885 - auc: 0.9555 - prc: 0.9551 - val_loss: 0.2647 - val_tp: 31632.0000 - val_fp: 4122.0000 - val_tn: 31808.0000 - val_fn: 4546.0000 - val_accuracy: 0.8798 - val_precision: 0.8847 - val_recall: 0.8743 - val_auc: 0.9566 - val_prc: 0.9565
# Epoch 89/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2648 - tp: 128155.0000 - fp: 18544.0000 - tn: 125788.0000 - fn: 15942.0000 - accuracy: 0.8804 - precision: 0.8736 - recall: 0.8894 - auc: 0.9563 - prc: 0.9558 - val_loss: 0.2754 - val_tp: 29992.0000 - val_fp: 3092.0000 - val_tn: 32838.0000 - val_fn: 6186.0000 - val_accuracy: 0.8713 - val_precision: 0.9065 - val_recall: 0.8290 - val_auc: 0.9563 - val_prc: 0.9562
# Epoch 90/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2661 - tp: 128122.0000 - fp: 18556.0000 - tn: 125776.0000 - fn: 15975.0000 - accuracy: 0.8803 - precision: 0.8735 - recall: 0.8891 - auc: 0.9558 - prc: 0.9553 - val_loss: 0.2646 - val_tp: 31808.0000 - val_fp: 4119.0000 - val_tn: 31811.0000 - val_fn: 4370.0000 - val_accuracy: 0.8823 - val_precision: 0.8854 - val_recall: 0.8792 - val_auc: 0.9567 - val_prc: 0.9563
# Epoch 91/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2654 - tp: 128324.0000 - fp: 18626.0000 - tn: 125706.0000 - fn: 15773.0000 - accuracy: 0.8807 - precision: 0.8732 - recall: 0.8905 - auc: 0.9560 - prc: 0.9555 - val_loss: 0.2816 - val_tp: 29763.0000 - val_fp: 2881.0000 - val_tn: 33049.0000 - val_fn: 6415.0000 - val_accuracy: 0.8711 - val_precision: 0.9117 - val_recall: 0.8227 - val_auc: 0.9537 - val_prc: 0.9538
# Epoch 92/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2654 - tp: 128192.0000 - fp: 18327.0000 - tn: 126005.0000 - fn: 15905.0000 - accuracy: 0.8813 - precision: 0.8749 - recall: 0.8896 - auc: 0.9561 - prc: 0.9556 - val_loss: 0.3200 - val_tp: 33098.0000 - val_fp: 7783.0000 - val_tn: 28147.0000 - val_fn: 3080.0000 - val_accuracy: 0.8494 - val_precision: 0.8096 - val_recall: 0.9149 - val_auc: 0.9418 - val_prc: 0.9422
# Epoch 93/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2655 - tp: 128056.0000 - fp: 18571.0000 - tn: 125761.0000 - fn: 16041.0000 - accuracy: 0.8800 - precision: 0.8733 - recall: 0.8887 - auc: 0.9559 - prc: 0.9554 - val_loss: 0.3034 - val_tp: 34168.0000 - val_fp: 8346.0000 - val_tn: 27584.0000 - val_fn: 2010.0000 - val_accuracy: 0.8564 - val_precision: 0.8037 - val_recall: 0.9444 - val_auc: 0.9509 - val_prc: 0.9506
# Epoch 94/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2662 - tp: 128190.0000 - fp: 18706.0000 - tn: 125626.0000 - fn: 15907.0000 - accuracy: 0.8800 - precision: 0.8727 - recall: 0.8896 - auc: 0.9557 - prc: 0.9552 - val_loss: 0.2690 - val_tp: 30764.0000 - val_fp: 3578.0000 - val_tn: 32352.0000 - val_fn: 5414.0000 - val_accuracy: 0.8753 - val_precision: 0.8958 - val_recall: 0.8504 - val_auc: 0.9563 - val_prc: 0.9561
# Epoch 95/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2630 - tp: 128307.0000 - fp: 18232.0000 - tn: 126100.0000 - fn: 15790.0000 - accuracy: 0.8820 - precision: 0.8756 - recall: 0.8904 - auc: 0.9568 - prc: 0.9564 - val_loss: 0.2642 - val_tp: 31402.0000 - val_fp: 3751.0000 - val_tn: 32179.0000 - val_fn: 4776.0000 - val_accuracy: 0.8817 - val_precision: 0.8933 - val_recall: 0.8680 - val_auc: 0.9575 - val_prc: 0.9573
# Epoch 96/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2626 - tp: 128095.0000 - fp: 18174.0000 - tn: 126158.0000 - fn: 16002.0000 - accuracy: 0.8815 - precision: 0.8757 - recall: 0.8889 - auc: 0.9570 - prc: 0.9564 - val_loss: 0.2672 - val_tp: 33446.0000 - val_fp: 6134.0000 - val_tn: 29796.0000 - val_fn: 2732.0000 - val_accuracy: 0.8770 - val_precision: 0.8450 - val_recall: 0.9245 - val_auc: 0.9567 - val_prc: 0.9566
# Epoch 97/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2604 - tp: 128751.0000 - fp: 18214.0000 - tn: 126118.0000 - fn: 15346.0000 - accuracy: 0.8836 - precision: 0.8761 - recall: 0.8935 - auc: 0.9578 - prc: 0.9572 - val_loss: 0.3057 - val_tp: 28617.0000 - val_fp: 2943.0000 - val_tn: 32987.0000 - val_fn: 7561.0000 - val_accuracy: 0.8543 - val_precision: 0.9067 - val_recall: 0.7910 - val_auc: 0.9471 - val_prc: 0.9481
# Epoch 98/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2640 - tp: 128140.0000 - fp: 18388.0000 - tn: 125944.0000 - fn: 15957.0000 - accuracy: 0.8809 - precision: 0.8745 - recall: 0.8893 - auc: 0.9565 - prc: 0.9560 - val_loss: 0.2625 - val_tp: 32195.0000 - val_fp: 4501.0000 - val_tn: 31429.0000 - val_fn: 3983.0000 - val_accuracy: 0.8823 - val_precision: 0.8773 - val_recall: 0.8899 - val_auc: 0.9570 - val_prc: 0.9569
# Epoch 99/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2615 - tp: 128434.0000 - fp: 18243.0000 - tn: 126089.0000 - fn: 15663.0000 - accuracy: 0.8824 - precision: 0.8756 - recall: 0.8913 - auc: 0.9573 - prc: 0.9567 - val_loss: 0.2740 - val_tp: 34035.0000 - val_fp: 6671.0000 - val_tn: 29259.0000 - val_fn: 2143.0000 - val_accuracy: 0.8778 - val_precision: 0.8361 - val_recall: 0.9408 - val_auc: 0.9581 - val_prc: 0.9575
# Epoch 100/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2616 - tp: 128410.0000 - fp: 18310.0000 - tn: 126022.0000 - fn: 15687.0000 - accuracy: 0.8821 - precision: 0.8752 - recall: 0.8911 - auc: 0.9573 - prc: 0.9566 - val_loss: 0.2575 - val_tp: 32975.0000 - val_fp: 5007.0000 - val_tn: 30923.0000 - val_fn: 3203.0000 - val_accuracy: 0.8861 - val_precision: 0.8682 - val_recall: 0.9115 - val_auc: 0.9594 - val_prc: 0.9590
# Epoch 101/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2570 - tp: 129140.0000 - fp: 18053.0000 - tn: 126279.0000 - fn: 14957.0000 - accuracy: 0.8856 - precision: 0.8774 - recall: 0.8962 - auc: 0.9589 - prc: 0.9583 - val_loss: 0.2995 - val_tp: 27299.0000 - val_fp: 1687.0000 - val_tn: 34243.0000 - val_fn: 8879.0000 - val_accuracy: 0.8535 - val_precision: 0.9418 - val_recall: 0.7546 - val_auc: 0.9580 - val_prc: 0.9577
# Epoch 102/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2636 - tp: 127623.0000 - fp: 18097.0000 - tn: 126235.0000 - fn: 16474.0000 - accuracy: 0.8801 - precision: 0.8758 - recall: 0.8857 - auc: 0.9565 - prc: 0.9558 - val_loss: 0.2836 - val_tp: 30513.0000 - val_fp: 3891.0000 - val_tn: 32039.0000 - val_fn: 5665.0000 - val_accuracy: 0.8675 - val_precision: 0.8869 - val_recall: 0.8434 - val_auc: 0.9506 - val_prc: 0.9507
# Epoch 103/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2568 - tp: 128743.0000 - fp: 17823.0000 - tn: 126509.0000 - fn: 15354.0000 - accuracy: 0.8850 - precision: 0.8784 - recall: 0.8934 - auc: 0.9591 - prc: 0.9584 - val_loss: 0.2569 - val_tp: 33685.0000 - val_fp: 5859.0000 - val_tn: 30071.0000 - val_fn: 2493.0000 - val_accuracy: 0.8842 - val_precision: 0.8518 - val_recall: 0.9311 - val_auc: 0.9603 - val_prc: 0.9601
# Epoch 104/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2566 - tp: 128907.0000 - fp: 17904.0000 - tn: 126428.0000 - fn: 15190.0000 - accuracy: 0.8853 - precision: 0.8780 - recall: 0.8946 - auc: 0.9590 - prc: 0.9584 - val_loss: 0.2588 - val_tp: 31844.0000 - val_fp: 4098.0000 - val_tn: 31832.0000 - val_fn: 4334.0000 - val_accuracy: 0.8831 - val_precision: 0.8860 - val_recall: 0.8802 - val_auc: 0.9583 - val_prc: 0.9579
# Epoch 105/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2592 - tp: 128522.0000 - fp: 18053.0000 - tn: 126279.0000 - fn: 15575.0000 - accuracy: 0.8834 - precision: 0.8768 - recall: 0.8919 - auc: 0.9581 - prc: 0.9574 - val_loss: 0.2884 - val_tp: 34324.0000 - val_fp: 7825.0000 - val_tn: 28105.0000 - val_fn: 1854.0000 - val_accuracy: 0.8658 - val_precision: 0.8143 - val_recall: 0.9488 - val_auc: 0.9563 - val_prc: 0.9557
# Epoch 106/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2562 - tp: 128939.0000 - fp: 17964.0000 - tn: 126368.0000 - fn: 15158.0000 - accuracy: 0.8852 - precision: 0.8777 - recall: 0.8948 - auc: 0.9592 - prc: 0.9586 - val_loss: 0.2542 - val_tp: 32103.0000 - val_fp: 4148.0000 - val_tn: 31782.0000 - val_fn: 4075.0000 - val_accuracy: 0.8860 - val_precision: 0.8856 - val_recall: 0.8874 - val_auc: 0.9599 - val_prc: 0.9596
# Epoch 107/500
# 49/49 [==============================] - 1s 17ms/step - loss: 0.2555 - tp: 128764.0000 - fp: 17649.0000 - tn: 126683.0000 - fn: 15333.0000 - accuracy: 0.8856 - precision: 0.8795 - recall: 0.8936 - auc: 0.9593 - prc: 0.9587 - val_loss: 0.2622 - val_tp: 32516.0000 - val_fp: 4935.0000 - val_tn: 30995.0000 - val_fn: 3662.0000 - val_accuracy: 0.8808 - val_precision: 0.8682 - val_recall: 0.8988 - val_auc: 0.9569 - val_prc: 0.9565
# Epoch 108/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2554 - tp: 128786.0000 - fp: 17822.0000 - tn: 126510.0000 - fn: 15311.0000 - accuracy: 0.8851 - precision: 0.8784 - recall: 0.8937 - auc: 0.9594 - prc: 0.9587 - val_loss: 0.2567 - val_tp: 33006.0000 - val_fp: 4977.0000 - val_tn: 30953.0000 - val_fn: 3172.0000 - val_accuracy: 0.8870 - val_precision: 0.8690 - val_recall: 0.9123 - val_auc: 0.9591 - val_prc: 0.9585
# Epoch 109/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2547 - tp: 128925.0000 - fp: 17814.0000 - tn: 126518.0000 - fn: 15172.0000 - accuracy: 0.8856 - precision: 0.8786 - recall: 0.8947 - auc: 0.9596 - prc: 0.9589 - val_loss: 0.2553 - val_tp: 31934.0000 - val_fp: 3971.0000 - val_tn: 31959.0000 - val_fn: 4244.0000 - val_accuracy: 0.8861 - val_precision: 0.8894 - val_recall: 0.8827 - val_auc: 0.9596 - val_prc: 0.9590
# Epoch 110/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2534 - tp: 129185.0000 - fp: 17738.0000 - tn: 126594.0000 - fn: 14912.0000 - accuracy: 0.8868 - precision: 0.8793 - recall: 0.8965 - auc: 0.9601 - prc: 0.9595 - val_loss: 0.2657 - val_tp: 31854.0000 - val_fp: 4646.0000 - val_tn: 31284.0000 - val_fn: 4324.0000 - val_accuracy: 0.8756 - val_precision: 0.8727 - val_recall: 0.8805 - val_auc: 0.9554 - val_prc: 0.9554
# Epoch 111/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2568 - tp: 128662.0000 - fp: 17809.0000 - tn: 126523.0000 - fn: 15435.0000 - accuracy: 0.8847 - precision: 0.8784 - recall: 0.8929 - auc: 0.9589 - prc: 0.9581 - val_loss: 0.2685 - val_tp: 31277.0000 - val_fp: 4073.0000 - val_tn: 31857.0000 - val_fn: 4901.0000 - val_accuracy: 0.8755 - val_precision: 0.8848 - val_recall: 0.8645 - val_auc: 0.9549 - val_prc: 0.9551
# Epoch 112/500
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2542 - tp: 128872.0000 - fp: 17592.0000 - tn: 126740.0000 - fn: 15225.0000 - accuracy: 0.8862 - precision: 0.8799 - recall: 0.8943 - auc: 0.9598 - prc: 0.9591 - val_loss: 0.2544 - val_tp: 32420.0000 - val_fp: 4553.0000 - val_tn: 31377.0000 - val_fn: 3758.0000 - val_accuracy: 0.8847 - val_precision: 0.8769 - val_recall: 0.8961 - val_auc: 0.9596 - val_prc: 0.9595
# Epoch 113/500
# 49/49 [==============================] - 1s 15ms/step - loss: 0.2521 - tp: 129276.0000 - fp: 17457.0000 - tn: 126875.0000 - fn: 14821.0000 - accuracy: 0.8881 - precision: 0.8810 - recall: 0.8971 - auc: 0.9605 - prc: 0.9597 - val_loss: 0.2719 - val_tp: 34254.0000 - val_fp: 7041.0000 - val_tn: 28889.0000 - val_fn: 1924.0000 - val_accuracy: 0.8757 - val_precision: 0.8295 - val_recall: 0.9468 - val_auc: 0.9600 - val_prc: 0.9593
# Restoring model weights from the end of the best epoch.
# Epoch 00113: early stopping
# loss :  0.25731003284454346 /n
# tp :  42068.0 /n
# fp :  7370.0 /n
# tn :  37704.0 /n
# fn :  2993.0 /n
# accuracy :  0.8850280046463013 /n
# precision :  0.8509243726730347 /n
# recall :  0.9335789084434509 /n
# auc :  0.9604892134666443 /n
# prc :  0.9597814679145813 /n
# True Negatives:  37704
# False Positives:  7370
# False Negatives:  2993
# True Positives:  42068
# Total:  45061
# INFO:tensorflow:Assets written to: C:\Users\angel\AppData\Local\Temp\tmp1ljfqw29\model\data\model\assets

# %% [markdown]
# ## 5. Register Model

# %%
model_uri = "runs:/{}/{}".format(run.info.run_id, model_name)
mv = mlflow.register_model(model_uri, model_name)
print("Name: {}".format(mv.name))
print("Version: {}".format(mv.version))
# Out:
# Successfully registered model 'cut_start_posenet'.
# 2021/05/17 02:00:42 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: cut_start_posenet, version 1
# Name: cut_start_posenet
# Version: 1
# Created version '1' of model 'cut_start_posenet'.
