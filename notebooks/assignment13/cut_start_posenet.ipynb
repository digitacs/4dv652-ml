# %% [markdown]
# # Model to Classify Start positions in PoseNet dataset
#
# Section for configurations and imports.

# %%
import os 
import tempfile

import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from tensorflow import keras

# MLflow dashboard
import mlflow
mlflow.set_tracking_uri('http://35.228.45.76:5000')
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='../../keys/mlflow-312506-8cfad529f4fd.json'

# Import data augmentation
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from augmentation.methods import *

# %%
import warnings
warnings.simplefilter('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
random_state = 47
np.random.seed(random_state)

# %%
physical_devices = tf.config.experimental.list_physical_devices( 'GPU' )
print( 'Num GPUs Available: ', len( physical_devices ) )
if len( physical_devices ) > 0:
    tf.config.experimental.set_memory_growth( physical_devices[0], True )
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # 1. Data Preparation
# ## 1.1 Load Kinect files
#
# These files are marked start and stop frames in one-hot encoding. <br />
# We're only interested in the 'start' column.

# %%
data_path = '../../datasets/new_posenet_marked_start_end/'

df = None

# %%
for file in os.listdir(data_path):
    if file.endswith('.csv'):
        try:
            dataset = pd.read_csv(data_path + file)
            dataset.drop(columns=['end'], inplace=True)

            if df is None:
                df = dataset
            else:
                df = pd.concat((df, dataset), ignore_index=True)

        except IOError as e:
            print('Error in reading file: ', e)

print(df.shape)
# Out:
# (141945, 52)

# %% [markdown]
# ## 1.2 Data Augmentation
#
# ### Mirror X coordinate

# %%
df = mirror(df,'x', append=True)
print(df.shape)
# Out:
# (283890, 52)

# %% [markdown]
# ## 1.3 Check Class Imbalance
#
# This shows the small fraction of start frames.

# %%
X = df.drop(columns=['start'])
y = df['start']

# %%
print(
    'Total: {}\n\nStart: {} ({:.2f}% of total)\nNone: {} ({:.2f}% of total)\n'
    .format(
      len(y), 
      len(y.values[y.values == 1]),
      len(y.values[y.values == 1]) / len(y),
      len(y.values[y.values == 0]),
      len(y.values[y.values == 0]) / len(y)
    )
  )
# Out:
# Total: 283890
#
# Start: 58554 (0.21% of total)
# None: 225336 (0.79% of total)

# %% [markdown]
# ## 1.4 Oversample the minority class

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=random_state) # Perform oversamling using SMOTE
resampled_X, resampled_y = sm.fit_resample(X, y)

print(resampled_X.shape)
print(resampled_y.shape)
# Out:
# (450672, 51)
# (450672,)

# %%
print(
    'Total: {}\n\nStart: {} ({:.2f}% of total)\nNone: {} ({:.2f}% of total)\n'
    .format(
      len(resampled_y), 
      len(resampled_y.values[resampled_y.values == 1]),
      len(resampled_y.values[resampled_y.values == 1]) / len(resampled_y),
      len(resampled_y.values[resampled_y.values == 0]),
      len(resampled_y.values[resampled_y.values == 0]) / len(resampled_y)
    )
  )
# Out:
# Total: 450672
#
# Start: 225336 (0.50% of total)
# None: 225336 (0.50% of total)

# %% [markdown]
# ## 1.5 Split and normalize the data
#
# We already dropped the 'FrameNo' and 'start' columns when the data was loading. <br />
# Now, we'll split the dataset into train, validation, and test sets:
#
# - The validation set is used during model fitting to evaluate the loss and other evaluation metrics.
# - The test set is unused during the training phase and is used at the end to evaluate how well the model generalizes to new data (i.e. a holdout set). This is especially important with imbalanced datasets where overfitting is a significant concern from the lack of training data.
#
# We also normalize the input features using the sklearn StandardScaler. StandardScaler is only fit using X_train. As we want to deploy a model, it's critical that you preserve the preprocessing calculations. The easiest way to implement them as layers, and attach them to your model before export.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(resampled_X, resampled_y, test_size=0.2, random_state=random_state)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

print('Training labels shape:', y_train.shape)
print('Validation labels shape:', y_val.shape)
print('Test labels shape:', y_test.shape, '\n')

print('Training features shape:', X_train.shape)
print('Validation features shape:', X_val.shape)
print('Test features shape:', X_test.shape)
# Out:
# Training labels shape: (288429,)
# Validation labels shape: (72108,)
# Test labels shape: (90135,)
#
# Training features shape: (288429, 51)
# Validation features shape: (72108, 51)
# Test features shape: (90135, 51)

# %% [markdown]
# # 2. Define the Model and Metrics
#
# ## 2.1 Layer Factory

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Dropout, Flatten

def layerFactory(type, nodes, activation):
    if type == 'Dense':
        if not activation:
            return Dense(units=nodes)
        else:
            return Dense(units=nodes, activation=activation)
    if type == 'Conv1D':
        if not activation:
            return Conv1D(units=nodes)
        else:
            return Conv1D(units=nodes, activation=activation)
    if type == 'MaxPooling1D':
        if not activation:
            return MaxPooling1D(units=nodes)
        else:
            return MaxPooling1D(units=nodes, activation=activation)
    if type == 'Dropout':
        return Dropout(rate=nodes)
    if type == 'Flatten':
        if not activation:
            return Flatten(units=nodes)
        else:
            return Flatten(units=nodes, activation=activation)
    
    # otherwise return dense as default
    return Dense(units=nodes, activation=activation)

# %% [markdown]
# ## 2.2 Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer

def make_model(metrics, layers, optimizer, input_dim, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %% [markdown]
# # 3. Build the Model
#
# 3.1 Estimate the initial bias
# We're going to keep the initial model's weights in a checkpoint file and load them into each model before training so the model doesn't need to spend the first few epochs just learning that start frames are unlikely. Therefore, we start by estimating the initial bias before defining the model.

# %%
neg, pos = np.bincount(y)

initial_bias = np.log([pos/neg])
initial_bias
# Out:
# array([-1.34764322])

# %% [markdown]
# ## 3.2 Define the Model and Evaluation Metrics
#
# We're using standard evaluation metrics for binary classification problems.
#
# The **make_model** function returns a model based on parameter values. It uses the Layer Factory for creating the model.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(layers, input_dim, loss, optimizer, learning_rate=0.001, metrics=METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    model = Sequential([
        InputLayer(input_shape=(input_dim))
    ])

    for layer in layers:
        model.add(layerFactory(layer['type'], layer['nodes'], layer['activation']))

    optimizer = tf.keras.optimizers.get(optimizer)
    optimizer.learning_rate.assign(learning_rate)

    model.compile(
      optimizer=optimizer,
      loss=loss,
      metrics=metrics)

    print(model.summary())

    return model

# %%
output_bias = tf.keras.initializers.Constant(initial_bias)
input_dim = X_train.shape[1]
output_size = 1

units = 32
activation = 'tanh'
kernel_initializer = 'he_uniform'
output_activation = 'sigmoid'
optimizer = 'Adam'
learning_rate = 1e-3

LAYERS = [ 
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':units, 'activation': activation },
    { 'type': 'Dense', 'nodes':64, 'activation': 'relu' },
    { 'type': 'Dense', 'nodes':units, 'activation': activation, 'kernel_initializer': kernel_initializer },
    { 'type': 'Dense', 'nodes':output_size, 'activation': output_activation, 'bias_initializer': initial_bias }
]

model = make_model(layers=LAYERS, input_dim=input_dim, loss='binary_crossentropy', optimizer=optimizer, learning_rate=learning_rate, output_bias=output_bias)

model.predict(X_train[:10])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                1664
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 6,945
# Trainable params: 6,945
# Non-trainable params: 0
# _________________________________________________________________
# None
# array([[0.5164541 ],
#        [0.49004078],
#        [0.48585087],
#        [0.5524039 ],
#        [0.5365949 ],
#        [0.49930924],
#        [0.47598395],
#        [0.40988708],
#        [0.5047977 ],
#        [0.416915  ]], dtype=float32)

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.6877

# %%
initial_weights = os.path.join(tempfile.mkdtemp(), 'initial_weights')
model.save_weights(initial_weights)

# %% [markdown]
# ## 3.3 Add Class Weights

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

print('Weight for class 0:', class_weights[0])
print('Weight for class 1:', class_weights[1])
# Out:
# Weight for class 0: 0.9991859047196741
# Weight for class 1: 1.0008154229442667

# %% [markdown]
# # 4. MLflow Experimentation
# ## 4.1 Define learning parameters for all models

# %%
from keras.callbacks import EarlyStopping

EPOCHS = 500
BATCH_SIZE = 3050

early_stopping = EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %% [markdown]
# ## 4.2 Define Experimentation Configurations
# The Model signature in MLflow defines the schema of a model's inputs and outputs.

# %%
from mlflow.models.signature import ModelSignature
from mlflow.types.schema import Schema, ColSpec

input_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "leftShoulder_x"),
    ColSpec("double", "leftShoulder_y"),
    ColSpec("double", "leftElbow_x"),
    ColSpec("double", "leftElbow_y"),
    ColSpec("double", "rightShoulder_x"),
    ColSpec("double", "rightShoulder_y"),
    ColSpec("double", "rightElbow_x"),
    ColSpec("double", "rightElbow_y"),
    ColSpec("double", "leftHand_x"),
    ColSpec("double", "leftHand_y"),
    ColSpec("double", "rightHand_x"),
    ColSpec("double", "rightHand_y"),
    ColSpec("double", "leftHip_x"),
    ColSpec("double", "leftHip_y"),
    ColSpec("double", "rightHip_x"),
    ColSpec("double", "rightHip_y"),
    ColSpec("double", "leftKnee_x"),
    ColSpec("double", "leftKnee_y"),
    ColSpec("double", "rightKnee_x"),
    ColSpec("double", "rightKnee_y"),
    ColSpec("double", "leftFoot_x"),
    ColSpec("double", "leftFoot_y"),
    ColSpec("double", "rightFoot_x"),
    ColSpec("double", "rightFoot_y"),
])
output_schema = Schema([
    ColSpec("double", "head_x"),
    ColSpec("double", "head_y"),
    ColSpec("double", "leftShoulder_x"),
    ColSpec("double", "leftShoulder_y"),
    ColSpec("double", "leftElbow_x"),
    ColSpec("double", "leftElbow_y"),
    ColSpec("double", "rightShoulder_x"),
    ColSpec("double", "rightShoulder_y"),
    ColSpec("double", "rightElbow_x"),
    ColSpec("double", "rightElbow_y"),
    ColSpec("double", "leftHand_x"),
    ColSpec("double", "leftHand_y"),
    ColSpec("double", "rightHand_x"),
    ColSpec("double", "rightHand_y"),
    ColSpec("double", "leftHip_x"),
    ColSpec("double", "leftHip_y"),
    ColSpec("double", "rightHip_x"),
    ColSpec("double", "rightHip_y"),
    ColSpec("double", "leftKnee_x"),
    ColSpec("double", "leftKnee_y"),
    ColSpec("double", "rightKnee_x"),
    ColSpec("double", "rightKnee_y"),
    ColSpec("double", "leftFoot_x"),
    ColSpec("double", "leftFoot_y"),
    ColSpec("double", "rightFoot_x"),
    ColSpec("double", "rightFoot_y"),
])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# %% [markdown]
# ## 4.3 Functions used in the experimentation
#
# For creating plots and others.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

def plot_loss(history, label, n):
  plt.semilogy(history.epoch, history.history['loss'],
               color=colors[n], label='Train ' + label)
  plt.semilogy(history.epoch, history.history['val_loss'],
               color=colors[n], label='Val ' + label,
               linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    print('True Negatives: ', cm[0][0])
    print('False Positives: ', cm[0][1])
    print('False Negatives: ', cm[1][0])
    print('True Positives: ', cm[1][1])
    print('Total: ', np.sum(cm[1]))


def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

def plot_prc(name, labels, predictions, **kwargs):
    precision, recall, _ = precision_recall_curve(labels, predictions)

    plt.plot(precision, recall, label=name, linewidth=2, **kwargs)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %% [markdown]
# ## 4.4 Start run
# Starting a run which fits the model according to chosen parameter values, then makes predictions and saves selected values to MLflow dashboard.

# %%
model_name = 'cut_start_posenet'

with mlflow.start_run(run_name=model_name) as run:

    run_id = run.info.run_id

    model = make_model(metrics=METRICS, 
                        layers=LAYERS, 
                        loss='binary_crossentropy', 
                        optimizer=optimizer, 
                        learning_rate=learning_rate, 
                        output_bias=initial_bias, 
                        input_dim=input_dim)
    model.load_weights(initial_weights)
    model.layers[-1].bias.assign([0.0])
    
    with tf.device('/CPU:0'):
        history = model.fit(
            x=X_train, 
            y=y_train, 
            class_weight=class_weight_dict, 
            validation_data=(X_val, y_val), 
            shuffle=True, 
            epochs=EPOCHS, 
            verbose=1,
            batch_size=BATCH_SIZE, 
            callbacks=[early_stopping])

        # Plot training history
        plot_loss(history, "Bias", 0)
        plt.savefig("loss.jpg")
        mlflow.log_artifact("loss.jpg")
        plt.show()
        
        # Plot and log metrics
        predictions_train = model.predict(X_train)
        predictions_test = model.predict(X_test)

        plot_metrics(history)
        plt.savefig("metrics.jpg")
        mlflow.log_artifact("metrics.jpg")
        plt.show()

        # Confusion matrix
        results = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE, verbose=0)
        for name, value in zip(model.metrics_names, results):
            print(name, ': ', value, '/n')
        plot_cm(y_test, predictions_test)
        plt.savefig("cm.jpg")
        mlflow.log_artifact("cm.jpg")
        plt.show()

        # ROC Curve
        plot_roc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("roc.jpg")
        mlflow.log_artifact("roc.jpg")
        plt.show()

        # Precision-Recall Curve (PRC)
        plot_prc("Train Predictions", y_train, predictions_train, color=colors[0])
        plot_prc("Test Predictions", y_test, predictions_test, color=colors[0], linestyle='--')
        plt.legend(loc='lower right')
        plt.savefig("prc.jpg")
        mlflow.log_artifact("prc.jpg")
        plt.show()
        
        # Log model, scaler, model parameters to MLflow
        mlflow.log_param("units", units)
        mlflow.log_param("activation", activation)
        mlflow.log_param("kernel_initializer", kernel_initializer)
        mlflow.log_param("output activation", output_activation)
        mlflow.log_param("optimizer", optimizer)
        mlflow.log_param("learning rate", learning_rate)
        mlflow.log_param("batch size", BATCH_SIZE)
        mlflow.log_metric("accuracy", results[5])
        mlflow.log_metric("average precision score", results[6])
        mlflow.log_metric("recall", results[7])
        mlflow.log_metric("auc", results[8])

        mlflow.keras.log_model(model, model_name, signature=signature)
        mlflow.sklearn.log_model(scaler, 'InputScaler')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 32)                1664
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 6,945
# Trainable params: 6,945
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\angel\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/500
# 95/95 [==============================] - 3s 17ms/step - loss: 0.4768 - tp: 186433.0000 - fp: 94690.0000 - tn: 193974.0000 - fn: 101761.0000 - accuracy: 0.6594 - precision: 0.6632 - recall: 0.6469 - auc: 0.7364 - prc: 0.7362 - val_loss: 0.4172 - val_tp: 30432.0000 - val_fp: 8937.0000 - val_tn: 26993.0000 - val_fn: 5746.0000 - val_accuracy: 0.7964 - val_precision: 0.7730 - val_recall: 0.8412 - val_auc: 0.8864 - val_prc: 0.8736
# Epoch 2/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.3919 - tp: 122611.0000 - fp: 32971.0000 - tn: 111361.0000 - fn: 21486.0000 - accuracy: 0.8112 - precision: 0.7881 - recall: 0.8509 - auc: 0.9022 - prc: 0.8954 - val_loss: 0.3676 - val_tp: 30534.0000 - val_fp: 6702.0000 - val_tn: 29228.0000 - val_fn: 5644.0000 - val_accuracy: 0.8288 - val_precision: 0.8200 - val_recall: 0.8440 - val_auc: 0.9152 - val_prc: 0.9101
# Epoch 3/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.3478 - tp: 124456.0000 - fp: 26769.0000 - tn: 117563.0000 - fn: 19641.0000 - accuracy: 0.8391 - precision: 0.8230 - recall: 0.8637 - auc: 0.9247 - prc: 0.9216 - val_loss: 0.3313 - val_tp: 31129.0000 - val_fp: 5884.0000 - val_tn: 30046.0000 - val_fn: 5049.0000 - val_accuracy: 0.8484 - val_precision: 0.8410 - val_recall: 0.8604 - val_auc: 0.9321 - val_prc: 0.9303
# Epoch 4/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.3129 - tp: 126707.0000 - fp: 23267.0000 - tn: 121065.0000 - fn: 17390.0000 - accuracy: 0.8590 - precision: 0.8449 - recall: 0.8793 - auc: 0.9398 - prc: 0.9383 - val_loss: 0.2984 - val_tp: 32074.0000 - val_fp: 5530.0000 - val_tn: 30400.0000 - val_fn: 4104.0000 - val_accuracy: 0.8664 - val_precision: 0.8529 - val_recall: 0.8866 - val_auc: 0.9451 - val_prc: 0.9437
# Epoch 5/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.2849 - tp: 128537.0000 - fp: 20605.0000 - tn: 123727.0000 - fn: 15560.0000 - accuracy: 0.8746 - precision: 0.8618 - recall: 0.8920 - auc: 0.9503 - prc: 0.9488 - val_loss: 0.2771 - val_tp: 31130.0000 - val_fp: 3842.0000 - val_tn: 32088.0000 - val_fn: 5048.0000 - val_accuracy: 0.8767 - val_precision: 0.8901 - val_recall: 0.8605 - val_auc: 0.9539 - val_prc: 0.9526
# Epoch 6/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.2634 - tp: 129926.0000 - fp: 18621.0000 - tn: 125711.0000 - fn: 14171.0000 - accuracy: 0.8863 - precision: 0.8746 - recall: 0.9017 - auc: 0.9578 - prc: 0.9562 - val_loss: 0.2564 - val_tp: 32813.0000 - val_fp: 4665.0000 - val_tn: 31265.0000 - val_fn: 3365.0000 - val_accuracy: 0.8886 - val_precision: 0.8755 - val_recall: 0.9070 - val_auc: 0.9602 - val_prc: 0.9589
# Epoch 7/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.2447 - tp: 131356.0000 - fp: 16877.0000 - tn: 127455.0000 - fn: 12741.0000 - accuracy: 0.8973 - precision: 0.8861 - recall: 0.9116 - auc: 0.9637 - prc: 0.9621 - val_loss: 0.2385 - val_tp: 33357.0000 - val_fp: 4432.0000 - val_tn: 31498.0000 - val_fn: 2821.0000 - val_accuracy: 0.8994 - val_precision: 0.8827 - val_recall: 0.9220 - val_auc: 0.9656 - val_prc: 0.9641
# Epoch 8/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.2311 - tp: 132090.0000 - fp: 15853.0000 - tn: 128479.0000 - fn: 12007.0000 - accuracy: 0.9034 - precision: 0.8928 - recall: 0.9167 - auc: 0.9675 - prc: 0.9660 - val_loss: 0.2286 - val_tp: 32040.0000 - val_fp: 3011.0000 - val_tn: 32919.0000 - val_fn: 4138.0000 - val_accuracy: 0.9009 - val_precision: 0.9141 - val_recall: 0.8856 - val_auc: 0.9694 - val_prc: 0.9683
# Epoch 9/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.2184 - tp: 133024.0000 - fp: 14871.0000 - tn: 129461.0000 - fn: 11073.0000 - accuracy: 0.9101 - precision: 0.8994 - recall: 0.9232 - auc: 0.9709 - prc: 0.9694 - val_loss: 0.2174 - val_tp: 34021.0000 - val_fp: 4323.0000 - val_tn: 31607.0000 - val_fn: 2157.0000 - val_accuracy: 0.9101 - val_precision: 0.8873 - val_recall: 0.9404 - val_auc: 0.9715 - val_prc: 0.9701
# Epoch 10/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.2058 - tp: 133873.0000 - fp: 13983.0000 - tn: 130349.0000 - fn: 10224.0000 - accuracy: 0.9161 - precision: 0.9054 - recall: 0.9290 - auc: 0.9742 - prc: 0.9728 - val_loss: 0.2033 - val_tp: 33974.0000 - val_fp: 3950.0000 - val_tn: 31980.0000 - val_fn: 2204.0000 - val_accuracy: 0.9147 - val_precision: 0.8958 - val_recall: 0.9391 - val_auc: 0.9748 - val_prc: 0.9733
# Epoch 11/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1973 - tp: 134287.0000 - fp: 13434.0000 - tn: 130898.0000 - fn: 9810.0000 - accuracy: 0.9194 - precision: 0.9091 - recall: 0.9319 - auc: 0.9761 - prc: 0.9748 - val_loss: 0.2015 - val_tp: 34242.0000 - val_fp: 4172.0000 - val_tn: 31758.0000 - val_fn: 1936.0000 - val_accuracy: 0.9153 - val_precision: 0.8914 - val_recall: 0.9465 - val_auc: 0.9757 - val_prc: 0.9744
# Epoch 12/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1900 - tp: 134765.0000 - fp: 12961.0000 - tn: 131371.0000 - fn: 9332.0000 - accuracy: 0.9227 - precision: 0.9123 - recall: 0.9352 - auc: 0.9778 - prc: 0.9763 - val_loss: 0.1929 - val_tp: 33909.0000 - val_fp: 3533.0000 - val_tn: 32397.0000 - val_fn: 2269.0000 - val_accuracy: 0.9195 - val_precision: 0.9056 - val_recall: 0.9373 - val_auc: 0.9772 - val_prc: 0.9758
# Epoch 13/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1817 - tp: 135301.0000 - fp: 12437.0000 - tn: 131895.0000 - fn: 8796.0000 - accuracy: 0.9264 - precision: 0.9158 - recall: 0.9390 - auc: 0.9797 - prc: 0.9783 - val_loss: 0.1818 - val_tp: 33551.0000 - val_fp: 2858.0000 - val_tn: 33072.0000 - val_fn: 2627.0000 - val_accuracy: 0.9239 - val_precision: 0.9215 - val_recall: 0.9274 - val_auc: 0.9796 - val_prc: 0.9780
# Epoch 14/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1757 - tp: 135614.0000 - fp: 11984.0000 - tn: 132348.0000 - fn: 8483.0000 - accuracy: 0.9290 - precision: 0.9188 - recall: 0.9411 - auc: 0.9809 - prc: 0.9794 - val_loss: 0.1757 - val_tp: 33766.0000 - val_fp: 2751.0000 - val_tn: 33179.0000 - val_fn: 2412.0000 - val_accuracy: 0.9284 - val_precision: 0.9247 - val_recall: 0.9333 - val_auc: 0.9810 - val_prc: 0.9797
# Epoch 15/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1702 - tp: 136013.0000 - fp: 11464.0000 - tn: 132868.0000 - fn: 8084.0000 - accuracy: 0.9322 - precision: 0.9223 - recall: 0.9439 - auc: 0.9820 - prc: 0.9805 - val_loss: 0.1684 - val_tp: 34588.0000 - val_fp: 3230.0000 - val_tn: 32700.0000 - val_fn: 1590.0000 - val_accuracy: 0.9332 - val_precision: 0.9146 - val_recall: 0.9561 - val_auc: 0.9825 - val_prc: 0.9809
# Epoch 16/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1650 - tp: 136363.0000 - fp: 11239.0000 - tn: 133093.0000 - fn: 7734.0000 - accuracy: 0.9342 - precision: 0.9239 - recall: 0.9463 - auc: 0.9830 - prc: 0.9815 - val_loss: 0.1673 - val_tp: 33902.0000 - val_fp: 2532.0000 - val_tn: 33398.0000 - val_fn: 2276.0000 - val_accuracy: 0.9333 - val_precision: 0.9305 - val_recall: 0.9371 - val_auc: 0.9827 - val_prc: 0.9811
# Epoch 17/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1611 - tp: 136613.0000 - fp: 10778.0000 - tn: 133554.0000 - fn: 7484.0000 - accuracy: 0.9367 - precision: 0.9269 - recall: 0.9481 - auc: 0.9836 - prc: 0.9821 - val_loss: 0.1599 - val_tp: 34548.0000 - val_fp: 2929.0000 - val_tn: 33001.0000 - val_fn: 1630.0000 - val_accuracy: 0.9368 - val_precision: 0.9218 - val_recall: 0.9549 - val_auc: 0.9840 - val_prc: 0.9822
# Epoch 18/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1557 - tp: 137035.0000 - fp: 10451.0000 - tn: 133881.0000 - fn: 7062.0000 - accuracy: 0.9393 - precision: 0.9291 - recall: 0.9510 - auc: 0.9847 - prc: 0.9832 - val_loss: 0.1608 - val_tp: 34823.0000 - val_fp: 3291.0000 - val_tn: 32639.0000 - val_fn: 1355.0000 - val_accuracy: 0.9356 - val_precision: 0.9137 - val_recall: 0.9625 - val_auc: 0.9842 - val_prc: 0.9823
# Epoch 19/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1523 - tp: 137210.0000 - fp: 10361.0000 - tn: 133971.0000 - fn: 6887.0000 - accuracy: 0.9402 - precision: 0.9298 - recall: 0.9522 - auc: 0.9853 - prc: 0.9838 - val_loss: 0.1517 - val_tp: 34352.0000 - val_fp: 2510.0000 - val_tn: 33420.0000 - val_fn: 1826.0000 - val_accuracy: 0.9399 - val_precision: 0.9319 - val_recall: 0.9495 - val_auc: 0.9855 - val_prc: 0.9840
# Epoch 20/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1491 - tp: 137487.0000 - fp: 10111.0000 - tn: 134221.0000 - fn: 6610.0000 - accuracy: 0.9420 - precision: 0.9315 - recall: 0.9541 - auc: 0.9858 - prc: 0.9843 - val_loss: 0.1492 - val_tp: 34344.0000 - val_fp: 2411.0000 - val_tn: 33519.0000 - val_fn: 1834.0000 - val_accuracy: 0.9411 - val_precision: 0.9344 - val_recall: 0.9493 - val_auc: 0.9860 - val_prc: 0.9842
# Epoch 21/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1455 - tp: 137783.0000 - fp: 9811.0000 - tn: 134521.0000 - fn: 6314.0000 - accuracy: 0.9441 - precision: 0.9335 - recall: 0.9562 - auc: 0.9865 - prc: 0.9850 - val_loss: 0.1446 - val_tp: 34492.0000 - val_fp: 2396.0000 - val_tn: 33534.0000 - val_fn: 1686.0000 - val_accuracy: 0.9434 - val_precision: 0.9350 - val_recall: 0.9534 - val_auc: 0.9866 - val_prc: 0.9851
# Epoch 22/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1419 - tp: 137998.0000 - fp: 9650.0000 - tn: 134682.0000 - fn: 6099.0000 - accuracy: 0.9454 - precision: 0.9346 - recall: 0.9577 - auc: 0.9871 - prc: 0.9857 - val_loss: 0.1446 - val_tp: 34733.0000 - val_fp: 2618.0000 - val_tn: 33312.0000 - val_fn: 1445.0000 - val_accuracy: 0.9437 - val_precision: 0.9299 - val_recall: 0.9601 - val_auc: 0.9867 - val_prc: 0.9849
# Epoch 23/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1396 - tp: 138100.0000 - fp: 9555.0000 - tn: 134777.0000 - fn: 5997.0000 - accuracy: 0.9461 - precision: 0.9353 - recall: 0.9584 - auc: 0.9874 - prc: 0.9860 - val_loss: 0.1407 - val_tp: 34593.0000 - val_fp: 2464.0000 - val_tn: 33466.0000 - val_fn: 1585.0000 - val_accuracy: 0.9438 - val_precision: 0.9335 - val_recall: 0.9562 - val_auc: 0.9871 - val_prc: 0.9855
# Epoch 24/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1364 - tp: 138282.0000 - fp: 9220.0000 - tn: 135112.0000 - fn: 5815.0000 - accuracy: 0.9479 - precision: 0.9375 - recall: 0.9596 - auc: 0.9879 - prc: 0.9866 - val_loss: 0.1394 - val_tp: 34886.0000 - val_fp: 2613.0000 - val_tn: 33317.0000 - val_fn: 1292.0000 - val_accuracy: 0.9458 - val_precision: 0.9303 - val_recall: 0.9643 - val_auc: 0.9876 - val_prc: 0.9860
# Epoch 25/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1350 - tp: 138254.0000 - fp: 9156.0000 - tn: 135176.0000 - fn: 5843.0000 - accuracy: 0.9480 - precision: 0.9379 - recall: 0.9595 - auc: 0.9881 - prc: 0.9868 - val_loss: 0.1401 - val_tp: 34469.0000 - val_fp: 2175.0000 - val_tn: 33755.0000 - val_fn: 1709.0000 - val_accuracy: 0.9461 - val_precision: 0.9406 - val_recall: 0.9528 - val_auc: 0.9875 - val_prc: 0.9859
# Epoch 26/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1310 - tp: 138512.0000 - fp: 8874.0000 - tn: 135458.0000 - fn: 5585.0000 - accuracy: 0.9499 - precision: 0.9398 - recall: 0.9612 - auc: 0.9888 - prc: 0.9875 - val_loss: 0.1360 - val_tp: 35202.0000 - val_fp: 2687.0000 - val_tn: 33243.0000 - val_fn: 976.0000 - val_accuracy: 0.9492 - val_precision: 0.9291 - val_recall: 0.9730 - val_auc: 0.9882 - val_prc: 0.9866
# Epoch 27/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1273 - tp: 138915.0000 - fp: 8733.0000 - tn: 135599.0000 - fn: 5182.0000 - accuracy: 0.9518 - precision: 0.9409 - recall: 0.9640 - auc: 0.9894 - prc: 0.9881 - val_loss: 0.1330 - val_tp: 35053.0000 - val_fp: 2554.0000 - val_tn: 33376.0000 - val_fn: 1125.0000 - val_accuracy: 0.9490 - val_precision: 0.9321 - val_recall: 0.9689 - val_auc: 0.9884 - val_prc: 0.9868
# Epoch 28/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1269 - tp: 138835.0000 - fp: 8597.0000 - tn: 135735.0000 - fn: 5262.0000 - accuracy: 0.9520 - precision: 0.9417 - recall: 0.9635 - auc: 0.9893 - prc: 0.9880 - val_loss: 0.1324 - val_tp: 35030.0000 - val_fp: 2529.0000 - val_tn: 33401.0000 - val_fn: 1148.0000 - val_accuracy: 0.9490 - val_precision: 0.9327 - val_recall: 0.9683 - val_auc: 0.9887 - val_prc: 0.9873
# Epoch 29/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1253 - tp: 138921.0000 - fp: 8587.0000 - tn: 135745.0000 - fn: 5176.0000 - accuracy: 0.9523 - precision: 0.9418 - recall: 0.9641 - auc: 0.9896 - prc: 0.9884 - val_loss: 0.1306 - val_tp: 34818.0000 - val_fp: 2284.0000 - val_tn: 33646.0000 - val_fn: 1360.0000 - val_accuracy: 0.9495 - val_precision: 0.9384 - val_recall: 0.9624 - val_auc: 0.9888 - val_prc: 0.9875
# Epoch 30/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1225 - tp: 139146.0000 - fp: 8360.0000 - tn: 135972.0000 - fn: 4951.0000 - accuracy: 0.9538 - precision: 0.9433 - recall: 0.9656 - auc: 0.9900 - prc: 0.9888 - val_loss: 0.1300 - val_tp: 35132.0000 - val_fp: 2549.0000 - val_tn: 33381.0000 - val_fn: 1046.0000 - val_accuracy: 0.9501 - val_precision: 0.9324 - val_recall: 0.9711 - val_auc: 0.9889 - val_prc: 0.9877
# Epoch 31/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1205 - tp: 139184.0000 - fp: 8303.0000 - tn: 136029.0000 - fn: 4913.0000 - accuracy: 0.9542 - precision: 0.9437 - recall: 0.9659 - auc: 0.9903 - prc: 0.9892 - val_loss: 0.1234 - val_tp: 34886.0000 - val_fp: 2074.0000 - val_tn: 33856.0000 - val_fn: 1292.0000 - val_accuracy: 0.9533 - val_precision: 0.9439 - val_recall: 0.9643 - val_auc: 0.9900 - val_prc: 0.9888
# Epoch 32/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1188 - tp: 139329.0000 - fp: 8167.0000 - tn: 136165.0000 - fn: 4768.0000 - accuracy: 0.9552 - precision: 0.9446 - recall: 0.9669 - auc: 0.9906 - prc: 0.9895 - val_loss: 0.1206 - val_tp: 34734.0000 - val_fp: 1894.0000 - val_tn: 34036.0000 - val_fn: 1444.0000 - val_accuracy: 0.9537 - val_precision: 0.9483 - val_recall: 0.9601 - val_auc: 0.9904 - val_prc: 0.9891
# Epoch 33/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1170 - tp: 139355.0000 - fp: 7883.0000 - tn: 136449.0000 - fn: 4742.0000 - accuracy: 0.9562 - precision: 0.9465 - recall: 0.9671 - auc: 0.9908 - prc: 0.9897 - val_loss: 0.1216 - val_tp: 35228.0000 - val_fp: 2357.0000 - val_tn: 33573.0000 - val_fn: 950.0000 - val_accuracy: 0.9541 - val_precision: 0.9373 - val_recall: 0.9737 - val_auc: 0.9903 - val_prc: 0.9889
# Epoch 34/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1158 - tp: 139469.0000 - fp: 7848.0000 - tn: 136484.0000 - fn: 4628.0000 - accuracy: 0.9567 - precision: 0.9467 - recall: 0.9679 - auc: 0.9910 - prc: 0.9900 - val_loss: 0.1237 - val_tp: 34097.0000 - val_fp: 1514.0000 - val_tn: 34416.0000 - val_fn: 2081.0000 - val_accuracy: 0.9501 - val_precision: 0.9575 - val_recall: 0.9425 - val_auc: 0.9903 - val_prc: 0.9894
# Epoch 35/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.1143 - tp: 139499.0000 - fp: 7881.0000 - tn: 136451.0000 - fn: 4598.0000 - accuracy: 0.9567 - precision: 0.9465 - recall: 0.9681 - auc: 0.9912 - prc: 0.9901 - val_loss: 0.1207 - val_tp: 34308.0000 - val_fp: 1655.0000 - val_tn: 34275.0000 - val_fn: 1870.0000 - val_accuracy: 0.9511 - val_precision: 0.9540 - val_recall: 0.9483 - val_auc: 0.9904 - val_prc: 0.9894
# Epoch 36/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1122 - tp: 139634.0000 - fp: 7688.0000 - tn: 136644.0000 - fn: 4463.0000 - accuracy: 0.9579 - precision: 0.9478 - recall: 0.9690 - auc: 0.9915 - prc: 0.9905 - val_loss: 0.1173 - val_tp: 34700.0000 - val_fp: 1779.0000 - val_tn: 34151.0000 - val_fn: 1478.0000 - val_accuracy: 0.9548 - val_precision: 0.9512 - val_recall: 0.9591 - val_auc: 0.9910 - val_prc: 0.9899
# Epoch 37/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1103 - tp: 139720.0000 - fp: 7601.0000 - tn: 136731.0000 - fn: 4377.0000 - accuracy: 0.9585 - precision: 0.9484 - recall: 0.9696 - auc: 0.9917 - prc: 0.9907 - val_loss: 0.1162 - val_tp: 35168.0000 - val_fp: 2181.0000 - val_tn: 33749.0000 - val_fn: 1010.0000 - val_accuracy: 0.9557 - val_precision: 0.9416 - val_recall: 0.9721 - val_auc: 0.9907 - val_prc: 0.9892
# Epoch 38/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1093 - tp: 139782.0000 - fp: 7467.0000 - tn: 136865.0000 - fn: 4315.0000 - accuracy: 0.9592 - precision: 0.9493 - recall: 0.9701 - auc: 0.9919 - prc: 0.9909 - val_loss: 0.1129 - val_tp: 35193.0000 - val_fp: 2012.0000 - val_tn: 33918.0000 - val_fn: 985.0000 - val_accuracy: 0.9584 - val_precision: 0.9459 - val_recall: 0.9728 - val_auc: 0.9912 - val_prc: 0.9898
# Epoch 39/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.1081 - tp: 139854.0000 - fp: 7366.0000 - tn: 136966.0000 - fn: 4243.0000 - accuracy: 0.9598 - precision: 0.9500 - recall: 0.9706 - auc: 0.9920 - prc: 0.9911 - val_loss: 0.1124 - val_tp: 34925.0000 - val_fp: 1833.0000 - val_tn: 34097.0000 - val_fn: 1253.0000 - val_accuracy: 0.9572 - val_precision: 0.9501 - val_recall: 0.9654 - val_auc: 0.9912 - val_prc: 0.9901
# Epoch 40/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1067 - tp: 139924.0000 - fp: 7262.0000 - tn: 137070.0000 - fn: 4173.0000 - accuracy: 0.9604 - precision: 0.9507 - recall: 0.9710 - auc: 0.9921 - prc: 0.9911 - val_loss: 0.1102 - val_tp: 34662.0000 - val_fp: 1547.0000 - val_tn: 34383.0000 - val_fn: 1516.0000 - val_accuracy: 0.9575 - val_precision: 0.9573 - val_recall: 0.9581 - val_auc: 0.9919 - val_prc: 0.9911
# Epoch 41/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1045 - tp: 140030.0000 - fp: 7133.0000 - tn: 137199.0000 - fn: 4067.0000 - accuracy: 0.9612 - precision: 0.9515 - recall: 0.9718 - auc: 0.9924 - prc: 0.9914 - val_loss: 0.1088 - val_tp: 35292.0000 - val_fp: 2034.0000 - val_tn: 33896.0000 - val_fn: 886.0000 - val_accuracy: 0.9595 - val_precision: 0.9455 - val_recall: 0.9755 - val_auc: 0.9920 - val_prc: 0.9909
# Epoch 42/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.1043 - tp: 140089.0000 - fp: 7151.0000 - tn: 137181.0000 - fn: 4008.0000 - accuracy: 0.9613 - precision: 0.9514 - recall: 0.9722 - auc: 0.9925 - prc: 0.9915 - val_loss: 0.1075 - val_tp: 34822.0000 - val_fp: 1517.0000 - val_tn: 34413.0000 - val_fn: 1356.0000 - val_accuracy: 0.9602 - val_precision: 0.9583 - val_recall: 0.9625 - val_auc: 0.9922 - val_prc: 0.9912
# Epoch 43/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1044 - tp: 139926.0000 - fp: 7074.0000 - tn: 137258.0000 - fn: 4171.0000 - accuracy: 0.9610 - precision: 0.9519 - recall: 0.9711 - auc: 0.9924 - prc: 0.9914 - val_loss: 0.1064 - val_tp: 35572.0000 - val_fp: 2161.0000 - val_tn: 33769.0000 - val_fn: 606.0000 - val_accuracy: 0.9616 - val_precision: 0.9427 - val_recall: 0.9832 - val_auc: 0.9923 - val_prc: 0.9913
# Epoch 44/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1022 - tp: 140109.0000 - fp: 6971.0000 - tn: 137361.0000 - fn: 3988.0000 - accuracy: 0.9620 - precision: 0.9526 - recall: 0.9723 - auc: 0.9927 - prc: 0.9918 - val_loss: 0.1060 - val_tp: 35485.0000 - val_fp: 2122.0000 - val_tn: 33808.0000 - val_fn: 693.0000 - val_accuracy: 0.9610 - val_precision: 0.9436 - val_recall: 0.9808 - val_auc: 0.9923 - val_prc: 0.9910
# Epoch 45/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1007 - tp: 140215.0000 - fp: 6819.0000 - tn: 137513.0000 - fn: 3882.0000 - accuracy: 0.9629 - precision: 0.9536 - recall: 0.9731 - auc: 0.9929 - prc: 0.9920 - val_loss: 0.1048 - val_tp: 34828.0000 - val_fp: 1603.0000 - val_tn: 34327.0000 - val_fn: 1350.0000 - val_accuracy: 0.9590 - val_precision: 0.9560 - val_recall: 0.9627 - val_auc: 0.9925 - val_prc: 0.9916
# Epoch 46/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.1002 - tp: 140166.0000 - fp: 6807.0000 - tn: 137525.0000 - fn: 3931.0000 - accuracy: 0.9628 - precision: 0.9537 - recall: 0.9727 - auc: 0.9930 - prc: 0.9920 - val_loss: 0.1045 - val_tp: 35713.0000 - val_fp: 2289.0000 - val_tn: 33641.0000 - val_fn: 465.0000 - val_accuracy: 0.9618 - val_precision: 0.9398 - val_recall: 0.9871 - val_auc: 0.9931 - val_prc: 0.9920
# Epoch 47/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0988 - tp: 140351.0000 - fp: 6769.0000 - tn: 137563.0000 - fn: 3746.0000 - accuracy: 0.9635 - precision: 0.9540 - recall: 0.9740 - auc: 0.9931 - prc: 0.9922 - val_loss: 0.1010 - val_tp: 35301.0000 - val_fp: 1825.0000 - val_tn: 34105.0000 - val_fn: 877.0000 - val_accuracy: 0.9625 - val_precision: 0.9508 - val_recall: 0.9758 - val_auc: 0.9929 - val_prc: 0.9920
# Epoch 48/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0967 - tp: 140479.0000 - fp: 6615.0000 - tn: 137717.0000 - fn: 3618.0000 - accuracy: 0.9645 - precision: 0.9550 - recall: 0.9749 - auc: 0.9934 - prc: 0.9925 - val_loss: 0.0973 - val_tp: 35408.0000 - val_fp: 1739.0000 - val_tn: 34191.0000 - val_fn: 770.0000 - val_accuracy: 0.9652 - val_precision: 0.9532 - val_recall: 0.9787 - val_auc: 0.9934 - val_prc: 0.9925
# Epoch 49/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0955 - tp: 140582.0000 - fp: 6540.0000 - tn: 137792.0000 - fn: 3515.0000 - accuracy: 0.9651 - precision: 0.9555 - recall: 0.9756 - auc: 0.9936 - prc: 0.9927 - val_loss: 0.1025 - val_tp: 35026.0000 - val_fp: 1645.0000 - val_tn: 34285.0000 - val_fn: 1152.0000 - val_accuracy: 0.9612 - val_precision: 0.9551 - val_recall: 0.9682 - val_auc: 0.9927 - val_prc: 0.9917
# Epoch 50/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0959 - tp: 140400.0000 - fp: 6549.0000 - tn: 137783.0000 - fn: 3697.0000 - accuracy: 0.9645 - precision: 0.9554 - recall: 0.9743 - auc: 0.9935 - prc: 0.9927 - val_loss: 0.1025 - val_tp: 35752.0000 - val_fp: 2301.0000 - val_tn: 33629.0000 - val_fn: 426.0000 - val_accuracy: 0.9622 - val_precision: 0.9395 - val_recall: 0.9882 - val_auc: 0.9932 - val_prc: 0.9921
# Epoch 51/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0943 - tp: 140595.0000 - fp: 6492.0000 - tn: 137840.0000 - fn: 3502.0000 - accuracy: 0.9654 - precision: 0.9559 - recall: 0.9757 - auc: 0.9937 - prc: 0.9928 - val_loss: 0.0954 - val_tp: 35356.0000 - val_fp: 1697.0000 - val_tn: 34233.0000 - val_fn: 822.0000 - val_accuracy: 0.9651 - val_precision: 0.9542 - val_recall: 0.9773 - val_auc: 0.9936 - val_prc: 0.9928
# Epoch 52/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0934 - tp: 140609.0000 - fp: 6383.0000 - tn: 137949.0000 - fn: 3488.0000 - accuracy: 0.9658 - precision: 0.9566 - recall: 0.9758 - auc: 0.9938 - prc: 0.9929 - val_loss: 0.0974 - val_tp: 35146.0000 - val_fp: 1582.0000 - val_tn: 34348.0000 - val_fn: 1032.0000 - val_accuracy: 0.9637 - val_precision: 0.9569 - val_recall: 0.9715 - val_auc: 0.9932 - val_prc: 0.9924
# Epoch 53/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0927 - tp: 140587.0000 - fp: 6274.0000 - tn: 138058.0000 - fn: 3510.0000 - accuracy: 0.9661 - precision: 0.9573 - recall: 0.9756 - auc: 0.9938 - prc: 0.9929 - val_loss: 0.0998 - val_tp: 34603.0000 - val_fp: 1202.0000 - val_tn: 34728.0000 - val_fn: 1575.0000 - val_accuracy: 0.9615 - val_precision: 0.9664 - val_recall: 0.9565 - val_auc: 0.9934 - val_prc: 0.9925
# Epoch 54/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0909 - tp: 140789.0000 - fp: 6148.0000 - tn: 138184.0000 - fn: 3308.0000 - accuracy: 0.9672 - precision: 0.9582 - recall: 0.9770 - auc: 0.9941 - prc: 0.9932 - val_loss: 0.0924 - val_tp: 35408.0000 - val_fp: 1637.0000 - val_tn: 34293.0000 - val_fn: 770.0000 - val_accuracy: 0.9666 - val_precision: 0.9558 - val_recall: 0.9787 - val_auc: 0.9938 - val_prc: 0.9930
# Epoch 55/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0906 - tp: 140754.0000 - fp: 6133.0000 - tn: 138199.0000 - fn: 3343.0000 - accuracy: 0.9671 - precision: 0.9582 - recall: 0.9768 - auc: 0.9941 - prc: 0.9932 - val_loss: 0.0967 - val_tp: 35555.0000 - val_fp: 1884.0000 - val_tn: 34046.0000 - val_fn: 623.0000 - val_accuracy: 0.9652 - val_precision: 0.9497 - val_recall: 0.9828 - val_auc: 0.9933 - val_prc: 0.9921
# Epoch 56/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0890 - tp: 140891.0000 - fp: 6056.0000 - tn: 138276.0000 - fn: 3206.0000 - accuracy: 0.9679 - precision: 0.9588 - recall: 0.9778 - auc: 0.9942 - prc: 0.9934 - val_loss: 0.0999 - val_tp: 35373.0000 - val_fp: 1891.0000 - val_tn: 34039.0000 - val_fn: 805.0000 - val_accuracy: 0.9626 - val_precision: 0.9493 - val_recall: 0.9777 - val_auc: 0.9931 - val_prc: 0.9922
# Epoch 57/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0888 - tp: 140925.0000 - fp: 6059.0000 - tn: 138273.0000 - fn: 3172.0000 - accuracy: 0.9680 - precision: 0.9588 - recall: 0.9780 - auc: 0.9943 - prc: 0.9934 - val_loss: 0.0904 - val_tp: 35347.0000 - val_fp: 1521.0000 - val_tn: 34409.0000 - val_fn: 831.0000 - val_accuracy: 0.9674 - val_precision: 0.9587 - val_recall: 0.9770 - val_auc: 0.9942 - val_prc: 0.9933
# Epoch 58/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0880 - tp: 140931.0000 - fp: 5966.0000 - tn: 138366.0000 - fn: 3166.0000 - accuracy: 0.9683 - precision: 0.9594 - recall: 0.9780 - auc: 0.9944 - prc: 0.9935 - val_loss: 0.0928 - val_tp: 35392.0000 - val_fp: 1670.0000 - val_tn: 34260.0000 - val_fn: 786.0000 - val_accuracy: 0.9659 - val_precision: 0.9549 - val_recall: 0.9783 - val_auc: 0.9939 - val_prc: 0.9932
# Epoch 59/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0887 - tp: 140810.0000 - fp: 6063.0000 - tn: 138269.0000 - fn: 3287.0000 - accuracy: 0.9676 - precision: 0.9587 - recall: 0.9772 - auc: 0.9943 - prc: 0.9934 - val_loss: 0.0976 - val_tp: 35258.0000 - val_fp: 1753.0000 - val_tn: 34177.0000 - val_fn: 920.0000 - val_accuracy: 0.9629 - val_precision: 0.9526 - val_recall: 0.9746 - val_auc: 0.9932 - val_prc: 0.9920
# Epoch 60/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0870 - tp: 140938.0000 - fp: 5875.0000 - tn: 138457.0000 - fn: 3159.0000 - accuracy: 0.9687 - precision: 0.9600 - recall: 0.9781 - auc: 0.9945 - prc: 0.9937 - val_loss: 0.0964 - val_tp: 35530.0000 - val_fp: 1877.0000 - val_tn: 34053.0000 - val_fn: 648.0000 - val_accuracy: 0.9650 - val_precision: 0.9498 - val_recall: 0.9821 - val_auc: 0.9934 - val_prc: 0.9922
# Epoch 61/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0865 - tp: 140981.0000 - fp: 5809.0000 - tn: 138523.0000 - fn: 3116.0000 - accuracy: 0.9691 - precision: 0.9604 - recall: 0.9784 - auc: 0.9945 - prc: 0.9936 - val_loss: 0.0910 - val_tp: 35589.0000 - val_fp: 1781.0000 - val_tn: 34149.0000 - val_fn: 589.0000 - val_accuracy: 0.9671 - val_precision: 0.9523 - val_recall: 0.9837 - val_auc: 0.9940 - val_prc: 0.9932
# Epoch 62/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0867 - tp: 140844.0000 - fp: 5789.0000 - tn: 138543.0000 - fn: 3253.0000 - accuracy: 0.9687 - precision: 0.9605 - recall: 0.9774 - auc: 0.9945 - prc: 0.9937 - val_loss: 0.0894 - val_tp: 35465.0000 - val_fp: 1619.0000 - val_tn: 34311.0000 - val_fn: 713.0000 - val_accuracy: 0.9677 - val_precision: 0.9563 - val_recall: 0.9803 - val_auc: 0.9943 - val_prc: 0.9935
# Epoch 63/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0846 - tp: 141161.0000 - fp: 5722.0000 - tn: 138610.0000 - fn: 2936.0000 - accuracy: 0.9700 - precision: 0.9610 - recall: 0.9796 - auc: 0.9947 - prc: 0.9939 - val_loss: 0.0878 - val_tp: 35438.0000 - val_fp: 1552.0000 - val_tn: 34378.0000 - val_fn: 740.0000 - val_accuracy: 0.9682 - val_precision: 0.9580 - val_recall: 0.9795 - val_auc: 0.9945 - val_prc: 0.9938
# Epoch 64/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0833 - tp: 141188.0000 - fp: 5636.0000 - tn: 138696.0000 - fn: 2909.0000 - accuracy: 0.9704 - precision: 0.9616 - recall: 0.9798 - auc: 0.9949 - prc: 0.9940 - val_loss: 0.0938 - val_tp: 35255.0000 - val_fp: 1625.0000 - val_tn: 34305.0000 - val_fn: 923.0000 - val_accuracy: 0.9647 - val_precision: 0.9559 - val_recall: 0.9745 - val_auc: 0.9937 - val_prc: 0.9929
# Epoch 65/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0830 - tp: 141213.0000 - fp: 5605.0000 - tn: 138727.0000 - fn: 2884.0000 - accuracy: 0.9706 - precision: 0.9618 - recall: 0.9800 - auc: 0.9949 - prc: 0.9941 - val_loss: 0.0951 - val_tp: 35098.0000 - val_fp: 1455.0000 - val_tn: 34475.0000 - val_fn: 1080.0000 - val_accuracy: 0.9648 - val_precision: 0.9602 - val_recall: 0.9701 - val_auc: 0.9936 - val_prc: 0.9928
# Epoch 66/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0820 - tp: 141254.0000 - fp: 5505.0000 - tn: 138827.0000 - fn: 2843.0000 - accuracy: 0.9711 - precision: 0.9625 - recall: 0.9803 - auc: 0.9950 - prc: 0.9942 - val_loss: 0.0853 - val_tp: 35474.0000 - val_fp: 1536.0000 - val_tn: 34394.0000 - val_fn: 704.0000 - val_accuracy: 0.9689 - val_precision: 0.9585 - val_recall: 0.9805 - val_auc: 0.9946 - val_prc: 0.9937
# Epoch 67/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0822 - tp: 141221.0000 - fp: 5542.0000 - tn: 138790.0000 - fn: 2876.0000 - accuracy: 0.9708 - precision: 0.9622 - recall: 0.9800 - auc: 0.9950 - prc: 0.9941 - val_loss: 0.0883 - val_tp: 35197.0000 - val_fp: 1349.0000 - val_tn: 34581.0000 - val_fn: 981.0000 - val_accuracy: 0.9677 - val_precision: 0.9631 - val_recall: 0.9729 - val_auc: 0.9944 - val_prc: 0.9935
# Epoch 68/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0827 - tp: 141108.0000 - fp: 5569.0000 - tn: 138763.0000 - fn: 2989.0000 - accuracy: 0.9703 - precision: 0.9620 - recall: 0.9793 - auc: 0.9949 - prc: 0.9941 - val_loss: 0.0831 - val_tp: 35654.0000 - val_fp: 1501.0000 - val_tn: 34429.0000 - val_fn: 524.0000 - val_accuracy: 0.9719 - val_precision: 0.9596 - val_recall: 0.9855 - val_auc: 0.9948 - val_prc: 0.9938
# Epoch 69/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0818 - tp: 141252.0000 - fp: 5505.0000 - tn: 138827.0000 - fn: 2845.0000 - accuracy: 0.9711 - precision: 0.9625 - recall: 0.9803 - auc: 0.9950 - prc: 0.9942 - val_loss: 0.0868 - val_tp: 35037.0000 - val_fp: 1216.0000 - val_tn: 34714.0000 - val_fn: 1141.0000 - val_accuracy: 0.9673 - val_precision: 0.9665 - val_recall: 0.9685 - val_auc: 0.9947 - val_prc: 0.9940
# Epoch 70/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0815 - tp: 141210.0000 - fp: 5480.0000 - tn: 138852.0000 - fn: 2887.0000 - accuracy: 0.9710 - precision: 0.9626 - recall: 0.9800 - auc: 0.9951 - prc: 0.9942 - val_loss: 0.0950 - val_tp: 34557.0000 - val_fp: 1004.0000 - val_tn: 34926.0000 - val_fn: 1621.0000 - val_accuracy: 0.9636 - val_precision: 0.9718 - val_recall: 0.9552 - val_auc: 0.9945 - val_prc: 0.9939
# Epoch 71/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0801 - tp: 141280.0000 - fp: 5368.0000 - tn: 138964.0000 - fn: 2817.0000 - accuracy: 0.9716 - precision: 0.9634 - recall: 0.9805 - auc: 0.9952 - prc: 0.9945 - val_loss: 0.0840 - val_tp: 35734.0000 - val_fp: 1589.0000 - val_tn: 34341.0000 - val_fn: 444.0000 - val_accuracy: 0.9718 - val_precision: 0.9574 - val_recall: 0.9877 - val_auc: 0.9948 - val_prc: 0.9939
# Epoch 72/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0804 - tp: 141282.0000 - fp: 5440.0000 - tn: 138892.0000 - fn: 2815.0000 - accuracy: 0.9714 - precision: 0.9629 - recall: 0.9805 - auc: 0.9951 - prc: 0.9943 - val_loss: 0.0825 - val_tp: 35667.0000 - val_fp: 1609.0000 - val_tn: 34321.0000 - val_fn: 511.0000 - val_accuracy: 0.9706 - val_precision: 0.9568 - val_recall: 0.9859 - val_auc: 0.9950 - val_prc: 0.9941
# Epoch 73/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0806 - tp: 141222.0000 - fp: 5430.0000 - tn: 138902.0000 - fn: 2875.0000 - accuracy: 0.9712 - precision: 0.9630 - recall: 0.9800 - auc: 0.9951 - prc: 0.9943 - val_loss: 0.0851 - val_tp: 35325.0000 - val_fp: 1441.0000 - val_tn: 34489.0000 - val_fn: 853.0000 - val_accuracy: 0.9682 - val_precision: 0.9608 - val_recall: 0.9764 - val_auc: 0.9946 - val_prc: 0.9937
# Epoch 74/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0795 - tp: 141325.0000 - fp: 5345.0000 - tn: 138987.0000 - fn: 2772.0000 - accuracy: 0.9719 - precision: 0.9636 - recall: 0.9808 - auc: 0.9952 - prc: 0.9944 - val_loss: 0.0836 - val_tp: 35663.0000 - val_fp: 1580.0000 - val_tn: 34350.0000 - val_fn: 515.0000 - val_accuracy: 0.9709 - val_precision: 0.9576 - val_recall: 0.9858 - val_auc: 0.9948 - val_prc: 0.9938
# Epoch 75/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0787 - tp: 141399.0000 - fp: 5263.0000 - tn: 139069.0000 - fn: 2698.0000 - accuracy: 0.9724 - precision: 0.9641 - recall: 0.9813 - auc: 0.9953 - prc: 0.9945 - val_loss: 0.0846 - val_tp: 35024.0000 - val_fp: 1112.0000 - val_tn: 34818.0000 - val_fn: 1154.0000 - val_accuracy: 0.9686 - val_precision: 0.9692 - val_recall: 0.9681 - val_auc: 0.9951 - val_prc: 0.9945
# Epoch 76/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0789 - tp: 141349.0000 - fp: 5296.0000 - tn: 139036.0000 - fn: 2748.0000 - accuracy: 0.9721 - precision: 0.9639 - recall: 0.9809 - auc: 0.9953 - prc: 0.9944 - val_loss: 0.0827 - val_tp: 35507.0000 - val_fp: 1466.0000 - val_tn: 34464.0000 - val_fn: 671.0000 - val_accuracy: 0.9704 - val_precision: 0.9603 - val_recall: 0.9815 - val_auc: 0.9949 - val_prc: 0.9941
# Epoch 77/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0761 - tp: 141546.0000 - fp: 5096.0000 - tn: 139236.0000 - fn: 2551.0000 - accuracy: 0.9735 - precision: 0.9652 - recall: 0.9823 - auc: 0.9956 - prc: 0.9948 - val_loss: 0.0861 - val_tp: 35802.0000 - val_fp: 1830.0000 - val_tn: 34100.0000 - val_fn: 376.0000 - val_accuracy: 0.9694 - val_precision: 0.9514 - val_recall: 0.9896 - val_auc: 0.9946 - val_prc: 0.9930
# Epoch 78/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0750 - tp: 141608.0000 - fp: 5040.0000 - tn: 139292.0000 - fn: 2489.0000 - accuracy: 0.9739 - precision: 0.9656 - recall: 0.9827 - auc: 0.9957 - prc: 0.9949 - val_loss: 0.0810 - val_tp: 35465.0000 - val_fp: 1360.0000 - val_tn: 34570.0000 - val_fn: 713.0000 - val_accuracy: 0.9713 - val_precision: 0.9631 - val_recall: 0.9803 - val_auc: 0.9950 - val_prc: 0.9942
# Epoch 79/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0763 - tp: 141439.0000 - fp: 5158.0000 - tn: 139174.0000 - fn: 2658.0000 - accuracy: 0.9729 - precision: 0.9648 - recall: 0.9816 - auc: 0.9956 - prc: 0.9948 - val_loss: 0.0859 - val_tp: 35145.0000 - val_fp: 1340.0000 - val_tn: 34590.0000 - val_fn: 1033.0000 - val_accuracy: 0.9671 - val_precision: 0.9633 - val_recall: 0.9714 - val_auc: 0.9946 - val_prc: 0.9937
# Epoch 80/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0755 - tp: 141609.0000 - fp: 5062.0000 - tn: 139270.0000 - fn: 2488.0000 - accuracy: 0.9738 - precision: 0.9655 - recall: 0.9827 - auc: 0.9957 - prc: 0.9949 - val_loss: 0.0811 - val_tp: 35306.0000 - val_fp: 1126.0000 - val_tn: 34804.0000 - val_fn: 872.0000 - val_accuracy: 0.9723 - val_precision: 0.9691 - val_recall: 0.9759 - val_auc: 0.9952 - val_prc: 0.9947
# Epoch 81/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0749 - tp: 141580.0000 - fp: 5039.0000 - tn: 139293.0000 - fn: 2517.0000 - accuracy: 0.9738 - precision: 0.9656 - recall: 0.9825 - auc: 0.9957 - prc: 0.9950 - val_loss: 0.0796 - val_tp: 35234.0000 - val_fp: 1217.0000 - val_tn: 34713.0000 - val_fn: 944.0000 - val_accuracy: 0.9700 - val_precision: 0.9666 - val_recall: 0.9739 - val_auc: 0.9952 - val_prc: 0.9944
# Epoch 82/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0762 - tp: 141380.0000 - fp: 5043.0000 - tn: 139289.0000 - fn: 2717.0000 - accuracy: 0.9731 - precision: 0.9656 - recall: 0.9811 - auc: 0.9956 - prc: 0.9949 - val_loss: 0.0773 - val_tp: 35574.0000 - val_fp: 1344.0000 - val_tn: 34586.0000 - val_fn: 604.0000 - val_accuracy: 0.9730 - val_precision: 0.9636 - val_recall: 0.9833 - val_auc: 0.9954 - val_prc: 0.9946
# Epoch 83/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0742 - tp: 141666.0000 - fp: 4919.0000 - tn: 139413.0000 - fn: 2431.0000 - accuracy: 0.9745 - precision: 0.9664 - recall: 0.9831 - auc: 0.9958 - prc: 0.9950 - val_loss: 0.0778 - val_tp: 35520.0000 - val_fp: 1299.0000 - val_tn: 34631.0000 - val_fn: 658.0000 - val_accuracy: 0.9729 - val_precision: 0.9647 - val_recall: 0.9818 - val_auc: 0.9954 - val_prc: 0.9947
# Epoch 84/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0742 - tp: 141565.0000 - fp: 4929.0000 - tn: 139403.0000 - fn: 2532.0000 - accuracy: 0.9741 - precision: 0.9664 - recall: 0.9824 - auc: 0.9958 - prc: 0.9950 - val_loss: 0.0775 - val_tp: 35693.0000 - val_fp: 1456.0000 - val_tn: 34474.0000 - val_fn: 485.0000 - val_accuracy: 0.9731 - val_precision: 0.9608 - val_recall: 0.9866 - val_auc: 0.9954 - val_prc: 0.9946
# Epoch 85/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0748 - tp: 141437.0000 - fp: 4960.0000 - tn: 139372.0000 - fn: 2660.0000 - accuracy: 0.9736 - precision: 0.9661 - recall: 0.9815 - auc: 0.9957 - prc: 0.9949 - val_loss: 0.0852 - val_tp: 35749.0000 - val_fp: 1730.0000 - val_tn: 34200.0000 - val_fn: 429.0000 - val_accuracy: 0.9701 - val_precision: 0.9538 - val_recall: 0.9881 - val_auc: 0.9947 - val_prc: 0.9935
# Epoch 86/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0740 - tp: 141533.0000 - fp: 5000.0000 - tn: 139332.0000 - fn: 2564.0000 - accuracy: 0.9738 - precision: 0.9659 - recall: 0.9822 - auc: 0.9958 - prc: 0.9950 - val_loss: 0.0760 - val_tp: 35482.0000 - val_fp: 1152.0000 - val_tn: 34778.0000 - val_fn: 696.0000 - val_accuracy: 0.9744 - val_precision: 0.9686 - val_recall: 0.9808 - val_auc: 0.9956 - val_prc: 0.9949
# Epoch 87/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0718 - tp: 141793.0000 - fp: 4809.0000 - tn: 139523.0000 - fn: 2304.0000 - accuracy: 0.9753 - precision: 0.9672 - recall: 0.9840 - auc: 0.9960 - prc: 0.9953 - val_loss: 0.0779 - val_tp: 35742.0000 - val_fp: 1501.0000 - val_tn: 34429.0000 - val_fn: 436.0000 - val_accuracy: 0.9731 - val_precision: 0.9597 - val_recall: 0.9879 - val_auc: 0.9952 - val_prc: 0.9938
# Epoch 88/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0707 - tp: 141847.0000 - fp: 4775.0000 - tn: 139557.0000 - fn: 2250.0000 - accuracy: 0.9756 - precision: 0.9674 - recall: 0.9844 - auc: 0.9961 - prc: 0.9954 - val_loss: 0.0738 - val_tp: 35407.0000 - val_fp: 1088.0000 - val_tn: 34842.0000 - val_fn: 771.0000 - val_accuracy: 0.9742 - val_precision: 0.9702 - val_recall: 0.9787 - val_auc: 0.9959 - val_prc: 0.9951
# Epoch 89/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0714 - tp: 141751.0000 - fp: 4718.0000 - tn: 139614.0000 - fn: 2346.0000 - accuracy: 0.9755 - precision: 0.9678 - recall: 0.9837 - auc: 0.9961 - prc: 0.9953 - val_loss: 0.0754 - val_tp: 35602.0000 - val_fp: 1362.0000 - val_tn: 34568.0000 - val_fn: 576.0000 - val_accuracy: 0.9731 - val_precision: 0.9632 - val_recall: 0.9841 - val_auc: 0.9955 - val_prc: 0.9945
# Epoch 90/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0700 - tp: 141874.0000 - fp: 4627.0000 - tn: 139705.0000 - fn: 2223.0000 - accuracy: 0.9763 - precision: 0.9684 - recall: 0.9846 - auc: 0.9962 - prc: 0.9954 - val_loss: 0.0781 - val_tp: 35041.0000 - val_fp: 920.0000 - val_tn: 35010.0000 - val_fn: 1137.0000 - val_accuracy: 0.9715 - val_precision: 0.9744 - val_recall: 0.9686 - val_auc: 0.9956 - val_prc: 0.9947
# Epoch 91/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0708 - tp: 141728.0000 - fp: 4778.0000 - tn: 139554.0000 - fn: 2369.0000 - accuracy: 0.9752 - precision: 0.9674 - recall: 0.9836 - auc: 0.9961 - prc: 0.9954 - val_loss: 0.0771 - val_tp: 35789.0000 - val_fp: 1484.0000 - val_tn: 34446.0000 - val_fn: 389.0000 - val_accuracy: 0.9740 - val_precision: 0.9602 - val_recall: 0.9892 - val_auc: 0.9953 - val_prc: 0.9942
# Epoch 92/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0701 - tp: 141785.0000 - fp: 4674.0000 - tn: 139658.0000 - fn: 2312.0000 - accuracy: 0.9758 - precision: 0.9681 - recall: 0.9840 - auc: 0.9962 - prc: 0.9955 - val_loss: 0.0740 - val_tp: 35405.0000 - val_fp: 1084.0000 - val_tn: 34846.0000 - val_fn: 773.0000 - val_accuracy: 0.9742 - val_precision: 0.9703 - val_recall: 0.9786 - val_auc: 0.9958 - val_prc: 0.9951
# Epoch 93/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0716 - tp: 141646.0000 - fp: 4757.0000 - tn: 139575.0000 - fn: 2451.0000 - accuracy: 0.9750 - precision: 0.9675 - recall: 0.9830 - auc: 0.9960 - prc: 0.9952 - val_loss: 0.0747 - val_tp: 35372.0000 - val_fp: 1111.0000 - val_tn: 34819.0000 - val_fn: 806.0000 - val_accuracy: 0.9734 - val_precision: 0.9695 - val_recall: 0.9777 - val_auc: 0.9958 - val_prc: 0.9952
# Epoch 94/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0704 - tp: 141678.0000 - fp: 4721.0000 - tn: 139611.0000 - fn: 2419.0000 - accuracy: 0.9752 - precision: 0.9678 - recall: 0.9832 - auc: 0.9961 - prc: 0.9954 - val_loss: 0.0718 - val_tp: 35647.0000 - val_fp: 1245.0000 - val_tn: 34685.0000 - val_fn: 531.0000 - val_accuracy: 0.9754 - val_precision: 0.9663 - val_recall: 0.9853 - val_auc: 0.9958 - val_prc: 0.9949
# Epoch 95/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0699 - tp: 141760.0000 - fp: 4622.0000 - tn: 139710.0000 - fn: 2337.0000 - accuracy: 0.9759 - precision: 0.9684 - recall: 0.9838 - auc: 0.9961 - prc: 0.9954 - val_loss: 0.0743 - val_tp: 35578.0000 - val_fp: 1230.0000 - val_tn: 34700.0000 - val_fn: 600.0000 - val_accuracy: 0.9746 - val_precision: 0.9666 - val_recall: 0.9834 - val_auc: 0.9956 - val_prc: 0.9946
# Epoch 96/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0686 - tp: 141831.0000 - fp: 4542.0000 - tn: 139790.0000 - fn: 2266.0000 - accuracy: 0.9764 - precision: 0.9690 - recall: 0.9843 - auc: 0.9963 - prc: 0.9956 - val_loss: 0.0762 - val_tp: 35424.0000 - val_fp: 1200.0000 - val_tn: 34730.0000 - val_fn: 754.0000 - val_accuracy: 0.9729 - val_precision: 0.9672 - val_recall: 0.9792 - val_auc: 0.9955 - val_prc: 0.9948
# Epoch 97/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0688 - tp: 141820.0000 - fp: 4602.0000 - tn: 139730.0000 - fn: 2277.0000 - accuracy: 0.9762 - precision: 0.9686 - recall: 0.9842 - auc: 0.9963 - prc: 0.9956 - val_loss: 0.0771 - val_tp: 35221.0000 - val_fp: 1073.0000 - val_tn: 34857.0000 - val_fn: 957.0000 - val_accuracy: 0.9718 - val_precision: 0.9704 - val_recall: 0.9735 - val_auc: 0.9955 - val_prc: 0.9947
# Epoch 98/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0687 - tp: 141804.0000 - fp: 4610.0000 - tn: 139722.0000 - fn: 2293.0000 - accuracy: 0.9761 - precision: 0.9685 - recall: 0.9841 - auc: 0.9963 - prc: 0.9957 - val_loss: 0.0717 - val_tp: 35647.0000 - val_fp: 1216.0000 - val_tn: 34714.0000 - val_fn: 531.0000 - val_accuracy: 0.9758 - val_precision: 0.9670 - val_recall: 0.9853 - val_auc: 0.9958 - val_prc: 0.9951
# Epoch 99/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0685 - tp: 141842.0000 - fp: 4519.0000 - tn: 139813.0000 - fn: 2255.0000 - accuracy: 0.9765 - precision: 0.9691 - recall: 0.9844 - auc: 0.9963 - prc: 0.9955 - val_loss: 0.0726 - val_tp: 35756.0000 - val_fp: 1422.0000 - val_tn: 34508.0000 - val_fn: 422.0000 - val_accuracy: 0.9744 - val_precision: 0.9618 - val_recall: 0.9883 - val_auc: 0.9959 - val_prc: 0.9950
# Epoch 100/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0667 - tp: 141939.0000 - fp: 4472.0000 - tn: 139860.0000 - fn: 2158.0000 - accuracy: 0.9770 - precision: 0.9695 - recall: 0.9850 - auc: 0.9965 - prc: 0.9958 - val_loss: 0.0733 - val_tp: 35323.0000 - val_fp: 1082.0000 - val_tn: 34848.0000 - val_fn: 855.0000 - val_accuracy: 0.9731 - val_precision: 0.9703 - val_recall: 0.9764 - val_auc: 0.9957 - val_prc: 0.9948
# Epoch 101/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0670 - tp: 141876.0000 - fp: 4428.0000 - tn: 139904.0000 - fn: 2221.0000 - accuracy: 0.9769 - precision: 0.9697 - recall: 0.9846 - auc: 0.9965 - prc: 0.9958 - val_loss: 0.0702 - val_tp: 35807.0000 - val_fp: 1421.0000 - val_tn: 34509.0000 - val_fn: 371.0000 - val_accuracy: 0.9751 - val_precision: 0.9618 - val_recall: 0.9897 - val_auc: 0.9962 - val_prc: 0.9954
# Epoch 102/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0671 - tp: 141927.0000 - fp: 4450.0000 - tn: 139882.0000 - fn: 2170.0000 - accuracy: 0.9770 - precision: 0.9696 - recall: 0.9849 - auc: 0.9964 - prc: 0.9956 - val_loss: 0.0736 - val_tp: 35822.0000 - val_fp: 1377.0000 - val_tn: 34553.0000 - val_fn: 356.0000 - val_accuracy: 0.9760 - val_precision: 0.9630 - val_recall: 0.9902 - val_auc: 0.9957 - val_prc: 0.9947
# Epoch 103/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0683 - tp: 141762.0000 - fp: 4531.0000 - tn: 139801.0000 - fn: 2335.0000 - accuracy: 0.9762 - precision: 0.9690 - recall: 0.9838 - auc: 0.9963 - prc: 0.9956 - val_loss: 0.0767 - val_tp: 35680.0000 - val_fp: 1365.0000 - val_tn: 34565.0000 - val_fn: 498.0000 - val_accuracy: 0.9742 - val_precision: 0.9632 - val_recall: 0.9862 - val_auc: 0.9953 - val_prc: 0.9942
# Epoch 104/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0670 - tp: 141926.0000 - fp: 4431.0000 - tn: 139901.0000 - fn: 2171.0000 - accuracy: 0.9771 - precision: 0.9697 - recall: 0.9849 - auc: 0.9964 - prc: 0.9957 - val_loss: 0.0724 - val_tp: 35723.0000 - val_fp: 1423.0000 - val_tn: 34507.0000 - val_fn: 455.0000 - val_accuracy: 0.9740 - val_precision: 0.9617 - val_recall: 0.9874 - val_auc: 0.9959 - val_prc: 0.9949
# Epoch 105/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0659 - tp: 142000.0000 - fp: 4338.0000 - tn: 139994.0000 - fn: 2097.0000 - accuracy: 0.9777 - precision: 0.9704 - recall: 0.9854 - auc: 0.9966 - prc: 0.9959 - val_loss: 0.0703 - val_tp: 35790.0000 - val_fp: 1349.0000 - val_tn: 34581.0000 - val_fn: 388.0000 - val_accuracy: 0.9759 - val_precision: 0.9637 - val_recall: 0.9893 - val_auc: 0.9961 - val_prc: 0.9952
# Epoch 106/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0654 - tp: 142008.0000 - fp: 4349.0000 - tn: 139983.0000 - fn: 2089.0000 - accuracy: 0.9777 - precision: 0.9703 - recall: 0.9855 - auc: 0.9966 - prc: 0.9959 - val_loss: 0.0717 - val_tp: 35391.0000 - val_fp: 995.0000 - val_tn: 34935.0000 - val_fn: 787.0000 - val_accuracy: 0.9753 - val_precision: 0.9727 - val_recall: 0.9782 - val_auc: 0.9961 - val_prc: 0.9954
# Epoch 107/500
# ...
# Epoch 110/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0650 - tp: 141958.0000 - fp: 4308.0000 - tn: 140024.0000 - fn: 2139.0000 - accuracy: 0.9776 - precision: 0.9705 - recall: 0.9852 - auc: 0.9966 - prc: 0.9960 - val_loss: 0.0732 - val_tp: 35636.0000 - val_fp: 1317.0000 - val_tn: 34613.0000 - val_fn: 542.0000 - val_accuracy: 0.9742 - val_precision: 0.9644 - val_recall: 0.9850 - val_auc: 0.9957 - val_prc: 0.9944
# Epoch 111/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0643 - tp: 142040.0000 - fp: 4264.0000 - tn: 140068.0000 - fn: 2057.0000 - accuracy: 0.9781 - precision: 0.9709 - recall: 0.9857 - auc: 0.9967 - prc: 0.9961 - val_loss: 0.0664 - val_tp: 35740.0000 - val_fp: 1168.0000 - val_tn: 34762.0000 - val_fn: 438.0000 - val_accuracy: 0.9777 - val_precision: 0.9684 - val_recall: 0.9879 - val_auc: 0.9965 - val_prc: 0.9959
# Epoch 112/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0624 - tp: 142220.0000 - fp: 4124.0000 - tn: 140208.0000 - fn: 1877.0000 - accuracy: 0.9792 - precision: 0.9718 - recall: 0.9870 - auc: 0.9968 - prc: 0.9962 - val_loss: 0.0665 - val_tp: 35485.0000 - val_fp: 954.0000 - val_tn: 34976.0000 - val_fn: 693.0000 - val_accuracy: 0.9772 - val_precision: 0.9738 - val_recall: 0.9808 - val_auc: 0.9965 - val_prc: 0.9958
# Epoch 113/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0642 - tp: 142004.0000 - fp: 4230.0000 - tn: 140102.0000 - fn: 2093.0000 - accuracy: 0.9781 - precision: 0.9711 - recall: 0.9855 - auc: 0.9967 - prc: 0.9960 - val_loss: 0.0672 - val_tp: 35436.0000 - val_fp: 994.0000 - val_tn: 34936.0000 - val_fn: 742.0000 - val_accuracy: 0.9759 - val_precision: 0.9727 - val_recall: 0.9795 - val_auc: 0.9965 - val_prc: 0.9960
# Epoch 114/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0631 - tp: 142165.0000 - fp: 4208.0000 - tn: 140124.0000 - fn: 1932.0000 - accuracy: 0.9787 - precision: 0.9713 - recall: 0.9866 - auc: 0.9968 - prc: 0.9962 - val_loss: 0.0723 - val_tp: 34975.0000 - val_fp: 807.0000 - val_tn: 35123.0000 - val_fn: 1203.0000 - val_accuracy: 0.9721 - val_precision: 0.9774 - val_recall: 0.9667 - val_auc: 0.9964 - val_prc: 0.9960
# Epoch 115/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0621 - tp: 142142.0000 - fp: 4131.0000 - tn: 140201.0000 - fn: 1955.0000 - accuracy: 0.9789 - precision: 0.9718 - recall: 0.9864 - auc: 0.9969 - prc: 0.9963 - val_loss: 0.0683 - val_tp: 35530.0000 - val_fp: 1075.0000 - val_tn: 34855.0000 - val_fn: 648.0000 - val_accuracy: 0.9761 - val_precision: 0.9706 - val_recall: 0.9821 - val_auc: 0.9962 - val_prc: 0.9955
# Epoch 116/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0620 - tp: 142187.0000 - fp: 4110.0000 - tn: 140222.0000 - fn: 1910.0000 - accuracy: 0.9791 - precision: 0.9719 - recall: 0.9867 - auc: 0.9969 - prc: 0.9963 - val_loss: 0.0649 - val_tp: 35627.0000 - val_fp: 1037.0000 - val_tn: 34893.0000 - val_fn: 551.0000 - val_accuracy: 0.9780 - val_precision: 0.9717 - val_recall: 0.9848 - val_auc: 0.9965 - val_prc: 0.9956
# Epoch 117/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0623 - tp: 142028.0000 - fp: 4147.0000 - tn: 140185.0000 - fn: 2069.0000 - accuracy: 0.9784 - precision: 0.9716 - recall: 0.9856 - auc: 0.9969 - prc: 0.9963 - val_loss: 0.0669 - val_tp: 35586.0000 - val_fp: 1049.0000 - val_tn: 34881.0000 - val_fn: 592.0000 - val_accuracy: 0.9772 - val_precision: 0.9714 - val_recall: 0.9836 - val_auc: 0.9964 - val_prc: 0.9959
# Epoch 118/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0621 - tp: 142161.0000 - fp: 4125.0000 - tn: 140207.0000 - fn: 1936.0000 - accuracy: 0.9790 - precision: 0.9718 - recall: 0.9866 - auc: 0.9968 - prc: 0.9962 - val_loss: 0.0656 - val_tp: 35779.0000 - val_fp: 1228.0000 - val_tn: 34702.0000 - val_fn: 399.0000 - val_accuracy: 0.9774 - val_precision: 0.9668 - val_recall: 0.9890 - val_auc: 0.9964 - val_prc: 0.9957
# Epoch 119/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0623 - tp: 142110.0000 - fp: 4079.0000 - tn: 140253.0000 - fn: 1987.0000 - accuracy: 0.9790 - precision: 0.9721 - recall: 0.9862 - auc: 0.9968 - prc: 0.9963 - val_loss: 0.0711 - val_tp: 35247.0000 - val_fp: 1056.0000 - val_tn: 34874.0000 - val_fn: 931.0000 - val_accuracy: 0.9724 - val_precision: 0.9709 - val_recall: 0.9743 - val_auc: 0.9961 - val_prc: 0.9955
# Epoch 120/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0627 - tp: 142019.0000 - fp: 4144.0000 - tn: 140188.0000 - fn: 2078.0000 - accuracy: 0.9784 - precision: 0.9716 - recall: 0.9856 - auc: 0.9968 - prc: 0.9962 - val_loss: 0.0663 - val_tp: 35710.0000 - val_fp: 1117.0000 - val_tn: 34813.0000 - val_fn: 468.0000 - val_accuracy: 0.9780 - val_precision: 0.9697 - val_recall: 0.9871 - val_auc: 0.9962 - val_prc: 0.9953
# Epoch 121/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0613 - tp: 142151.0000 - fp: 4056.0000 - tn: 140276.0000 - fn: 1946.0000 - accuracy: 0.9792 - precision: 0.9723 - recall: 0.9865 - auc: 0.9969 - prc: 0.9963 - val_loss: 0.0642 - val_tp: 35616.0000 - val_fp: 970.0000 - val_tn: 34960.0000 - val_fn: 562.0000 - val_accuracy: 0.9788 - val_precision: 0.9735 - val_recall: 0.9845 - val_auc: 0.9967 - val_prc: 0.9961
# Epoch 122/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0618 - tp: 142119.0000 - fp: 4097.0000 - tn: 140235.0000 - fn: 1978.0000 - accuracy: 0.9789 - precision: 0.9720 - recall: 0.9863 - auc: 0.9969 - prc: 0.9962 - val_loss: 0.0668 - val_tp: 35722.0000 - val_fp: 1202.0000 - val_tn: 34728.0000 - val_fn: 456.0000 - val_accuracy: 0.9770 - val_precision: 0.9674 - val_recall: 0.9874 - val_auc: 0.9964 - val_prc: 0.9956
# Epoch 123/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0599 - tp: 142223.0000 - fp: 3967.0000 - tn: 140365.0000 - fn: 1874.0000 - accuracy: 0.9797 - precision: 0.9729 - recall: 0.9870 - auc: 0.9971 - prc: 0.9965 - val_loss: 0.0678 - val_tp: 35905.0000 - val_fp: 1393.0000 - val_tn: 34537.0000 - val_fn: 273.0000 - val_accuracy: 0.9769 - val_precision: 0.9627 - val_recall: 0.9925 - val_auc: 0.9964 - val_prc: 0.9956
# Epoch 124/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0611 - tp: 142146.0000 - fp: 4008.0000 - tn: 140324.0000 - fn: 1951.0000 - accuracy: 0.9793 - precision: 0.9726 - recall: 0.9865 - auc: 0.9969 - prc: 0.9963 - val_loss: 0.0735 - val_tp: 35603.0000 - val_fp: 1255.0000 - val_tn: 34675.0000 - val_fn: 575.0000 - val_accuracy: 0.9746 - val_precision: 0.9660 - val_recall: 0.9841 - val_auc: 0.9955 - val_prc: 0.9944
# Epoch 125/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0617 - tp: 142017.0000 - fp: 4083.0000 - tn: 140249.0000 - fn: 2080.0000 - accuracy: 0.9786 - precision: 0.9721 - recall: 0.9856 - auc: 0.9969 - prc: 0.9963 - val_loss: 0.0682 - val_tp: 35440.0000 - val_fp: 1012.0000 - val_tn: 34918.0000 - val_fn: 738.0000 - val_accuracy: 0.9757 - val_precision: 0.9722 - val_recall: 0.9796 - val_auc: 0.9961 - val_prc: 0.9952
# Epoch 126/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0597 - tp: 142316.0000 - fp: 3867.0000 - tn: 140465.0000 - fn: 1781.0000 - accuracy: 0.9804 - precision: 0.9735 - recall: 0.9876 - auc: 0.9971 - prc: 0.9966 - val_loss: 0.0645 - val_tp: 35772.0000 - val_fp: 1119.0000 - val_tn: 34811.0000 - val_fn: 406.0000 - val_accuracy: 0.9789 - val_precision: 0.9697 - val_recall: 0.9888 - val_auc: 0.9964 - val_prc: 0.9953
# Epoch 127/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0607 - tp: 142130.0000 - fp: 3991.0000 - tn: 140341.0000 - fn: 1967.0000 - accuracy: 0.9793 - precision: 0.9727 - recall: 0.9863 - auc: 0.9970 - prc: 0.9963 - val_loss: 0.0658 - val_tp: 35540.0000 - val_fp: 1039.0000 - val_tn: 34891.0000 - val_fn: 638.0000 - val_accuracy: 0.9767 - val_precision: 0.9716 - val_recall: 0.9824 - val_auc: 0.9965 - val_prc: 0.9960
# Epoch 128/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0584 - tp: 142261.0000 - fp: 3811.0000 - tn: 140521.0000 - fn: 1836.0000 - accuracy: 0.9804 - precision: 0.9739 - recall: 0.9873 - auc: 0.9972 - prc: 0.9966 - val_loss: 0.0628 - val_tp: 35877.0000 - val_fp: 1227.0000 - val_tn: 34703.0000 - val_fn: 301.0000 - val_accuracy: 0.9788 - val_precision: 0.9669 - val_recall: 0.9917 - val_auc: 0.9968 - val_prc: 0.9960
# Epoch 129/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0589 - tp: 142325.0000 - fp: 3921.0000 - tn: 140411.0000 - fn: 1772.0000 - accuracy: 0.9803 - precision: 0.9732 - recall: 0.9877 - auc: 0.9971 - prc: 0.9966 - val_loss: 0.0660 - val_tp: 35626.0000 - val_fp: 1177.0000 - val_tn: 34753.0000 - val_fn: 552.0000 - val_accuracy: 0.9760 - val_precision: 0.9680 - val_recall: 0.9847 - val_auc: 0.9964 - val_prc: 0.9954
# Epoch 130/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0583 - tp: 142323.0000 - fp: 3853.0000 - tn: 140479.0000 - fn: 1774.0000 - accuracy: 0.9805 - precision: 0.9736 - recall: 0.9877 - auc: 0.9972 - prc: 0.9967 - val_loss: 0.0634 - val_tp: 35399.0000 - val_fp: 787.0000 - val_tn: 35143.0000 - val_fn: 779.0000 - val_accuracy: 0.9783 - val_precision: 0.9783 - val_recall: 0.9785 - val_auc: 0.9969 - val_prc: 0.9962
# Epoch 131/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0600 - tp: 142173.0000 - fp: 3936.0000 - tn: 140396.0000 - fn: 1924.0000 - accuracy: 0.9797 - precision: 0.9731 - recall: 0.9866 - auc: 0.9970 - prc: 0.9963 - val_loss: 0.0619 - val_tp: 35610.0000 - val_fp: 927.0000 - val_tn: 35003.0000 - val_fn: 568.0000 - val_accuracy: 0.9793 - val_precision: 0.9746 - val_recall: 0.9843 - val_auc: 0.9969 - val_prc: 0.9964
# Epoch 132/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0573 - tp: 142394.0000 - fp: 3776.0000 - tn: 140556.0000 - fn: 1703.0000 - accuracy: 0.9810 - precision: 0.9742 - recall: 0.9882 - auc: 0.9973 - prc: 0.9968 - val_loss: 0.0629 - val_tp: 35611.0000 - val_fp: 962.0000 - val_tn: 34968.0000 - val_fn: 567.0000 - val_accuracy: 0.9788 - val_precision: 0.9737 - val_recall: 0.9843 - val_auc: 0.9965 - val_prc: 0.9955
# Epoch 133/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0572 - tp: 142369.0000 - fp: 3752.0000 - tn: 140580.0000 - fn: 1728.0000 - accuracy: 0.9810 - precision: 0.9743 - recall: 0.9880 - auc: 0.9973 - prc: 0.9967 - val_loss: 0.0600 - val_tp: 35825.0000 - val_fp: 1072.0000 - val_tn: 34858.0000 - val_fn: 353.0000 - val_accuracy: 0.9802 - val_precision: 0.9709 - val_recall: 0.9902 - val_auc: 0.9968 - val_prc: 0.9959
# Epoch 134/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0572 - tp: 142415.0000 - fp: 3758.0000 - tn: 140574.0000 - fn: 1682.0000 - accuracy: 0.9811 - precision: 0.9743 - recall: 0.9883 - auc: 0.9973 - prc: 0.9967 - val_loss: 0.0619 - val_tp: 35613.0000 - val_fp: 964.0000 - val_tn: 34966.0000 - val_fn: 565.0000 - val_accuracy: 0.9788 - val_precision: 0.9736 - val_recall: 0.9844 - val_auc: 0.9969 - val_prc: 0.9964
# Epoch 135/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0553 - tp: 142518.0000 - fp: 3705.0000 - tn: 140627.0000 - fn: 1579.0000 - accuracy: 0.9817 - precision: 0.9747 - recall: 0.9890 - auc: 0.9975 - prc: 0.9969 - val_loss: 0.0601 - val_tp: 35850.0000 - val_fp: 1083.0000 - val_tn: 34847.0000 - val_fn: 328.0000 - val_accuracy: 0.9804 - val_precision: 0.9707 - val_recall: 0.9909 - val_auc: 0.9968 - val_prc: 0.9958
# Epoch 136/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0574 - tp: 142289.0000 - fp: 3824.0000 - tn: 140508.0000 - fn: 1808.0000 - accuracy: 0.9805 - precision: 0.9738 - recall: 0.9875 - auc: 0.9973 - prc: 0.9967 - val_loss: 0.0640 - val_tp: 35879.0000 - val_fp: 1271.0000 - val_tn: 34659.0000 - val_fn: 299.0000 - val_accuracy: 0.9782 - val_precision: 0.9658 - val_recall: 0.9917 - val_auc: 0.9965 - val_prc: 0.9954
# Epoch 137/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0598 - tp: 142086.0000 - fp: 3955.0000 - tn: 140377.0000 - fn: 2011.0000 - accuracy: 0.9793 - precision: 0.9729 - recall: 0.9860 - auc: 0.9970 - prc: 0.9963 - val_loss: 0.0614 - val_tp: 35754.0000 - val_fp: 1115.0000 - val_tn: 34815.0000 - val_fn: 424.0000 - val_accuracy: 0.9787 - val_precision: 0.9698 - val_recall: 0.9883 - val_auc: 0.9969 - val_prc: 0.9960
# Epoch 138/500
# 95/95 [==============================] - 1s 10ms/step - loss: 0.0564 - tp: 142342.0000 - fp: 3708.0000 - tn: 140624.0000 - fn: 1755.0000 - accuracy: 0.9811 - precision: 0.9746 - recall: 0.9878 - auc: 0.9973 - prc: 0.9968 - val_loss: 0.0627 - val_tp: 35605.0000 - val_fp: 1006.0000 - val_tn: 34924.0000 - val_fn: 573.0000 - val_accuracy: 0.9781 - val_precision: 0.9725 - val_recall: 0.9842 - val_auc: 0.9967 - val_prc: 0.9960
# Epoch 139/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0572 - tp: 142275.0000 - fp: 3767.0000 - tn: 140565.0000 - fn: 1822.0000 - accuracy: 0.9806 - precision: 0.9742 - recall: 0.9874 - auc: 0.9973 - prc: 0.9968 - val_loss: 0.0639 - val_tp: 35796.0000 - val_fp: 1173.0000 - val_tn: 34757.0000 - val_fn: 382.0000 - val_accuracy: 0.9784 - val_precision: 0.9683 - val_recall: 0.9894 - val_auc: 0.9964 - val_prc: 0.9953
# Epoch 140/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0563 - tp: 142341.0000 - fp: 3672.0000 - tn: 140660.0000 - fn: 1756.0000 - accuracy: 0.9812 - precision: 0.9749 - recall: 0.9878 - auc: 0.9973 - prc: 0.9967 - val_loss: 0.0646 - val_tp: 35809.0000 - val_fp: 1263.0000 - val_tn: 34667.0000 - val_fn: 369.0000 - val_accuracy: 0.9774 - val_precision: 0.9659 - val_recall: 0.9898 - val_auc: 0.9967 - val_prc: 0.9958
# Epoch 141/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0586 - tp: 142133.0000 - fp: 3892.0000 - tn: 140440.0000 - fn: 1964.0000 - accuracy: 0.9797 - precision: 0.9733 - recall: 0.9864 - auc: 0.9971 - prc: 0.9964 - val_loss: 0.0592 - val_tp: 35898.0000 - val_fp: 1108.0000 - val_tn: 34822.0000 - val_fn: 280.0000 - val_accuracy: 0.9808 - val_precision: 0.9701 - val_recall: 0.9923 - val_auc: 0.9970 - val_prc: 0.9963
# Epoch 142/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0572 - tp: 142255.0000 - fp: 3771.0000 - tn: 140561.0000 - fn: 1842.0000 - accuracy: 0.9805 - precision: 0.9742 - recall: 0.9872 - auc: 0.9973 - prc: 0.9967 - val_loss: 0.0648 - val_tp: 35325.0000 - val_fp: 775.0000 - val_tn: 35155.0000 - val_fn: 853.0000 - val_accuracy: 0.9774 - val_precision: 0.9785 - val_recall: 0.9764 - val_auc: 0.9967 - val_prc: 0.9958
# Epoch 143/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0585 - tp: 142188.0000 - fp: 3847.0000 - tn: 140485.0000 - fn: 1909.0000 - accuracy: 0.9800 - precision: 0.9737 - recall: 0.9868 - auc: 0.9971 - prc: 0.9965 - val_loss: 0.0645 - val_tp: 35806.0000 - val_fp: 1212.0000 - val_tn: 34718.0000 - val_fn: 372.0000 - val_accuracy: 0.9780 - val_precision: 0.9673 - val_recall: 0.9897 - val_auc: 0.9966 - val_prc: 0.9955
# Epoch 144/500
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0563 - tp: 142271.0000 - fp: 3712.0000 - tn: 140620.0000 - fn: 1826.0000 - accuracy: 0.9808 - precision: 0.9746 - recall: 0.9873 - auc: 0.9973 - prc: 0.9967 - val_loss: 0.0608 - val_tp: 35797.0000 - val_fp: 1138.0000 - val_tn: 34792.0000 - val_fn: 381.0000 - val_accuracy: 0.9789 - val_precision: 0.9692 - val_recall: 0.9895 - val_auc: 0.9968 - val_prc: 0.9960
# Restoring model weights from the end of the best epoch.
# Epoch 00144: early stopping
# loss :  0.06078317016363144 /n
# tp :  44378.0 /n
# fp :  1171.0 /n
# tn :  43903.0 /n
# fn :  683.0 /n
# accuracy :  0.9794308543205261 /n
# precision :  0.9742914438247681 /n
# recall :  0.9848427772521973 /n
# auc :  0.9968400001525879 /n
# prc :  0.9961504340171814 /n
# True Negatives:  43903
# False Positives:  1171
# False Negatives:  683
# True Positives:  44378
# Total:  45061
# INFO:tensorflow:Assets written to: C:\Users\angel\AppData\Local\Temp\tmpag96cr54\model\data\model\assets

# %% [markdown]
# ## 5. Register Model

# %%
model_uri = "runs:/{}/{}".format(run.info.run_id, model_name)
mv = mlflow.register_model(model_uri, model_name)
print("Name: {}".format(mv.name))
print("Version: {}".format(mv.version))
# Out:
# Successfully registered model 'cut_start_posenet'.
# 2021/05/17 00:59:27 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: cut_start_posenet, version 1
# Name: cut_start_posenet
# Version: 1
# Created version '1' of model 'cut_start_posenet'.
