# %% [markdown]
# # Assignment 2 - version 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm

# %%
AimoScore = pd.read_excel('./AimoScore/AimoScore_WeakLink_big_scores.xls')
df = pd.DataFrame(AimoScore)
print (df)
# Out:
#       AimoScore  No_1_Angle_Deviation  No_2_Angle_Deviation  \
# 0      0.323667              0.538020              0.815878
# 1      0.323699              0.443807              0.306552
# 2      0.848327              0.603539              0.373984
# 3      0.351332              0.484935              0.623625
# 4      0.627181              0.860832              0.657580
# ...         ...                   ...                   ...
# 2089   0.407197              0.279770              0.131038
# 2090   0.965930              0.564802              0.311813
# 2091   0.527640              0.404489              0.214422
# 2092   0.407197              0.606972              0.863897
# 2093   0.965930              0.479943              0.250239
#
#       No_3_Angle_Deviation  No_4_Angle_Deviation  No_5_Angle_Deviation  \
# 0                 0.346724              0.382114              0.302248
# 1                 0.823529              0.188905              0.497370
# ...

# %%
df.describe()
# Out:
#          AimoScore  No_1_Angle_Deviation  No_2_Angle_Deviation  \
# count  2094.000000           2094.000000           2094.000000
# mean      0.572740              0.539248              0.504462
# std       0.236510              0.239284              0.282136
# min       0.010000              0.279770              0.092300
# 25%       0.407907              0.279770              0.250149
# 50%       0.617248              0.500000              0.500000
# 75%       0.759378              0.749761              0.750239
# max       0.993987              1.000000              1.000000
#
#        No_3_Angle_Deviation  No_4_Angle_Deviation  No_5_Angle_Deviation  \
# count           2094.000000           2094.000000           2094.000000
# mean               0.560258              0.518065              0.513932
# std                0.217828              0.264104              0.270076
# min                0.346724              0.188905              0.163080
# ...

# %%
# using hist()
df.hist(figsize = (15, 20))
plt.show()

# %%
# using corr()
corrMatrix = df.corr()
corrMatrix['AimoScore']
print (corrMatrix)
# Out:
#                        AimoScore  No_1_Angle_Deviation  No_2_Angle_Deviation  \
# AimoScore               1.000000             -0.137229             -0.084567
# No_1_Angle_Deviation   -0.137229              1.000000              0.526053
# No_2_Angle_Deviation   -0.084567              0.526053              1.000000
# No_3_Angle_Deviation   -0.148295              0.156826              0.081910
# No_4_Angle_Deviation   -0.134915              0.278644              0.295949
# No_5_Angle_Deviation   -0.286813             -0.094320             -0.157224
# No_6_Angle_Deviation   -0.307983              0.131920              0.168520
# No_7_Angle_Deviation   -0.223230             -0.141623             -0.200167
# No_8_Angle_Deviation   -0.309268              0.341792              0.379083
# No_9_Angle_Deviation   -0.218926              0.019461             -0.025865
# No_10_Angle_Deviation  -0.374444             -0.119849             -0.217131
# ...

# %%
# using heatmap()
fig, ax = plt.subplots(figsize=(25,20)) 

#sns.heatmap(corrMatrix)

ax = sns.heatmap(
    corrMatrix, 
    vmin=-1, vmax=1, center=0,
    square=True,
    annot=True
)

plt.show()

# %%
x = list(df)
x1 = x[1:6]
x2 = x[7:12]
x3 = x[13:18]
x4 = x[19:24]
x5 = x[25:30]
x6 = x[31:36]
x7 = x[37:42]

# %%
#using pairplot()
sns.pairplot(data=df,
                  y_vars=['AimoScore'],
                  x_vars=x1)

plt.show()

# %%
#using pairplot()
sns.pairplot(data=df,
                  y_vars=['AimoScore'],
                  x_vars=x2)

plt.show()

# %%
#using pairplot()
sns.pairplot(data=df,
                  y_vars=['AimoScore'],
                  x_vars=x3)

plt.show()

# %%
#using pairplot()
sns.pairplot(data=df,
                  y_vars=['AimoScore'],
                  x_vars=x4)

plt.show()

# %%
#using pairplot()
sns.pairplot(data=df,
                  y_vars=['AimoScore'],
                  x_vars=x5)

plt.show()

# %%
#using pairplot()
sns.pairplot(data=df,
                  y_vars=['AimoScore'],
                  x_vars=x6)

plt.show()

# %%
#using pairplot()
sns.pairplot(data=df,
                  y_vars=['AimoScore'],
                  x_vars=x7)

plt.show()

# %%
#multiple linear regression OLS()
x = df.loc[:, 'No_1_Angle_Deviation':'EstimatedScore']
y = df['AimoScore']
x = sm.add_constant(x)
mlrm_all = sm.OLS(y, x).fit()
mlrm_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              AimoScore   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     85.04
# Date:                Sat, 06 Feb 2021   Prob (F-statistic):               0.00
# Time:                        01:44:15   Log-Likelihood:                 1002.8
# No. Observations:                2094   AIC:                            -1932.
# Df Residuals:                    2057   BIC:                            -1723.
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...
